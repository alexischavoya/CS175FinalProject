# %% [markdown]
# # ChatBot References
#
# Professor Smyth's website discussing projects
#
# https://www.ics.uci.edu/~smyth/courses/cs175/project_reading.html
#
# Chatbot resources on website
#
# https://pytorch.org/tutorials/beginner/chatbot_tutorial.html
#
# https://web.stanford.edu/~jurafsky/slp3/26.pdf
#
# https://www.microsoft.com/en-us/research/wp-content/uploads/2016/12/CortanaLUDialog-FromSLTproceedings.pdf
#
# Dataset for tutorial
#
# https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html

# %% [markdown]
# # Start of Tutorial

# %% [markdown]
# ### Import necessary libraries

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math

USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# additional imports
import numpy as np

# added for more consistent work, doesnt actually result in same model.
# random.seed(0)
# torch.manual_seed(0)
# np.random.seed(0)

# %% [markdown]
# ### Preprocess Data

# %% [markdown]
# Looking at some files in the data to see how they are structured ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = "/content/drive/MyDrive/CS175_Datasets"
# corpus = os.path.join("data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

# printLines(os.path.join(data, "qa_Video_Games.json"))

# %% [markdown]
# Scan through data files and reformat them to be (sentence, response) pairs separated by a tab eventually. First we create helper functions to help clean up the data a bit and make it more readable ...

# %%
import json
import gzip

def parse(file):
  g = gzip.open(path, 'r')
  for l in g:
    yield eval(l)

def loadConversations(fileName):
  conversations = []
  g = gzip.open(fileName, 'r')
  for conversation in g:
      conversation=eval(conversation)
      conversations.append([conversation["question"], conversation["answer"]])
  return conversations


def extractSentencePairs(conversations):
    return conversations

# %% [markdown]
# Next we will be using the functions above we now parse the data into a form that is useful to us and see what a few lines from the data look like ...

# %%
# Define path to new file
corpus=data
datafile_path = os.path.join(corpus, "amazonqa")
datasets = [f for f in os.listdir(datafile_path) if os.path.isfile(os.path.join(datafile_path,f))]
outfile_path = os.path.join(datafile_path, "csv_files")
datafile = os.path.join(outfile_path, "amazon_qa.csv")
corpus_name = "amazon_qa"
# load data if data file is already been processed as csv file
load_data = True

conversations = []
if not load_data: 
  # Load lines and process conversations
  print("\nProcessing corpus...")
  # lines = loadLines(os.path.join(corpus, "movie_lines.txt"), MOVIE_LINES_FIELDS)
  print("\nLoading conversations...")
  print(datasets)
  for gzip_file in datasets:
      print("processing data file", gzip_file)
      conversations = loadConversations(os.path.join(datafile_path,gzip_file))

  # Write new csv file
  print("\nWriting newly formatted file...")
  with open(datafile, 'w', encoding='utf-8') as outputfile:
      writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
      for pair in extractSentencePairs(conversations):
          writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Sample lines from file:
# b'Are both sides white? Are both sides magnetic?\tYes, both sides are white and magnetic but markers do not wipe off easily...\n'
# b"How sturdy or flimsy is the board. I am also looking at the Expo dry erase magnetic easel. I would like for a child to be on each side of the board.\tThe board is very sturdy. It folds flat. It is great for a child's table top. It is not tall enough to stand and play. I have been very pleased with it.\n"
# b'Does it come with letters, numbers and/or pictures?\tNo,it is just the easel.\n'
# b"Can it hold up wooden magnetic letters?\tsorry, i do not have like-wooden magnet letters to test...but there is no reason to believe that it wouldn't hold wooden magnet unless the wood letters itself is too heavy that it falls off the slanted surface...it holds the plastic mag-letters just fine and the surface can be written/draw on with an erasable marker...and you can use the letters on the fridge surface...the board is a nice addition...kids like different things to do to keep their interests up...\n"
# b'Can this be lain on its side? I need a landscape board. Thank you.\tIt can, yes...but may be a bit awkward to work with, but I guess that depends on what you are using it for. It folds up flat...the bottom pieces have 2 little velcro circles that snap together to keep the bottom pieces together.\n'
# b'should I purchase plain magnet alphabets and numbers?\tMy grandsons love their letters and animals but any magnets work, and fridge works fine for them.\n'
# b'Is it Dry-erase?\tYes\n'
# b'Is it Dry-erase?\tYes\n'
# b'What is appropriate age group for this easel?\tMy four year old granddaughter loves it.\n'
# b'Can 2 children use it simultaneously from opposite sides, as in this 2-step easel http://www.amazon.com/gp/aw/d/B008VUP...\tYes...love this product!\n'

# %% [markdown]
# We want to create a vocabulary of words that we see. We represent these words numerically using the index of their first appearance in the history of all added words to the set of vocuabulary. See `addWord()` for specifics.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we finally getting to the part where we begin to make the (sentence, response) pairs. We begin preprocessing by converting the Unicode string texts to ASCII `unicodeToAscii()`. We also make everything lower case, and remove nonletters except for basic punctuation `normalizeString()`. The last thing that is done in preprocessing is ignore sentences beyond a certain length to aid in training `filterPair()` and `MAX_LENGTH`.

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
# changed for colab
save_dir = os.path.join(data, "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 51486 sentence pairs
# Trimmed to 7983 sentence pairs
# Counting words...
# Counted words: 5374
#
# pairs:
# ['is it dry erase ?', 'yes']
# ['is it dry erase ?', 'yes']
# ['what is appropriate age group for this easel ?', 'my four year old granddaughter loves it .']
# ['how many pages in book ?', 'up to pages']
# ['what age child is this directed to ?', 'yrs old']
# ['for yr . olds ?', 'yes with adult help .']
# ['how many cards are in this game ?', 'cards with questions per card . questions']
# ['can you just purchase the birthday outfit alone ?', 'it s the outfit and book .']
# ['would they fit an ipad mini ?', 'yes it would fit any apple product .']
# ['can these fit on lg g phones ?', 'no']

# %% [markdown]
# Another way to speed up training is by removing words that are rarely used. We "trim" these words using `Voc.trim()` and as a result must also remove (sentence, response) pairs that include these words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 1895 / 5371 = 0.3528
# Trimmed from 7983 pairs to 5113, 0.6405 of total

# %% [markdown]
# ### Using our Data on our Models

# %% [markdown]
# The data still needs to be processed more. The model that we use will take numerical values and not actual strings to do computation. We convert our sentences to tensors (vectors) that our model will take as inputs. To do this, we just take every sentence and change it to be a vector of index that corresponds to that word. This is how we will use our data to train the model.
#
# If we would like to train our model we usually do it with minbatches since it makes things faster. We make a matrix of dimensions (BatchLength, MaxLengthOfSentenceInBatch) represented numerically as mentioned in the previous paragraph. With this we make sure that each row (sentence) of our matrix terminates with `EOS_Token` and is followed by 0 entries until the end of the row.
#
# This implementation almost works, the problem with this is that each row is a sentence and every column is a step in time. However, it is better to think of every row as a step in time and the column to be possible words to choose for that step in time. For this reason, we construct the Matrix as mentioned in the previous paragraph except it is now transposed.
#
# We define some function that help us achieve this ...

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[   9,   43,   23,    3,   67],
#         [  38,    4,  306,    4,    4],
#         [  47,  454,   43,  215,  169],
#         [ 433,  475,    4,   73,   68],
#         [  73,  623,  254,  185,  670],
#         [  47, 1102,    2,    2,    2],
#         [1038,    7,    0,    0,    0],
#         [ 339,    2,    0,    0,    0],
#         [   7,    0,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([10,  8,  6,  6,  6])
# target_variable: tensor([[1039,    8,  223,  953,  501],
#         [ 843,    2,  223,    2,   67],
#         [ 143,    0,  223,    0,   90],
#         [ 322,    0,   86,    0,  169],
#         [ 105,    0,  895,    0,   68],
#         [   2,    0,    2,    0,  670],
#         [   0,    0,    0,    0,   22],
#         [   0,    0,    0,    0,    2]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False,  True, False,  True],
#         [ True, False,  True, False,  True],
#         [ True, False,  True, False,  True],
#         [ True, False,  True, False,  True],
#         [False, False, False, False,  True],
#         [False, False, False, False,  True]])
# max_target_len: 8

# %% [markdown]
# Seeing the output from preping the data above, it appears that `input_variable` is the matrix described in the previous secsion. `lenghts` is just a tensor (vector) of how long the sentences in the input were. This will eventually be used for the **decoder** later in the program. `target_variable` seems to be the response that our model is supposed to learn. `mask` looks like it is a mask for responses where true is that there is a word and false is that there is no word there. Not sure why this variable is necessary but maybe it will become clearer at some point in the tutorial.

# %% [markdown]
# ### Defining our Model

# %% [markdown]
# Our base model is a Sequence-to-Sequence model using two RNN's. The first RNN is what is called the **encoder** and it takes a variable length input and converts it into a *fixed length* "context" vector that is intended to hold onto some semantic meaning of the input. The **decoder** takes the context vector provided by the decoder along with an input word to guess the next word in a sequence. I suppose our (sentence, response) pairs are learned as one long continuous sequence where the sentence is the start of hte sequence and the response is the remainder of the sequence, though this might be entirely incorrect.

# %% [markdown]
# Some discussion on the Encoder. The encoder uses a bidirectional GRU (Gated Recurrent Unit), meaning that there is basically two RNN's that make up the encoder, one that goes through the sequence of data in the forward direction while another RNN goes through the sequence in the backward direction. At each time step, both RNN's produce an output and a hidden state vector. At each time step, the output of both RNNs are summed and the output is recorded (somewhere) while the hidden state vectors are pushed along and used in the next step of the RNN. The outputs are summed makes it so that at each time step, the RNN is considering present and future context.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Some discussion on the Decoder. The decoder uses the context vector that is produced by the encoder. Usually, this is all that will be used by a decoder to produce output but this can result in a loss of information, expecially when the input sentences are very long. To counter this, the decoder also uses its current hidden state as a way of determining what it should be "paying attention" to. These are refered to as attention weights and are multiplied by the outputs from the encoder (the output that is apperantly recorded somewhere, this is where they are used) from the current time step to rescale the values, making less important parts of the encoder output smaller and more important parts of the encoder output larger. This can be further improved by using all of the encoder outputs instead of just the one of the current time step to have a more comprehensive set of attention weights. This is the method implemented below, followed by the implementation of the decoder using this attention method.

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# ### Defining the Training Procedure

# %% [markdown]
# Recall earlier in the `mask` produced along side the `target_variable` was produced for an unknown purpose, it turns out its purpose is for determining the loss of the model. This implementation below is the negative-log-likelihood loss and the variable `mask` along with `target_variable`.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# For training the model, two tricks are used to help convergence. The first trick is refered to as "teacher forcing" which just overrides the prediction of the decoder and uses the actual target value instead, this happens with some small probability p. Doing it too much will make the decoder unable to make predictions on its own and not having this feature will make it so that convergence is just slower. The second trick they do is gradient clipping, meaning that at areas in the feature space where there is a steep gradient and therefore a chance to improve the model very fast, the magnitude of the gradient is limited some value. This is to not drastically overshoot local minima on "cliffs". The training function is implemented below. This trains only one iteration.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# This version of the training function trains on multiple iterations. It is built on the previous training function. This function also saves the current variables in a tarball file. This is to continue training at a later period or just use the current accumulated training to make predictions.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, 
               encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, 
               clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(
                iteration, iteration / n_iteration * 100, print_loss_avg
            ))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(
                encoder_n_layers, decoder_n_layers, hidden_size
            ))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# ### Defining Evaluation

# %% [markdown]
# This is the training method used by our bot when we are not using the "teacher forcing" method. This just basically chooses the output of hte decoder to be the output with the highest softmax score, ie the best response given its prior training. I think this is defining a decoder method for whenever we are actually using our model instead of when it is training.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# The `evaluateInput` function is meant to take input from the user, prepare it so that it may be fed to our model, and pring out the response from our bot. `evaluate` handles most of hte actual calculation while `evaluateInput` handles most of the user interaction phase.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    #lengths = lengths.to(device) # removed bc of gpu cpu tensor difference ###################################
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# ### Running the Model

# %% [markdown]
# This defines and builds our model based on the following parameters. Notice that parts of the code are commented out as these are other possibilities ofr initialization. attn_model can be given one of three different models. We can also choose to load a model that we previously trained.

# %%
# Configure models
model_name = 'amazon_qa_stochastic'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
# loadFilename = os.path.join("/content/drive/MyDrive/CS175_Datasets",
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Now we train our model using `trainIters`. We first set some training parameters and initialize optimizers and prepare our model for training. Training is likely to take a very long time, thankfully there is the option to load from a previous model and this piece of code here doesn't need to be run every time.

# %%
# Safty precaution so that we dont accidentally begin training a model we didnt want to train
TRAIN_THE_MODEL = True

# %%
if TRAIN_THE_MODEL:
    
    # Configure training/optimization
    clip = 50.0
    teacher_forcing_ratio = 1.0
    learning_rate = 0.0001
    decoder_learning_ratio = 5.0
    n_iteration = 4000
    print_every = 1
    save_every = 500

    # Ensure dropout layers are in train mode
    encoder.train()
    decoder.train()

    # Initialize optimizers
    print('Building optimizers ...')
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
    if loadFilename:
        encoder_optimizer.load_state_dict(encoder_optimizer_sd)
        decoder_optimizer.load_state_dict(decoder_optimizer_sd)

    # If you have cuda, configure cuda to call
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    # Run training iterations
    print("Starting Training!")
    trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
               embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
               print_every, save_every, clip, corpus_name, loadFilename)
    
    TRAIN_THE_MODEL = False

else:
    
    print(f"Make the variable 'TRAIN_THE_MODEL' in the code block above True and run the code block")
    print(f"Value of 'TRAIN_THE_MODEL' currently: {TRAIN_THE_MODEL}")
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 7.5633
# Iteration: 2; Percent complete: 0.1%; Average loss: 7.4533
# Iteration: 3; Percent complete: 0.1%; Average loss: 7.3226
# Iteration: 4; Percent complete: 0.1%; Average loss: 7.0481
# Iteration: 5; Percent complete: 0.1%; Average loss: 6.6750
# Iteration: 6; Percent complete: 0.1%; Average loss: 6.1783
# Iteration: 7; Percent complete: 0.2%; Average loss: 6.1128
# Iteration: 8; Percent complete: 0.2%; Average loss: 6.4485
# Iteration: 9; Percent complete: 0.2%; Average loss: 5.9400
# Iteration: 10; Percent complete: 0.2%; Average loss: 5.9262
# Iteration: 11; Percent complete: 0.3%; Average loss: 5.5554
# Iteration: 12; Percent complete: 0.3%; Average loss: 5.3456
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.1542
# Iteration: 14; Percent complete: 0.4%; Average loss: 5.2627
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.1718
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.0634
# Iteration: 17; Percent complete: 0.4%; Average loss: 4.6001
# Iteration: 18; Percent complete: 0.4%; Average loss: 4.7808
# Iteration: 19; Percent complete: 0.5%; Average loss: 4.8840
# Iteration: 20; Percent complete: 0.5%; Average loss: 4.8991
# Iteration: 21; Percent complete: 0.5%; Average loss: 4.5790
# Iteration: 22; Percent complete: 0.5%; Average loss: 4.6375
# Iteration: 23; Percent complete: 0.6%; Average loss: 5.0794
# Iteration: 24; Percent complete: 0.6%; Average loss: 4.5316
# Iteration: 25; Percent complete: 0.6%; Average loss: 4.5427
# Iteration: 26; Percent complete: 0.7%; Average loss: 4.4517
# Iteration: 27; Percent complete: 0.7%; Average loss: 4.4619
# Iteration: 28; Percent complete: 0.7%; Average loss: 4.6458
# Iteration: 29; Percent complete: 0.7%; Average loss: 4.7301
# Iteration: 30; Percent complete: 0.8%; Average loss: 4.6530
# Iteration: 31; Percent complete: 0.8%; Average loss: 4.3729
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.5274
# Iteration: 33; Percent complete: 0.8%; Average loss: 4.7292
# Iteration: 34; Percent complete: 0.9%; Average loss: 4.8549
# Iteration: 35; Percent complete: 0.9%; Average loss: 4.3859
# Iteration: 36; Percent complete: 0.9%; Average loss: 4.3385
# Iteration: 37; Percent complete: 0.9%; Average loss: 4.1826
# Iteration: 38; Percent complete: 0.9%; Average loss: 4.3105
# Iteration: 39; Percent complete: 1.0%; Average loss: 4.3316
# Iteration: 40; Percent complete: 1.0%; Average loss: 4.3555
# Iteration: 41; Percent complete: 1.0%; Average loss: 4.4193
# Iteration: 42; Percent complete: 1.1%; Average loss: 4.3875
# Iteration: 43; Percent complete: 1.1%; Average loss: 4.1942
# Iteration: 44; Percent complete: 1.1%; Average loss: 4.4657
# Iteration: 45; Percent complete: 1.1%; Average loss: 4.4698
# Iteration: 46; Percent complete: 1.1%; Average loss: 4.1566
# Iteration: 47; Percent complete: 1.2%; Average loss: 4.2852
# Iteration: 48; Percent complete: 1.2%; Average loss: 4.3065
# Iteration: 49; Percent complete: 1.2%; Average loss: 4.2629
# Iteration: 50; Percent complete: 1.2%; Average loss: 4.5431
# Iteration: 51; Percent complete: 1.3%; Average loss: 4.4677
# Iteration: 52; Percent complete: 1.3%; Average loss: 4.4349
# Iteration: 53; Percent complete: 1.3%; Average loss: 3.8890
# Iteration: 54; Percent complete: 1.4%; Average loss: 3.8763
# Iteration: 55; Percent complete: 1.4%; Average loss: 4.1714
# Iteration: 56; Percent complete: 1.4%; Average loss: 3.7927
# Iteration: 57; Percent complete: 1.4%; Average loss: 4.3526
# Iteration: 58; Percent complete: 1.5%; Average loss: 3.8827
# Iteration: 59; Percent complete: 1.5%; Average loss: 3.9372
# Iteration: 60; Percent complete: 1.5%; Average loss: 4.4811
# Iteration: 61; Percent complete: 1.5%; Average loss: 4.1048
# Iteration: 62; Percent complete: 1.6%; Average loss: 4.0712
# Iteration: 63; Percent complete: 1.6%; Average loss: 4.3857
# Iteration: 64; Percent complete: 1.6%; Average loss: 4.0343
# Iteration: 65; Percent complete: 1.6%; Average loss: 4.2275
# Iteration: 66; Percent complete: 1.7%; Average loss: 4.1611
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.1419
# Iteration: 68; Percent complete: 1.7%; Average loss: 4.0254
# Iteration: 69; Percent complete: 1.7%; Average loss: 3.9879
# Iteration: 70; Percent complete: 1.8%; Average loss: 4.0506
# Iteration: 71; Percent complete: 1.8%; Average loss: 4.0049
# Iteration: 72; Percent complete: 1.8%; Average loss: 4.0544
# Iteration: 73; Percent complete: 1.8%; Average loss: 4.1052
# Iteration: 74; Percent complete: 1.8%; Average loss: 4.4430
# Iteration: 75; Percent complete: 1.9%; Average loss: 4.1208
# Iteration: 76; Percent complete: 1.9%; Average loss: 3.9913
# Iteration: 77; Percent complete: 1.9%; Average loss: 4.0450
# Iteration: 78; Percent complete: 1.9%; Average loss: 4.2724
# Iteration: 79; Percent complete: 2.0%; Average loss: 4.2849
# Iteration: 80; Percent complete: 2.0%; Average loss: 4.3368
# Iteration: 81; Percent complete: 2.0%; Average loss: 3.9497
# Iteration: 82; Percent complete: 2.1%; Average loss: 4.0444
# Iteration: 83; Percent complete: 2.1%; Average loss: 4.4148
# Iteration: 84; Percent complete: 2.1%; Average loss: 4.0591
# Iteration: 85; Percent complete: 2.1%; Average loss: 3.8036
# Iteration: 86; Percent complete: 2.1%; Average loss: 4.2853
# Iteration: 87; Percent complete: 2.2%; Average loss: 4.0097
# Iteration: 88; Percent complete: 2.2%; Average loss: 3.9792
# Iteration: 89; Percent complete: 2.2%; Average loss: 4.2188
# Iteration: 90; Percent complete: 2.2%; Average loss: 3.9079
# Iteration: 91; Percent complete: 2.3%; Average loss: 3.8108
# Iteration: 92; Percent complete: 2.3%; Average loss: 3.9902
# Iteration: 93; Percent complete: 2.3%; Average loss: 4.1655
# Iteration: 94; Percent complete: 2.4%; Average loss: 3.8126
# Iteration: 95; Percent complete: 2.4%; Average loss: 4.2649
# Iteration: 96; Percent complete: 2.4%; Average loss: 3.7159
# Iteration: 97; Percent complete: 2.4%; Average loss: 4.1668
# Iteration: 98; Percent complete: 2.5%; Average loss: 3.9190
# Iteration: 99; Percent complete: 2.5%; Average loss: 3.7226
# Iteration: 100; Percent complete: 2.5%; Average loss: 3.8750
# Iteration: 101; Percent complete: 2.5%; Average loss: 3.8264
# Iteration: 102; Percent complete: 2.5%; Average loss: 3.6966
# Iteration: 103; Percent complete: 2.6%; Average loss: 3.8387
# Iteration: 104; Percent complete: 2.6%; Average loss: 3.6329
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.1120
# Iteration: 106; Percent complete: 2.6%; Average loss: 3.6370
# Iteration: 107; Percent complete: 2.7%; Average loss: 4.0225
# Iteration: 108; Percent complete: 2.7%; Average loss: 3.7094
# Iteration: 109; Percent complete: 2.7%; Average loss: 3.9133
# Iteration: 110; Percent complete: 2.8%; Average loss: 3.9286
# Iteration: 111; Percent complete: 2.8%; Average loss: 3.7067
# Iteration: 112; Percent complete: 2.8%; Average loss: 3.5175
# Iteration: 113; Percent complete: 2.8%; Average loss: 3.9407
# Iteration: 114; Percent complete: 2.9%; Average loss: 3.6441
# Iteration: 115; Percent complete: 2.9%; Average loss: 3.7011
# Iteration: 116; Percent complete: 2.9%; Average loss: 3.9204
# Iteration: 117; Percent complete: 2.9%; Average loss: 3.7286
# Iteration: 118; Percent complete: 2.9%; Average loss: 3.7272
# Iteration: 119; Percent complete: 3.0%; Average loss: 4.0385
# Iteration: 120; Percent complete: 3.0%; Average loss: 3.6668
# Iteration: 121; Percent complete: 3.0%; Average loss: 3.6203
# Iteration: 122; Percent complete: 3.0%; Average loss: 3.7379
# Iteration: 123; Percent complete: 3.1%; Average loss: 3.6682
# Iteration: 124; Percent complete: 3.1%; Average loss: 4.0606
# Iteration: 125; Percent complete: 3.1%; Average loss: 3.5716
# Iteration: 126; Percent complete: 3.1%; Average loss: 3.6281
# Iteration: 127; Percent complete: 3.2%; Average loss: 3.7198
# Iteration: 128; Percent complete: 3.2%; Average loss: 3.6981
# Iteration: 129; Percent complete: 3.2%; Average loss: 3.7912
# Iteration: 130; Percent complete: 3.2%; Average loss: 3.6951
# Iteration: 131; Percent complete: 3.3%; Average loss: 3.7953
# Iteration: 132; Percent complete: 3.3%; Average loss: 3.3265
# Iteration: 133; Percent complete: 3.3%; Average loss: 3.8028
# Iteration: 134; Percent complete: 3.4%; Average loss: 3.6640
# Iteration: 135; Percent complete: 3.4%; Average loss: 3.9710
# Iteration: 136; Percent complete: 3.4%; Average loss: 4.0917
# Iteration: 137; Percent complete: 3.4%; Average loss: 3.9627
# Iteration: 138; Percent complete: 3.5%; Average loss: 3.7745
# Iteration: 139; Percent complete: 3.5%; Average loss: 3.5733
# Iteration: 140; Percent complete: 3.5%; Average loss: 3.7529
# Iteration: 141; Percent complete: 3.5%; Average loss: 3.9052
# Iteration: 142; Percent complete: 3.5%; Average loss: 3.5914
# Iteration: 143; Percent complete: 3.6%; Average loss: 3.8267
# Iteration: 144; Percent complete: 3.6%; Average loss: 3.6459
# Iteration: 145; Percent complete: 3.6%; Average loss: 3.7259
# Iteration: 146; Percent complete: 3.6%; Average loss: 3.8082
# Iteration: 147; Percent complete: 3.7%; Average loss: 3.4724
# Iteration: 148; Percent complete: 3.7%; Average loss: 3.5156
# Iteration: 149; Percent complete: 3.7%; Average loss: 3.4323
# Iteration: 150; Percent complete: 3.8%; Average loss: 3.4567
# Iteration: 151; Percent complete: 3.8%; Average loss: 3.4566
# Iteration: 152; Percent complete: 3.8%; Average loss: 3.8321
# Iteration: 153; Percent complete: 3.8%; Average loss: 3.2976
# Iteration: 154; Percent complete: 3.9%; Average loss: 3.8207
# Iteration: 155; Percent complete: 3.9%; Average loss: 3.5243
# Iteration: 156; Percent complete: 3.9%; Average loss: 3.5392
# Iteration: 157; Percent complete: 3.9%; Average loss: 3.7003
# Iteration: 158; Percent complete: 4.0%; Average loss: 3.4712
# Iteration: 159; Percent complete: 4.0%; Average loss: 3.1902
# Iteration: 160; Percent complete: 4.0%; Average loss: 3.5104
# Iteration: 161; Percent complete: 4.0%; Average loss: 3.3886
# Iteration: 162; Percent complete: 4.0%; Average loss: 4.0310
# Iteration: 163; Percent complete: 4.1%; Average loss: 3.5489
# Iteration: 164; Percent complete: 4.1%; Average loss: 3.3701
# Iteration: 165; Percent complete: 4.1%; Average loss: 3.6693
# Iteration: 166; Percent complete: 4.2%; Average loss: 3.4896
# Iteration: 167; Percent complete: 4.2%; Average loss: 3.8467
# Iteration: 168; Percent complete: 4.2%; Average loss: 3.3089
# Iteration: 169; Percent complete: 4.2%; Average loss: 3.6602
# Iteration: 170; Percent complete: 4.2%; Average loss: 3.5352
# Iteration: 171; Percent complete: 4.3%; Average loss: 3.2542
# Iteration: 172; Percent complete: 4.3%; Average loss: 3.0997
# Iteration: 173; Percent complete: 4.3%; Average loss: 3.8301
# Iteration: 174; Percent complete: 4.3%; Average loss: 3.4422
# Iteration: 175; Percent complete: 4.4%; Average loss: 3.5106
# Iteration: 176; Percent complete: 4.4%; Average loss: 3.1883
# Iteration: 177; Percent complete: 4.4%; Average loss: 3.3900
# Iteration: 178; Percent complete: 4.5%; Average loss: 3.5702
# Iteration: 179; Percent complete: 4.5%; Average loss: 3.2202
# Iteration: 180; Percent complete: 4.5%; Average loss: 3.6044
# Iteration: 181; Percent complete: 4.5%; Average loss: 3.5214
# Iteration: 182; Percent complete: 4.5%; Average loss: 3.4339
# Iteration: 183; Percent complete: 4.6%; Average loss: 3.6493
# Iteration: 184; Percent complete: 4.6%; Average loss: 3.2350
# Iteration: 185; Percent complete: 4.6%; Average loss: 3.6122
# Iteration: 186; Percent complete: 4.7%; Average loss: 3.3541
# Iteration: 187; Percent complete: 4.7%; Average loss: 2.8578
# Iteration: 188; Percent complete: 4.7%; Average loss: 3.8206
# Iteration: 189; Percent complete: 4.7%; Average loss: 3.7060
# Iteration: 190; Percent complete: 4.8%; Average loss: 3.3342
# Iteration: 191; Percent complete: 4.8%; Average loss: 3.5225
# Iteration: 192; Percent complete: 4.8%; Average loss: 3.5054
# Iteration: 193; Percent complete: 4.8%; Average loss: 3.3385
# Iteration: 194; Percent complete: 4.9%; Average loss: 3.3760
# Iteration: 195; Percent complete: 4.9%; Average loss: 3.4342
# Iteration: 196; Percent complete: 4.9%; Average loss: 3.5674
# Iteration: 197; Percent complete: 4.9%; Average loss: 3.2967
# Iteration: 198; Percent complete: 5.0%; Average loss: 3.6137
# Iteration: 199; Percent complete: 5.0%; Average loss: 3.1046
# Iteration: 200; Percent complete: 5.0%; Average loss: 3.4680
# Iteration: 201; Percent complete: 5.0%; Average loss: 3.4627
# Iteration: 202; Percent complete: 5.1%; Average loss: 3.6158
# Iteration: 203; Percent complete: 5.1%; Average loss: 3.3210
# Iteration: 204; Percent complete: 5.1%; Average loss: 3.4708
# Iteration: 205; Percent complete: 5.1%; Average loss: 3.6287
# Iteration: 206; Percent complete: 5.1%; Average loss: 3.4762
# Iteration: 207; Percent complete: 5.2%; Average loss: 3.0443
# Iteration: 208; Percent complete: 5.2%; Average loss: 3.1417
# Iteration: 209; Percent complete: 5.2%; Average loss: 3.2124
# Iteration: 210; Percent complete: 5.2%; Average loss: 3.3840
# Iteration: 211; Percent complete: 5.3%; Average loss: 3.5457
# Iteration: 212; Percent complete: 5.3%; Average loss: 3.5617
# Iteration: 213; Percent complete: 5.3%; Average loss: 3.0991
# Iteration: 214; Percent complete: 5.3%; Average loss: 3.1940
# Iteration: 215; Percent complete: 5.4%; Average loss: 3.3113
# Iteration: 216; Percent complete: 5.4%; Average loss: 3.4099
# Iteration: 217; Percent complete: 5.4%; Average loss: 3.2978
# Iteration: 218; Percent complete: 5.5%; Average loss: 3.4144
# Iteration: 219; Percent complete: 5.5%; Average loss: 3.2748
# Iteration: 220; Percent complete: 5.5%; Average loss: 3.2666
# Iteration: 221; Percent complete: 5.5%; Average loss: 3.8201
# Iteration: 222; Percent complete: 5.5%; Average loss: 3.3937
# Iteration: 223; Percent complete: 5.6%; Average loss: 3.2650
# Iteration: 224; Percent complete: 5.6%; Average loss: 3.4754
# Iteration: 225; Percent complete: 5.6%; Average loss: 3.2966
# Iteration: 226; Percent complete: 5.7%; Average loss: 3.2488
# Iteration: 227; Percent complete: 5.7%; Average loss: 3.2280
# Iteration: 228; Percent complete: 5.7%; Average loss: 3.5725
# Iteration: 229; Percent complete: 5.7%; Average loss: 3.3133
# Iteration: 230; Percent complete: 5.8%; Average loss: 3.3339
# Iteration: 231; Percent complete: 5.8%; Average loss: 3.3065
# Iteration: 232; Percent complete: 5.8%; Average loss: 3.2470
# Iteration: 233; Percent complete: 5.8%; Average loss: 3.2648
# Iteration: 234; Percent complete: 5.9%; Average loss: 3.4854
# Iteration: 235; Percent complete: 5.9%; Average loss: 3.2305
# Iteration: 236; Percent complete: 5.9%; Average loss: 3.4624
# Iteration: 237; Percent complete: 5.9%; Average loss: 3.4948
# Iteration: 238; Percent complete: 5.9%; Average loss: 3.5902
# Iteration: 239; Percent complete: 6.0%; Average loss: 3.1625
# Iteration: 240; Percent complete: 6.0%; Average loss: 3.4448
# Iteration: 241; Percent complete: 6.0%; Average loss: 3.2884
# Iteration: 242; Percent complete: 6.0%; Average loss: 3.1314
# Iteration: 243; Percent complete: 6.1%; Average loss: 3.4169
# Iteration: 244; Percent complete: 6.1%; Average loss: 3.2256
# Iteration: 245; Percent complete: 6.1%; Average loss: 3.1965
# Iteration: 246; Percent complete: 6.2%; Average loss: 3.3677
# Iteration: 247; Percent complete: 6.2%; Average loss: 3.2726
# Iteration: 248; Percent complete: 6.2%; Average loss: 3.3244
# Iteration: 249; Percent complete: 6.2%; Average loss: 3.1550
# Iteration: 250; Percent complete: 6.2%; Average loss: 3.2156
# Iteration: 251; Percent complete: 6.3%; Average loss: 3.2774
# Iteration: 252; Percent complete: 6.3%; Average loss: 3.0790
# Iteration: 253; Percent complete: 6.3%; Average loss: 3.1057
# Iteration: 254; Percent complete: 6.3%; Average loss: 3.3234
# Iteration: 255; Percent complete: 6.4%; Average loss: 3.2413
# Iteration: 256; Percent complete: 6.4%; Average loss: 3.1539
# Iteration: 257; Percent complete: 6.4%; Average loss: 3.2518
# Iteration: 258; Percent complete: 6.5%; Average loss: 3.0510
# Iteration: 259; Percent complete: 6.5%; Average loss: 3.3849
# Iteration: 260; Percent complete: 6.5%; Average loss: 3.2824
# Iteration: 261; Percent complete: 6.5%; Average loss: 3.2216
# Iteration: 262; Percent complete: 6.6%; Average loss: 2.8731
# Iteration: 263; Percent complete: 6.6%; Average loss: 3.2306
# Iteration: 264; Percent complete: 6.6%; Average loss: 3.1445
# Iteration: 265; Percent complete: 6.6%; Average loss: 3.0938
# Iteration: 266; Percent complete: 6.7%; Average loss: 3.2737
# Iteration: 267; Percent complete: 6.7%; Average loss: 3.3092
# Iteration: 268; Percent complete: 6.7%; Average loss: 3.2488
# Iteration: 269; Percent complete: 6.7%; Average loss: 3.1240
# Iteration: 270; Percent complete: 6.8%; Average loss: 2.9146
# Iteration: 271; Percent complete: 6.8%; Average loss: 3.1268
# Iteration: 272; Percent complete: 6.8%; Average loss: 3.2506
# Iteration: 273; Percent complete: 6.8%; Average loss: 3.1285
# Iteration: 274; Percent complete: 6.9%; Average loss: 3.3109
# Iteration: 275; Percent complete: 6.9%; Average loss: 3.4407
# Iteration: 276; Percent complete: 6.9%; Average loss: 2.5628
# Iteration: 277; Percent complete: 6.9%; Average loss: 3.3320
# Iteration: 278; Percent complete: 7.0%; Average loss: 3.1620
# Iteration: 279; Percent complete: 7.0%; Average loss: 2.7702
# Iteration: 280; Percent complete: 7.0%; Average loss: 2.9797
# Iteration: 281; Percent complete: 7.0%; Average loss: 2.8941
# Iteration: 282; Percent complete: 7.0%; Average loss: 3.1872
# Iteration: 283; Percent complete: 7.1%; Average loss: 3.1524
# Iteration: 284; Percent complete: 7.1%; Average loss: 2.7939
# Iteration: 285; Percent complete: 7.1%; Average loss: 3.0202
# Iteration: 286; Percent complete: 7.1%; Average loss: 3.0989
# Iteration: 287; Percent complete: 7.2%; Average loss: 2.9854
# Iteration: 288; Percent complete: 7.2%; Average loss: 2.7602
# Iteration: 289; Percent complete: 7.2%; Average loss: 3.1082
# Iteration: 290; Percent complete: 7.2%; Average loss: 2.7525
# Iteration: 291; Percent complete: 7.3%; Average loss: 3.0797
# Iteration: 292; Percent complete: 7.3%; Average loss: 2.9044
# Iteration: 293; Percent complete: 7.3%; Average loss: 2.9447
# Iteration: 294; Percent complete: 7.3%; Average loss: 2.8283
# Iteration: 295; Percent complete: 7.4%; Average loss: 2.8343
# Iteration: 296; Percent complete: 7.4%; Average loss: 3.2992
# Iteration: 297; Percent complete: 7.4%; Average loss: 3.2018
# Iteration: 298; Percent complete: 7.4%; Average loss: 2.8999
# Iteration: 299; Percent complete: 7.5%; Average loss: 3.0080
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.1017
# Iteration: 301; Percent complete: 7.5%; Average loss: 3.0904
# Iteration: 302; Percent complete: 7.5%; Average loss: 3.0524
# Iteration: 303; Percent complete: 7.6%; Average loss: 2.9930
# Iteration: 304; Percent complete: 7.6%; Average loss: 3.0647
# Iteration: 305; Percent complete: 7.6%; Average loss: 2.6818
# Iteration: 306; Percent complete: 7.6%; Average loss: 2.9952
# Iteration: 307; Percent complete: 7.7%; Average loss: 3.0618
# Iteration: 308; Percent complete: 7.7%; Average loss: 3.0209
# Iteration: 309; Percent complete: 7.7%; Average loss: 2.8411
# Iteration: 310; Percent complete: 7.8%; Average loss: 3.0656
# Iteration: 311; Percent complete: 7.8%; Average loss: 3.0089
# Iteration: 312; Percent complete: 7.8%; Average loss: 2.9133
# Iteration: 313; Percent complete: 7.8%; Average loss: 3.1102
# Iteration: 314; Percent complete: 7.8%; Average loss: 3.0857
# Iteration: 315; Percent complete: 7.9%; Average loss: 3.0623
# Iteration: 316; Percent complete: 7.9%; Average loss: 2.8873
# Iteration: 317; Percent complete: 7.9%; Average loss: 3.1872
# Iteration: 318; Percent complete: 8.0%; Average loss: 3.1040
# Iteration: 319; Percent complete: 8.0%; Average loss: 3.0622
# Iteration: 320; Percent complete: 8.0%; Average loss: 2.9512
# Iteration: 321; Percent complete: 8.0%; Average loss: 2.6164
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.0292
# Iteration: 323; Percent complete: 8.1%; Average loss: 2.8616
# Iteration: 324; Percent complete: 8.1%; Average loss: 2.7448
# Iteration: 325; Percent complete: 8.1%; Average loss: 2.7728
# Iteration: 326; Percent complete: 8.2%; Average loss: 2.9468
# Iteration: 327; Percent complete: 8.2%; Average loss: 2.8165
# Iteration: 328; Percent complete: 8.2%; Average loss: 2.8981
# Iteration: 329; Percent complete: 8.2%; Average loss: 3.0584
# Iteration: 330; Percent complete: 8.2%; Average loss: 2.8139
# Iteration: 331; Percent complete: 8.3%; Average loss: 2.6473
# Iteration: 332; Percent complete: 8.3%; Average loss: 3.0270
# Iteration: 333; Percent complete: 8.3%; Average loss: 2.9771
# Iteration: 334; Percent complete: 8.3%; Average loss: 3.0336
# Iteration: 335; Percent complete: 8.4%; Average loss: 2.9434
# Iteration: 336; Percent complete: 8.4%; Average loss: 2.7729
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.2023
# Iteration: 338; Percent complete: 8.5%; Average loss: 2.9118
# Iteration: 339; Percent complete: 8.5%; Average loss: 2.8162
# Iteration: 340; Percent complete: 8.5%; Average loss: 3.1244
# Iteration: 341; Percent complete: 8.5%; Average loss: 2.7866
# Iteration: 342; Percent complete: 8.6%; Average loss: 2.7501
# Iteration: 343; Percent complete: 8.6%; Average loss: 2.8492
# Iteration: 344; Percent complete: 8.6%; Average loss: 2.8916
# Iteration: 345; Percent complete: 8.6%; Average loss: 2.9981
# Iteration: 346; Percent complete: 8.6%; Average loss: 2.8670
# Iteration: 347; Percent complete: 8.7%; Average loss: 2.7450
# Iteration: 348; Percent complete: 8.7%; Average loss: 2.6684
# Iteration: 349; Percent complete: 8.7%; Average loss: 3.0303
# Iteration: 350; Percent complete: 8.8%; Average loss: 2.8807
# Iteration: 351; Percent complete: 8.8%; Average loss: 3.2247
# Iteration: 352; Percent complete: 8.8%; Average loss: 3.0309
# Iteration: 353; Percent complete: 8.8%; Average loss: 2.7836
# Iteration: 354; Percent complete: 8.8%; Average loss: 2.8386
# Iteration: 355; Percent complete: 8.9%; Average loss: 2.5156
# Iteration: 356; Percent complete: 8.9%; Average loss: 2.8513
# Iteration: 357; Percent complete: 8.9%; Average loss: 2.6915
# Iteration: 358; Percent complete: 8.9%; Average loss: 2.7076
# Iteration: 359; Percent complete: 9.0%; Average loss: 2.4536
# Iteration: 360; Percent complete: 9.0%; Average loss: 2.7062
# Iteration: 361; Percent complete: 9.0%; Average loss: 2.9403
# Iteration: 362; Percent complete: 9.0%; Average loss: 2.7144
# Iteration: 363; Percent complete: 9.1%; Average loss: 2.7462
# Iteration: 364; Percent complete: 9.1%; Average loss: 2.7678
# Iteration: 365; Percent complete: 9.1%; Average loss: 2.7205
# Iteration: 366; Percent complete: 9.2%; Average loss: 2.9172
# Iteration: 367; Percent complete: 9.2%; Average loss: 2.7972
# Iteration: 368; Percent complete: 9.2%; Average loss: 2.7462
# Iteration: 369; Percent complete: 9.2%; Average loss: 2.7740
# Iteration: 370; Percent complete: 9.2%; Average loss: 3.0202
# Iteration: 371; Percent complete: 9.3%; Average loss: 2.8337
# Iteration: 372; Percent complete: 9.3%; Average loss: 2.6499
# Iteration: 373; Percent complete: 9.3%; Average loss: 2.6077
# Iteration: 374; Percent complete: 9.3%; Average loss: 2.5274
# Iteration: 375; Percent complete: 9.4%; Average loss: 2.5168
# Iteration: 376; Percent complete: 9.4%; Average loss: 2.5716
# Iteration: 377; Percent complete: 9.4%; Average loss: 3.0168
# Iteration: 378; Percent complete: 9.4%; Average loss: 2.7940
# Iteration: 379; Percent complete: 9.5%; Average loss: 2.8658
# Iteration: 380; Percent complete: 9.5%; Average loss: 2.8618
# Iteration: 381; Percent complete: 9.5%; Average loss: 2.8863
# Iteration: 382; Percent complete: 9.6%; Average loss: 2.3105
# Iteration: 383; Percent complete: 9.6%; Average loss: 2.6797
# Iteration: 384; Percent complete: 9.6%; Average loss: 2.8998
# Iteration: 385; Percent complete: 9.6%; Average loss: 2.8589
# Iteration: 386; Percent complete: 9.7%; Average loss: 2.6993
# Iteration: 387; Percent complete: 9.7%; Average loss: 2.6564
# Iteration: 388; Percent complete: 9.7%; Average loss: 2.5742
# Iteration: 389; Percent complete: 9.7%; Average loss: 2.8128
# Iteration: 390; Percent complete: 9.8%; Average loss: 2.7811
# Iteration: 391; Percent complete: 9.8%; Average loss: 2.7872
# Iteration: 392; Percent complete: 9.8%; Average loss: 2.6478
# Iteration: 393; Percent complete: 9.8%; Average loss: 2.8774
# Iteration: 394; Percent complete: 9.8%; Average loss: 2.7248
# Iteration: 395; Percent complete: 9.9%; Average loss: 2.7160
# Iteration: 396; Percent complete: 9.9%; Average loss: 2.7747
# Iteration: 397; Percent complete: 9.9%; Average loss: 2.9189
# Iteration: 398; Percent complete: 10.0%; Average loss: 2.6448
# Iteration: 399; Percent complete: 10.0%; Average loss: 2.7049
# Iteration: 400; Percent complete: 10.0%; Average loss: 2.6678
# Iteration: 401; Percent complete: 10.0%; Average loss: 2.6673
# Iteration: 402; Percent complete: 10.1%; Average loss: 2.5736
# Iteration: 403; Percent complete: 10.1%; Average loss: 2.3609
# Iteration: 404; Percent complete: 10.1%; Average loss: 2.7675
# Iteration: 405; Percent complete: 10.1%; Average loss: 2.7517
# Iteration: 406; Percent complete: 10.2%; Average loss: 2.9017
# Iteration: 407; Percent complete: 10.2%; Average loss: 2.4685
# Iteration: 408; Percent complete: 10.2%; Average loss: 2.8541
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.0480
# Iteration: 410; Percent complete: 10.2%; Average loss: 2.8686
# Iteration: 411; Percent complete: 10.3%; Average loss: 2.6117
# Iteration: 412; Percent complete: 10.3%; Average loss: 2.4373
# Iteration: 413; Percent complete: 10.3%; Average loss: 2.8686
# Iteration: 414; Percent complete: 10.3%; Average loss: 2.8522
# Iteration: 415; Percent complete: 10.4%; Average loss: 2.7066
# Iteration: 416; Percent complete: 10.4%; Average loss: 2.5292
# Iteration: 417; Percent complete: 10.4%; Average loss: 2.6433
# Iteration: 418; Percent complete: 10.4%; Average loss: 2.6483
# Iteration: 419; Percent complete: 10.5%; Average loss: 2.6099
# Iteration: 420; Percent complete: 10.5%; Average loss: 2.7913
# Iteration: 421; Percent complete: 10.5%; Average loss: 2.6344
# Iteration: 422; Percent complete: 10.5%; Average loss: 2.5040
# Iteration: 423; Percent complete: 10.6%; Average loss: 2.6949
# Iteration: 424; Percent complete: 10.6%; Average loss: 2.7422
# Iteration: 425; Percent complete: 10.6%; Average loss: 2.7659
# Iteration: 426; Percent complete: 10.7%; Average loss: 2.6221
# Iteration: 427; Percent complete: 10.7%; Average loss: 2.7168
# Iteration: 428; Percent complete: 10.7%; Average loss: 2.4145
# Iteration: 429; Percent complete: 10.7%; Average loss: 2.7698
# Iteration: 430; Percent complete: 10.8%; Average loss: 2.7322
# Iteration: 431; Percent complete: 10.8%; Average loss: 2.6302
# Iteration: 432; Percent complete: 10.8%; Average loss: 2.7471
# Iteration: 433; Percent complete: 10.8%; Average loss: 2.7782
# Iteration: 434; Percent complete: 10.8%; Average loss: 2.6232
# Iteration: 435; Percent complete: 10.9%; Average loss: 2.8200
# Iteration: 436; Percent complete: 10.9%; Average loss: 2.5367
# Iteration: 437; Percent complete: 10.9%; Average loss: 2.6143
# Iteration: 438; Percent complete: 10.9%; Average loss: 2.5163
# Iteration: 439; Percent complete: 11.0%; Average loss: 2.6640
# Iteration: 440; Percent complete: 11.0%; Average loss: 2.6884
# Iteration: 441; Percent complete: 11.0%; Average loss: 2.5669
# Iteration: 442; Percent complete: 11.1%; Average loss: 2.4698
# Iteration: 443; Percent complete: 11.1%; Average loss: 2.4016
# Iteration: 444; Percent complete: 11.1%; Average loss: 2.8620
# Iteration: 445; Percent complete: 11.1%; Average loss: 2.6788
# Iteration: 446; Percent complete: 11.2%; Average loss: 2.4503
# Iteration: 447; Percent complete: 11.2%; Average loss: 2.5309
# Iteration: 448; Percent complete: 11.2%; Average loss: 2.4524
# Iteration: 449; Percent complete: 11.2%; Average loss: 2.7207
# Iteration: 450; Percent complete: 11.2%; Average loss: 2.4416
# Iteration: 451; Percent complete: 11.3%; Average loss: 2.5061
# Iteration: 452; Percent complete: 11.3%; Average loss: 2.5002
# Iteration: 453; Percent complete: 11.3%; Average loss: 2.6938
# Iteration: 454; Percent complete: 11.3%; Average loss: 2.7294
# Iteration: 455; Percent complete: 11.4%; Average loss: 2.5935
# Iteration: 456; Percent complete: 11.4%; Average loss: 2.5477
# Iteration: 457; Percent complete: 11.4%; Average loss: 2.6325
# Iteration: 458; Percent complete: 11.5%; Average loss: 2.4537
# Iteration: 459; Percent complete: 11.5%; Average loss: 2.4202
# Iteration: 460; Percent complete: 11.5%; Average loss: 2.5967
# Iteration: 461; Percent complete: 11.5%; Average loss: 2.3874
# Iteration: 462; Percent complete: 11.6%; Average loss: 2.5172
# Iteration: 463; Percent complete: 11.6%; Average loss: 2.6252
# Iteration: 464; Percent complete: 11.6%; Average loss: 2.5723
# Iteration: 465; Percent complete: 11.6%; Average loss: 2.7382
# Iteration: 466; Percent complete: 11.7%; Average loss: 2.2853
# Iteration: 467; Percent complete: 11.7%; Average loss: 2.4483
# Iteration: 468; Percent complete: 11.7%; Average loss: 2.4311
# Iteration: 469; Percent complete: 11.7%; Average loss: 2.2550
# Iteration: 470; Percent complete: 11.8%; Average loss: 2.9435
# Iteration: 471; Percent complete: 11.8%; Average loss: 2.8842
# Iteration: 472; Percent complete: 11.8%; Average loss: 2.5536
# Iteration: 473; Percent complete: 11.8%; Average loss: 2.5970
# Iteration: 474; Percent complete: 11.8%; Average loss: 2.7370
# Iteration: 475; Percent complete: 11.9%; Average loss: 2.6465
# Iteration: 476; Percent complete: 11.9%; Average loss: 2.4365
# Iteration: 477; Percent complete: 11.9%; Average loss: 2.2858
# Iteration: 478; Percent complete: 11.9%; Average loss: 2.4153
# Iteration: 479; Percent complete: 12.0%; Average loss: 2.4051
# Iteration: 480; Percent complete: 12.0%; Average loss: 2.1648
# Iteration: 481; Percent complete: 12.0%; Average loss: 2.4129
# Iteration: 482; Percent complete: 12.0%; Average loss: 2.6247
# Iteration: 483; Percent complete: 12.1%; Average loss: 2.7627
# Iteration: 484; Percent complete: 12.1%; Average loss: 2.5435
# Iteration: 485; Percent complete: 12.1%; Average loss: 2.4341
# Iteration: 486; Percent complete: 12.2%; Average loss: 2.2858
# Iteration: 487; Percent complete: 12.2%; Average loss: 2.6577
# Iteration: 488; Percent complete: 12.2%; Average loss: 2.4484
# Iteration: 489; Percent complete: 12.2%; Average loss: 2.3635
# Iteration: 490; Percent complete: 12.2%; Average loss: 2.3581
# Iteration: 491; Percent complete: 12.3%; Average loss: 2.4770
# Iteration: 492; Percent complete: 12.3%; Average loss: 2.4937
# Iteration: 493; Percent complete: 12.3%; Average loss: 2.2006
# Iteration: 494; Percent complete: 12.3%; Average loss: 2.4935
# Iteration: 495; Percent complete: 12.4%; Average loss: 2.3457
# Iteration: 496; Percent complete: 12.4%; Average loss: 2.4038
# Iteration: 497; Percent complete: 12.4%; Average loss: 2.5024
# Iteration: 498; Percent complete: 12.4%; Average loss: 2.4017
# Iteration: 499; Percent complete: 12.5%; Average loss: 2.4262
# Iteration: 500; Percent complete: 12.5%; Average loss: 2.3877
# Iteration: 501; Percent complete: 12.5%; Average loss: 2.6618
# Iteration: 502; Percent complete: 12.6%; Average loss: 2.4607
# Iteration: 503; Percent complete: 12.6%; Average loss: 2.3618
# Iteration: 504; Percent complete: 12.6%; Average loss: 2.2415
# Iteration: 505; Percent complete: 12.6%; Average loss: 2.3335
# Iteration: 506; Percent complete: 12.7%; Average loss: 2.3200
# Iteration: 507; Percent complete: 12.7%; Average loss: 2.5497
# Iteration: 508; Percent complete: 12.7%; Average loss: 2.1278
# Iteration: 509; Percent complete: 12.7%; Average loss: 2.3745
# Iteration: 510; Percent complete: 12.8%; Average loss: 2.6910
# Iteration: 511; Percent complete: 12.8%; Average loss: 2.4044
# Iteration: 512; Percent complete: 12.8%; Average loss: 2.2890
# Iteration: 513; Percent complete: 12.8%; Average loss: 2.5077
# Iteration: 514; Percent complete: 12.8%; Average loss: 2.3947
# Iteration: 515; Percent complete: 12.9%; Average loss: 2.3634
# Iteration: 516; Percent complete: 12.9%; Average loss: 2.1986
# Iteration: 517; Percent complete: 12.9%; Average loss: 2.6680
# Iteration: 518; Percent complete: 13.0%; Average loss: 2.6731
# Iteration: 519; Percent complete: 13.0%; Average loss: 2.5286
# Iteration: 520; Percent complete: 13.0%; Average loss: 2.3550
# Iteration: 521; Percent complete: 13.0%; Average loss: 2.2492
# Iteration: 522; Percent complete: 13.1%; Average loss: 2.4510
# Iteration: 523; Percent complete: 13.1%; Average loss: 2.2594
# Iteration: 524; Percent complete: 13.1%; Average loss: 2.4160
# Iteration: 525; Percent complete: 13.1%; Average loss: 2.4032
# Iteration: 526; Percent complete: 13.2%; Average loss: 2.3556
# Iteration: 527; Percent complete: 13.2%; Average loss: 2.4013
# Iteration: 528; Percent complete: 13.2%; Average loss: 2.2594
# Iteration: 529; Percent complete: 13.2%; Average loss: 2.3351
# Iteration: 530; Percent complete: 13.2%; Average loss: 2.1075
# Iteration: 531; Percent complete: 13.3%; Average loss: 2.3892
# Iteration: 532; Percent complete: 13.3%; Average loss: 2.3196
# Iteration: 533; Percent complete: 13.3%; Average loss: 2.8454
# Iteration: 534; Percent complete: 13.4%; Average loss: 2.5360
# Iteration: 535; Percent complete: 13.4%; Average loss: 2.4364
# Iteration: 536; Percent complete: 13.4%; Average loss: 2.5172
# Iteration: 537; Percent complete: 13.4%; Average loss: 2.3794
# Iteration: 538; Percent complete: 13.5%; Average loss: 2.5842
# Iteration: 539; Percent complete: 13.5%; Average loss: 2.4470
# Iteration: 540; Percent complete: 13.5%; Average loss: 2.1019
# Iteration: 541; Percent complete: 13.5%; Average loss: 2.4581
# Iteration: 542; Percent complete: 13.6%; Average loss: 2.2307
# Iteration: 543; Percent complete: 13.6%; Average loss: 2.4056
# Iteration: 544; Percent complete: 13.6%; Average loss: 2.2467
# Iteration: 545; Percent complete: 13.6%; Average loss: 2.4867
# Iteration: 546; Percent complete: 13.7%; Average loss: 2.3415
# Iteration: 547; Percent complete: 13.7%; Average loss: 2.4361
# Iteration: 548; Percent complete: 13.7%; Average loss: 2.4181
# Iteration: 549; Percent complete: 13.7%; Average loss: 2.3781
# Iteration: 550; Percent complete: 13.8%; Average loss: 2.3315
# Iteration: 551; Percent complete: 13.8%; Average loss: 2.4264
# Iteration: 552; Percent complete: 13.8%; Average loss: 2.3290
# Iteration: 553; Percent complete: 13.8%; Average loss: 2.2940
# Iteration: 554; Percent complete: 13.9%; Average loss: 2.1750
# Iteration: 555; Percent complete: 13.9%; Average loss: 2.3583
# Iteration: 556; Percent complete: 13.9%; Average loss: 2.4080
# Iteration: 557; Percent complete: 13.9%; Average loss: 2.3710
# Iteration: 558; Percent complete: 14.0%; Average loss: 2.4148
# Iteration: 559; Percent complete: 14.0%; Average loss: 2.4157
# Iteration: 560; Percent complete: 14.0%; Average loss: 2.0928
# Iteration: 561; Percent complete: 14.0%; Average loss: 2.0039
# Iteration: 562; Percent complete: 14.1%; Average loss: 2.2218
# Iteration: 563; Percent complete: 14.1%; Average loss: 2.2348
# Iteration: 564; Percent complete: 14.1%; Average loss: 2.4018
# Iteration: 565; Percent complete: 14.1%; Average loss: 2.3440
# Iteration: 566; Percent complete: 14.1%; Average loss: 2.1526
# Iteration: 567; Percent complete: 14.2%; Average loss: 2.1804
# Iteration: 568; Percent complete: 14.2%; Average loss: 2.3184
# Iteration: 569; Percent complete: 14.2%; Average loss: 1.7961
# Iteration: 570; Percent complete: 14.2%; Average loss: 2.3675
# Iteration: 571; Percent complete: 14.3%; Average loss: 2.2061
# Iteration: 572; Percent complete: 14.3%; Average loss: 2.1617
# Iteration: 573; Percent complete: 14.3%; Average loss: 2.2183
# Iteration: 574; Percent complete: 14.3%; Average loss: 2.4362
# Iteration: 575; Percent complete: 14.4%; Average loss: 2.5183
# Iteration: 576; Percent complete: 14.4%; Average loss: 2.2386
# Iteration: 577; Percent complete: 14.4%; Average loss: 2.1164
# Iteration: 578; Percent complete: 14.4%; Average loss: 2.3973
# Iteration: 579; Percent complete: 14.5%; Average loss: 2.1759
# Iteration: 580; Percent complete: 14.5%; Average loss: 2.2186
# Iteration: 581; Percent complete: 14.5%; Average loss: 2.1211
# Iteration: 582; Percent complete: 14.5%; Average loss: 2.3738
# Iteration: 583; Percent complete: 14.6%; Average loss: 2.3591
# Iteration: 584; Percent complete: 14.6%; Average loss: 2.0588
# Iteration: 585; Percent complete: 14.6%; Average loss: 2.2995
# Iteration: 586; Percent complete: 14.6%; Average loss: 2.1910
# Iteration: 587; Percent complete: 14.7%; Average loss: 1.9596
# Iteration: 588; Percent complete: 14.7%; Average loss: 2.3290
# Iteration: 589; Percent complete: 14.7%; Average loss: 2.1840
# Iteration: 590; Percent complete: 14.8%; Average loss: 1.9377
# Iteration: 591; Percent complete: 14.8%; Average loss: 2.3057
# Iteration: 592; Percent complete: 14.8%; Average loss: 2.5418
# Iteration: 593; Percent complete: 14.8%; Average loss: 2.1323
# Iteration: 594; Percent complete: 14.8%; Average loss: 2.1605
# Iteration: 595; Percent complete: 14.9%; Average loss: 2.1645
# Iteration: 596; Percent complete: 14.9%; Average loss: 2.1288
# Iteration: 597; Percent complete: 14.9%; Average loss: 2.3604
# Iteration: 598; Percent complete: 14.9%; Average loss: 1.9791
# Iteration: 599; Percent complete: 15.0%; Average loss: 2.2087
# Iteration: 600; Percent complete: 15.0%; Average loss: 2.1101
# Iteration: 601; Percent complete: 15.0%; Average loss: 2.1383
# Iteration: 602; Percent complete: 15.0%; Average loss: 2.1448
# Iteration: 603; Percent complete: 15.1%; Average loss: 2.2443
# Iteration: 604; Percent complete: 15.1%; Average loss: 2.1255
# Iteration: 605; Percent complete: 15.1%; Average loss: 2.0056
# Iteration: 606; Percent complete: 15.2%; Average loss: 2.2163
# Iteration: 607; Percent complete: 15.2%; Average loss: 2.0965
# Iteration: 608; Percent complete: 15.2%; Average loss: 2.1103
# Iteration: 609; Percent complete: 15.2%; Average loss: 2.0492
# Iteration: 610; Percent complete: 15.2%; Average loss: 2.0685
# Iteration: 611; Percent complete: 15.3%; Average loss: 2.1576
# Iteration: 612; Percent complete: 15.3%; Average loss: 2.1866
# Iteration: 613; Percent complete: 15.3%; Average loss: 1.9627
# Iteration: 614; Percent complete: 15.3%; Average loss: 2.3911
# Iteration: 615; Percent complete: 15.4%; Average loss: 2.0068
# Iteration: 616; Percent complete: 15.4%; Average loss: 2.3477
# Iteration: 617; Percent complete: 15.4%; Average loss: 2.1912
# Iteration: 618; Percent complete: 15.4%; Average loss: 1.9111
# Iteration: 619; Percent complete: 15.5%; Average loss: 1.9066
# Iteration: 620; Percent complete: 15.5%; Average loss: 2.3041
# Iteration: 621; Percent complete: 15.5%; Average loss: 2.1478
# Iteration: 622; Percent complete: 15.6%; Average loss: 2.4133
# Iteration: 623; Percent complete: 15.6%; Average loss: 2.2413
# Iteration: 624; Percent complete: 15.6%; Average loss: 2.0097
# Iteration: 625; Percent complete: 15.6%; Average loss: 1.9721
# Iteration: 626; Percent complete: 15.7%; Average loss: 2.0724
# Iteration: 627; Percent complete: 15.7%; Average loss: 2.0051
# Iteration: 628; Percent complete: 15.7%; Average loss: 2.0022
# Iteration: 629; Percent complete: 15.7%; Average loss: 2.0155
# Iteration: 630; Percent complete: 15.8%; Average loss: 2.0571
# Iteration: 631; Percent complete: 15.8%; Average loss: 2.3903
# Iteration: 632; Percent complete: 15.8%; Average loss: 1.6968
# Iteration: 633; Percent complete: 15.8%; Average loss: 2.2408
# Iteration: 634; Percent complete: 15.8%; Average loss: 2.3438
# Iteration: 635; Percent complete: 15.9%; Average loss: 2.1516
# Iteration: 636; Percent complete: 15.9%; Average loss: 2.0081
# Iteration: 637; Percent complete: 15.9%; Average loss: 2.2020
# Iteration: 638; Percent complete: 16.0%; Average loss: 1.8005
# Iteration: 639; Percent complete: 16.0%; Average loss: 2.1871
# Iteration: 640; Percent complete: 16.0%; Average loss: 2.1139
# Iteration: 641; Percent complete: 16.0%; Average loss: 1.7899
# Iteration: 642; Percent complete: 16.1%; Average loss: 2.0767
# Iteration: 643; Percent complete: 16.1%; Average loss: 2.1439
# Iteration: 644; Percent complete: 16.1%; Average loss: 2.1469
# Iteration: 645; Percent complete: 16.1%; Average loss: 2.2634
# Iteration: 646; Percent complete: 16.2%; Average loss: 2.2019
# Iteration: 647; Percent complete: 16.2%; Average loss: 2.1556
# Iteration: 648; Percent complete: 16.2%; Average loss: 1.8946
# Iteration: 649; Percent complete: 16.2%; Average loss: 2.0507
# Iteration: 650; Percent complete: 16.2%; Average loss: 1.8051
# Iteration: 651; Percent complete: 16.3%; Average loss: 2.1581
# Iteration: 652; Percent complete: 16.3%; Average loss: 1.9818
# Iteration: 653; Percent complete: 16.3%; Average loss: 2.1643
# Iteration: 654; Percent complete: 16.4%; Average loss: 2.0714
# Iteration: 655; Percent complete: 16.4%; Average loss: 2.1499
# Iteration: 656; Percent complete: 16.4%; Average loss: 2.0108
# Iteration: 657; Percent complete: 16.4%; Average loss: 2.0585
# Iteration: 658; Percent complete: 16.4%; Average loss: 1.9766
# Iteration: 659; Percent complete: 16.5%; Average loss: 2.0371
# Iteration: 660; Percent complete: 16.5%; Average loss: 2.2148
# Iteration: 661; Percent complete: 16.5%; Average loss: 2.2505
# Iteration: 662; Percent complete: 16.6%; Average loss: 2.0643
# Iteration: 663; Percent complete: 16.6%; Average loss: 2.0566
# Iteration: 664; Percent complete: 16.6%; Average loss: 2.2053
# Iteration: 665; Percent complete: 16.6%; Average loss: 1.9010
# Iteration: 666; Percent complete: 16.7%; Average loss: 2.0026
# Iteration: 667; Percent complete: 16.7%; Average loss: 2.0635
# Iteration: 668; Percent complete: 16.7%; Average loss: 2.0811
# Iteration: 669; Percent complete: 16.7%; Average loss: 1.8301
# Iteration: 670; Percent complete: 16.8%; Average loss: 1.9785
# Iteration: 671; Percent complete: 16.8%; Average loss: 1.9318
# Iteration: 672; Percent complete: 16.8%; Average loss: 1.9102
# Iteration: 673; Percent complete: 16.8%; Average loss: 2.1746
# Iteration: 674; Percent complete: 16.9%; Average loss: 2.1307
# Iteration: 675; Percent complete: 16.9%; Average loss: 1.9805
# Iteration: 676; Percent complete: 16.9%; Average loss: 2.0525
# Iteration: 677; Percent complete: 16.9%; Average loss: 1.9653
# Iteration: 678; Percent complete: 17.0%; Average loss: 1.9857
# Iteration: 679; Percent complete: 17.0%; Average loss: 1.9312
# Iteration: 680; Percent complete: 17.0%; Average loss: 2.1590
# Iteration: 681; Percent complete: 17.0%; Average loss: 2.0635
# Iteration: 682; Percent complete: 17.1%; Average loss: 1.9205
# Iteration: 683; Percent complete: 17.1%; Average loss: 1.9018
# Iteration: 684; Percent complete: 17.1%; Average loss: 1.7050
# Iteration: 685; Percent complete: 17.1%; Average loss: 2.0465
# Iteration: 686; Percent complete: 17.2%; Average loss: 2.0064
# Iteration: 687; Percent complete: 17.2%; Average loss: 2.1092
# Iteration: 688; Percent complete: 17.2%; Average loss: 2.2274
# Iteration: 689; Percent complete: 17.2%; Average loss: 1.8240
# Iteration: 690; Percent complete: 17.2%; Average loss: 2.0398
# Iteration: 691; Percent complete: 17.3%; Average loss: 1.9976
# Iteration: 692; Percent complete: 17.3%; Average loss: 1.9399
# Iteration: 693; Percent complete: 17.3%; Average loss: 2.0361
# Iteration: 694; Percent complete: 17.3%; Average loss: 1.9231
# Iteration: 695; Percent complete: 17.4%; Average loss: 1.9785
# Iteration: 696; Percent complete: 17.4%; Average loss: 2.0067
# Iteration: 697; Percent complete: 17.4%; Average loss: 2.0517
# Iteration: 698; Percent complete: 17.4%; Average loss: 2.2065
# Iteration: 699; Percent complete: 17.5%; Average loss: 1.8494
# Iteration: 700; Percent complete: 17.5%; Average loss: 2.1207
# Iteration: 701; Percent complete: 17.5%; Average loss: 1.8515
# Iteration: 702; Percent complete: 17.5%; Average loss: 1.9351
# Iteration: 703; Percent complete: 17.6%; Average loss: 1.8940
# Iteration: 704; Percent complete: 17.6%; Average loss: 1.9613
# Iteration: 705; Percent complete: 17.6%; Average loss: 1.8722
# Iteration: 706; Percent complete: 17.6%; Average loss: 1.9730
# Iteration: 707; Percent complete: 17.7%; Average loss: 1.8866
# Iteration: 708; Percent complete: 17.7%; Average loss: 2.1082
# Iteration: 709; Percent complete: 17.7%; Average loss: 1.8856
# Iteration: 710; Percent complete: 17.8%; Average loss: 2.0276
# Iteration: 711; Percent complete: 17.8%; Average loss: 1.8416
# Iteration: 712; Percent complete: 17.8%; Average loss: 1.8703
# Iteration: 713; Percent complete: 17.8%; Average loss: 2.0918
# Iteration: 714; Percent complete: 17.8%; Average loss: 1.9106
# Iteration: 715; Percent complete: 17.9%; Average loss: 1.6517
# Iteration: 716; Percent complete: 17.9%; Average loss: 1.9462
# Iteration: 717; Percent complete: 17.9%; Average loss: 2.1245
# Iteration: 718; Percent complete: 17.9%; Average loss: 2.0832
# Iteration: 719; Percent complete: 18.0%; Average loss: 1.8234
# Iteration: 720; Percent complete: 18.0%; Average loss: 2.0586
# Iteration: 721; Percent complete: 18.0%; Average loss: 2.1438
# Iteration: 722; Percent complete: 18.1%; Average loss: 1.8381
# Iteration: 723; Percent complete: 18.1%; Average loss: 1.7522
# Iteration: 724; Percent complete: 18.1%; Average loss: 2.1262
# Iteration: 725; Percent complete: 18.1%; Average loss: 1.9322
# Iteration: 726; Percent complete: 18.1%; Average loss: 1.8749
# Iteration: 727; Percent complete: 18.2%; Average loss: 1.9761
# Iteration: 728; Percent complete: 18.2%; Average loss: 1.9327
# Iteration: 729; Percent complete: 18.2%; Average loss: 2.0426
# Iteration: 730; Percent complete: 18.2%; Average loss: 1.9163
# Iteration: 731; Percent complete: 18.3%; Average loss: 2.1283
# Iteration: 732; Percent complete: 18.3%; Average loss: 1.9720
# Iteration: 733; Percent complete: 18.3%; Average loss: 1.9369
# Iteration: 734; Percent complete: 18.4%; Average loss: 1.8726
# Iteration: 735; Percent complete: 18.4%; Average loss: 1.5997
# Iteration: 736; Percent complete: 18.4%; Average loss: 1.7663
# Iteration: 737; Percent complete: 18.4%; Average loss: 1.8121
# Iteration: 738; Percent complete: 18.4%; Average loss: 1.6707
# Iteration: 739; Percent complete: 18.5%; Average loss: 1.9532
# Iteration: 740; Percent complete: 18.5%; Average loss: 1.8470
# Iteration: 741; Percent complete: 18.5%; Average loss: 1.7035
# Iteration: 742; Percent complete: 18.6%; Average loss: 1.9868
# Iteration: 743; Percent complete: 18.6%; Average loss: 1.8319
# Iteration: 744; Percent complete: 18.6%; Average loss: 2.0823
# Iteration: 745; Percent complete: 18.6%; Average loss: 1.7340
# Iteration: 746; Percent complete: 18.6%; Average loss: 1.8037
# Iteration: 747; Percent complete: 18.7%; Average loss: 2.0109
# Iteration: 748; Percent complete: 18.7%; Average loss: 1.9913
# Iteration: 749; Percent complete: 18.7%; Average loss: 1.9896
# Iteration: 750; Percent complete: 18.8%; Average loss: 2.0920
# Iteration: 751; Percent complete: 18.8%; Average loss: 1.9291
# Iteration: 752; Percent complete: 18.8%; Average loss: 1.7655
# Iteration: 753; Percent complete: 18.8%; Average loss: 1.8854
# Iteration: 754; Percent complete: 18.9%; Average loss: 1.7042
# Iteration: 755; Percent complete: 18.9%; Average loss: 1.8090
# Iteration: 756; Percent complete: 18.9%; Average loss: 1.9080
# Iteration: 757; Percent complete: 18.9%; Average loss: 1.8120
# Iteration: 758; Percent complete: 18.9%; Average loss: 1.8611
# Iteration: 759; Percent complete: 19.0%; Average loss: 1.7001
# Iteration: 760; Percent complete: 19.0%; Average loss: 1.9017
# Iteration: 761; Percent complete: 19.0%; Average loss: 1.7399
# Iteration: 762; Percent complete: 19.1%; Average loss: 1.9912
# Iteration: 763; Percent complete: 19.1%; Average loss: 1.7715
# Iteration: 764; Percent complete: 19.1%; Average loss: 1.8293
# Iteration: 765; Percent complete: 19.1%; Average loss: 1.8807
# Iteration: 766; Percent complete: 19.1%; Average loss: 2.0379
# Iteration: 767; Percent complete: 19.2%; Average loss: 1.7621
# Iteration: 768; Percent complete: 19.2%; Average loss: 1.9607
# Iteration: 769; Percent complete: 19.2%; Average loss: 2.0742
# Iteration: 770; Percent complete: 19.2%; Average loss: 1.8866
# Iteration: 771; Percent complete: 19.3%; Average loss: 1.6763
# Iteration: 772; Percent complete: 19.3%; Average loss: 1.7478
# Iteration: 773; Percent complete: 19.3%; Average loss: 1.9689
# Iteration: 774; Percent complete: 19.4%; Average loss: 1.6092
# Iteration: 775; Percent complete: 19.4%; Average loss: 1.9019
# Iteration: 776; Percent complete: 19.4%; Average loss: 1.7841
# Iteration: 777; Percent complete: 19.4%; Average loss: 1.7414
# Iteration: 778; Percent complete: 19.4%; Average loss: 1.8370
# Iteration: 779; Percent complete: 19.5%; Average loss: 1.8153
# Iteration: 780; Percent complete: 19.5%; Average loss: 1.8820
# Iteration: 781; Percent complete: 19.5%; Average loss: 1.9715
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 0.1291
# Iteration: 3749; Percent complete: 93.7%; Average loss: 0.1702
# Iteration: 3750; Percent complete: 93.8%; Average loss: 0.2320
# Iteration: 3751; Percent complete: 93.8%; Average loss: 0.2217
# Iteration: 3752; Percent complete: 93.8%; Average loss: 0.2039
# Iteration: 3753; Percent complete: 93.8%; Average loss: 0.2702
# Iteration: 3754; Percent complete: 93.8%; Average loss: 0.1248
# Iteration: 3755; Percent complete: 93.9%; Average loss: 0.1740
# Iteration: 3756; Percent complete: 93.9%; Average loss: 0.2438
# Iteration: 3757; Percent complete: 93.9%; Average loss: 0.1576
# Iteration: 3758; Percent complete: 94.0%; Average loss: 0.2007
# Iteration: 3759; Percent complete: 94.0%; Average loss: 0.2230
# Iteration: 3760; Percent complete: 94.0%; Average loss: 0.2455
# Iteration: 3761; Percent complete: 94.0%; Average loss: 0.1747
# Iteration: 3762; Percent complete: 94.0%; Average loss: 0.0826
# Iteration: 3763; Percent complete: 94.1%; Average loss: 0.2090
# Iteration: 3764; Percent complete: 94.1%; Average loss: 0.1687
# Iteration: 3765; Percent complete: 94.1%; Average loss: 0.2242
# Iteration: 3766; Percent complete: 94.2%; Average loss: 0.1711
# Iteration: 3767; Percent complete: 94.2%; Average loss: 0.1861
# Iteration: 3768; Percent complete: 94.2%; Average loss: 0.1401
# Iteration: 3769; Percent complete: 94.2%; Average loss: 0.1308
# Iteration: 3770; Percent complete: 94.2%; Average loss: 0.1916
# Iteration: 3771; Percent complete: 94.3%; Average loss: 0.1226
# Iteration: 3772; Percent complete: 94.3%; Average loss: 0.1768
# Iteration: 3773; Percent complete: 94.3%; Average loss: 0.1758
# Iteration: 3774; Percent complete: 94.3%; Average loss: 0.1272
# Iteration: 3775; Percent complete: 94.4%; Average loss: 0.1389
# Iteration: 3776; Percent complete: 94.4%; Average loss: 0.2089
# Iteration: 3777; Percent complete: 94.4%; Average loss: 0.1464
# Iteration: 3778; Percent complete: 94.5%; Average loss: 0.1657
# Iteration: 3779; Percent complete: 94.5%; Average loss: 0.1726
# Iteration: 3780; Percent complete: 94.5%; Average loss: 0.2007
# Iteration: 3781; Percent complete: 94.5%; Average loss: 0.1937
# Iteration: 3782; Percent complete: 94.5%; Average loss: 0.1589
# Iteration: 3783; Percent complete: 94.6%; Average loss: 0.1497
# Iteration: 3784; Percent complete: 94.6%; Average loss: 0.1601
# Iteration: 3785; Percent complete: 94.6%; Average loss: 0.1359
# Iteration: 3786; Percent complete: 94.7%; Average loss: 0.1869
# Iteration: 3787; Percent complete: 94.7%; Average loss: 0.1652
# Iteration: 3788; Percent complete: 94.7%; Average loss: 0.1505
# Iteration: 3789; Percent complete: 94.7%; Average loss: 0.1487
# Iteration: 3790; Percent complete: 94.8%; Average loss: 0.1956
# Iteration: 3791; Percent complete: 94.8%; Average loss: 0.1670
# Iteration: 3792; Percent complete: 94.8%; Average loss: 0.1736
# Iteration: 3793; Percent complete: 94.8%; Average loss: 0.1557
# Iteration: 3794; Percent complete: 94.8%; Average loss: 0.1768
# Iteration: 3795; Percent complete: 94.9%; Average loss: 0.1332
# Iteration: 3796; Percent complete: 94.9%; Average loss: 0.2645
# Iteration: 3797; Percent complete: 94.9%; Average loss: 0.1981
# Iteration: 3798; Percent complete: 95.0%; Average loss: 0.1417
# Iteration: 3799; Percent complete: 95.0%; Average loss: 0.1694
# Iteration: 3800; Percent complete: 95.0%; Average loss: 0.1961
# Iteration: 3801; Percent complete: 95.0%; Average loss: 0.1454
# Iteration: 3802; Percent complete: 95.0%; Average loss: 0.1716
# Iteration: 3803; Percent complete: 95.1%; Average loss: 0.1500
# Iteration: 3804; Percent complete: 95.1%; Average loss: 0.1240
# Iteration: 3805; Percent complete: 95.1%; Average loss: 0.1590
# Iteration: 3806; Percent complete: 95.2%; Average loss: 0.1427
# Iteration: 3807; Percent complete: 95.2%; Average loss: 0.1509
# Iteration: 3808; Percent complete: 95.2%; Average loss: 0.2228
# Iteration: 3809; Percent complete: 95.2%; Average loss: 0.1704
# Iteration: 3810; Percent complete: 95.2%; Average loss: 0.2551
# Iteration: 3811; Percent complete: 95.3%; Average loss: 0.2129
# Iteration: 3812; Percent complete: 95.3%; Average loss: 0.2170
# Iteration: 3813; Percent complete: 95.3%; Average loss: 0.1557
# Iteration: 3814; Percent complete: 95.3%; Average loss: 0.1715
# Iteration: 3815; Percent complete: 95.4%; Average loss: 0.1995
# Iteration: 3816; Percent complete: 95.4%; Average loss: 0.1675
# Iteration: 3817; Percent complete: 95.4%; Average loss: 0.1458
# Iteration: 3818; Percent complete: 95.5%; Average loss: 0.1695
# Iteration: 3819; Percent complete: 95.5%; Average loss: 0.2054
# Iteration: 3820; Percent complete: 95.5%; Average loss: 0.1750
# Iteration: 3821; Percent complete: 95.5%; Average loss: 0.1655
# Iteration: 3822; Percent complete: 95.5%; Average loss: 0.2122
# Iteration: 3823; Percent complete: 95.6%; Average loss: 0.1677
# Iteration: 3824; Percent complete: 95.6%; Average loss: 0.1923
# Iteration: 3825; Percent complete: 95.6%; Average loss: 0.3057
# Iteration: 3826; Percent complete: 95.7%; Average loss: 0.1891
# Iteration: 3827; Percent complete: 95.7%; Average loss: 0.1296
# Iteration: 3828; Percent complete: 95.7%; Average loss: 0.1697
# Iteration: 3829; Percent complete: 95.7%; Average loss: 0.2065
# Iteration: 3830; Percent complete: 95.8%; Average loss: 0.2244
# Iteration: 3831; Percent complete: 95.8%; Average loss: 0.1584
# Iteration: 3832; Percent complete: 95.8%; Average loss: 0.1911
# Iteration: 3833; Percent complete: 95.8%; Average loss: 0.1493
# Iteration: 3834; Percent complete: 95.9%; Average loss: 0.1851
# Iteration: 3835; Percent complete: 95.9%; Average loss: 0.1657
# Iteration: 3836; Percent complete: 95.9%; Average loss: 0.1867
# Iteration: 3837; Percent complete: 95.9%; Average loss: 0.1493
# Iteration: 3838; Percent complete: 96.0%; Average loss: 0.1866
# Iteration: 3839; Percent complete: 96.0%; Average loss: 0.2510
# Iteration: 3840; Percent complete: 96.0%; Average loss: 0.1532
# Iteration: 3841; Percent complete: 96.0%; Average loss: 0.1688
# Iteration: 3842; Percent complete: 96.0%; Average loss: 0.1465
# Iteration: 3843; Percent complete: 96.1%; Average loss: 0.1974
# Iteration: 3844; Percent complete: 96.1%; Average loss: 0.3306
# Iteration: 3845; Percent complete: 96.1%; Average loss: 0.1809
# Iteration: 3846; Percent complete: 96.2%; Average loss: 0.2216
# Iteration: 3847; Percent complete: 96.2%; Average loss: 0.2068
# Iteration: 3848; Percent complete: 96.2%; Average loss: 0.1556
# Iteration: 3849; Percent complete: 96.2%; Average loss: 0.1740
# Iteration: 3850; Percent complete: 96.2%; Average loss: 0.2411
# Iteration: 3851; Percent complete: 96.3%; Average loss: 0.2557
# Iteration: 3852; Percent complete: 96.3%; Average loss: 0.1602
# Iteration: 3853; Percent complete: 96.3%; Average loss: 0.2010
# Iteration: 3854; Percent complete: 96.4%; Average loss: 0.1957
# Iteration: 3855; Percent complete: 96.4%; Average loss: 0.0756
# Iteration: 3856; Percent complete: 96.4%; Average loss: 0.2313
# Iteration: 3857; Percent complete: 96.4%; Average loss: 0.1273
# Iteration: 3858; Percent complete: 96.5%; Average loss: 0.1924
# Iteration: 3859; Percent complete: 96.5%; Average loss: 0.1579
# Iteration: 3860; Percent complete: 96.5%; Average loss: 0.2438
# Iteration: 3861; Percent complete: 96.5%; Average loss: 0.2245
# Iteration: 3862; Percent complete: 96.5%; Average loss: 0.1302
# Iteration: 3863; Percent complete: 96.6%; Average loss: 0.2221
# Iteration: 3864; Percent complete: 96.6%; Average loss: 0.2514
# Iteration: 3865; Percent complete: 96.6%; Average loss: 0.2558
# Iteration: 3866; Percent complete: 96.7%; Average loss: 0.1681
# Iteration: 3867; Percent complete: 96.7%; Average loss: 0.2403
# Iteration: 3868; Percent complete: 96.7%; Average loss: 0.1605
# Iteration: 3869; Percent complete: 96.7%; Average loss: 0.1504
# Iteration: 3870; Percent complete: 96.8%; Average loss: 0.1524
# Iteration: 3871; Percent complete: 96.8%; Average loss: 0.2018
# Iteration: 3872; Percent complete: 96.8%; Average loss: 0.2055
# Iteration: 3873; Percent complete: 96.8%; Average loss: 0.1892
# Iteration: 3874; Percent complete: 96.9%; Average loss: 0.1172
# Iteration: 3875; Percent complete: 96.9%; Average loss: 0.1156
# Iteration: 3876; Percent complete: 96.9%; Average loss: 0.1342
# Iteration: 3877; Percent complete: 96.9%; Average loss: 0.1722
# Iteration: 3878; Percent complete: 97.0%; Average loss: 0.1700
# Iteration: 3879; Percent complete: 97.0%; Average loss: 0.1785
# Iteration: 3880; Percent complete: 97.0%; Average loss: 0.1682
# Iteration: 3881; Percent complete: 97.0%; Average loss: 0.1430
# Iteration: 3882; Percent complete: 97.0%; Average loss: 0.1162
# Iteration: 3883; Percent complete: 97.1%; Average loss: 0.1510
# Iteration: 3884; Percent complete: 97.1%; Average loss: 0.1823
# Iteration: 3885; Percent complete: 97.1%; Average loss: 0.1749
# Iteration: 3886; Percent complete: 97.2%; Average loss: 0.1680
# Iteration: 3887; Percent complete: 97.2%; Average loss: 0.1770
# Iteration: 3888; Percent complete: 97.2%; Average loss: 0.1975
# Iteration: 3889; Percent complete: 97.2%; Average loss: 0.1804
# Iteration: 3890; Percent complete: 97.2%; Average loss: 0.1918
# Iteration: 3891; Percent complete: 97.3%; Average loss: 0.1591
# Iteration: 3892; Percent complete: 97.3%; Average loss: 0.1187
# Iteration: 3893; Percent complete: 97.3%; Average loss: 0.1740
# Iteration: 3894; Percent complete: 97.4%; Average loss: 0.1405
# Iteration: 3895; Percent complete: 97.4%; Average loss: 0.1804
# Iteration: 3896; Percent complete: 97.4%; Average loss: 0.1597
# Iteration: 3897; Percent complete: 97.4%; Average loss: 0.2526
# Iteration: 3898; Percent complete: 97.5%; Average loss: 0.2014
# Iteration: 3899; Percent complete: 97.5%; Average loss: 0.1251
# Iteration: 3900; Percent complete: 97.5%; Average loss: 0.1444
# Iteration: 3901; Percent complete: 97.5%; Average loss: 0.1935
# Iteration: 3902; Percent complete: 97.5%; Average loss: 0.2001
# Iteration: 3903; Percent complete: 97.6%; Average loss: 0.1633
# Iteration: 3904; Percent complete: 97.6%; Average loss: 0.1122
# Iteration: 3905; Percent complete: 97.6%; Average loss: 0.1593
# Iteration: 3906; Percent complete: 97.7%; Average loss: 0.1778
# Iteration: 3907; Percent complete: 97.7%; Average loss: 0.1568
# Iteration: 3908; Percent complete: 97.7%; Average loss: 0.1891
# Iteration: 3909; Percent complete: 97.7%; Average loss: 0.1074
# Iteration: 3910; Percent complete: 97.8%; Average loss: 0.1260
# Iteration: 3911; Percent complete: 97.8%; Average loss: 0.1782
# Iteration: 3912; Percent complete: 97.8%; Average loss: 0.1685
# Iteration: 3913; Percent complete: 97.8%; Average loss: 0.1330
# Iteration: 3914; Percent complete: 97.9%; Average loss: 0.1416
# Iteration: 3915; Percent complete: 97.9%; Average loss: 0.1542
# Iteration: 3916; Percent complete: 97.9%; Average loss: 0.1299
# Iteration: 3917; Percent complete: 97.9%; Average loss: 0.1034
# Iteration: 3918; Percent complete: 98.0%; Average loss: 0.1622
# Iteration: 3919; Percent complete: 98.0%; Average loss: 0.1098
# Iteration: 3920; Percent complete: 98.0%; Average loss: 0.1838
# Iteration: 3921; Percent complete: 98.0%; Average loss: 0.1564
# Iteration: 3922; Percent complete: 98.0%; Average loss: 0.2064
# Iteration: 3923; Percent complete: 98.1%; Average loss: 0.1320
# Iteration: 3924; Percent complete: 98.1%; Average loss: 0.1416
# Iteration: 3925; Percent complete: 98.1%; Average loss: 0.1451
# Iteration: 3926; Percent complete: 98.2%; Average loss: 0.1357
# Iteration: 3927; Percent complete: 98.2%; Average loss: 0.1950
# Iteration: 3928; Percent complete: 98.2%; Average loss: 0.1402
# Iteration: 3929; Percent complete: 98.2%; Average loss: 0.1175
# Iteration: 3930; Percent complete: 98.2%; Average loss: 0.1476
# Iteration: 3931; Percent complete: 98.3%; Average loss: 0.1974
# Iteration: 3932; Percent complete: 98.3%; Average loss: 0.1730
# Iteration: 3933; Percent complete: 98.3%; Average loss: 0.1199
# Iteration: 3934; Percent complete: 98.4%; Average loss: 0.1066
# Iteration: 3935; Percent complete: 98.4%; Average loss: 0.2122
# Iteration: 3936; Percent complete: 98.4%; Average loss: 0.1402
# Iteration: 3937; Percent complete: 98.4%; Average loss: 0.1678
# Iteration: 3938; Percent complete: 98.5%; Average loss: 0.1000
# Iteration: 3939; Percent complete: 98.5%; Average loss: 0.1450
# Iteration: 3940; Percent complete: 98.5%; Average loss: 0.1778
# Iteration: 3941; Percent complete: 98.5%; Average loss: 0.2108
# Iteration: 3942; Percent complete: 98.6%; Average loss: 0.1164
# Iteration: 3943; Percent complete: 98.6%; Average loss: 0.1418
# Iteration: 3944; Percent complete: 98.6%; Average loss: 0.1053
# Iteration: 3945; Percent complete: 98.6%; Average loss: 0.0962
# Iteration: 3946; Percent complete: 98.7%; Average loss: 0.1026
# Iteration: 3947; Percent complete: 98.7%; Average loss: 0.1555
# Iteration: 3948; Percent complete: 98.7%; Average loss: 0.1756
# Iteration: 3949; Percent complete: 98.7%; Average loss: 0.1493
# Iteration: 3950; Percent complete: 98.8%; Average loss: 0.1652
# Iteration: 3951; Percent complete: 98.8%; Average loss: 0.0895
# Iteration: 3952; Percent complete: 98.8%; Average loss: 0.1243
# Iteration: 3953; Percent complete: 98.8%; Average loss: 0.1097
# Iteration: 3954; Percent complete: 98.9%; Average loss: 0.1474
# Iteration: 3955; Percent complete: 98.9%; Average loss: 0.1118
# Iteration: 3956; Percent complete: 98.9%; Average loss: 0.1048
# Iteration: 3957; Percent complete: 98.9%; Average loss: 0.1392
# Iteration: 3958; Percent complete: 99.0%; Average loss: 0.1174
# Iteration: 3959; Percent complete: 99.0%; Average loss: 0.1447
# Iteration: 3960; Percent complete: 99.0%; Average loss: 0.1694
# Iteration: 3961; Percent complete: 99.0%; Average loss: 0.1731
# Iteration: 3962; Percent complete: 99.1%; Average loss: 0.1457
# Iteration: 3963; Percent complete: 99.1%; Average loss: 0.1473
# Iteration: 3964; Percent complete: 99.1%; Average loss: 0.1329
# Iteration: 3965; Percent complete: 99.1%; Average loss: 0.1948
# Iteration: 3966; Percent complete: 99.2%; Average loss: 0.1094
# Iteration: 3967; Percent complete: 99.2%; Average loss: 0.1267
# Iteration: 3968; Percent complete: 99.2%; Average loss: 0.1340
# Iteration: 3969; Percent complete: 99.2%; Average loss: 0.1438
# Iteration: 3970; Percent complete: 99.2%; Average loss: 0.1349
# Iteration: 3971; Percent complete: 99.3%; Average loss: 0.0920
# Iteration: 3972; Percent complete: 99.3%; Average loss: 0.1286
# Iteration: 3973; Percent complete: 99.3%; Average loss: 0.0955
# Iteration: 3974; Percent complete: 99.4%; Average loss: 0.1082
# Iteration: 3975; Percent complete: 99.4%; Average loss: 0.1241
# Iteration: 3976; Percent complete: 99.4%; Average loss: 0.1309
# Iteration: 3977; Percent complete: 99.4%; Average loss: 0.1304
# Iteration: 3978; Percent complete: 99.5%; Average loss: 0.1203
# Iteration: 3979; Percent complete: 99.5%; Average loss: 0.1008
# Iteration: 3980; Percent complete: 99.5%; Average loss: 0.1060
# Iteration: 3981; Percent complete: 99.5%; Average loss: 0.1234
# Iteration: 3982; Percent complete: 99.6%; Average loss: 0.1966
# Iteration: 3983; Percent complete: 99.6%; Average loss: 0.1149
# Iteration: 3984; Percent complete: 99.6%; Average loss: 0.0845
# Iteration: 3985; Percent complete: 99.6%; Average loss: 0.1648
# Iteration: 3986; Percent complete: 99.7%; Average loss: 0.1231
# Iteration: 3987; Percent complete: 99.7%; Average loss: 0.1179
# Iteration: 3988; Percent complete: 99.7%; Average loss: 0.1102
# Iteration: 3989; Percent complete: 99.7%; Average loss: 0.1619
# Iteration: 3990; Percent complete: 99.8%; Average loss: 0.1096
# Iteration: 3991; Percent complete: 99.8%; Average loss: 0.1609
# Iteration: 3992; Percent complete: 99.8%; Average loss: 0.1461
# Iteration: 3993; Percent complete: 99.8%; Average loss: 0.1245
# Iteration: 3994; Percent complete: 99.9%; Average loss: 0.0902
# Iteration: 3995; Percent complete: 99.9%; Average loss: 0.1708
# Iteration: 3996; Percent complete: 99.9%; Average loss: 0.1848
# Iteration: 3997; Percent complete: 99.9%; Average loss: 0.1223
# Iteration: 3998; Percent complete: 100.0%; Average loss: 0.1350
# Iteration: 3999; Percent complete: 100.0%; Average loss: 0.1188
# Iteration: 4000; Percent complete: 100.0%; Average loss: 0.1375

# %% [markdown]
# # Baseline model from the tutorial

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > hello
# Bot: yes . and it s not in this
# > who are you
# Bot: yes and not very
# > what?
# Bot: a little year old . are .
# > who is a little year old?
# Bot: yes very easy together perfect ! perfect
# > what are you talking about
# Bot: two three and two . !
# > wtf
# Error: Encountered unknown word.
# > what is going on here
# Bot: . v . v as a gift
# > q

# %% [markdown]
# ### Notes on the Model

# %% [markdown]
# Overall, the model is OK. It was not as intelligent as i thought it would be, but I suppose that is a good thing. One of the things that I noticed from playing with the bot was that everything is pretty predictable. In fact, it feels less like it is responding to you and more like it has memories what to day based on an input string from the user.
#
# `Done` I think the first thing we can do to improve the model is to add some randomness to the model, so asking "hello" wont keep generating the same output.
#
# To improve this one a bit more we can change some of the variable like the learning rate and the depth.
#
# Eventually, to improve the overall feeling of the chat bot we can implement an entirely new model using BERT or GPT3 or other transformer models.

# %% [markdown]
# # Improving Evaluation: Adding randomness to Model Responses

# %% [markdown]
# ### Experiment 1

# %% [markdown]
# In the following implementation we choose one of the top k responses from our model at each word uniformly at random.

# %%
class StochasticTopKUniformDecoder(nn.Module):
    def __init__(self, encoder, decoder, k):
        super(StochasticTopKUniformDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            # select from the top k words at each word in the sentence
            # uniformly at random.
            decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
            i = int(random.random()*self.k)
            decoder_input = torch.tensor([ind[0,i]]).to(device)
            decoder_scores = torch.tensor([decoder_output_topk[0,i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = StochasticTopKUniformDecoder(encoder, decoder, 2)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > Hello
# Bot: yea i love it . . . .
# > what?
# Bot: a little that looks ? . .
# > looks what
# Bot: the boat is made of regular model . . .
# > which boat?
# Bot: disney frozen complete story playset . so .
# > ?
# Bot: i do believe so . my son .
# > q

# %% [markdown]
# I like this model a lot more than the previous version since it feels a lot more like a person speaking. Sometimes it doesnt make too much sense but compared to the previous model I feel like they make about the same amount of sense.
#
# I think there is more we can do to explore this stochastic model instead of the greedy model, for example, instead of uniformly at random choosing the next word based off of the top k choices, randomly choose the next word based on the scores of the top k choices. So, more like a sample with a given distrubution that just uniformly at random. This might slightly create better sentences, but introduce slightly less randomness than the uniform case since better words are more likely to be chosen than worse words like in the previous case.
#
# Another idea is to only randomly choose the first word based of the top k choices then let the bot make up a new sentence based on that random first word. The reason this might be a better idea is because when the bot has a k value too large (even 5 is too large) it sort of rambles and makes weird run-on/long sentences. I found that a k value of 2 worked best for uniform random word choice model but this might be different for for the random sample choice model.

# %% [markdown]
# ### Experiment 2

# %% [markdown]
# In the following implementation we choose one of the top k responses from our model at each word by sampling. This version uses how good the response is as a measure of how likely it should be to be chosen.

# %%
class StochasticTopKSampleDecoder(nn.Module):
    def __init__(self, encoder, decoder, k):
        super(StochasticTopKSampleDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            # sample choice of word from the top k words at each word
            # in the sentence
            decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
            decoder_output_topk = decoder_output_topk.cpu().detach().numpy().flatten()
            ind = ind.cpu().detach().numpy().flatten()
            probabilities = decoder_output_topk/np.sum(decoder_output_topk)
            value = np.random.choice(ind, 1, p=probabilities)
            i = np.where(ind == value[0])[0][0]
            decoder_input = torch.tensor([ind[i]]).to(device)
            decoder_scores = torch.tensor([decoder_output_topk[i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = StochasticTopKSampleDecoder(encoder, decoder, 5)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > Hello
# Bot: yes . and love it .
# > .
# Bot: they are not and well !
# > what are you talking about?
# Bot: each clothes ! two and well grandson .
# > q

# %% [markdown]
# For these sentences to be as good as the previous version we must increase k a little bit, but nothing seems too weird. Some more testing will have to be done tomorrow ...

# %% [markdown]
# ### Experiment 3

# %% [markdown]
# This evaluation code works the same as the sampling code except now it only samples for the first n words before becoming greedy for the remainder of words. This is to ensure that we get a bit of a random start of the sentence then the model chooses the best combination of words after that random initialization.

# %%
class StochasticSentenceInitializerSamplingDecoder(nn.Module):
    def __init__(self, encoder, decoder, k, n):
        super(StochasticSentenceInitializerSamplingDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k
        self.n = n

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for i in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            if i >= self.n:
                # be greedy >:)
                decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            else:
                # sample choice of word from the top k words at each word
                # in the sentence
                decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
                decoder_output_topk = decoder_output_topk.cpu().detach().numpy().flatten()
                ind = ind.cpu().detach().numpy().flatten()
                probabilities = decoder_output_topk/np.sum(decoder_output_topk)
                value = np.random.choice(ind, 1, p=probabilities)
                i = np.where(ind == value[0])[0][0]
                decoder_input = torch.tensor([ind[i]]).to(device)
                decoder_scores = torch.tensor([decoder_output_topk[i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = StochasticSentenceInitializerSamplingDecoder(encoder, decoder, 5, 3)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)

# %% [markdown]
# This is a nice in between of always randomly choosing words and the greedy approach. One of the things that I noticed from this experiment is that the best responces arent necessarily ones that have the greedy approach will get. For example, one of the trainings I had were as follows:
# ```text
# hi
# Bot: hi . a little . . .
# hi
# Bot: hi . a little . . .
# hi
# Bot: hello . stan . a minute .
# hi
# Bot: oh hi how d your day go ? ?
# hi
# Bot: hi . a little . . .
# hi
# Bot: hi . a little . . .
# ```
# The 4th response from the bot was incredible good, but how do we get this from the bot more often then the other greedy words with a stochastic or other method?

# %% [markdown]
# ### Experiment 4

# %%
class StochasticSentenceInitializerUniformDecoder(nn.Module):
    def __init__(self, encoder, decoder, k, n):
        super(StochasticSentenceInitializerUniformDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k
        self.n = n

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for i in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            if i >= self.n:
                # be greedy >:)
                decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            else:
                # sample choice of word from the top k words at each word
                # in the sentence (uniformly at random)
                decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
                i = int(random.random()*self.k)
                decoder_input = torch.tensor([ind[0,i]]).to(device)
                decoder_scores = torch.tensor([decoder_output_topk[0,i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = StochasticSentenceInitializerSamplingDecoder(encoder, decoder, 10, 3)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)

# %% [markdown]
# This model seems to work just like the previous one, however less random. I think this model is only just a bit better than the greedy approach. There is very little in terms of differences so maybe one thing that could be done to improve the performance of htis model is to make the first n words randomly selected then let the greedy approach kick in. I think that this could be good for making the bot a bit more random, but not too random to the point where nothing makes sense.

# %% [markdown]
# ### Results

# %% [markdown]
# Before moving on to more complicated models, playing around with maybe trying to come of with a way to score these sentences as good or bad responses could help.
#
# Currently these evaluation methods perform as follows (from best to worst):
# ```text
# 1. StochasticTopKUniformDecoder
# 2. StochasticSentenceInitializerSamplingDecoder
# 3. StochasticSentenceInitializerUniformDecoder
# 4. StochasticTopKSampleDecoder
# ```

# %% [markdown]
# # Questions

# %% [markdown]
# What are the best ways to evaluate the model?
#
# 1. Is it possible to first try to evaluate the models based on single responses?
#
# Not really, since responses might be more noisy. Instead, professor suggested having just two images of conversations, side by side and have a users say what conversation they would prefer to continue, the left image or the right image.
#
# 2. When doing this left-right conversation question, is it helpful to only include conversations of human-human and human-bot or should we also include human-human and bot-bot?
