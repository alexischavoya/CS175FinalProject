# %% [markdown]
# # ChatBot References
#
# Professor Smyth's website discussing projects
#
# https://www.ics.uci.edu/~smyth/courses/cs175/project_reading.html
#
# Chatbot resources on website
#
# https://pytorch.org/tutorials/beginner/chatbot_tutorial.html
#
# https://web.stanford.edu/~jurafsky/slp3/26.pdf
#
# https://www.microsoft.com/en-us/research/wp-content/uploads/2016/12/CortanaLUDialog-FromSLTproceedings.pdf
#
# Dataset for tutorial
#
# https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html

# %% [markdown]
# # Start of Tutorial

# %% [markdown]
# ### Import necessary libraries

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# ### Preprocess Data

# %% [markdown]
# Looking at some files in the data to see how they are structured ...

# %%
corpus_name = "cornell movie-dialogs corpus"
corpus = os.path.join("data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "movie_lines.txt"))
# Out:
# b'L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!\n'
# b'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!\n'
# b'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.\n'
# b'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?\n'
# b"L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.\n"
# b'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow\n'
# b"L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.\n"
# b'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No\n'
# b'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?\n'
# b'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?\n'

# %% [markdown]
# Scan through data files and reformat them to be (sentence, response) pairs separated by a tab eventually. First we create helper functions to help clean up the data a bit and make it more readable ...

# %%
# Splits each line of the file into a dictionary of fields
def loadLines(fileName, fields):
    lines = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            lineObj = {}
            for i, field in enumerate(fields):
                lineObj[field] = values[i]
            lines[lineObj['lineID']] = lineObj
    return lines


# Groups fields of lines from `loadLines` into conversations based on *movie_conversations.txt*
def loadConversations(fileName, lines, fields):
    conversations = []
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            convObj = {}
            for i, field in enumerate(fields):
                convObj[field] = values[i]
            # Convert string to list (convObj["utteranceIDs"] == "['L598485', 'L598486', ...]")
            utterance_id_pattern = re.compile('L[0-9]+')
            lineIds = utterance_id_pattern.findall(convObj["utteranceIDs"])
            # Reassemble lines
            convObj["lines"] = []
            for lineId in lineIds:
                convObj["lines"].append(lines[lineId])
            conversations.append(convObj)
    return conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations:
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Next we will be using the functions above we now parse the data into a form that is useful to us and see what a few lines from the data look like ...

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict, conversations list, and field ids
lines = {}
conversations = []
MOVIE_LINES_FIELDS = ["lineID", "characterID", "movieID", "character", "text"]
MOVIE_CONVERSATIONS_FIELDS = ["character1ID", "character2ID", "movieID", "utteranceIDs"]

# Load lines and process conversations
print("\nProcessing corpus...")
lines = loadLines(os.path.join(corpus, "movie_lines.txt"), MOVIE_LINES_FIELDS)
print("\nLoading conversations...")
conversations = loadConversations(os.path.join(corpus, "movie_conversations.txt"),
                                  lines, MOVIE_CONVERSATIONS_FIELDS)

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus...
#
# Loading conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b"Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.\tWell, I thought we'd start with pronunciation, if that's okay with you.\r\n"
# b"Well, I thought we'd start with pronunciation, if that's okay with you.\tNot the hacking and gagging and spitting part.  Please.\r\n"
# b"Not the hacking and gagging and spitting part.  Please.\tOkay... then how 'bout we try out some French cuisine.  Saturday?  Night?\r\n"
# b"You're asking me out.  That's so cute. What's your name again?\tForget it.\r\n"
# b"No, no, it's my fault -- we didn't have a proper introduction ---\tCameron.\r\n"
# b"Cameron.\tThe thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\r\n"
# b"The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\tSeems like she could get a date easy enough...\r\n"
# b'Why?\tUnsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\r\n'
# b"Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\tThat's a shame.\r\n"
# b'Gosh, if only we could find Kat a boyfriend...\tLet me see what I can do.\r\n'

# %% [markdown]
# We want to create a vocabulary of words that we see. We represent these words numerically using the index of their first appearance in the history of all added words to the set of vocuabulary. See `addWord()` for specifics.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we finally getting to the part where we begin to make the (sentence, response) pairs. We begin preprocessing by converting the Unicode string texts to ASCII `unicodeToAscii()`. We also make everything lower case, and remove nonletters except for basic punctuation `normalizeString()`. The last thing that is done in preprocessing is ignore sentences beyond a certain length to aid in training `filterPair()` and `MAX_LENGTH`.

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64271 sentence pairs
# Counting words...
# Counted words: 18008
#
# pairs:
# ['there .', 'where ?']
# ['you have my word . as a gentleman', 'you re sweet .']
# ['hi .', 'looks like things worked out tonight huh ?']
# ['you know chastity ?', 'i believe we share an art instructor']
# ['have fun tonight ?', 'tons']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['what good stuff ?', 'the real you .']

# %% [markdown]
# Another way to speed up training is by removing words that are rarely used. We "trim" these words using `Voc.trim()` and as a result must also remove (sentence, response) pairs that include these words.

# %%
MIN_COUNT = 10    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 2869 / 18005 = 0.1593
# Trimmed from 64271 pairs to 38681, 0.6018 of total

# %% [markdown]
# ### Using our Data on our Models

# %% [markdown]
# The data still needs to be processed more. The model that we use will take numerical values and not actual strings to do computation. We convert our sentences to tensors (vectors) that our model will take as inputs. To do this, we just take every sentence and change it to be a vector of index that corresponds to that word. This is how we will use our data to train the model.
#
# If we would like to train our model we usually do it with minbatches since it makes things faster. We make a matrix of dimensions (BatchLength, MaxLengthOfSentenceInBatch) represented numerically as mentioned in the previous paragraph. With this we make sure that each row (sentence) of our matrix terminates with `EOS_Token` and is followed by 0 entries until the end of the row.
#
# This implementation almost works, the problem with this is that each row is a sentence and every column is a step in time. However, it is better to think of every row as a step in time and the column to be possible words to choose for that step in time. For this reason, we construct the Matrix as mentioned in the previous paragraph except it is now transposed.
#
# We define some function that help us achieve this ...

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[  65,    7,   45,   35,  798],
#         [ 246,  138,    7,   36,    4],
#         [ 132,   81,  332,  258,    2],
#         [ 582,   51,   81,    4,    0],
#         [ 258, 2104,    6,    2,    0],
#         [1218,    4,    2,    0,    0],
#         [2147,    2,    0,    0,    0],
#         [   4,    0,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([9, 7, 6, 5, 3])
# target_variable: tensor([[  25,   51,   54,   35,  403],
#         [ 130,   48,  710,   36, 1218],
#         [ 289,    6,    4,   12, 1219],
#         [1317,    2,    2, 2210,    4],
#         [ 507,    0,    0,  181,    2],
#         [   4,    0,    0,  253,    0],
#         [   2,    0,    0,    4,    0],
#         [   0,    0,    0,    2,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False, False,  True,  True],
#         [ True, False, False,  True, False],
#         [ True, False, False,  True, False],
#         [False, False, False,  True, False]])
# max_target_len: 8

# %% [markdown]
# Seeing the output from preping the data above, it appears that `input_variable` is the matrix described in the previous secsion. `lenghts` is just a tensor (vector) of how long the sentences in the input were. This will eventually be used for the **decoder** later in the program. `target_variable` seems to be the response that our model is supposed to learn. `mask` looks like it is a mask for responses where true is that there is a word and false is that there is no word there. Not sure why this variable is necessary but maybe it will become clearer at some point in the tutorial.

# %% [markdown]
# ### Defining our Model

# %% [markdown]
# Our base model is a Sequence-to-Sequence model using two RNN's. The first RNN is what is called the **encoder** and it takes a variable length input and converts it into a *fixed length* "context" vector that is intended to hold onto some semantic meaning of the input. The **decoder** takes the context vector provided by the decoder along with an input word to guess the next word in a sequence. I suppose our (sentence, response) pairs are learned as one long continuous sequence where the sentence is the start of hte sequence and the response is the remainder of the sequence, though this might be entirely incorrect.

# %% [markdown]
# Some discussion on the Encoder. The encoder uses a bidirectional GRU (Gated Recurrent Unit), meaning that there is basically two RNN's that make up the encoder, one that goes through the sequence of data in the forward direction while another RNN goes through the sequence in the backward direction. At each time step, both RNN's produce an output and a hidden state vector. At each time step, the output of both RNNs are summed and the output is recorded (somewhere) while the hidden state vectors are pushed along and used in the next step of the RNN. The outputs are summed makes it so that at each time step, the RNN is considering present and future context.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.LSTM(hidden_size,hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Some discussion on the Decoder. The decoder uses the context vector that is produced by the encoder. Usually, this is all that will be used by a decoder to produce output but this can result in a loss of information, expecially when the input sentences are very long. To counter this, the decoder also uses its current hidden state as a way of determining what it should be "paying attention" to. These are refered to as attention weights and are multiplied by the outputs from the encoder (the output that is apperantly recorded somewhere, this is where they are used) from the current time step to rescale the values, making less important parts of the encoder output smaller and more important parts of the encoder output larger. This can be further improved by using all of the encoder outputs instead of just the one of the current time step to have a more comprehensive set of attention weights. This is the method implemented below, followed by the implementation of the decoder using this attention method.

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.LSTM(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# ### Defining the Training Procedure

# %% [markdown]
# Recall earlier in the `mask` produced along side the `target_variable` was produced for an unknown purpose, it turns out its purpose is for determining the loss of the model. This implementation below is the negative-log-likelihood loss and the variable `mask` along with `target_variable`.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# For training the model, two tricks are used to help convergence. The first trick is refered to as "teacher forcing" which just overrides the prediction of the decoder and uses the actual target value instead, this happens with some small probability p. Doing it too much will make the decoder unable to make predictions on its own and not having this feature will make it so that convergence is just slower. The second trick they do is gradient clipping, meaning that at areas in the feature space where there is a steep gradient and therefore a chance to improve the model very fast, the magnitude of the gradient is limited some value. This is to not drastically overshoot local minima on "cliffs". The training function is implemented below. This trains only one iteration.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
        #Get the encoder final h_hidden_state
    encoder_h_hidden, encoder_c_hidden = encoder_hidden
    decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
    decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
    # Recombine the final hidden states as hidden tuple
    decoder_hidden = (decoder_h_hidden, decoder_c_hidden)

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# This version of the training function trains on multiple iterations. It is built on the previous training function. This function also saves the current variables in a tarball file. This is to continue training at a later period or just use the current accumulated training to make predictions.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, 
               encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, 
               clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(
                iteration, iteration / n_iteration * 100, print_loss_avg
            ))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(
                encoder_n_layers, decoder_n_layers, hidden_size
            ))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# ### Defining Evaluation

# %% [markdown]
# This is the training method used by our bot when we are not using the "teacher forcing" method. This just basically chooses the output of hte decoder to be the output with the highest softmax score, ie the best response given its prior training. I think this is defining a decoder method for whenever we are actually using our model instead of when it is training.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# The `evaluateInput` function is meant to take input from the user, prepare it so that it may be fed to our model, and pring out the response from our bot. `evaluate` handles most of hte actual calculation while `evaluateInput` handles most of the user interaction phase.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    #lengths = lengths.to(device) # removed bc of gpu cpu tensor difference ###################################
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words), len(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# ### Running the Model

# %% [markdown]
# This defines and builds our model based on the following parameters. Notice that parts of the code are commented out as these are other possibilities ofr initialization. attn_model can be given one of three different models. We can also choose to load a model that we previously trained.

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
# attn_model = 'general'
# attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Now we train our model using `trainIters`. We first set some training parameters and initialize optimizers and prepare our model for training. Training is likely to take a very long time, thankfully there is the option to load from a previous model and this piece of code here doesn't need to be run every time.

# %%
# Safty precaution so that we dont accidentally begin training a model we didnt want to train
TRAIN_THE_MODEL = True

# %%
if TRAIN_THE_MODEL:
    
    # Configure training/optimization
    clip = 50.0
    teacher_forcing_ratio = 1.0
    learning_rate = 0.0001
    decoder_learning_ratio = 5.0
    n_iteration = 5000
    print_every = 1
    save_every = 2000

    # Ensure dropout layers are in train mode
    encoder.train()
    decoder.train()

    # Initialize optimizers
    print('Building optimizers ...')
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
    if loadFilename:
        encoder_optimizer.load_state_dict(encoder_optimizer_sd)
        decoder_optimizer.load_state_dict(decoder_optimizer_sd)

    # If you have cuda, configure cuda to call
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    # Run training iterations
    print("Starting Training!")
    trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
               embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
               print_every, save_every, clip, corpus_name, loadFilename)
    
    TRAIN_THE_MODEL = False

else:
    
    print(f"Make the variable 'TRAIN_THE_MODEL' in the code block above True and run the code block")
    print(f"Value of 'TRAIN_THE_MODEL' currently: {TRAIN_THE_MODEL}")
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 7.9593
# Iteration: 2; Percent complete: 0.0%; Average loss: 7.9163
# Iteration: 3; Percent complete: 0.1%; Average loss: 7.8661
# Iteration: 4; Percent complete: 0.1%; Average loss: 7.7844
# Iteration: 5; Percent complete: 0.1%; Average loss: 7.6542
# Iteration: 6; Percent complete: 0.1%; Average loss: 7.3791
# Iteration: 7; Percent complete: 0.1%; Average loss: 7.0492
# Iteration: 8; Percent complete: 0.2%; Average loss: 6.4180
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.1644
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.1926
# Iteration: 11; Percent complete: 0.2%; Average loss: 5.9613
# Iteration: 12; Percent complete: 0.2%; Average loss: 5.7327
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.5210
# Iteration: 14; Percent complete: 0.3%; Average loss: 5.1009
# Iteration: 15; Percent complete: 0.3%; Average loss: 5.2959
# Iteration: 16; Percent complete: 0.3%; Average loss: 4.9962
# Iteration: 17; Percent complete: 0.3%; Average loss: 4.9767
# Iteration: 18; Percent complete: 0.4%; Average loss: 4.7583
# Iteration: 19; Percent complete: 0.4%; Average loss: 5.1028
# Iteration: 20; Percent complete: 0.4%; Average loss: 4.6178
# Iteration: 21; Percent complete: 0.4%; Average loss: 4.7415
# Iteration: 22; Percent complete: 0.4%; Average loss: 4.8083
# Iteration: 23; Percent complete: 0.5%; Average loss: 4.6840
# Iteration: 24; Percent complete: 0.5%; Average loss: 4.9880
# Iteration: 25; Percent complete: 0.5%; Average loss: 4.9022
# Iteration: 26; Percent complete: 0.5%; Average loss: 4.6451
# Iteration: 27; Percent complete: 0.5%; Average loss: 4.6905
# Iteration: 28; Percent complete: 0.6%; Average loss: 4.6408
# Iteration: 29; Percent complete: 0.6%; Average loss: 4.4619
# Iteration: 30; Percent complete: 0.6%; Average loss: 4.6700
# Iteration: 31; Percent complete: 0.6%; Average loss: 4.7011
# Iteration: 32; Percent complete: 0.6%; Average loss: 4.5854
# Iteration: 33; Percent complete: 0.7%; Average loss: 4.7514
# Iteration: 34; Percent complete: 0.7%; Average loss: 4.6111
# Iteration: 35; Percent complete: 0.7%; Average loss: 4.5524
# Iteration: 36; Percent complete: 0.7%; Average loss: 4.7273
# Iteration: 37; Percent complete: 0.7%; Average loss: 4.5918
# Iteration: 38; Percent complete: 0.8%; Average loss: 4.4908
# Iteration: 39; Percent complete: 0.8%; Average loss: 4.4516
# Iteration: 40; Percent complete: 0.8%; Average loss: 4.5978
# Iteration: 41; Percent complete: 0.8%; Average loss: 4.5338
# Iteration: 42; Percent complete: 0.8%; Average loss: 4.1946
# Iteration: 43; Percent complete: 0.9%; Average loss: 4.4458
# Iteration: 44; Percent complete: 0.9%; Average loss: 4.5635
# Iteration: 45; Percent complete: 0.9%; Average loss: 4.4431
# Iteration: 46; Percent complete: 0.9%; Average loss: 4.5028
# Iteration: 47; Percent complete: 0.9%; Average loss: 4.7619
# Iteration: 48; Percent complete: 1.0%; Average loss: 4.4844
# Iteration: 49; Percent complete: 1.0%; Average loss: 4.5460
# Iteration: 50; Percent complete: 1.0%; Average loss: 4.4026
# Iteration: 51; Percent complete: 1.0%; Average loss: 4.6283
# Iteration: 52; Percent complete: 1.0%; Average loss: 4.5004
# Iteration: 53; Percent complete: 1.1%; Average loss: 4.3496
# Iteration: 54; Percent complete: 1.1%; Average loss: 4.3405
# Iteration: 55; Percent complete: 1.1%; Average loss: 4.1656
# Iteration: 56; Percent complete: 1.1%; Average loss: 4.3365
# Iteration: 57; Percent complete: 1.1%; Average loss: 4.5202
# Iteration: 58; Percent complete: 1.2%; Average loss: 4.3446
# Iteration: 59; Percent complete: 1.2%; Average loss: 4.3660
# Iteration: 60; Percent complete: 1.2%; Average loss: 4.4738
# Iteration: 61; Percent complete: 1.2%; Average loss: 4.2903
# Iteration: 62; Percent complete: 1.2%; Average loss: 4.3751
# Iteration: 63; Percent complete: 1.3%; Average loss: 4.4585
# Iteration: 64; Percent complete: 1.3%; Average loss: 4.4229
# Iteration: 65; Percent complete: 1.3%; Average loss: 4.2249
# Iteration: 66; Percent complete: 1.3%; Average loss: 4.4251
# Iteration: 67; Percent complete: 1.3%; Average loss: 4.5281
# Iteration: 68; Percent complete: 1.4%; Average loss: 4.2366
# Iteration: 69; Percent complete: 1.4%; Average loss: 4.5420
# Iteration: 70; Percent complete: 1.4%; Average loss: 4.4834
# Iteration: 71; Percent complete: 1.4%; Average loss: 4.3646
# Iteration: 72; Percent complete: 1.4%; Average loss: 4.3780
# Iteration: 73; Percent complete: 1.5%; Average loss: 4.3160
# Iteration: 74; Percent complete: 1.5%; Average loss: 4.4314
# Iteration: 75; Percent complete: 1.5%; Average loss: 4.4024
# Iteration: 76; Percent complete: 1.5%; Average loss: 4.1845
# Iteration: 77; Percent complete: 1.5%; Average loss: 4.1814
# Iteration: 78; Percent complete: 1.6%; Average loss: 4.3035
# Iteration: 79; Percent complete: 1.6%; Average loss: 4.6380
# Iteration: 80; Percent complete: 1.6%; Average loss: 4.1360
# Iteration: 81; Percent complete: 1.6%; Average loss: 4.2634
# Iteration: 82; Percent complete: 1.6%; Average loss: 4.3250
# Iteration: 83; Percent complete: 1.7%; Average loss: 4.2391
# Iteration: 84; Percent complete: 1.7%; Average loss: 4.6243
# Iteration: 85; Percent complete: 1.7%; Average loss: 4.2170
# Iteration: 86; Percent complete: 1.7%; Average loss: 4.1982
# Iteration: 87; Percent complete: 1.7%; Average loss: 4.1370
# Iteration: 88; Percent complete: 1.8%; Average loss: 4.3459
# Iteration: 89; Percent complete: 1.8%; Average loss: 4.3775
# Iteration: 90; Percent complete: 1.8%; Average loss: 4.2787
# Iteration: 91; Percent complete: 1.8%; Average loss: 4.1846
# Iteration: 92; Percent complete: 1.8%; Average loss: 4.3369
# Iteration: 93; Percent complete: 1.9%; Average loss: 4.5173
# Iteration: 94; Percent complete: 1.9%; Average loss: 4.2788
# Iteration: 95; Percent complete: 1.9%; Average loss: 4.2082
# Iteration: 96; Percent complete: 1.9%; Average loss: 4.2737
# Iteration: 97; Percent complete: 1.9%; Average loss: 4.3080
# Iteration: 98; Percent complete: 2.0%; Average loss: 4.1404
# Iteration: 99; Percent complete: 2.0%; Average loss: 4.1314
# Iteration: 100; Percent complete: 2.0%; Average loss: 4.2248
# Iteration: 101; Percent complete: 2.0%; Average loss: 4.1466
# Iteration: 102; Percent complete: 2.0%; Average loss: 4.1726
# Iteration: 103; Percent complete: 2.1%; Average loss: 4.4095
# Iteration: 104; Percent complete: 2.1%; Average loss: 4.2826
# Iteration: 105; Percent complete: 2.1%; Average loss: 4.1218
# Iteration: 106; Percent complete: 2.1%; Average loss: 4.2897
# Iteration: 107; Percent complete: 2.1%; Average loss: 4.0545
# Iteration: 108; Percent complete: 2.2%; Average loss: 4.2983
# Iteration: 109; Percent complete: 2.2%; Average loss: 4.2952
# Iteration: 110; Percent complete: 2.2%; Average loss: 4.1736
# Iteration: 111; Percent complete: 2.2%; Average loss: 4.3088
# Iteration: 112; Percent complete: 2.2%; Average loss: 4.1103
# Iteration: 113; Percent complete: 2.3%; Average loss: 4.2963
# Iteration: 114; Percent complete: 2.3%; Average loss: 4.2292
# Iteration: 115; Percent complete: 2.3%; Average loss: 4.1714
# Iteration: 116; Percent complete: 2.3%; Average loss: 4.1849
# Iteration: 117; Percent complete: 2.3%; Average loss: 4.2705
# Iteration: 118; Percent complete: 2.4%; Average loss: 4.1963
# Iteration: 119; Percent complete: 2.4%; Average loss: 3.9332
# Iteration: 120; Percent complete: 2.4%; Average loss: 3.9672
# Iteration: 121; Percent complete: 2.4%; Average loss: 4.1705
# Iteration: 122; Percent complete: 2.4%; Average loss: 3.9909
# Iteration: 123; Percent complete: 2.5%; Average loss: 4.0562
# Iteration: 124; Percent complete: 2.5%; Average loss: 4.0697
# Iteration: 125; Percent complete: 2.5%; Average loss: 4.0377
# Iteration: 126; Percent complete: 2.5%; Average loss: 4.0504
# Iteration: 127; Percent complete: 2.5%; Average loss: 4.1424
# Iteration: 128; Percent complete: 2.6%; Average loss: 3.8824
# Iteration: 129; Percent complete: 2.6%; Average loss: 4.0792
# Iteration: 130; Percent complete: 2.6%; Average loss: 4.2488
# Iteration: 131; Percent complete: 2.6%; Average loss: 4.1612
# Iteration: 132; Percent complete: 2.6%; Average loss: 4.2220
# Iteration: 133; Percent complete: 2.7%; Average loss: 4.2466
# Iteration: 134; Percent complete: 2.7%; Average loss: 4.1289
# Iteration: 135; Percent complete: 2.7%; Average loss: 4.0283
# Iteration: 136; Percent complete: 2.7%; Average loss: 4.0404
# Iteration: 137; Percent complete: 2.7%; Average loss: 4.0546
# Iteration: 138; Percent complete: 2.8%; Average loss: 4.0738
# Iteration: 139; Percent complete: 2.8%; Average loss: 4.2626
# Iteration: 140; Percent complete: 2.8%; Average loss: 4.0095
# Iteration: 141; Percent complete: 2.8%; Average loss: 4.0648
# Iteration: 142; Percent complete: 2.8%; Average loss: 4.1093
# Iteration: 143; Percent complete: 2.9%; Average loss: 4.2627
# Iteration: 144; Percent complete: 2.9%; Average loss: 4.2479
# Iteration: 145; Percent complete: 2.9%; Average loss: 3.8643
# Iteration: 146; Percent complete: 2.9%; Average loss: 4.1709
# Iteration: 147; Percent complete: 2.9%; Average loss: 4.0260
# Iteration: 148; Percent complete: 3.0%; Average loss: 4.1082
# Iteration: 149; Percent complete: 3.0%; Average loss: 4.1793
# Iteration: 150; Percent complete: 3.0%; Average loss: 4.1311
# Iteration: 151; Percent complete: 3.0%; Average loss: 4.1266
# Iteration: 152; Percent complete: 3.0%; Average loss: 4.0362
# Iteration: 153; Percent complete: 3.1%; Average loss: 3.9646
# Iteration: 154; Percent complete: 3.1%; Average loss: 4.0502
# Iteration: 155; Percent complete: 3.1%; Average loss: 3.8884
# Iteration: 156; Percent complete: 3.1%; Average loss: 4.0274
# Iteration: 157; Percent complete: 3.1%; Average loss: 4.0251
# Iteration: 158; Percent complete: 3.2%; Average loss: 3.9713
# Iteration: 159; Percent complete: 3.2%; Average loss: 3.9799
# Iteration: 160; Percent complete: 3.2%; Average loss: 3.8289
# Iteration: 161; Percent complete: 3.2%; Average loss: 4.0633
# Iteration: 162; Percent complete: 3.2%; Average loss: 4.1240
# Iteration: 163; Percent complete: 3.3%; Average loss: 4.1508
# Iteration: 164; Percent complete: 3.3%; Average loss: 4.1521
# Iteration: 165; Percent complete: 3.3%; Average loss: 4.0744
# Iteration: 166; Percent complete: 3.3%; Average loss: 3.8076
# Iteration: 167; Percent complete: 3.3%; Average loss: 3.9725
# Iteration: 168; Percent complete: 3.4%; Average loss: 3.9314
# Iteration: 169; Percent complete: 3.4%; Average loss: 4.1760
# Iteration: 170; Percent complete: 3.4%; Average loss: 4.0411
# Iteration: 171; Percent complete: 3.4%; Average loss: 3.9377
# Iteration: 172; Percent complete: 3.4%; Average loss: 3.9334
# Iteration: 173; Percent complete: 3.5%; Average loss: 4.1416
# Iteration: 174; Percent complete: 3.5%; Average loss: 3.9321
# Iteration: 175; Percent complete: 3.5%; Average loss: 4.0546
# Iteration: 176; Percent complete: 3.5%; Average loss: 3.9057
# Iteration: 177; Percent complete: 3.5%; Average loss: 4.0717
# Iteration: 178; Percent complete: 3.6%; Average loss: 4.1720
# Iteration: 179; Percent complete: 3.6%; Average loss: 3.8998
# Iteration: 180; Percent complete: 3.6%; Average loss: 4.1115
# Iteration: 181; Percent complete: 3.6%; Average loss: 4.1534
# Iteration: 182; Percent complete: 3.6%; Average loss: 3.9833
# Iteration: 183; Percent complete: 3.7%; Average loss: 4.0720
# Iteration: 184; Percent complete: 3.7%; Average loss: 3.9080
# Iteration: 185; Percent complete: 3.7%; Average loss: 3.8466
# Iteration: 186; Percent complete: 3.7%; Average loss: 3.8438
# Iteration: 187; Percent complete: 3.7%; Average loss: 4.1618
# Iteration: 188; Percent complete: 3.8%; Average loss: 4.1969
# Iteration: 189; Percent complete: 3.8%; Average loss: 4.2139
# Iteration: 190; Percent complete: 3.8%; Average loss: 4.0666
# Iteration: 191; Percent complete: 3.8%; Average loss: 4.2118
# Iteration: 192; Percent complete: 3.8%; Average loss: 4.0316
# Iteration: 193; Percent complete: 3.9%; Average loss: 3.7376
# Iteration: 194; Percent complete: 3.9%; Average loss: 3.8202
# Iteration: 195; Percent complete: 3.9%; Average loss: 3.9536
# Iteration: 196; Percent complete: 3.9%; Average loss: 3.8974
# Iteration: 197; Percent complete: 3.9%; Average loss: 3.9849
# Iteration: 198; Percent complete: 4.0%; Average loss: 4.1471
# Iteration: 199; Percent complete: 4.0%; Average loss: 4.0184
# Iteration: 200; Percent complete: 4.0%; Average loss: 4.1246
# Iteration: 201; Percent complete: 4.0%; Average loss: 4.1584
# Iteration: 202; Percent complete: 4.0%; Average loss: 3.9533
# Iteration: 203; Percent complete: 4.1%; Average loss: 4.0988
# Iteration: 204; Percent complete: 4.1%; Average loss: 3.9235
# Iteration: 205; Percent complete: 4.1%; Average loss: 3.6644
# Iteration: 206; Percent complete: 4.1%; Average loss: 4.0081
# Iteration: 207; Percent complete: 4.1%; Average loss: 4.0970
# Iteration: 208; Percent complete: 4.2%; Average loss: 3.7583
# Iteration: 209; Percent complete: 4.2%; Average loss: 4.0296
# Iteration: 210; Percent complete: 4.2%; Average loss: 3.7465
# Iteration: 211; Percent complete: 4.2%; Average loss: 3.7886
# Iteration: 212; Percent complete: 4.2%; Average loss: 4.1160
# Iteration: 213; Percent complete: 4.3%; Average loss: 4.0313
# Iteration: 214; Percent complete: 4.3%; Average loss: 4.0219
# Iteration: 215; Percent complete: 4.3%; Average loss: 4.1140
# Iteration: 216; Percent complete: 4.3%; Average loss: 4.2181
# Iteration: 217; Percent complete: 4.3%; Average loss: 4.0450
# Iteration: 218; Percent complete: 4.4%; Average loss: 3.7920
# Iteration: 219; Percent complete: 4.4%; Average loss: 4.0004
# Iteration: 220; Percent complete: 4.4%; Average loss: 4.0248
# Iteration: 221; Percent complete: 4.4%; Average loss: 4.0523
# Iteration: 222; Percent complete: 4.4%; Average loss: 3.9736
# Iteration: 223; Percent complete: 4.5%; Average loss: 3.8006
# Iteration: 224; Percent complete: 4.5%; Average loss: 3.9212
# Iteration: 225; Percent complete: 4.5%; Average loss: 4.0066
# Iteration: 226; Percent complete: 4.5%; Average loss: 4.0807
# Iteration: 227; Percent complete: 4.5%; Average loss: 3.8671
# Iteration: 228; Percent complete: 4.6%; Average loss: 3.8648
# Iteration: 229; Percent complete: 4.6%; Average loss: 4.0926
# Iteration: 230; Percent complete: 4.6%; Average loss: 3.7730
# Iteration: 231; Percent complete: 4.6%; Average loss: 3.6235
# Iteration: 232; Percent complete: 4.6%; Average loss: 3.9345
# Iteration: 233; Percent complete: 4.7%; Average loss: 3.9167
# Iteration: 234; Percent complete: 4.7%; Average loss: 4.0750
# Iteration: 235; Percent complete: 4.7%; Average loss: 3.9105
# Iteration: 236; Percent complete: 4.7%; Average loss: 3.7944
# Iteration: 237; Percent complete: 4.7%; Average loss: 4.0355
# Iteration: 238; Percent complete: 4.8%; Average loss: 3.8079
# Iteration: 239; Percent complete: 4.8%; Average loss: 3.8804
# Iteration: 240; Percent complete: 4.8%; Average loss: 3.9905
# Iteration: 241; Percent complete: 4.8%; Average loss: 3.9231
# Iteration: 242; Percent complete: 4.8%; Average loss: 4.0599
# Iteration: 243; Percent complete: 4.9%; Average loss: 3.7744
# Iteration: 244; Percent complete: 4.9%; Average loss: 3.8623
# Iteration: 245; Percent complete: 4.9%; Average loss: 3.7786
# Iteration: 246; Percent complete: 4.9%; Average loss: 3.9469
# Iteration: 247; Percent complete: 4.9%; Average loss: 3.9299
# Iteration: 248; Percent complete: 5.0%; Average loss: 3.9407
# Iteration: 249; Percent complete: 5.0%; Average loss: 4.0448
# Iteration: 250; Percent complete: 5.0%; Average loss: 3.8147
# Iteration: 251; Percent complete: 5.0%; Average loss: 3.9384
# Iteration: 252; Percent complete: 5.0%; Average loss: 3.5175
# Iteration: 253; Percent complete: 5.1%; Average loss: 4.0251
# Iteration: 254; Percent complete: 5.1%; Average loss: 3.8047
# Iteration: 255; Percent complete: 5.1%; Average loss: 3.8906
# Iteration: 256; Percent complete: 5.1%; Average loss: 3.8726
# Iteration: 257; Percent complete: 5.1%; Average loss: 3.7632
# Iteration: 258; Percent complete: 5.2%; Average loss: 4.0628
# Iteration: 259; Percent complete: 5.2%; Average loss: 3.7819
# Iteration: 260; Percent complete: 5.2%; Average loss: 3.5397
# Iteration: 261; Percent complete: 5.2%; Average loss: 3.9123
# Iteration: 262; Percent complete: 5.2%; Average loss: 3.7036
# Iteration: 263; Percent complete: 5.3%; Average loss: 3.8799
# Iteration: 264; Percent complete: 5.3%; Average loss: 3.8900
# Iteration: 265; Percent complete: 5.3%; Average loss: 3.9445
# Iteration: 266; Percent complete: 5.3%; Average loss: 3.8325
# Iteration: 267; Percent complete: 5.3%; Average loss: 3.9059
# Iteration: 268; Percent complete: 5.4%; Average loss: 3.8623
# Iteration: 269; Percent complete: 5.4%; Average loss: 3.6174
# Iteration: 270; Percent complete: 5.4%; Average loss: 3.6464
# Iteration: 271; Percent complete: 5.4%; Average loss: 3.8617
# Iteration: 272; Percent complete: 5.4%; Average loss: 3.7676
# Iteration: 273; Percent complete: 5.5%; Average loss: 3.6444
# Iteration: 274; Percent complete: 5.5%; Average loss: 4.0186
# Iteration: 275; Percent complete: 5.5%; Average loss: 3.9116
# Iteration: 276; Percent complete: 5.5%; Average loss: 3.8258
# Iteration: 277; Percent complete: 5.5%; Average loss: 4.0779
# Iteration: 278; Percent complete: 5.6%; Average loss: 3.6664
# Iteration: 279; Percent complete: 5.6%; Average loss: 3.7911
# Iteration: 280; Percent complete: 5.6%; Average loss: 3.9515
# Iteration: 281; Percent complete: 5.6%; Average loss: 3.5568
# Iteration: 282; Percent complete: 5.6%; Average loss: 3.8039
# Iteration: 283; Percent complete: 5.7%; Average loss: 3.9449
# Iteration: 284; Percent complete: 5.7%; Average loss: 3.5479
# Iteration: 285; Percent complete: 5.7%; Average loss: 3.8812
# Iteration: 286; Percent complete: 5.7%; Average loss: 3.9106
# Iteration: 287; Percent complete: 5.7%; Average loss: 3.8936
# Iteration: 288; Percent complete: 5.8%; Average loss: 3.6509
# Iteration: 289; Percent complete: 5.8%; Average loss: 3.8235
# Iteration: 290; Percent complete: 5.8%; Average loss: 3.7790
# Iteration: 291; Percent complete: 5.8%; Average loss: 3.7793
# Iteration: 292; Percent complete: 5.8%; Average loss: 3.9550
# Iteration: 293; Percent complete: 5.9%; Average loss: 3.6840
# Iteration: 294; Percent complete: 5.9%; Average loss: 4.0936
# Iteration: 295; Percent complete: 5.9%; Average loss: 3.7077
# Iteration: 296; Percent complete: 5.9%; Average loss: 3.6849
# Iteration: 297; Percent complete: 5.9%; Average loss: 3.7455
# Iteration: 298; Percent complete: 6.0%; Average loss: 4.0328
# Iteration: 299; Percent complete: 6.0%; Average loss: 3.7288
# Iteration: 300; Percent complete: 6.0%; Average loss: 3.6575
# Iteration: 301; Percent complete: 6.0%; Average loss: 3.8392
# Iteration: 302; Percent complete: 6.0%; Average loss: 3.9734
# Iteration: 303; Percent complete: 6.1%; Average loss: 3.7442
# Iteration: 304; Percent complete: 6.1%; Average loss: 3.5300
# Iteration: 305; Percent complete: 6.1%; Average loss: 3.3499
# Iteration: 306; Percent complete: 6.1%; Average loss: 3.6975
# Iteration: 307; Percent complete: 6.1%; Average loss: 3.8074
# Iteration: 308; Percent complete: 6.2%; Average loss: 3.9232
# Iteration: 309; Percent complete: 6.2%; Average loss: 3.4801
# Iteration: 310; Percent complete: 6.2%; Average loss: 3.7152
# Iteration: 311; Percent complete: 6.2%; Average loss: 3.5735
# Iteration: 312; Percent complete: 6.2%; Average loss: 3.8642
# Iteration: 313; Percent complete: 6.3%; Average loss: 3.5691
# Iteration: 314; Percent complete: 6.3%; Average loss: 4.2252
# Iteration: 315; Percent complete: 6.3%; Average loss: 3.6584
# Iteration: 316; Percent complete: 6.3%; Average loss: 3.6505
# Iteration: 317; Percent complete: 6.3%; Average loss: 3.8032
# Iteration: 318; Percent complete: 6.4%; Average loss: 3.7419
# Iteration: 319; Percent complete: 6.4%; Average loss: 3.6745
# Iteration: 320; Percent complete: 6.4%; Average loss: 3.9527
# Iteration: 321; Percent complete: 6.4%; Average loss: 3.5986
# Iteration: 322; Percent complete: 6.4%; Average loss: 3.7796
# Iteration: 323; Percent complete: 6.5%; Average loss: 3.7032
# Iteration: 324; Percent complete: 6.5%; Average loss: 3.6132
# Iteration: 325; Percent complete: 6.5%; Average loss: 3.3858
# Iteration: 326; Percent complete: 6.5%; Average loss: 3.5056
# Iteration: 327; Percent complete: 6.5%; Average loss: 3.6127
# Iteration: 328; Percent complete: 6.6%; Average loss: 3.6421
# Iteration: 329; Percent complete: 6.6%; Average loss: 3.6610
# Iteration: 330; Percent complete: 6.6%; Average loss: 3.4727
# Iteration: 331; Percent complete: 6.6%; Average loss: 3.3072
# Iteration: 332; Percent complete: 6.6%; Average loss: 3.8298
# Iteration: 333; Percent complete: 6.7%; Average loss: 3.6056
# Iteration: 334; Percent complete: 6.7%; Average loss: 3.6818
# Iteration: 335; Percent complete: 6.7%; Average loss: 3.6262
# Iteration: 336; Percent complete: 6.7%; Average loss: 3.5583
# Iteration: 337; Percent complete: 6.7%; Average loss: 3.8276
# Iteration: 338; Percent complete: 6.8%; Average loss: 3.7818
# Iteration: 339; Percent complete: 6.8%; Average loss: 3.3896
# Iteration: 340; Percent complete: 6.8%; Average loss: 3.8054
# Iteration: 341; Percent complete: 6.8%; Average loss: 3.7174
# Iteration: 342; Percent complete: 6.8%; Average loss: 3.5614
# Iteration: 343; Percent complete: 6.9%; Average loss: 3.7738
# Iteration: 344; Percent complete: 6.9%; Average loss: 3.7223
# Iteration: 345; Percent complete: 6.9%; Average loss: 3.5680
# Iteration: 346; Percent complete: 6.9%; Average loss: 3.8246
# Iteration: 347; Percent complete: 6.9%; Average loss: 3.5360
# Iteration: 348; Percent complete: 7.0%; Average loss: 3.6097
# Iteration: 349; Percent complete: 7.0%; Average loss: 3.7748
# Iteration: 350; Percent complete: 7.0%; Average loss: 3.8021
# Iteration: 351; Percent complete: 7.0%; Average loss: 3.7559
# Iteration: 352; Percent complete: 7.0%; Average loss: 3.7233
# Iteration: 353; Percent complete: 7.1%; Average loss: 3.5965
# Iteration: 354; Percent complete: 7.1%; Average loss: 3.5110
# Iteration: 355; Percent complete: 7.1%; Average loss: 3.7796
# Iteration: 356; Percent complete: 7.1%; Average loss: 3.7392
# Iteration: 357; Percent complete: 7.1%; Average loss: 3.5792
# Iteration: 358; Percent complete: 7.2%; Average loss: 3.5971
# Iteration: 359; Percent complete: 7.2%; Average loss: 3.8132
# Iteration: 360; Percent complete: 7.2%; Average loss: 3.9736
# Iteration: 361; Percent complete: 7.2%; Average loss: 3.8509
# Iteration: 362; Percent complete: 7.2%; Average loss: 3.7146
# Iteration: 363; Percent complete: 7.3%; Average loss: 3.4503
# Iteration: 364; Percent complete: 7.3%; Average loss: 3.3431
# Iteration: 365; Percent complete: 7.3%; Average loss: 3.4593
# Iteration: 366; Percent complete: 7.3%; Average loss: 3.9223
# Iteration: 367; Percent complete: 7.3%; Average loss: 3.6762
# Iteration: 368; Percent complete: 7.4%; Average loss: 3.6334
# Iteration: 369; Percent complete: 7.4%; Average loss: 3.7279
# Iteration: 370; Percent complete: 7.4%; Average loss: 3.7361
# Iteration: 371; Percent complete: 7.4%; Average loss: 3.4397
# Iteration: 372; Percent complete: 7.4%; Average loss: 3.7416
# Iteration: 373; Percent complete: 7.5%; Average loss: 3.6552
# Iteration: 374; Percent complete: 7.5%; Average loss: 3.6913
# Iteration: 375; Percent complete: 7.5%; Average loss: 3.5008
# Iteration: 376; Percent complete: 7.5%; Average loss: 3.6734
# Iteration: 377; Percent complete: 7.5%; Average loss: 3.8209
# Iteration: 378; Percent complete: 7.6%; Average loss: 3.6042
# Iteration: 379; Percent complete: 7.6%; Average loss: 3.8382
# Iteration: 380; Percent complete: 7.6%; Average loss: 3.7531
# Iteration: 381; Percent complete: 7.6%; Average loss: 3.7889
# Iteration: 382; Percent complete: 7.6%; Average loss: 3.6313
# Iteration: 383; Percent complete: 7.7%; Average loss: 3.8524
# Iteration: 384; Percent complete: 7.7%; Average loss: 3.4440
# Iteration: 385; Percent complete: 7.7%; Average loss: 3.6081
# Iteration: 386; Percent complete: 7.7%; Average loss: 3.5246
# Iteration: 387; Percent complete: 7.7%; Average loss: 3.5281
# Iteration: 388; Percent complete: 7.8%; Average loss: 3.8267
# Iteration: 389; Percent complete: 7.8%; Average loss: 3.7757
# Iteration: 390; Percent complete: 7.8%; Average loss: 3.5244
# Iteration: 391; Percent complete: 7.8%; Average loss: 3.4865
# Iteration: 392; Percent complete: 7.8%; Average loss: 3.6097
# Iteration: 393; Percent complete: 7.9%; Average loss: 3.6394
# Iteration: 394; Percent complete: 7.9%; Average loss: 3.5557
# Iteration: 395; Percent complete: 7.9%; Average loss: 3.9010
# Iteration: 396; Percent complete: 7.9%; Average loss: 3.5341
# Iteration: 397; Percent complete: 7.9%; Average loss: 3.5865
# Iteration: 398; Percent complete: 8.0%; Average loss: 3.6630
# Iteration: 399; Percent complete: 8.0%; Average loss: 3.8138
# Iteration: 400; Percent complete: 8.0%; Average loss: 3.7115
# Iteration: 401; Percent complete: 8.0%; Average loss: 3.4594
# Iteration: 402; Percent complete: 8.0%; Average loss: 3.6127
# Iteration: 403; Percent complete: 8.1%; Average loss: 3.5675
# Iteration: 404; Percent complete: 8.1%; Average loss: 3.5057
# Iteration: 405; Percent complete: 8.1%; Average loss: 3.6514
# Iteration: 406; Percent complete: 8.1%; Average loss: 3.5914
# Iteration: 407; Percent complete: 8.1%; Average loss: 3.5362
# Iteration: 408; Percent complete: 8.2%; Average loss: 3.3500
# Iteration: 409; Percent complete: 8.2%; Average loss: 3.5003
# Iteration: 410; Percent complete: 8.2%; Average loss: 3.7070
# Iteration: 411; Percent complete: 8.2%; Average loss: 3.6201
# Iteration: 412; Percent complete: 8.2%; Average loss: 3.4974
# Iteration: 413; Percent complete: 8.3%; Average loss: 3.6167
# Iteration: 414; Percent complete: 8.3%; Average loss: 3.6288
# Iteration: 415; Percent complete: 8.3%; Average loss: 3.4178
# Iteration: 416; Percent complete: 8.3%; Average loss: 3.4333
# Iteration: 417; Percent complete: 8.3%; Average loss: 3.8205
# Iteration: 418; Percent complete: 8.4%; Average loss: 3.6484
# Iteration: 419; Percent complete: 8.4%; Average loss: 3.4927
# Iteration: 420; Percent complete: 8.4%; Average loss: 3.4783
# Iteration: 421; Percent complete: 8.4%; Average loss: 3.8243
# Iteration: 422; Percent complete: 8.4%; Average loss: 3.7140
# Iteration: 423; Percent complete: 8.5%; Average loss: 3.6752
# Iteration: 424; Percent complete: 8.5%; Average loss: 3.5426
# Iteration: 425; Percent complete: 8.5%; Average loss: 3.5379
# Iteration: 426; Percent complete: 8.5%; Average loss: 3.5306
# Iteration: 427; Percent complete: 8.5%; Average loss: 3.7835
# Iteration: 428; Percent complete: 8.6%; Average loss: 3.3313
# Iteration: 429; Percent complete: 8.6%; Average loss: 3.5496
# Iteration: 430; Percent complete: 8.6%; Average loss: 3.8030
# Iteration: 431; Percent complete: 8.6%; Average loss: 3.3615
# Iteration: 432; Percent complete: 8.6%; Average loss: 3.7251
# Iteration: 433; Percent complete: 8.7%; Average loss: 3.6046
# Iteration: 434; Percent complete: 8.7%; Average loss: 3.4222
# Iteration: 435; Percent complete: 8.7%; Average loss: 3.3403
# Iteration: 436; Percent complete: 8.7%; Average loss: 3.3254
# Iteration: 437; Percent complete: 8.7%; Average loss: 3.7932
# Iteration: 438; Percent complete: 8.8%; Average loss: 3.6012
# Iteration: 439; Percent complete: 8.8%; Average loss: 3.6678
# Iteration: 440; Percent complete: 8.8%; Average loss: 3.4362
# Iteration: 441; Percent complete: 8.8%; Average loss: 3.6026
# Iteration: 442; Percent complete: 8.8%; Average loss: 3.3556
# Iteration: 443; Percent complete: 8.9%; Average loss: 3.3239
# Iteration: 444; Percent complete: 8.9%; Average loss: 3.7265
# Iteration: 445; Percent complete: 8.9%; Average loss: 3.6007
# Iteration: 446; Percent complete: 8.9%; Average loss: 3.6819
# Iteration: 447; Percent complete: 8.9%; Average loss: 3.3322
# Iteration: 448; Percent complete: 9.0%; Average loss: 3.4860
# Iteration: 449; Percent complete: 9.0%; Average loss: 3.6727
# Iteration: 450; Percent complete: 9.0%; Average loss: 3.4461
# Iteration: 451; Percent complete: 9.0%; Average loss: 3.3989
# Iteration: 452; Percent complete: 9.0%; Average loss: 3.4875
# Iteration: 453; Percent complete: 9.1%; Average loss: 3.5502
# Iteration: 454; Percent complete: 9.1%; Average loss: 3.6015
# Iteration: 455; Percent complete: 9.1%; Average loss: 3.7065
# Iteration: 456; Percent complete: 9.1%; Average loss: 3.4864
# Iteration: 457; Percent complete: 9.1%; Average loss: 3.6515
# Iteration: 458; Percent complete: 9.2%; Average loss: 3.4228
# Iteration: 459; Percent complete: 9.2%; Average loss: 3.5444
# Iteration: 460; Percent complete: 9.2%; Average loss: 3.2595
# Iteration: 461; Percent complete: 9.2%; Average loss: 3.6863
# Iteration: 462; Percent complete: 9.2%; Average loss: 3.5296
# Iteration: 463; Percent complete: 9.3%; Average loss: 3.4413
# Iteration: 464; Percent complete: 9.3%; Average loss: 3.7708
# Iteration: 465; Percent complete: 9.3%; Average loss: 3.7258
# Iteration: 466; Percent complete: 9.3%; Average loss: 3.5284
# Iteration: 467; Percent complete: 9.3%; Average loss: 3.6630
# Iteration: 468; Percent complete: 9.4%; Average loss: 3.6762
# Iteration: 469; Percent complete: 9.4%; Average loss: 3.5244
# Iteration: 470; Percent complete: 9.4%; Average loss: 3.6324
# Iteration: 471; Percent complete: 9.4%; Average loss: 3.5606
# Iteration: 472; Percent complete: 9.4%; Average loss: 3.6136
# Iteration: 473; Percent complete: 9.5%; Average loss: 3.5120
# Iteration: 474; Percent complete: 9.5%; Average loss: 3.4775
# Iteration: 475; Percent complete: 9.5%; Average loss: 3.5347
# Iteration: 476; Percent complete: 9.5%; Average loss: 3.6110
# Iteration: 477; Percent complete: 9.5%; Average loss: 3.8051
# Iteration: 478; Percent complete: 9.6%; Average loss: 3.6028
# Iteration: 479; Percent complete: 9.6%; Average loss: 3.3758
# Iteration: 480; Percent complete: 9.6%; Average loss: 3.6742
# Iteration: 481; Percent complete: 9.6%; Average loss: 3.4915
# Iteration: 482; Percent complete: 9.6%; Average loss: 3.7772
# Iteration: 483; Percent complete: 9.7%; Average loss: 3.5087
# Iteration: 484; Percent complete: 9.7%; Average loss: 3.4704
# Iteration: 485; Percent complete: 9.7%; Average loss: 3.6661
# Iteration: 486; Percent complete: 9.7%; Average loss: 3.5570
# Iteration: 487; Percent complete: 9.7%; Average loss: 3.3961
# Iteration: 488; Percent complete: 9.8%; Average loss: 3.5485
# Iteration: 489; Percent complete: 9.8%; Average loss: 3.5569
# Iteration: 490; Percent complete: 9.8%; Average loss: 3.4848
# Iteration: 491; Percent complete: 9.8%; Average loss: 3.4388
# Iteration: 492; Percent complete: 9.8%; Average loss: 3.8734
# Iteration: 493; Percent complete: 9.9%; Average loss: 3.7167
# Iteration: 494; Percent complete: 9.9%; Average loss: 3.4078
# Iteration: 495; Percent complete: 9.9%; Average loss: 3.6044
# Iteration: 496; Percent complete: 9.9%; Average loss: 3.7860
# Iteration: 497; Percent complete: 9.9%; Average loss: 3.5063
# Iteration: 498; Percent complete: 10.0%; Average loss: 3.5979
# Iteration: 499; Percent complete: 10.0%; Average loss: 3.5718
# Iteration: 500; Percent complete: 10.0%; Average loss: 3.2571
# Iteration: 501; Percent complete: 10.0%; Average loss: 3.4170
# Iteration: 502; Percent complete: 10.0%; Average loss: 3.6115
# Iteration: 503; Percent complete: 10.1%; Average loss: 3.3256
# Iteration: 504; Percent complete: 10.1%; Average loss: 3.6461
# Iteration: 505; Percent complete: 10.1%; Average loss: 3.4005
# Iteration: 506; Percent complete: 10.1%; Average loss: 3.7312
# Iteration: 507; Percent complete: 10.1%; Average loss: 3.6086
# Iteration: 508; Percent complete: 10.2%; Average loss: 3.5570
# Iteration: 509; Percent complete: 10.2%; Average loss: 3.6014
# Iteration: 510; Percent complete: 10.2%; Average loss: 3.4525
# Iteration: 511; Percent complete: 10.2%; Average loss: 3.4804
# Iteration: 512; Percent complete: 10.2%; Average loss: 3.3734
# Iteration: 513; Percent complete: 10.3%; Average loss: 3.4583
# Iteration: 514; Percent complete: 10.3%; Average loss: 3.5267
# Iteration: 515; Percent complete: 10.3%; Average loss: 3.5886
# Iteration: 516; Percent complete: 10.3%; Average loss: 3.1496
# Iteration: 517; Percent complete: 10.3%; Average loss: 3.4050
# Iteration: 518; Percent complete: 10.4%; Average loss: 3.4100
# Iteration: 519; Percent complete: 10.4%; Average loss: 3.7293
# Iteration: 520; Percent complete: 10.4%; Average loss: 3.5806
# Iteration: 521; Percent complete: 10.4%; Average loss: 3.3644
# Iteration: 522; Percent complete: 10.4%; Average loss: 3.3988
# Iteration: 523; Percent complete: 10.5%; Average loss: 3.5576
# Iteration: 524; Percent complete: 10.5%; Average loss: 3.6587
# Iteration: 525; Percent complete: 10.5%; Average loss: 3.3510
# Iteration: 526; Percent complete: 10.5%; Average loss: 3.5991
# Iteration: 527; Percent complete: 10.5%; Average loss: 3.4145
# Iteration: 528; Percent complete: 10.6%; Average loss: 3.3911
# Iteration: 529; Percent complete: 10.6%; Average loss: 3.3558
# Iteration: 530; Percent complete: 10.6%; Average loss: 3.5373
# Iteration: 531; Percent complete: 10.6%; Average loss: 3.4494
# Iteration: 532; Percent complete: 10.6%; Average loss: 3.6121
# Iteration: 533; Percent complete: 10.7%; Average loss: 3.6248
# Iteration: 534; Percent complete: 10.7%; Average loss: 3.5450
# Iteration: 535; Percent complete: 10.7%; Average loss: 3.5324
# Iteration: 536; Percent complete: 10.7%; Average loss: 3.4723
# Iteration: 537; Percent complete: 10.7%; Average loss: 3.3997
# Iteration: 538; Percent complete: 10.8%; Average loss: 3.3165
# Iteration: 539; Percent complete: 10.8%; Average loss: 3.5542
# Iteration: 540; Percent complete: 10.8%; Average loss: 3.4793
# Iteration: 541; Percent complete: 10.8%; Average loss: 3.3046
# Iteration: 542; Percent complete: 10.8%; Average loss: 3.2824
# Iteration: 543; Percent complete: 10.9%; Average loss: 3.5113
# Iteration: 544; Percent complete: 10.9%; Average loss: 3.4473
# Iteration: 545; Percent complete: 10.9%; Average loss: 3.3963
# Iteration: 546; Percent complete: 10.9%; Average loss: 3.5689
# Iteration: 547; Percent complete: 10.9%; Average loss: 3.5047
# Iteration: 548; Percent complete: 11.0%; Average loss: 3.4491
# Iteration: 549; Percent complete: 11.0%; Average loss: 3.4484
# Iteration: 550; Percent complete: 11.0%; Average loss: 3.4699
# Iteration: 551; Percent complete: 11.0%; Average loss: 3.4890
# Iteration: 552; Percent complete: 11.0%; Average loss: 3.6175
# Iteration: 553; Percent complete: 11.1%; Average loss: 3.4402
# Iteration: 554; Percent complete: 11.1%; Average loss: 3.6675
# Iteration: 555; Percent complete: 11.1%; Average loss: 3.2820
# Iteration: 556; Percent complete: 11.1%; Average loss: 3.4926
# Iteration: 557; Percent complete: 11.1%; Average loss: 3.5366
# Iteration: 558; Percent complete: 11.2%; Average loss: 3.6371
# Iteration: 559; Percent complete: 11.2%; Average loss: 3.4767
# Iteration: 560; Percent complete: 11.2%; Average loss: 3.6496
# Iteration: 561; Percent complete: 11.2%; Average loss: 3.4476
# Iteration: 562; Percent complete: 11.2%; Average loss: 3.2783
# Iteration: 563; Percent complete: 11.3%; Average loss: 3.6575
# Iteration: 564; Percent complete: 11.3%; Average loss: 3.6611
# Iteration: 565; Percent complete: 11.3%; Average loss: 3.4284
# Iteration: 566; Percent complete: 11.3%; Average loss: 3.5492
# Iteration: 567; Percent complete: 11.3%; Average loss: 3.5914
# Iteration: 568; Percent complete: 11.4%; Average loss: 3.4141
# Iteration: 569; Percent complete: 11.4%; Average loss: 3.1871
# Iteration: 570; Percent complete: 11.4%; Average loss: 3.4044
# Iteration: 571; Percent complete: 11.4%; Average loss: 3.4355
# Iteration: 572; Percent complete: 11.4%; Average loss: 3.5026
# Iteration: 573; Percent complete: 11.5%; Average loss: 3.4702
# Iteration: 574; Percent complete: 11.5%; Average loss: 3.5225
# Iteration: 575; Percent complete: 11.5%; Average loss: 3.3514
# Iteration: 576; Percent complete: 11.5%; Average loss: 3.5174
# Iteration: 577; Percent complete: 11.5%; Average loss: 3.3550
# Iteration: 578; Percent complete: 11.6%; Average loss: 3.7004
# Iteration: 579; Percent complete: 11.6%; Average loss: 3.3305
# Iteration: 580; Percent complete: 11.6%; Average loss: 3.4859
# Iteration: 581; Percent complete: 11.6%; Average loss: 3.5133
# Iteration: 582; Percent complete: 11.6%; Average loss: 3.4852
# Iteration: 583; Percent complete: 11.7%; Average loss: 3.5961
# Iteration: 584; Percent complete: 11.7%; Average loss: 3.3987
# Iteration: 585; Percent complete: 11.7%; Average loss: 3.5738
# Iteration: 586; Percent complete: 11.7%; Average loss: 3.4826
# Iteration: 587; Percent complete: 11.7%; Average loss: 3.2979
# Iteration: 588; Percent complete: 11.8%; Average loss: 3.3535
# Iteration: 589; Percent complete: 11.8%; Average loss: 3.6234
# Iteration: 590; Percent complete: 11.8%; Average loss: 3.5112
# Iteration: 591; Percent complete: 11.8%; Average loss: 3.3957
# Iteration: 592; Percent complete: 11.8%; Average loss: 3.3082
# Iteration: 593; Percent complete: 11.9%; Average loss: 3.4717
# Iteration: 594; Percent complete: 11.9%; Average loss: 3.6672
# Iteration: 595; Percent complete: 11.9%; Average loss: 3.6178
# Iteration: 596; Percent complete: 11.9%; Average loss: 3.4319
# Iteration: 597; Percent complete: 11.9%; Average loss: 3.5383
# Iteration: 598; Percent complete: 12.0%; Average loss: 3.5996
# Iteration: 599; Percent complete: 12.0%; Average loss: 3.6853
# Iteration: 600; Percent complete: 12.0%; Average loss: 3.4817
# Iteration: 601; Percent complete: 12.0%; Average loss: 3.4274
# Iteration: 602; Percent complete: 12.0%; Average loss: 3.5819
# Iteration: 603; Percent complete: 12.1%; Average loss: 3.4120
# Iteration: 604; Percent complete: 12.1%; Average loss: 3.4337
# Iteration: 605; Percent complete: 12.1%; Average loss: 3.4370
# Iteration: 606; Percent complete: 12.1%; Average loss: 3.3868
# Iteration: 607; Percent complete: 12.1%; Average loss: 3.3214
# Iteration: 608; Percent complete: 12.2%; Average loss: 3.6616
# Iteration: 609; Percent complete: 12.2%; Average loss: 3.3972
# Iteration: 610; Percent complete: 12.2%; Average loss: 3.4118
# Iteration: 611; Percent complete: 12.2%; Average loss: 3.5257
# Iteration: 612; Percent complete: 12.2%; Average loss: 3.6132
# Iteration: 613; Percent complete: 12.3%; Average loss: 3.1420
# Iteration: 614; Percent complete: 12.3%; Average loss: 3.6134
# Iteration: 615; Percent complete: 12.3%; Average loss: 3.2970
# Iteration: 616; Percent complete: 12.3%; Average loss: 3.4592
# Iteration: 617; Percent complete: 12.3%; Average loss: 3.4313
# Iteration: 618; Percent complete: 12.4%; Average loss: 3.5566
# Iteration: 619; Percent complete: 12.4%; Average loss: 3.5075
# Iteration: 620; Percent complete: 12.4%; Average loss: 3.6668
# Iteration: 621; Percent complete: 12.4%; Average loss: 3.5843
# Iteration: 622; Percent complete: 12.4%; Average loss: 3.4239
# Iteration: 623; Percent complete: 12.5%; Average loss: 3.3467
# Iteration: 624; Percent complete: 12.5%; Average loss: 3.5318
# Iteration: 625; Percent complete: 12.5%; Average loss: 3.2879
# Iteration: 626; Percent complete: 12.5%; Average loss: 3.4660
# Iteration: 627; Percent complete: 12.5%; Average loss: 3.3514
# Iteration: 628; Percent complete: 12.6%; Average loss: 3.4203
# Iteration: 629; Percent complete: 12.6%; Average loss: 3.4709
# Iteration: 630; Percent complete: 12.6%; Average loss: 3.5075
# Iteration: 631; Percent complete: 12.6%; Average loss: 3.3523
# Iteration: 632; Percent complete: 12.6%; Average loss: 3.4645
# Iteration: 633; Percent complete: 12.7%; Average loss: 3.2207
# Iteration: 634; Percent complete: 12.7%; Average loss: 3.5486
# Iteration: 635; Percent complete: 12.7%; Average loss: 3.4449
# Iteration: 636; Percent complete: 12.7%; Average loss: 3.3082
# Iteration: 637; Percent complete: 12.7%; Average loss: 3.4434
# Iteration: 638; Percent complete: 12.8%; Average loss: 3.3290
# Iteration: 639; Percent complete: 12.8%; Average loss: 3.6058
# Iteration: 640; Percent complete: 12.8%; Average loss: 3.3537
# Iteration: 641; Percent complete: 12.8%; Average loss: 3.4505
# Iteration: 642; Percent complete: 12.8%; Average loss: 3.4035
# Iteration: 643; Percent complete: 12.9%; Average loss: 3.5311
# Iteration: 644; Percent complete: 12.9%; Average loss: 3.4597
# Iteration: 645; Percent complete: 12.9%; Average loss: 3.4959
# Iteration: 646; Percent complete: 12.9%; Average loss: 3.3545
# Iteration: 647; Percent complete: 12.9%; Average loss: 3.4602
# Iteration: 648; Percent complete: 13.0%; Average loss: 3.4908
# Iteration: 649; Percent complete: 13.0%; Average loss: 3.6158
# Iteration: 650; Percent complete: 13.0%; Average loss: 3.3460
# Iteration: 651; Percent complete: 13.0%; Average loss: 3.3915
# Iteration: 652; Percent complete: 13.0%; Average loss: 3.5117
# Iteration: 653; Percent complete: 13.1%; Average loss: 3.4818
# Iteration: 654; Percent complete: 13.1%; Average loss: 3.3730
# Iteration: 655; Percent complete: 13.1%; Average loss: 3.3884
# Iteration: 656; Percent complete: 13.1%; Average loss: 3.4059
# Iteration: 657; Percent complete: 13.1%; Average loss: 3.4186
# Iteration: 658; Percent complete: 13.2%; Average loss: 3.5174
# Iteration: 659; Percent complete: 13.2%; Average loss: 3.6025
# Iteration: 660; Percent complete: 13.2%; Average loss: 3.6555
# Iteration: 661; Percent complete: 13.2%; Average loss: 3.4911
# Iteration: 662; Percent complete: 13.2%; Average loss: 3.5739
# Iteration: 663; Percent complete: 13.3%; Average loss: 3.3670
# Iteration: 664; Percent complete: 13.3%; Average loss: 3.6319
# Iteration: 665; Percent complete: 13.3%; Average loss: 3.3873
# Iteration: 666; Percent complete: 13.3%; Average loss: 3.3230
# Iteration: 667; Percent complete: 13.3%; Average loss: 3.3606
# Iteration: 668; Percent complete: 13.4%; Average loss: 3.4033
# Iteration: 669; Percent complete: 13.4%; Average loss: 3.4197
# Iteration: 670; Percent complete: 13.4%; Average loss: 3.1648
# Iteration: 671; Percent complete: 13.4%; Average loss: 3.5097
# Iteration: 672; Percent complete: 13.4%; Average loss: 3.3449
# Iteration: 673; Percent complete: 13.5%; Average loss: 3.4394
# Iteration: 674; Percent complete: 13.5%; Average loss: 3.3318
# Iteration: 675; Percent complete: 13.5%; Average loss: 3.3817
# Iteration: 676; Percent complete: 13.5%; Average loss: 3.5271
# Iteration: 677; Percent complete: 13.5%; Average loss: 3.4480
# Iteration: 678; Percent complete: 13.6%; Average loss: 3.6226
# Iteration: 679; Percent complete: 13.6%; Average loss: 3.4038
# Iteration: 680; Percent complete: 13.6%; Average loss: 3.4371
# Iteration: 681; Percent complete: 13.6%; Average loss: 3.3671
# Iteration: 682; Percent complete: 13.6%; Average loss: 3.3567
# Iteration: 683; Percent complete: 13.7%; Average loss: 3.5549
# Iteration: 684; Percent complete: 13.7%; Average loss: 3.4314
# Iteration: 685; Percent complete: 13.7%; Average loss: 3.4826
# Iteration: 686; Percent complete: 13.7%; Average loss: 3.4244
# Iteration: 687; Percent complete: 13.7%; Average loss: 3.5411
# Iteration: 688; Percent complete: 13.8%; Average loss: 3.2513
# Iteration: 689; Percent complete: 13.8%; Average loss: 3.3512
# Iteration: 690; Percent complete: 13.8%; Average loss: 3.4859
# Iteration: 691; Percent complete: 13.8%; Average loss: 3.3989
# Iteration: 692; Percent complete: 13.8%; Average loss: 3.6142
# Iteration: 693; Percent complete: 13.9%; Average loss: 3.3387
# Iteration: 694; Percent complete: 13.9%; Average loss: 3.2806
# Iteration: 695; Percent complete: 13.9%; Average loss: 3.2305
# Iteration: 696; Percent complete: 13.9%; Average loss: 3.2818
# Iteration: 697; Percent complete: 13.9%; Average loss: 3.3126
# Iteration: 698; Percent complete: 14.0%; Average loss: 3.4248
# Iteration: 699; Percent complete: 14.0%; Average loss: 3.3619
# Iteration: 700; Percent complete: 14.0%; Average loss: 3.2720
# Iteration: 701; Percent complete: 14.0%; Average loss: 3.3760
# Iteration: 702; Percent complete: 14.0%; Average loss: 3.6843
# Iteration: 703; Percent complete: 14.1%; Average loss: 3.2533
# Iteration: 704; Percent complete: 14.1%; Average loss: 3.6079
# Iteration: 705; Percent complete: 14.1%; Average loss: 3.7091
# Iteration: 706; Percent complete: 14.1%; Average loss: 3.2841
# Iteration: 707; Percent complete: 14.1%; Average loss: 3.4593
# Iteration: 708; Percent complete: 14.2%; Average loss: 3.5501
# Iteration: 709; Percent complete: 14.2%; Average loss: 3.4883
# Iteration: 710; Percent complete: 14.2%; Average loss: 3.4344
# Iteration: 711; Percent complete: 14.2%; Average loss: 3.2501
# Iteration: 712; Percent complete: 14.2%; Average loss: 3.2419
# Iteration: 713; Percent complete: 14.3%; Average loss: 3.4703
# Iteration: 714; Percent complete: 14.3%; Average loss: 3.0524
# Iteration: 715; Percent complete: 14.3%; Average loss: 3.4563
# Iteration: 716; Percent complete: 14.3%; Average loss: 3.3757
# Iteration: 717; Percent complete: 14.3%; Average loss: 3.4766
# Iteration: 718; Percent complete: 14.4%; Average loss: 3.4187
# Iteration: 719; Percent complete: 14.4%; Average loss: 3.5658
# Iteration: 720; Percent complete: 14.4%; Average loss: 3.3426
# Iteration: 721; Percent complete: 14.4%; Average loss: 3.4941
# Iteration: 722; Percent complete: 14.4%; Average loss: 3.3190
# Iteration: 723; Percent complete: 14.5%; Average loss: 3.5374
# Iteration: 724; Percent complete: 14.5%; Average loss: 3.6526
# Iteration: 725; Percent complete: 14.5%; Average loss: 3.5491
# Iteration: 726; Percent complete: 14.5%; Average loss: 3.5390
# Iteration: 727; Percent complete: 14.5%; Average loss: 3.5320
# Iteration: 728; Percent complete: 14.6%; Average loss: 3.4967
# Iteration: 729; Percent complete: 14.6%; Average loss: 3.3547
# Iteration: 730; Percent complete: 14.6%; Average loss: 3.5293
# Iteration: 731; Percent complete: 14.6%; Average loss: 3.4784
# Iteration: 732; Percent complete: 14.6%; Average loss: 3.6575
# Iteration: 733; Percent complete: 14.7%; Average loss: 3.2754
# Iteration: 734; Percent complete: 14.7%; Average loss: 3.6219
# Iteration: 735; Percent complete: 14.7%; Average loss: 3.3862
# Iteration: 736; Percent complete: 14.7%; Average loss: 3.2750
# Iteration: 737; Percent complete: 14.7%; Average loss: 3.4051
# Iteration: 738; Percent complete: 14.8%; Average loss: 3.5341
# Iteration: 739; Percent complete: 14.8%; Average loss: 3.4262
# Iteration: 740; Percent complete: 14.8%; Average loss: 3.3708
# Iteration: 741; Percent complete: 14.8%; Average loss: 3.5903
# Iteration: 742; Percent complete: 14.8%; Average loss: 3.3140
# Iteration: 743; Percent complete: 14.9%; Average loss: 3.4360
# Iteration: 744; Percent complete: 14.9%; Average loss: 3.4690
# Iteration: 745; Percent complete: 14.9%; Average loss: 3.6559
# Iteration: 746; Percent complete: 14.9%; Average loss: 3.5354
# Iteration: 747; Percent complete: 14.9%; Average loss: 3.4822
# Iteration: 748; Percent complete: 15.0%; Average loss: 3.1369
# Iteration: 749; Percent complete: 15.0%; Average loss: 3.4396
# Iteration: 750; Percent complete: 15.0%; Average loss: 3.5733
# Iteration: 751; Percent complete: 15.0%; Average loss: 3.6173
# Iteration: 752; Percent complete: 15.0%; Average loss: 3.5321
# Iteration: 753; Percent complete: 15.1%; Average loss: 3.3140
# Iteration: 754; Percent complete: 15.1%; Average loss: 3.3638
# Iteration: 755; Percent complete: 15.1%; Average loss: 3.3950
# Iteration: 756; Percent complete: 15.1%; Average loss: 3.4276
# Iteration: 757; Percent complete: 15.1%; Average loss: 3.5447
# Iteration: 758; Percent complete: 15.2%; Average loss: 3.3293
# Iteration: 759; Percent complete: 15.2%; Average loss: 3.2503
# Iteration: 760; Percent complete: 15.2%; Average loss: 3.4114
# Iteration: 761; Percent complete: 15.2%; Average loss: 3.2640
# Iteration: 762; Percent complete: 15.2%; Average loss: 3.4426
# Iteration: 763; Percent complete: 15.3%; Average loss: 3.1603
# Iteration: 764; Percent complete: 15.3%; Average loss: 3.4956
# Iteration: 765; Percent complete: 15.3%; Average loss: 3.3664
# Iteration: 766; Percent complete: 15.3%; Average loss: 3.6196
# Iteration: 767; Percent complete: 15.3%; Average loss: 3.3362
# Iteration: 768; Percent complete: 15.4%; Average loss: 3.2839
# Iteration: 769; Percent complete: 15.4%; Average loss: 3.1227
# Iteration: 770; Percent complete: 15.4%; Average loss: 3.4676
# Iteration: 771; Percent complete: 15.4%; Average loss: 3.1390
# Iteration: 772; Percent complete: 15.4%; Average loss: 3.2159
# Iteration: 773; Percent complete: 15.5%; Average loss: 3.3892
# Iteration: 774; Percent complete: 15.5%; Average loss: 3.2562
# Iteration: 775; Percent complete: 15.5%; Average loss: 3.5256
# Iteration: 776; Percent complete: 15.5%; Average loss: 3.4947
# Iteration: 777; Percent complete: 15.5%; Average loss: 3.4395
# Iteration: 778; Percent complete: 15.6%; Average loss: 3.3026
# Iteration: 779; Percent complete: 15.6%; Average loss: 3.2371
# Iteration: 780; Percent complete: 15.6%; Average loss: 3.2184
# Iteration: 781; Percent complete: 15.6%; Average loss: 3.3622
# Iteration: 782; Percent complete: 15.6%; Average loss: 3.3266
# ...
# Iteration: 4748; Percent complete: 95.0%; Average loss: 1.8654
# Iteration: 4749; Percent complete: 95.0%; Average loss: 2.2086
# Iteration: 4750; Percent complete: 95.0%; Average loss: 2.0575
# Iteration: 4751; Percent complete: 95.0%; Average loss: 1.9007
# Iteration: 4752; Percent complete: 95.0%; Average loss: 2.1531
# Iteration: 4753; Percent complete: 95.1%; Average loss: 1.9642
# Iteration: 4754; Percent complete: 95.1%; Average loss: 2.0039
# Iteration: 4755; Percent complete: 95.1%; Average loss: 2.1684
# Iteration: 4756; Percent complete: 95.1%; Average loss: 1.9621
# Iteration: 4757; Percent complete: 95.1%; Average loss: 2.2335
# Iteration: 4758; Percent complete: 95.2%; Average loss: 1.7989
# Iteration: 4759; Percent complete: 95.2%; Average loss: 2.0102
# Iteration: 4760; Percent complete: 95.2%; Average loss: 1.9784
# Iteration: 4761; Percent complete: 95.2%; Average loss: 2.1479
# Iteration: 4762; Percent complete: 95.2%; Average loss: 2.0537
# Iteration: 4763; Percent complete: 95.3%; Average loss: 1.9552
# Iteration: 4764; Percent complete: 95.3%; Average loss: 1.9864
# Iteration: 4765; Percent complete: 95.3%; Average loss: 1.9690
# Iteration: 4766; Percent complete: 95.3%; Average loss: 1.9039
# Iteration: 4767; Percent complete: 95.3%; Average loss: 1.8893
# Iteration: 4768; Percent complete: 95.4%; Average loss: 1.9856
# Iteration: 4769; Percent complete: 95.4%; Average loss: 2.0903
# Iteration: 4770; Percent complete: 95.4%; Average loss: 1.9832
# Iteration: 4771; Percent complete: 95.4%; Average loss: 1.8085
# Iteration: 4772; Percent complete: 95.4%; Average loss: 2.0202
# Iteration: 4773; Percent complete: 95.5%; Average loss: 2.2801
# Iteration: 4774; Percent complete: 95.5%; Average loss: 1.9309
# Iteration: 4775; Percent complete: 95.5%; Average loss: 2.0911
# Iteration: 4776; Percent complete: 95.5%; Average loss: 1.8911
# Iteration: 4777; Percent complete: 95.5%; Average loss: 1.7102
# Iteration: 4778; Percent complete: 95.6%; Average loss: 1.8941
# Iteration: 4779; Percent complete: 95.6%; Average loss: 1.9453
# Iteration: 4780; Percent complete: 95.6%; Average loss: 1.9803
# Iteration: 4781; Percent complete: 95.6%; Average loss: 2.0342
# Iteration: 4782; Percent complete: 95.6%; Average loss: 2.0096
# Iteration: 4783; Percent complete: 95.7%; Average loss: 2.0250
# Iteration: 4784; Percent complete: 95.7%; Average loss: 1.8692
# Iteration: 4785; Percent complete: 95.7%; Average loss: 1.7434
# Iteration: 4786; Percent complete: 95.7%; Average loss: 1.9794
# Iteration: 4787; Percent complete: 95.7%; Average loss: 1.8176
# Iteration: 4788; Percent complete: 95.8%; Average loss: 2.1403
# Iteration: 4789; Percent complete: 95.8%; Average loss: 1.7871
# Iteration: 4790; Percent complete: 95.8%; Average loss: 1.9355
# Iteration: 4791; Percent complete: 95.8%; Average loss: 1.9875
# Iteration: 4792; Percent complete: 95.8%; Average loss: 2.2739
# Iteration: 4793; Percent complete: 95.9%; Average loss: 2.1156
# Iteration: 4794; Percent complete: 95.9%; Average loss: 2.1980
# Iteration: 4795; Percent complete: 95.9%; Average loss: 1.9182
# Iteration: 4796; Percent complete: 95.9%; Average loss: 2.0616
# Iteration: 4797; Percent complete: 95.9%; Average loss: 1.9119
# Iteration: 4798; Percent complete: 96.0%; Average loss: 1.8932
# Iteration: 4799; Percent complete: 96.0%; Average loss: 1.9876
# Iteration: 4800; Percent complete: 96.0%; Average loss: 2.0885
# Iteration: 4801; Percent complete: 96.0%; Average loss: 2.0036
# Iteration: 4802; Percent complete: 96.0%; Average loss: 1.8324
# Iteration: 4803; Percent complete: 96.1%; Average loss: 2.0393
# Iteration: 4804; Percent complete: 96.1%; Average loss: 2.0908
# Iteration: 4805; Percent complete: 96.1%; Average loss: 2.1311
# Iteration: 4806; Percent complete: 96.1%; Average loss: 1.8496
# Iteration: 4807; Percent complete: 96.1%; Average loss: 1.9015
# Iteration: 4808; Percent complete: 96.2%; Average loss: 1.9438
# Iteration: 4809; Percent complete: 96.2%; Average loss: 1.9408
# Iteration: 4810; Percent complete: 96.2%; Average loss: 2.0535
# Iteration: 4811; Percent complete: 96.2%; Average loss: 1.8973
# Iteration: 4812; Percent complete: 96.2%; Average loss: 1.9210
# Iteration: 4813; Percent complete: 96.3%; Average loss: 1.9361
# Iteration: 4814; Percent complete: 96.3%; Average loss: 1.7555
# Iteration: 4815; Percent complete: 96.3%; Average loss: 1.9822
# Iteration: 4816; Percent complete: 96.3%; Average loss: 1.8211
# Iteration: 4817; Percent complete: 96.3%; Average loss: 1.9537
# Iteration: 4818; Percent complete: 96.4%; Average loss: 1.9070
# Iteration: 4819; Percent complete: 96.4%; Average loss: 1.8861
# Iteration: 4820; Percent complete: 96.4%; Average loss: 1.9686
# Iteration: 4821; Percent complete: 96.4%; Average loss: 1.9342
# Iteration: 4822; Percent complete: 96.4%; Average loss: 2.0449
# Iteration: 4823; Percent complete: 96.5%; Average loss: 1.7699
# Iteration: 4824; Percent complete: 96.5%; Average loss: 1.9874
# Iteration: 4825; Percent complete: 96.5%; Average loss: 1.8184
# Iteration: 4826; Percent complete: 96.5%; Average loss: 2.1019
# Iteration: 4827; Percent complete: 96.5%; Average loss: 1.8744
# Iteration: 4828; Percent complete: 96.6%; Average loss: 2.1293
# Iteration: 4829; Percent complete: 96.6%; Average loss: 1.9035
# Iteration: 4830; Percent complete: 96.6%; Average loss: 2.2012
# Iteration: 4831; Percent complete: 96.6%; Average loss: 1.8850
# Iteration: 4832; Percent complete: 96.6%; Average loss: 1.7713
# Iteration: 4833; Percent complete: 96.7%; Average loss: 2.1278
# Iteration: 4834; Percent complete: 96.7%; Average loss: 2.1489
# Iteration: 4835; Percent complete: 96.7%; Average loss: 1.9574
# Iteration: 4836; Percent complete: 96.7%; Average loss: 1.9678
# Iteration: 4837; Percent complete: 96.7%; Average loss: 1.8148
# Iteration: 4838; Percent complete: 96.8%; Average loss: 1.8220
# Iteration: 4839; Percent complete: 96.8%; Average loss: 1.8762
# Iteration: 4840; Percent complete: 96.8%; Average loss: 2.0636
# Iteration: 4841; Percent complete: 96.8%; Average loss: 1.8751
# Iteration: 4842; Percent complete: 96.8%; Average loss: 2.0570
# Iteration: 4843; Percent complete: 96.9%; Average loss: 2.1273
# Iteration: 4844; Percent complete: 96.9%; Average loss: 1.8869
# Iteration: 4845; Percent complete: 96.9%; Average loss: 2.0591
# Iteration: 4846; Percent complete: 96.9%; Average loss: 1.9346
# Iteration: 4847; Percent complete: 96.9%; Average loss: 1.9562
# Iteration: 4848; Percent complete: 97.0%; Average loss: 1.9231
# Iteration: 4849; Percent complete: 97.0%; Average loss: 2.1488
# Iteration: 4850; Percent complete: 97.0%; Average loss: 2.0858
# Iteration: 4851; Percent complete: 97.0%; Average loss: 1.9876
# Iteration: 4852; Percent complete: 97.0%; Average loss: 1.8778
# Iteration: 4853; Percent complete: 97.1%; Average loss: 1.9294
# Iteration: 4854; Percent complete: 97.1%; Average loss: 1.8792
# Iteration: 4855; Percent complete: 97.1%; Average loss: 2.0963
# Iteration: 4856; Percent complete: 97.1%; Average loss: 1.9821
# Iteration: 4857; Percent complete: 97.1%; Average loss: 1.8932
# Iteration: 4858; Percent complete: 97.2%; Average loss: 2.0773
# Iteration: 4859; Percent complete: 97.2%; Average loss: 2.1476
# Iteration: 4860; Percent complete: 97.2%; Average loss: 1.8720
# Iteration: 4861; Percent complete: 97.2%; Average loss: 1.9416
# Iteration: 4862; Percent complete: 97.2%; Average loss: 2.0192
# Iteration: 4863; Percent complete: 97.3%; Average loss: 2.2729
# Iteration: 4864; Percent complete: 97.3%; Average loss: 2.0356
# Iteration: 4865; Percent complete: 97.3%; Average loss: 1.8680
# Iteration: 4866; Percent complete: 97.3%; Average loss: 2.0216
# Iteration: 4867; Percent complete: 97.3%; Average loss: 1.8776
# Iteration: 4868; Percent complete: 97.4%; Average loss: 2.0461
# Iteration: 4869; Percent complete: 97.4%; Average loss: 1.8379
# Iteration: 4870; Percent complete: 97.4%; Average loss: 2.0454
# Iteration: 4871; Percent complete: 97.4%; Average loss: 2.0570
# Iteration: 4872; Percent complete: 97.4%; Average loss: 1.8774
# Iteration: 4873; Percent complete: 97.5%; Average loss: 1.9950
# Iteration: 4874; Percent complete: 97.5%; Average loss: 1.8838
# Iteration: 4875; Percent complete: 97.5%; Average loss: 1.8302
# Iteration: 4876; Percent complete: 97.5%; Average loss: 1.9716
# Iteration: 4877; Percent complete: 97.5%; Average loss: 1.8794
# Iteration: 4878; Percent complete: 97.6%; Average loss: 2.0706
# Iteration: 4879; Percent complete: 97.6%; Average loss: 1.8739
# Iteration: 4880; Percent complete: 97.6%; Average loss: 1.8542
# Iteration: 4881; Percent complete: 97.6%; Average loss: 1.9950
# Iteration: 4882; Percent complete: 97.6%; Average loss: 1.8411
# Iteration: 4883; Percent complete: 97.7%; Average loss: 1.9921
# Iteration: 4884; Percent complete: 97.7%; Average loss: 2.0483
# Iteration: 4885; Percent complete: 97.7%; Average loss: 2.0271
# Iteration: 4886; Percent complete: 97.7%; Average loss: 1.9114
# Iteration: 4887; Percent complete: 97.7%; Average loss: 1.8453
# Iteration: 4888; Percent complete: 97.8%; Average loss: 1.8479
# Iteration: 4889; Percent complete: 97.8%; Average loss: 1.8573
# Iteration: 4890; Percent complete: 97.8%; Average loss: 1.9327
# Iteration: 4891; Percent complete: 97.8%; Average loss: 1.8957
# Iteration: 4892; Percent complete: 97.8%; Average loss: 1.9684
# Iteration: 4893; Percent complete: 97.9%; Average loss: 1.8334
# Iteration: 4894; Percent complete: 97.9%; Average loss: 1.8356
# Iteration: 4895; Percent complete: 97.9%; Average loss: 1.9503
# Iteration: 4896; Percent complete: 97.9%; Average loss: 2.0707
# Iteration: 4897; Percent complete: 97.9%; Average loss: 2.0721
# Iteration: 4898; Percent complete: 98.0%; Average loss: 1.9337
# Iteration: 4899; Percent complete: 98.0%; Average loss: 2.0071
# Iteration: 4900; Percent complete: 98.0%; Average loss: 1.6646
# Iteration: 4901; Percent complete: 98.0%; Average loss: 1.8533
# Iteration: 4902; Percent complete: 98.0%; Average loss: 1.8753
# Iteration: 4903; Percent complete: 98.1%; Average loss: 1.9057
# Iteration: 4904; Percent complete: 98.1%; Average loss: 1.8447
# Iteration: 4905; Percent complete: 98.1%; Average loss: 2.0366
# Iteration: 4906; Percent complete: 98.1%; Average loss: 1.8140
# Iteration: 4907; Percent complete: 98.1%; Average loss: 2.0602
# Iteration: 4908; Percent complete: 98.2%; Average loss: 1.9090
# Iteration: 4909; Percent complete: 98.2%; Average loss: 2.0353
# Iteration: 4910; Percent complete: 98.2%; Average loss: 1.9287
# Iteration: 4911; Percent complete: 98.2%; Average loss: 2.1388
# Iteration: 4912; Percent complete: 98.2%; Average loss: 2.1436
# Iteration: 4913; Percent complete: 98.3%; Average loss: 2.0081
# Iteration: 4914; Percent complete: 98.3%; Average loss: 2.0972
# Iteration: 4915; Percent complete: 98.3%; Average loss: 1.8713
# Iteration: 4916; Percent complete: 98.3%; Average loss: 1.9051
# Iteration: 4917; Percent complete: 98.3%; Average loss: 1.8737
# Iteration: 4918; Percent complete: 98.4%; Average loss: 1.8711
# Iteration: 4919; Percent complete: 98.4%; Average loss: 1.7273
# Iteration: 4920; Percent complete: 98.4%; Average loss: 1.8767
# Iteration: 4921; Percent complete: 98.4%; Average loss: 2.0070
# Iteration: 4922; Percent complete: 98.4%; Average loss: 1.9028
# Iteration: 4923; Percent complete: 98.5%; Average loss: 2.1513
# Iteration: 4924; Percent complete: 98.5%; Average loss: 1.9013
# Iteration: 4925; Percent complete: 98.5%; Average loss: 1.8049
# Iteration: 4926; Percent complete: 98.5%; Average loss: 2.0616
# Iteration: 4927; Percent complete: 98.5%; Average loss: 2.0451
# Iteration: 4928; Percent complete: 98.6%; Average loss: 2.0888
# Iteration: 4929; Percent complete: 98.6%; Average loss: 1.9243
# Iteration: 4930; Percent complete: 98.6%; Average loss: 2.0879
# Iteration: 4931; Percent complete: 98.6%; Average loss: 1.9737
# Iteration: 4932; Percent complete: 98.6%; Average loss: 2.0869
# Iteration: 4933; Percent complete: 98.7%; Average loss: 1.7393
# Iteration: 4934; Percent complete: 98.7%; Average loss: 1.9538
# Iteration: 4935; Percent complete: 98.7%; Average loss: 2.1295
# Iteration: 4936; Percent complete: 98.7%; Average loss: 1.8397
# Iteration: 4937; Percent complete: 98.7%; Average loss: 1.9428
# Iteration: 4938; Percent complete: 98.8%; Average loss: 2.0754
# Iteration: 4939; Percent complete: 98.8%; Average loss: 2.0244
# Iteration: 4940; Percent complete: 98.8%; Average loss: 1.6281
# Iteration: 4941; Percent complete: 98.8%; Average loss: 2.1925
# Iteration: 4942; Percent complete: 98.8%; Average loss: 1.8802
# Iteration: 4943; Percent complete: 98.9%; Average loss: 1.9463
# Iteration: 4944; Percent complete: 98.9%; Average loss: 1.8146
# Iteration: 4945; Percent complete: 98.9%; Average loss: 2.1823
# Iteration: 4946; Percent complete: 98.9%; Average loss: 1.8937
# Iteration: 4947; Percent complete: 98.9%; Average loss: 2.0678
# Iteration: 4948; Percent complete: 99.0%; Average loss: 1.7939
# Iteration: 4949; Percent complete: 99.0%; Average loss: 1.8544
# Iteration: 4950; Percent complete: 99.0%; Average loss: 1.8881
# Iteration: 4951; Percent complete: 99.0%; Average loss: 2.1709
# Iteration: 4952; Percent complete: 99.0%; Average loss: 1.6801
# Iteration: 4953; Percent complete: 99.1%; Average loss: 1.8765
# Iteration: 4954; Percent complete: 99.1%; Average loss: 1.8836
# Iteration: 4955; Percent complete: 99.1%; Average loss: 1.9911
# Iteration: 4956; Percent complete: 99.1%; Average loss: 1.8751
# Iteration: 4957; Percent complete: 99.1%; Average loss: 1.8706
# Iteration: 4958; Percent complete: 99.2%; Average loss: 1.8013
# Iteration: 4959; Percent complete: 99.2%; Average loss: 1.9208
# Iteration: 4960; Percent complete: 99.2%; Average loss: 1.9603
# Iteration: 4961; Percent complete: 99.2%; Average loss: 1.9574
# Iteration: 4962; Percent complete: 99.2%; Average loss: 2.2553
# Iteration: 4963; Percent complete: 99.3%; Average loss: 2.1054
# Iteration: 4964; Percent complete: 99.3%; Average loss: 2.0845
# Iteration: 4965; Percent complete: 99.3%; Average loss: 2.1124
# Iteration: 4966; Percent complete: 99.3%; Average loss: 2.0885
# Iteration: 4967; Percent complete: 99.3%; Average loss: 2.0506
# Iteration: 4968; Percent complete: 99.4%; Average loss: 1.9749
# Iteration: 4969; Percent complete: 99.4%; Average loss: 1.8020
# Iteration: 4970; Percent complete: 99.4%; Average loss: 1.8021
# Iteration: 4971; Percent complete: 99.4%; Average loss: 2.0148
# Iteration: 4972; Percent complete: 99.4%; Average loss: 1.7842
# Iteration: 4973; Percent complete: 99.5%; Average loss: 2.1079
# Iteration: 4974; Percent complete: 99.5%; Average loss: 1.7299
# Iteration: 4975; Percent complete: 99.5%; Average loss: 1.9993
# Iteration: 4976; Percent complete: 99.5%; Average loss: 1.8754
# Iteration: 4977; Percent complete: 99.5%; Average loss: 2.0779
# Iteration: 4978; Percent complete: 99.6%; Average loss: 1.7520
# Iteration: 4979; Percent complete: 99.6%; Average loss: 1.9613
# Iteration: 4980; Percent complete: 99.6%; Average loss: 1.9264
# Iteration: 4981; Percent complete: 99.6%; Average loss: 1.8053
# Iteration: 4982; Percent complete: 99.6%; Average loss: 1.9939
# Iteration: 4983; Percent complete: 99.7%; Average loss: 1.9899
# Iteration: 4984; Percent complete: 99.7%; Average loss: 1.7529
# Iteration: 4985; Percent complete: 99.7%; Average loss: 1.9745
# Iteration: 4986; Percent complete: 99.7%; Average loss: 1.8051
# Iteration: 4987; Percent complete: 99.7%; Average loss: 1.9918
# Iteration: 4988; Percent complete: 99.8%; Average loss: 2.2292
# Iteration: 4989; Percent complete: 99.8%; Average loss: 1.7589
# Iteration: 4990; Percent complete: 99.8%; Average loss: 1.8332
# Iteration: 4991; Percent complete: 99.8%; Average loss: 1.8872
# Iteration: 4992; Percent complete: 99.8%; Average loss: 1.9058
# Iteration: 4993; Percent complete: 99.9%; Average loss: 1.9572
# Iteration: 4994; Percent complete: 99.9%; Average loss: 2.0044
# Iteration: 4995; Percent complete: 99.9%; Average loss: 1.6647
# Iteration: 4996; Percent complete: 99.9%; Average loss: 1.9600
# Iteration: 4997; Percent complete: 99.9%; Average loss: 1.8458
# Iteration: 4998; Percent complete: 100.0%; Average loss: 1.6826
# Iteration: 4999; Percent complete: 100.0%; Average loss: 1.9620
# Iteration: 5000; Percent complete: 100.0%; Average loss: 1.9418

# %% [markdown]
# Run the model :)

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > Hello
# Bot: hello . . . . 5
# > How is your day
# Bot: i don t know what i m saying . 9
# > How are you
# Bot: i m fine . . 5
# > What is the weather like today?
# Bot: no sir . . . . 6
# > Are you hungry?
# Bot: no . . . . . 6
# > Can we get something to eat?
# Bot: sure . . . . . 6
# > Where should we eat?
# Bot: i don t know . . . 7
# > I love you
# Bot: i love you . . . 6
# > Really?
# Bot: yeah . . . . . 6
# > Dam
# Error: Encountered unknown word.
# > Damn
# Bot: what ? ? . . 5
# > I dont believe you
# Error: Encountered unknown word.
# > I do not believe you
# Bot: i don t know . . 6
# > quit

# %% [markdown]
# ### Notes on the Model

# %% [markdown]
# Overall, the model is OK. It was not as intelligent as i thought it would be, but I suppose that is a good thing. One of the things that I noticed from playing with the bot was that everything is pretty predictable. In fact, it feels less like it is responding to you and more like it has memories what to day based on an input string from the user. I think the first thing we can do to improve the model is to add some randomness to the model, so asking "hello" wont keep generating the same output. To improve this one a bit more we can change some of the variable like the learning rate and the depth. Eventually, to improve the overall feeling of the chat bot we can implement an entirely new model. Try to give a more meaningful number to words rather than what index they first appear in (ask professor if he thinks this would even matter, or would this just be a change of domain).
