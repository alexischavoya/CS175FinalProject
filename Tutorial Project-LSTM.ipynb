# %% [markdown]
# # ChatBot References
#
# Professor Smyth's website discussing projects
#
# https://www.ics.uci.edu/~smyth/courses/cs175/project_reading.html
#
# Chatbot resources on website
#
# https://pytorch.org/tutorials/beginner/chatbot_tutorial.html
#
# https://web.stanford.edu/~jurafsky/slp3/26.pdf
#
# https://www.microsoft.com/en-us/research/wp-content/uploads/2016/12/CortanaLUDialog-FromSLTproceedings.pdf
#
# Dataset for tutorial
#
# https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html

# %% [markdown]
# # Start of Tutorial

# %% [markdown]
# ### Import necessary libraries

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import numpy as np


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# ### Preprocess Data

# %% [markdown]
# Looking at some files in the data to see how they are structured ...

# %%
corpus_name = "cornell movie-dialogs corpus"
corpus = os.path.join("data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "movie_lines.txt"))
# Out:
# b'L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!\n'
# b'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!\n'
# b'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.\n'
# b'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?\n'
# b"L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.\n"
# b'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow\n'
# b"L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.\n"
# b'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No\n'
# b'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?\n'
# b'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?\n'

# %% [markdown]
# Scan through data files and reformat them to be (sentence, response) pairs separated by a tab eventually. First we create helper functions to help clean up the data a bit and make it more readable ...

# %%
# Splits each line of the file into a dictionary of fields
def loadLines(fileName, fields):
    lines = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            lineObj = {}
            for i, field in enumerate(fields):
                lineObj[field] = values[i]
            lines[lineObj['lineID']] = lineObj
    return lines


# Groups fields of lines from `loadLines` into conversations based on *movie_conversations.txt*
def loadConversations(fileName, lines, fields):
    conversations = []
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            convObj = {}
            for i, field in enumerate(fields):
                convObj[field] = values[i]
            # Convert string to list (convObj["utteranceIDs"] == "['L598485', 'L598486', ...]")
            utterance_id_pattern = re.compile('L[0-9]+')
            lineIds = utterance_id_pattern.findall(convObj["utteranceIDs"])
            # Reassemble lines
            convObj["lines"] = []
            for lineId in lineIds:
                convObj["lines"].append(lines[lineId])
            conversations.append(convObj)
    return conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations:
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Next we will be using the functions above we now parse the data into a form that is useful to us and see what a few lines from the data look like ...

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict, conversations list, and field ids
lines = {}
conversations = []
MOVIE_LINES_FIELDS = ["lineID", "characterID", "movieID", "character", "text"]
MOVIE_CONVERSATIONS_FIELDS = ["character1ID", "character2ID", "movieID", "utteranceIDs"]

# Load lines and process conversations
print("\nProcessing corpus...")
lines = loadLines(os.path.join(corpus, "movie_lines.txt"), MOVIE_LINES_FIELDS)
print("\nLoading conversations...")
conversations = loadConversations(os.path.join(corpus, "movie_conversations.txt"),
                                  lines, MOVIE_CONVERSATIONS_FIELDS)

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus...
#
# Loading conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b"Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.\tWell, I thought we'd start with pronunciation, if that's okay with you.\r\n"
# b"Well, I thought we'd start with pronunciation, if that's okay with you.\tNot the hacking and gagging and spitting part.  Please.\r\n"
# b"Not the hacking and gagging and spitting part.  Please.\tOkay... then how 'bout we try out some French cuisine.  Saturday?  Night?\r\n"
# b"You're asking me out.  That's so cute. What's your name again?\tForget it.\r\n"
# b"No, no, it's my fault -- we didn't have a proper introduction ---\tCameron.\r\n"
# b"Cameron.\tThe thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\r\n"
# b"The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\tSeems like she could get a date easy enough...\r\n"
# b'Why?\tUnsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\r\n'
# b"Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\tThat's a shame.\r\n"
# b'Gosh, if only we could find Kat a boyfriend...\tLet me see what I can do.\r\n'

# %% [markdown]
# We want to create a vocabulary of words that we see. We represent these words numerically using the index of their first appearance in the history of all added words to the set of vocuabulary. See `addWord()` for specifics.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we finally getting to the part where we begin to make the (sentence, response) pairs. We begin preprocessing by converting the Unicode string texts to ASCII `unicodeToAscii()`. We also make everything lower case, and remove nonletters except for basic punctuation `normalizeString()`. The last thing that is done in preprocessing is ignore sentences beyond a certain length to aid in training `filterPair()` and `MAX_LENGTH`.

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64271 sentence pairs
# Counting words...
# Counted words: 18008
#
# pairs:
# ['there .', 'where ?']
# ['you have my word . as a gentleman', 'you re sweet .']
# ['hi .', 'looks like things worked out tonight huh ?']
# ['you know chastity ?', 'i believe we share an art instructor']
# ['have fun tonight ?', 'tons']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['what good stuff ?', 'the real you .']

# %% [markdown]
# Another way to speed up training is by removing words that are rarely used. We "trim" these words using `Voc.trim()` and as a result must also remove (sentence, response) pairs that include these words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7823 / 18005 = 0.4345
# Trimmed from 64271 pairs to 53165, 0.8272 of total

# %% [markdown]
# ### Using our Data on our Models

# %% [markdown]
# The data still needs to be processed more. The model that we use will take numerical values and not actual strings to do computation. We convert our sentences to tensors (vectors) that our model will take as inputs. To do this, we just take every sentence and change it to be a vector of index that corresponds to that word. This is how we will use our data to train the model.
#
# If we would like to train our model we usually do it with minbatches since it makes things faster. We make a matrix of dimensions (BatchLength, MaxLengthOfSentenceInBatch) represented numerically as mentioned in the previous paragraph. With this we make sure that each row (sentence) of our matrix terminates with `EOS_Token` and is followed by 0 entries until the end of the row.
#
# This implementation almost works, the problem with this is that each row is a sentence and every column is a step in time. However, it is better to think of every row as a step in time and the column to be possible words to choose for that step in time. For this reason, we construct the Matrix as mentioned in the previous paragraph except it is now transposed.
#
# We define some function that help us achieve this ...

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[   9,    7,   25,  122,  659],
#         [ 997,  331,  200,    4,    6],
#         [  37,  117,  112,    4,    2],
#         [  96,  746, 1975,    4,    0],
#         [  53,   12,    9,    6,    0],
#         [ 301,  488, 1347,    2,    0],
#         [ 989,  469,    4,    0,    0],
#         [   4,   66,    2,    0,    0],
#         [   2,    2,    0,    0,    0]])
# lengths: tensor([9, 9, 8, 6, 3])
# target_variable: tensor([[  25,   25,  354,  122,   76],
#         [ 132,  197, 1686,   50,   37],
#         [ 273,  117,  254,    6,   98],
#         [ 385,  222,    4,    2,  427],
#         [  12,   40,    2,    0,    4],
#         [ 657,    4,    0,    0,    2],
#         [   4,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True, False,  True],
#         [ True,  True, False, False,  True],
#         [ True,  True, False, False, False],
#         [ True, False, False, False, False]])
# max_target_len: 8

# %% [markdown]
# Seeing the output from preping the data above, it appears that `input_variable` is the matrix described in the previous secsion. `lenghts` is just a tensor (vector) of how long the sentences in the input were. This will eventually be used for the **decoder** later in the program. `target_variable` seems to be the response that our model is supposed to learn. `mask` looks like it is a mask for responses where true is that there is a word and false is that there is no word there. Not sure why this variable is necessary but maybe it will become clearer at some point in the tutorial.

# %% [markdown]
# ### Defining our Model

# %% [markdown]
# Our base model is a Sequence-to-Sequence model using two RNN's. The first RNN is what is called the **encoder** and it takes a variable length input and converts it into a *fixed length* "context" vector that is intended to hold onto some semantic meaning of the input. The **decoder** takes the context vector provided by the decoder along with an input word to guess the next word in a sequence. I suppose our (sentence, response) pairs are learned as one long continuous sequence where the sentence is the start of hte sequence and the response is the remainder of the sequence, though this might be entirely incorrect.

# %% [markdown]
# Some discussion on the Encoder. The encoder uses a bidirectional GRU (Gated Recurrent Unit), meaning that there is basically two RNN's that make up the encoder, one that goes through the sequence of data in the forward direction while another RNN goes through the sequence in the backward direction. At each time step, both RNN's produce an output and a hidden state vector. At each time step, the output of both RNNs are summed and the output is recorded (somewhere) while the hidden state vectors are pushed along and used in the next step of the RNN. The outputs are summed makes it so that at each time step, the RNN is considering present and future context.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.LSTM(hidden_size,hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Some discussion on the Decoder. The decoder uses the context vector that is produced by the encoder. Usually, this is all that will be used by a decoder to produce output but this can result in a loss of information, expecially when the input sentences are very long. To counter this, the decoder also uses its current hidden state as a way of determining what it should be "paying attention" to. These are refered to as attention weights and are multiplied by the outputs from the encoder (the output that is apperantly recorded somewhere, this is where they are used) from the current time step to rescale the values, making less important parts of the encoder output smaller and more important parts of the encoder output larger. This can be further improved by using all of the encoder outputs instead of just the one of the current time step to have a more comprehensive set of attention weights. This is the method implemented below, followed by the implementation of the decoder using this attention method.

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.LSTM(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# ### Defining the Training Procedure

# %% [markdown]
# Recall earlier in the `mask` produced along side the `target_variable` was produced for an unknown purpose, it turns out its purpose is for determining the loss of the model. This implementation below is the negative-log-likelihood loss and the variable `mask` along with `target_variable`.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# For training the model, two tricks are used to help convergence. The first trick is refered to as "teacher forcing" which just overrides the prediction of the decoder and uses the actual target value instead, this happens with some small probability p. Doing it too much will make the decoder unable to make predictions on its own and not having this feature will make it so that convergence is just slower. The second trick they do is gradient clipping, meaning that at areas in the feature space where there is a steep gradient and therefore a chance to improve the model very fast, the magnitude of the gradient is limited some value. This is to not drastically overshoot local minima on "cliffs". The training function is implemented below. This trains only one iteration.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
        #Get the encoder final h_hidden_state
    encoder_h_hidden, encoder_c_hidden = encoder_hidden
    decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
    decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
    # Recombine the final hidden states as hidden tuple
    decoder_hidden = (decoder_h_hidden, decoder_c_hidden)

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# This version of the training function trains on multiple iterations. It is built on the previous training function. This function also saves the current variables in a tarball file. This is to continue training at a later period or just use the current accumulated training to make predictions.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, 
               encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, 
               clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(
                iteration, iteration / n_iteration * 100, print_loss_avg
            ))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(
                encoder_n_layers, decoder_n_layers, hidden_size
            ))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# ### Defining Evaluation

# %% [markdown]
# This is the training method used by our bot when we are not using the "teacher forcing" method. This just basically chooses the output of hte decoder to be the output with the highest softmax score, ie the best response given its prior training. I think this is defining a decoder method for whenever we are actually using our model instead of when it is training.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

#option to greedy search
class StochasticTopKUniformDecoder(nn.Module):
    def __init__(self, encoder, decoder, k):
        super(StochasticTopKUniformDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            # select from the top k words at each word in the sentence
            # uniformly at random.
            decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
            i = int(random.random()*self.k)
            decoder_input = torch.tensor([ind[0,i]]).to(device)
            decoder_scores = torch.tensor([decoder_output_topk[0,i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

class StochasticTopKSampleDecoder(nn.Module):
    def __init__(self, encoder, decoder, k):
        super(StochasticTopKSampleDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            # sample choice of word from the top k words at each word
            # in the sentence
            decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
            decoder_output_topk = decoder_output_topk.cpu().detach().numpy().flatten()
            ind = ind.cpu().detach().numpy().flatten()
            probabilities = decoder_output_topk/(np.sum(decoder_output_topk))
            value = np.random.choice(ind, 1, p=probabilities)
            i = np.where(ind == value[0])[0][0]
            decoder_input = torch.tensor([ind[i]]).to(device)
            decoder_scores = torch.tensor([decoder_output_topk[i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

class StochasticSentenceInitializerSamplingDecoder(nn.Module):
    def __init__(self, encoder, decoder, k, n):
        super(StochasticSentenceInitializerSamplingDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k
        self.n = n

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for i in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            if i >= self.n:
                # be greedy >:)
                decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            else:
                # sample choice of word from the top k words at each word
                # in the sentence
                decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
                decoder_output_topk = decoder_output_topk.cpu().detach().numpy().flatten()
                ind = ind.cpu().detach().numpy().flatten()
                probabilities = decoder_output_topk/(np.sum(decoder_output_topk))
                value = np.random.choice(ind, 1, p=probabilities)
                i = np.where(ind == value[0])[0][0]
                decoder_input = torch.tensor([ind[i]]).to(device)
                decoder_scores = torch.tensor([decoder_output_topk[i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

class StochasticSentenceInitializerUniformDecoder(nn.Module):
    def __init__(self, encoder, decoder, k, n):
        super(StochasticSentenceInitializerUniformDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k
        self.n = n

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for i in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            if i >= self.n:
                # be greedy >:)
                decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            else:
                # sample choice of word from the top k words at each word
                # in the sentence (uniformly at random)
                decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
                i = int(random.random()*self.k)
                decoder_input = torch.tensor([ind[0,i]]).to(device)
                decoder_scores = torch.tensor([decoder_output_topk[0,i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# The `evaluateInput` function is meant to take input from the user, prepare it so that it may be fed to our model, and pring out the response from our bot. `evaluate` handles most of hte actual calculation while `evaluateInput` handles most of the user interaction phase.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    #lengths = lengths.to(device) # removed bc of gpu cpu tensor difference ###################################
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# ### Running the Model

# %% [markdown]
# This defines and builds our model based on the following parameters. Notice that parts of the code are commented out as these are other possibilities ofr initialization. attn_model can be given one of three different models. We can also choose to load a model that we previously trained.

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
# attn_model = 'general'
# attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 1000

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Now we train our model using `trainIters`. We first set some training parameters and initialize optimizers and prepare our model for training. Training is likely to take a very long time, thankfully there is the option to load from a previous model and this piece of code here doesn't need to be run every time.

# %%
# Safty precaution so that we dont accidentally begin training a model we didnt want to train
TRAIN_THE_MODEL = True

# %%
if TRAIN_THE_MODEL:
    
    # Configure training/optimization
    clip = 50
    teacher_forcing_ratio = 1
    learning_rate = 0.0001
    decoder_learning_ratio = 5.0
    n_iteration = 5000
    print_every = 1
    save_every = 2000

    # Ensure dropout layers are in train mode
    encoder.train()
    decoder.train()

    # Initialize optimizers
    print('Building optimizers ...')
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
    if loadFilename:
        encoder_optimizer.load_state_dict(encoder_optimizer_sd)
        decoder_optimizer.load_state_dict(decoder_optimizer_sd)

    # If you have cuda, configure cuda to call
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    # Run training iterations
    print("Starting Training!")
    trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
               embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
               print_every, save_every, clip, corpus_name, loadFilename)
    
    TRAIN_THE_MODEL = False

else:
    
    print(f"Make the variable 'TRAIN_THE_MODEL' in the code block above True and run the code block")
    print(f"Value of 'TRAIN_THE_MODEL' currently: {TRAIN_THE_MODEL}")
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9605
# Iteration: 2; Percent complete: 0.0%; Average loss: 8.9131
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.8537
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.7638
# Iteration: 5; Percent complete: 0.1%; Average loss: 8.6066
# Iteration: 6; Percent complete: 0.1%; Average loss: 8.3379
# Iteration: 7; Percent complete: 0.1%; Average loss: 7.8598
# Iteration: 8; Percent complete: 0.2%; Average loss: 7.1995
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.7580
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.7284
# Iteration: 11; Percent complete: 0.2%; Average loss: 6.7260
# Iteration: 12; Percent complete: 0.2%; Average loss: 6.4629
# Iteration: 13; Percent complete: 0.3%; Average loss: 6.1065
# Iteration: 14; Percent complete: 0.3%; Average loss: 5.7675
# Iteration: 15; Percent complete: 0.3%; Average loss: 5.4779
# Iteration: 16; Percent complete: 0.3%; Average loss: 5.3707
# Iteration: 17; Percent complete: 0.3%; Average loss: 5.3285
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.2808
# Iteration: 19; Percent complete: 0.4%; Average loss: 5.1739
# Iteration: 20; Percent complete: 0.4%; Average loss: 5.0478
# Iteration: 21; Percent complete: 0.4%; Average loss: 5.0266
# Iteration: 22; Percent complete: 0.4%; Average loss: 4.9126
# Iteration: 23; Percent complete: 0.5%; Average loss: 4.9671
# Iteration: 24; Percent complete: 0.5%; Average loss: 4.9864
# Iteration: 25; Percent complete: 0.5%; Average loss: 5.0067
# Iteration: 26; Percent complete: 0.5%; Average loss: 4.9873
# Iteration: 27; Percent complete: 0.5%; Average loss: 4.9395
# Iteration: 28; Percent complete: 0.6%; Average loss: 5.0009
# Iteration: 29; Percent complete: 0.6%; Average loss: 4.8586
# Iteration: 30; Percent complete: 0.6%; Average loss: 4.8189
# Iteration: 31; Percent complete: 0.6%; Average loss: 4.8068
# Iteration: 32; Percent complete: 0.6%; Average loss: 4.7949
# Iteration: 33; Percent complete: 0.7%; Average loss: 4.8176
# Iteration: 34; Percent complete: 0.7%; Average loss: 4.7477
# Iteration: 35; Percent complete: 0.7%; Average loss: 4.7437
# Iteration: 36; Percent complete: 0.7%; Average loss: 4.7296
# Iteration: 37; Percent complete: 0.7%; Average loss: 4.6964
# Iteration: 38; Percent complete: 0.8%; Average loss: 4.7609
# Iteration: 39; Percent complete: 0.8%; Average loss: 4.7239
# Iteration: 40; Percent complete: 0.8%; Average loss: 4.7041
# Iteration: 41; Percent complete: 0.8%; Average loss: 4.7495
# Iteration: 42; Percent complete: 0.8%; Average loss: 4.7175
# Iteration: 43; Percent complete: 0.9%; Average loss: 4.7460
# Iteration: 44; Percent complete: 0.9%; Average loss: 4.7545
# Iteration: 45; Percent complete: 0.9%; Average loss: 4.7043
# Iteration: 46; Percent complete: 0.9%; Average loss: 4.7168
# Iteration: 47; Percent complete: 0.9%; Average loss: 4.6557
# Iteration: 48; Percent complete: 1.0%; Average loss: 4.6261
# Iteration: 49; Percent complete: 1.0%; Average loss: 4.6557
# Iteration: 50; Percent complete: 1.0%; Average loss: 4.6782
# Iteration: 51; Percent complete: 1.0%; Average loss: 4.6284
# Iteration: 52; Percent complete: 1.0%; Average loss: 4.6452
# Iteration: 53; Percent complete: 1.1%; Average loss: 4.5710
# Iteration: 54; Percent complete: 1.1%; Average loss: 4.5861
# Iteration: 55; Percent complete: 1.1%; Average loss: 4.6069
# Iteration: 56; Percent complete: 1.1%; Average loss: 4.5712
# Iteration: 57; Percent complete: 1.1%; Average loss: 4.5976
# Iteration: 58; Percent complete: 1.2%; Average loss: 4.5559
# Iteration: 59; Percent complete: 1.2%; Average loss: 4.5409
# Iteration: 60; Percent complete: 1.2%; Average loss: 4.6056
# Iteration: 61; Percent complete: 1.2%; Average loss: 4.5721
# Iteration: 62; Percent complete: 1.2%; Average loss: 4.5548
# Iteration: 63; Percent complete: 1.3%; Average loss: 4.5233
# Iteration: 64; Percent complete: 1.3%; Average loss: 4.5494
# Iteration: 65; Percent complete: 1.3%; Average loss: 4.5004
# Iteration: 66; Percent complete: 1.3%; Average loss: 4.5467
# Iteration: 67; Percent complete: 1.3%; Average loss: 4.5110
# Iteration: 68; Percent complete: 1.4%; Average loss: 4.5081
# Iteration: 69; Percent complete: 1.4%; Average loss: 4.4867
# Iteration: 70; Percent complete: 1.4%; Average loss: 4.4907
# Iteration: 71; Percent complete: 1.4%; Average loss: 4.5151
# Iteration: 72; Percent complete: 1.4%; Average loss: 4.4751
# Iteration: 73; Percent complete: 1.5%; Average loss: 4.4734
# Iteration: 74; Percent complete: 1.5%; Average loss: 4.5155
# Iteration: 75; Percent complete: 1.5%; Average loss: 4.4699
# Iteration: 76; Percent complete: 1.5%; Average loss: 4.4905
# Iteration: 77; Percent complete: 1.5%; Average loss: 4.4601
# Iteration: 78; Percent complete: 1.6%; Average loss: 4.4689
# Iteration: 79; Percent complete: 1.6%; Average loss: 4.4726
# Iteration: 80; Percent complete: 1.6%; Average loss: 4.5050
# Iteration: 81; Percent complete: 1.6%; Average loss: 4.4795
# Iteration: 82; Percent complete: 1.6%; Average loss: 4.4166
# Iteration: 83; Percent complete: 1.7%; Average loss: 4.4229
# Iteration: 84; Percent complete: 1.7%; Average loss: 4.4624
# Iteration: 85; Percent complete: 1.7%; Average loss: 4.4154
# Iteration: 86; Percent complete: 1.7%; Average loss: 4.4291
# Iteration: 87; Percent complete: 1.7%; Average loss: 4.4089
# Iteration: 88; Percent complete: 1.8%; Average loss: 4.3311
# Iteration: 89; Percent complete: 1.8%; Average loss: 4.4103
# Iteration: 90; Percent complete: 1.8%; Average loss: 4.3784
# Iteration: 91; Percent complete: 1.8%; Average loss: 4.4090
# Iteration: 92; Percent complete: 1.8%; Average loss: 4.4016
# Iteration: 93; Percent complete: 1.9%; Average loss: 4.4216
# Iteration: 94; Percent complete: 1.9%; Average loss: 4.3912
# Iteration: 95; Percent complete: 1.9%; Average loss: 4.3604
# Iteration: 96; Percent complete: 1.9%; Average loss: 4.4049
# Iteration: 97; Percent complete: 1.9%; Average loss: 4.3533
# Iteration: 98; Percent complete: 2.0%; Average loss: 4.3706
# Iteration: 99; Percent complete: 2.0%; Average loss: 4.3358
# Iteration: 100; Percent complete: 2.0%; Average loss: 4.4006
# Iteration: 101; Percent complete: 2.0%; Average loss: 4.3558
# Iteration: 102; Percent complete: 2.0%; Average loss: 4.2974
# Iteration: 103; Percent complete: 2.1%; Average loss: 4.3863
# Iteration: 104; Percent complete: 2.1%; Average loss: 4.3219
# Iteration: 105; Percent complete: 2.1%; Average loss: 4.3158
# Iteration: 106; Percent complete: 2.1%; Average loss: 4.2765
# Iteration: 107; Percent complete: 2.1%; Average loss: 4.3681
# Iteration: 108; Percent complete: 2.2%; Average loss: 4.3532
# Iteration: 109; Percent complete: 2.2%; Average loss: 4.3379
# Iteration: 110; Percent complete: 2.2%; Average loss: 4.3442
# Iteration: 111; Percent complete: 2.2%; Average loss: 4.3501
# Iteration: 112; Percent complete: 2.2%; Average loss: 4.2825
# Iteration: 113; Percent complete: 2.3%; Average loss: 4.3221
# Iteration: 114; Percent complete: 2.3%; Average loss: 4.2937
# Iteration: 115; Percent complete: 2.3%; Average loss: 4.2787
# Iteration: 116; Percent complete: 2.3%; Average loss: 4.2571
# Iteration: 117; Percent complete: 2.3%; Average loss: 4.2742
# Iteration: 118; Percent complete: 2.4%; Average loss: 4.2439
# Iteration: 119; Percent complete: 2.4%; Average loss: 4.2982
# Iteration: 120; Percent complete: 2.4%; Average loss: 4.2961
# Iteration: 121; Percent complete: 2.4%; Average loss: 4.2545
# Iteration: 122; Percent complete: 2.4%; Average loss: 4.2907
# Iteration: 123; Percent complete: 2.5%; Average loss: 4.3162
# Iteration: 124; Percent complete: 2.5%; Average loss: 4.2187
# Iteration: 125; Percent complete: 2.5%; Average loss: 4.2607
# Iteration: 126; Percent complete: 2.5%; Average loss: 4.2683
# Iteration: 127; Percent complete: 2.5%; Average loss: 4.2995
# Iteration: 128; Percent complete: 2.6%; Average loss: 4.2341
# Iteration: 129; Percent complete: 2.6%; Average loss: 4.2728
# Iteration: 130; Percent complete: 2.6%; Average loss: 4.2638
# Iteration: 131; Percent complete: 2.6%; Average loss: 4.2034
# Iteration: 132; Percent complete: 2.6%; Average loss: 4.2270
# Iteration: 133; Percent complete: 2.7%; Average loss: 4.2343
# Iteration: 134; Percent complete: 2.7%; Average loss: 4.2857
# Iteration: 135; Percent complete: 2.7%; Average loss: 4.2151
# Iteration: 136; Percent complete: 2.7%; Average loss: 4.2486
# Iteration: 137; Percent complete: 2.7%; Average loss: 4.2275
# Iteration: 138; Percent complete: 2.8%; Average loss: 4.2169
# Iteration: 139; Percent complete: 2.8%; Average loss: 4.1625
# Iteration: 140; Percent complete: 2.8%; Average loss: 4.1690
# Iteration: 141; Percent complete: 2.8%; Average loss: 4.1461
# Iteration: 142; Percent complete: 2.8%; Average loss: 4.2142
# Iteration: 143; Percent complete: 2.9%; Average loss: 4.1662
# Iteration: 144; Percent complete: 2.9%; Average loss: 4.1931
# Iteration: 145; Percent complete: 2.9%; Average loss: 4.2721
# Iteration: 146; Percent complete: 2.9%; Average loss: 4.2080
# Iteration: 147; Percent complete: 2.9%; Average loss: 4.2314
# Iteration: 148; Percent complete: 3.0%; Average loss: 4.1732
# Iteration: 149; Percent complete: 3.0%; Average loss: 4.2287
# Iteration: 150; Percent complete: 3.0%; Average loss: 4.1466
# Iteration: 151; Percent complete: 3.0%; Average loss: 4.1276
# Iteration: 152; Percent complete: 3.0%; Average loss: 4.1843
# Iteration: 153; Percent complete: 3.1%; Average loss: 4.1433
# Iteration: 154; Percent complete: 3.1%; Average loss: 4.1800
# Iteration: 155; Percent complete: 3.1%; Average loss: 4.1540
# Iteration: 156; Percent complete: 3.1%; Average loss: 4.1705
# Iteration: 157; Percent complete: 3.1%; Average loss: 4.1649
# Iteration: 158; Percent complete: 3.2%; Average loss: 4.1485
# Iteration: 159; Percent complete: 3.2%; Average loss: 4.1310
# Iteration: 160; Percent complete: 3.2%; Average loss: 4.1814
# Iteration: 161; Percent complete: 3.2%; Average loss: 4.1566
# Iteration: 162; Percent complete: 3.2%; Average loss: 4.1541
# Iteration: 163; Percent complete: 3.3%; Average loss: 4.1055
# Iteration: 164; Percent complete: 3.3%; Average loss: 4.1430
# Iteration: 165; Percent complete: 3.3%; Average loss: 4.1021
# Iteration: 166; Percent complete: 3.3%; Average loss: 4.0935
# Iteration: 167; Percent complete: 3.3%; Average loss: 4.1341
# Iteration: 168; Percent complete: 3.4%; Average loss: 4.0744
# Iteration: 169; Percent complete: 3.4%; Average loss: 4.0886
# Iteration: 170; Percent complete: 3.4%; Average loss: 4.1006
# Iteration: 171; Percent complete: 3.4%; Average loss: 4.0633
# Iteration: 172; Percent complete: 3.4%; Average loss: 4.0727
# Iteration: 173; Percent complete: 3.5%; Average loss: 4.1584
# Iteration: 174; Percent complete: 3.5%; Average loss: 4.0811
# Iteration: 175; Percent complete: 3.5%; Average loss: 4.0486
# Iteration: 176; Percent complete: 3.5%; Average loss: 4.0688
# Iteration: 177; Percent complete: 3.5%; Average loss: 4.1133
# Iteration: 178; Percent complete: 3.6%; Average loss: 4.0765
# Iteration: 179; Percent complete: 3.6%; Average loss: 4.1113
# Iteration: 180; Percent complete: 3.6%; Average loss: 4.0792
# Iteration: 181; Percent complete: 3.6%; Average loss: 4.1308
# Iteration: 182; Percent complete: 3.6%; Average loss: 4.0118
# Iteration: 183; Percent complete: 3.7%; Average loss: 4.0869
# Iteration: 184; Percent complete: 3.7%; Average loss: 4.0822
# Iteration: 185; Percent complete: 3.7%; Average loss: 4.0660
# Iteration: 186; Percent complete: 3.7%; Average loss: 4.0916
# Iteration: 187; Percent complete: 3.7%; Average loss: 4.0468
# Iteration: 188; Percent complete: 3.8%; Average loss: 4.0260
# Iteration: 189; Percent complete: 3.8%; Average loss: 4.0285
# Iteration: 190; Percent complete: 3.8%; Average loss: 4.0186
# Iteration: 191; Percent complete: 3.8%; Average loss: 4.0087
# Iteration: 192; Percent complete: 3.8%; Average loss: 4.0340
# Iteration: 193; Percent complete: 3.9%; Average loss: 4.0195
# Iteration: 194; Percent complete: 3.9%; Average loss: 4.0305
# Iteration: 195; Percent complete: 3.9%; Average loss: 4.0206
# Iteration: 196; Percent complete: 3.9%; Average loss: 4.0583
# Iteration: 197; Percent complete: 3.9%; Average loss: 4.0228
# Iteration: 198; Percent complete: 4.0%; Average loss: 4.0331
# Iteration: 199; Percent complete: 4.0%; Average loss: 3.9772
# Iteration: 200; Percent complete: 4.0%; Average loss: 3.9512
# Iteration: 201; Percent complete: 4.0%; Average loss: 3.9871
# Iteration: 202; Percent complete: 4.0%; Average loss: 4.0681
# Iteration: 203; Percent complete: 4.1%; Average loss: 4.0118
# Iteration: 204; Percent complete: 4.1%; Average loss: 4.0524
# Iteration: 205; Percent complete: 4.1%; Average loss: 3.9525
# Iteration: 206; Percent complete: 4.1%; Average loss: 3.9974
# Iteration: 207; Percent complete: 4.1%; Average loss: 3.9996
# Iteration: 208; Percent complete: 4.2%; Average loss: 3.9822
# Iteration: 209; Percent complete: 4.2%; Average loss: 3.9449
# Iteration: 210; Percent complete: 4.2%; Average loss: 3.9562
# Iteration: 211; Percent complete: 4.2%; Average loss: 3.9900
# Iteration: 212; Percent complete: 4.2%; Average loss: 3.9579
# Iteration: 213; Percent complete: 4.3%; Average loss: 3.9747
# Iteration: 214; Percent complete: 4.3%; Average loss: 3.9808
# Iteration: 215; Percent complete: 4.3%; Average loss: 4.0529
# Iteration: 216; Percent complete: 4.3%; Average loss: 3.9746
# Iteration: 217; Percent complete: 4.3%; Average loss: 3.9084
# Iteration: 218; Percent complete: 4.4%; Average loss: 3.9498
# Iteration: 219; Percent complete: 4.4%; Average loss: 3.9314
# Iteration: 220; Percent complete: 4.4%; Average loss: 3.9909
# Iteration: 221; Percent complete: 4.4%; Average loss: 3.9633
# Iteration: 222; Percent complete: 4.4%; Average loss: 3.9625
# Iteration: 223; Percent complete: 4.5%; Average loss: 3.9452
# Iteration: 224; Percent complete: 4.5%; Average loss: 3.9192
# Iteration: 225; Percent complete: 4.5%; Average loss: 3.9843
# Iteration: 226; Percent complete: 4.5%; Average loss: 4.0074
# Iteration: 227; Percent complete: 4.5%; Average loss: 3.9496
# Iteration: 228; Percent complete: 4.6%; Average loss: 3.9921
# Iteration: 229; Percent complete: 4.6%; Average loss: 3.8892
# Iteration: 230; Percent complete: 4.6%; Average loss: 3.9030
# Iteration: 231; Percent complete: 4.6%; Average loss: 3.9323
# Iteration: 232; Percent complete: 4.6%; Average loss: 3.9217
# Iteration: 233; Percent complete: 4.7%; Average loss: 3.9301
# Iteration: 234; Percent complete: 4.7%; Average loss: 3.8370
# Iteration: 235; Percent complete: 4.7%; Average loss: 3.9048
# Iteration: 236; Percent complete: 4.7%; Average loss: 3.8766
# Iteration: 237; Percent complete: 4.7%; Average loss: 3.8970
# Iteration: 238; Percent complete: 4.8%; Average loss: 3.9068
# Iteration: 239; Percent complete: 4.8%; Average loss: 3.9905
# Iteration: 240; Percent complete: 4.8%; Average loss: 3.9218
# Iteration: 241; Percent complete: 4.8%; Average loss: 3.8870
# Iteration: 242; Percent complete: 4.8%; Average loss: 3.8638
# Iteration: 243; Percent complete: 4.9%; Average loss: 3.8159
# Iteration: 244; Percent complete: 4.9%; Average loss: 3.8962
# Iteration: 245; Percent complete: 4.9%; Average loss: 3.9101
# Iteration: 246; Percent complete: 4.9%; Average loss: 3.9433
# Iteration: 247; Percent complete: 4.9%; Average loss: 3.8619
# Iteration: 248; Percent complete: 5.0%; Average loss: 3.8953
# Iteration: 249; Percent complete: 5.0%; Average loss: 3.8074
# Iteration: 250; Percent complete: 5.0%; Average loss: 3.8747
# Iteration: 251; Percent complete: 5.0%; Average loss: 3.8921
# Iteration: 252; Percent complete: 5.0%; Average loss: 3.8770
# Iteration: 253; Percent complete: 5.1%; Average loss: 3.8804
# Iteration: 254; Percent complete: 5.1%; Average loss: 3.8751
# Iteration: 255; Percent complete: 5.1%; Average loss: 3.8827
# Iteration: 256; Percent complete: 5.1%; Average loss: 3.9264
# Iteration: 257; Percent complete: 5.1%; Average loss: 3.7703
# Iteration: 258; Percent complete: 5.2%; Average loss: 3.8019
# Iteration: 259; Percent complete: 5.2%; Average loss: 3.7978
# Iteration: 260; Percent complete: 5.2%; Average loss: 3.8587
# Iteration: 261; Percent complete: 5.2%; Average loss: 3.8500
# Iteration: 262; Percent complete: 5.2%; Average loss: 3.8702
# Iteration: 263; Percent complete: 5.3%; Average loss: 3.7947
# Iteration: 264; Percent complete: 5.3%; Average loss: 3.8367
# Iteration: 265; Percent complete: 5.3%; Average loss: 3.7703
# Iteration: 266; Percent complete: 5.3%; Average loss: 3.7936
# Iteration: 267; Percent complete: 5.3%; Average loss: 3.8049
# Iteration: 268; Percent complete: 5.4%; Average loss: 3.8582
# Iteration: 269; Percent complete: 5.4%; Average loss: 3.8300
# Iteration: 270; Percent complete: 5.4%; Average loss: 3.7603
# Iteration: 271; Percent complete: 5.4%; Average loss: 3.8466
# Iteration: 272; Percent complete: 5.4%; Average loss: 3.7744
# Iteration: 273; Percent complete: 5.5%; Average loss: 3.8543
# Iteration: 274; Percent complete: 5.5%; Average loss: 3.8299
# Iteration: 275; Percent complete: 5.5%; Average loss: 3.7319
# Iteration: 276; Percent complete: 5.5%; Average loss: 3.9144
# Iteration: 277; Percent complete: 5.5%; Average loss: 3.7662
# Iteration: 278; Percent complete: 5.6%; Average loss: 3.8302
# Iteration: 279; Percent complete: 5.6%; Average loss: 3.7969
# Iteration: 280; Percent complete: 5.6%; Average loss: 3.8002
# Iteration: 281; Percent complete: 5.6%; Average loss: 3.7715
# Iteration: 282; Percent complete: 5.6%; Average loss: 3.7912
# Iteration: 283; Percent complete: 5.7%; Average loss: 3.7770
# Iteration: 284; Percent complete: 5.7%; Average loss: 3.7768
# Iteration: 285; Percent complete: 5.7%; Average loss: 3.7901
# Iteration: 286; Percent complete: 5.7%; Average loss: 3.7315
# Iteration: 287; Percent complete: 5.7%; Average loss: 3.8143
# Iteration: 288; Percent complete: 5.8%; Average loss: 3.7878
# Iteration: 289; Percent complete: 5.8%; Average loss: 3.8067
# Iteration: 290; Percent complete: 5.8%; Average loss: 3.8040
# Iteration: 291; Percent complete: 5.8%; Average loss: 3.7581
# Iteration: 292; Percent complete: 5.8%; Average loss: 3.7635
# Iteration: 293; Percent complete: 5.9%; Average loss: 3.8416
# Iteration: 294; Percent complete: 5.9%; Average loss: 3.7265
# Iteration: 295; Percent complete: 5.9%; Average loss: 3.7468
# Iteration: 296; Percent complete: 5.9%; Average loss: 3.8155
# Iteration: 297; Percent complete: 5.9%; Average loss: 3.7311
# Iteration: 298; Percent complete: 6.0%; Average loss: 3.7620
# Iteration: 299; Percent complete: 6.0%; Average loss: 3.7970
# Iteration: 300; Percent complete: 6.0%; Average loss: 3.7662
# Iteration: 301; Percent complete: 6.0%; Average loss: 3.7406
# Iteration: 302; Percent complete: 6.0%; Average loss: 3.7364
# Iteration: 303; Percent complete: 6.1%; Average loss: 3.7125
# Iteration: 304; Percent complete: 6.1%; Average loss: 3.7602
# Iteration: 305; Percent complete: 6.1%; Average loss: 3.7380
# Iteration: 306; Percent complete: 6.1%; Average loss: 3.6752
# Iteration: 307; Percent complete: 6.1%; Average loss: 3.7568
# Iteration: 308; Percent complete: 6.2%; Average loss: 3.7461
# Iteration: 309; Percent complete: 6.2%; Average loss: 3.8130
# Iteration: 310; Percent complete: 6.2%; Average loss: 3.7475
# Iteration: 311; Percent complete: 6.2%; Average loss: 3.6428
# Iteration: 312; Percent complete: 6.2%; Average loss: 3.6892
# Iteration: 313; Percent complete: 6.3%; Average loss: 3.7264
# Iteration: 314; Percent complete: 6.3%; Average loss: 3.7579
# Iteration: 315; Percent complete: 6.3%; Average loss: 3.6990
# Iteration: 316; Percent complete: 6.3%; Average loss: 3.7490
# Iteration: 317; Percent complete: 6.3%; Average loss: 3.7615
# Iteration: 318; Percent complete: 6.4%; Average loss: 3.7272
# Iteration: 319; Percent complete: 6.4%; Average loss: 3.6929
# Iteration: 320; Percent complete: 6.4%; Average loss: 3.7241
# Iteration: 321; Percent complete: 6.4%; Average loss: 3.7521
# Iteration: 322; Percent complete: 6.4%; Average loss: 3.7108
# Iteration: 323; Percent complete: 6.5%; Average loss: 3.6641
# Iteration: 324; Percent complete: 6.5%; Average loss: 3.7235
# Iteration: 325; Percent complete: 6.5%; Average loss: 3.6936
# Iteration: 326; Percent complete: 6.5%; Average loss: 3.6645
# Iteration: 327; Percent complete: 6.5%; Average loss: 3.6674
# Iteration: 328; Percent complete: 6.6%; Average loss: 3.6966
# Iteration: 329; Percent complete: 6.6%; Average loss: 3.6519
# Iteration: 330; Percent complete: 6.6%; Average loss: 3.7442
# Iteration: 331; Percent complete: 6.6%; Average loss: 3.6791
# Iteration: 332; Percent complete: 6.6%; Average loss: 3.6441
# Iteration: 333; Percent complete: 6.7%; Average loss: 3.6746
# Iteration: 334; Percent complete: 6.7%; Average loss: 3.6190
# Iteration: 335; Percent complete: 6.7%; Average loss: 3.7060
# Iteration: 336; Percent complete: 6.7%; Average loss: 3.6807
# Iteration: 337; Percent complete: 6.7%; Average loss: 3.6653
# Iteration: 338; Percent complete: 6.8%; Average loss: 3.7299
# Iteration: 339; Percent complete: 6.8%; Average loss: 3.7390
# Iteration: 340; Percent complete: 6.8%; Average loss: 3.6986
# Iteration: 341; Percent complete: 6.8%; Average loss: 3.6455
# Iteration: 342; Percent complete: 6.8%; Average loss: 3.6955
# Iteration: 343; Percent complete: 6.9%; Average loss: 3.7014
# Iteration: 344; Percent complete: 6.9%; Average loss: 3.6930
# Iteration: 345; Percent complete: 6.9%; Average loss: 3.6651
# Iteration: 346; Percent complete: 6.9%; Average loss: 3.7433
# Iteration: 347; Percent complete: 6.9%; Average loss: 3.6889
# Iteration: 348; Percent complete: 7.0%; Average loss: 3.6352
# Iteration: 349; Percent complete: 7.0%; Average loss: 3.6830
# Iteration: 350; Percent complete: 7.0%; Average loss: 3.7124
# Iteration: 351; Percent complete: 7.0%; Average loss: 3.6740
# Iteration: 352; Percent complete: 7.0%; Average loss: 3.5869
# Iteration: 353; Percent complete: 7.1%; Average loss: 3.6729
# Iteration: 354; Percent complete: 7.1%; Average loss: 3.6431
# Iteration: 355; Percent complete: 7.1%; Average loss: 3.6195
# Iteration: 356; Percent complete: 7.1%; Average loss: 3.7042
# Iteration: 357; Percent complete: 7.1%; Average loss: 3.7089
# Iteration: 358; Percent complete: 7.2%; Average loss: 3.6879
# Iteration: 359; Percent complete: 7.2%; Average loss: 3.6092
# Iteration: 360; Percent complete: 7.2%; Average loss: 3.6496
# Iteration: 361; Percent complete: 7.2%; Average loss: 3.6206
# Iteration: 362; Percent complete: 7.2%; Average loss: 3.6363
# Iteration: 363; Percent complete: 7.3%; Average loss: 3.7239
# Iteration: 364; Percent complete: 7.3%; Average loss: 3.6630
# Iteration: 365; Percent complete: 7.3%; Average loss: 3.6990
# Iteration: 366; Percent complete: 7.3%; Average loss: 3.6406
# Iteration: 367; Percent complete: 7.3%; Average loss: 3.6345
# Iteration: 368; Percent complete: 7.4%; Average loss: 3.6493
# Iteration: 369; Percent complete: 7.4%; Average loss: 3.6317
# Iteration: 370; Percent complete: 7.4%; Average loss: 3.6614
# Iteration: 371; Percent complete: 7.4%; Average loss: 3.6325
# Iteration: 372; Percent complete: 7.4%; Average loss: 3.6473
# Iteration: 373; Percent complete: 7.5%; Average loss: 3.6852
# Iteration: 374; Percent complete: 7.5%; Average loss: 3.6416
# Iteration: 375; Percent complete: 7.5%; Average loss: 3.6820
# Iteration: 376; Percent complete: 7.5%; Average loss: 3.5932
# Iteration: 377; Percent complete: 7.5%; Average loss: 3.6533
# Iteration: 378; Percent complete: 7.6%; Average loss: 3.5750
# Iteration: 379; Percent complete: 7.6%; Average loss: 3.5875
# Iteration: 380; Percent complete: 7.6%; Average loss: 3.5767
# Iteration: 381; Percent complete: 7.6%; Average loss: 3.6190
# Iteration: 382; Percent complete: 7.6%; Average loss: 3.6228
# Iteration: 383; Percent complete: 7.7%; Average loss: 3.5580
# Iteration: 384; Percent complete: 7.7%; Average loss: 3.6419
# Iteration: 385; Percent complete: 7.7%; Average loss: 3.5871
# Iteration: 386; Percent complete: 7.7%; Average loss: 3.6068
# Iteration: 387; Percent complete: 7.7%; Average loss: 3.6890
# Iteration: 388; Percent complete: 7.8%; Average loss: 3.6560
# Iteration: 389; Percent complete: 7.8%; Average loss: 3.5997
# Iteration: 390; Percent complete: 7.8%; Average loss: 3.6356
# Iteration: 391; Percent complete: 7.8%; Average loss: 3.6183
# Iteration: 392; Percent complete: 7.8%; Average loss: 3.6259
# Iteration: 393; Percent complete: 7.9%; Average loss: 3.6251
# Iteration: 394; Percent complete: 7.9%; Average loss: 3.6143
# Iteration: 395; Percent complete: 7.9%; Average loss: 3.5502
# Iteration: 396; Percent complete: 7.9%; Average loss: 3.6680
# Iteration: 397; Percent complete: 7.9%; Average loss: 3.5841
# Iteration: 398; Percent complete: 8.0%; Average loss: 3.5683
# Iteration: 399; Percent complete: 8.0%; Average loss: 3.6003
# Iteration: 400; Percent complete: 8.0%; Average loss: 3.6266
# Iteration: 401; Percent complete: 8.0%; Average loss: 3.6107
# Iteration: 402; Percent complete: 8.0%; Average loss: 3.6045
# Iteration: 403; Percent complete: 8.1%; Average loss: 3.6149
# Iteration: 404; Percent complete: 8.1%; Average loss: 3.5891
# Iteration: 405; Percent complete: 8.1%; Average loss: 3.6037
# Iteration: 406; Percent complete: 8.1%; Average loss: 3.6182
# Iteration: 407; Percent complete: 8.1%; Average loss: 3.5862
# Iteration: 408; Percent complete: 8.2%; Average loss: 3.5561
# Iteration: 409; Percent complete: 8.2%; Average loss: 3.5632
# Iteration: 410; Percent complete: 8.2%; Average loss: 3.6035
# Iteration: 411; Percent complete: 8.2%; Average loss: 3.6329
# Iteration: 412; Percent complete: 8.2%; Average loss: 3.5735
# Iteration: 413; Percent complete: 8.3%; Average loss: 3.6031
# Iteration: 414; Percent complete: 8.3%; Average loss: 3.5539
# Iteration: 415; Percent complete: 8.3%; Average loss: 3.6140
# Iteration: 416; Percent complete: 8.3%; Average loss: 3.5671
# Iteration: 417; Percent complete: 8.3%; Average loss: 3.5700
# Iteration: 418; Percent complete: 8.4%; Average loss: 3.5913
# Iteration: 419; Percent complete: 8.4%; Average loss: 3.5923
# Iteration: 420; Percent complete: 8.4%; Average loss: 3.6020
# Iteration: 421; Percent complete: 8.4%; Average loss: 3.5941
# Iteration: 422; Percent complete: 8.4%; Average loss: 3.6056
# Iteration: 423; Percent complete: 8.5%; Average loss: 3.5422
# Iteration: 424; Percent complete: 8.5%; Average loss: 3.5574
# Iteration: 425; Percent complete: 8.5%; Average loss: 3.5218
# Iteration: 426; Percent complete: 8.5%; Average loss: 3.5747
# Iteration: 427; Percent complete: 8.5%; Average loss: 3.5593
# Iteration: 428; Percent complete: 8.6%; Average loss: 3.5617
# Iteration: 429; Percent complete: 8.6%; Average loss: 3.5406
# Iteration: 430; Percent complete: 8.6%; Average loss: 3.5995
# Iteration: 431; Percent complete: 8.6%; Average loss: 3.5543
# Iteration: 432; Percent complete: 8.6%; Average loss: 3.5464
# Iteration: 433; Percent complete: 8.7%; Average loss: 3.5601
# Iteration: 434; Percent complete: 8.7%; Average loss: 3.5513
# Iteration: 435; Percent complete: 8.7%; Average loss: 3.6748
# Iteration: 436; Percent complete: 8.7%; Average loss: 3.5596
# Iteration: 437; Percent complete: 8.7%; Average loss: 3.5549
# Iteration: 438; Percent complete: 8.8%; Average loss: 3.5599
# Iteration: 439; Percent complete: 8.8%; Average loss: 3.5708
# Iteration: 440; Percent complete: 8.8%; Average loss: 3.5898
# Iteration: 441; Percent complete: 8.8%; Average loss: 3.5358
# Iteration: 442; Percent complete: 8.8%; Average loss: 3.5253
# Iteration: 443; Percent complete: 8.9%; Average loss: 3.5403
# Iteration: 444; Percent complete: 8.9%; Average loss: 3.5183
# Iteration: 445; Percent complete: 8.9%; Average loss: 3.5493
# Iteration: 446; Percent complete: 8.9%; Average loss: 3.5058
# Iteration: 447; Percent complete: 8.9%; Average loss: 3.5972
# Iteration: 448; Percent complete: 9.0%; Average loss: 3.5315
# Iteration: 449; Percent complete: 9.0%; Average loss: 3.5100
# Iteration: 450; Percent complete: 9.0%; Average loss: 3.5527
# Iteration: 451; Percent complete: 9.0%; Average loss: 3.5310
# Iteration: 452; Percent complete: 9.0%; Average loss: 3.5130
# Iteration: 453; Percent complete: 9.1%; Average loss: 3.5262
# Iteration: 454; Percent complete: 9.1%; Average loss: 3.4934
# Iteration: 455; Percent complete: 9.1%; Average loss: 3.5151
# Iteration: 456; Percent complete: 9.1%; Average loss: 3.4839
# Iteration: 457; Percent complete: 9.1%; Average loss: 3.4771
# Iteration: 458; Percent complete: 9.2%; Average loss: 3.5212
# Iteration: 459; Percent complete: 9.2%; Average loss: 3.4223
# Iteration: 460; Percent complete: 9.2%; Average loss: 3.5311
# Iteration: 461; Percent complete: 9.2%; Average loss: 3.5725
# Iteration: 462; Percent complete: 9.2%; Average loss: 3.5022
# Iteration: 463; Percent complete: 9.3%; Average loss: 3.5374
# Iteration: 464; Percent complete: 9.3%; Average loss: 3.5775
# Iteration: 465; Percent complete: 9.3%; Average loss: 3.5527
# Iteration: 466; Percent complete: 9.3%; Average loss: 3.4548
# Iteration: 467; Percent complete: 9.3%; Average loss: 3.5399
# Iteration: 468; Percent complete: 9.4%; Average loss: 3.4886
# Iteration: 469; Percent complete: 9.4%; Average loss: 3.4657
# Iteration: 470; Percent complete: 9.4%; Average loss: 3.4968
# Iteration: 471; Percent complete: 9.4%; Average loss: 3.5173
# Iteration: 472; Percent complete: 9.4%; Average loss: 3.5487
# Iteration: 473; Percent complete: 9.5%; Average loss: 3.5578
# Iteration: 474; Percent complete: 9.5%; Average loss: 3.5096
# Iteration: 475; Percent complete: 9.5%; Average loss: 3.5127
# Iteration: 476; Percent complete: 9.5%; Average loss: 3.4550
# Iteration: 477; Percent complete: 9.5%; Average loss: 3.4901
# Iteration: 478; Percent complete: 9.6%; Average loss: 3.5001
# Iteration: 479; Percent complete: 9.6%; Average loss: 3.4860
# Iteration: 480; Percent complete: 9.6%; Average loss: 3.4922
# Iteration: 481; Percent complete: 9.6%; Average loss: 3.4264
# Iteration: 482; Percent complete: 9.6%; Average loss: 3.4723
# Iteration: 483; Percent complete: 9.7%; Average loss: 3.5218
# Iteration: 484; Percent complete: 9.7%; Average loss: 3.5203
# Iteration: 485; Percent complete: 9.7%; Average loss: 3.4918
# Iteration: 486; Percent complete: 9.7%; Average loss: 3.5174
# Iteration: 487; Percent complete: 9.7%; Average loss: 3.4636
# Iteration: 488; Percent complete: 9.8%; Average loss: 3.4954
# Iteration: 489; Percent complete: 9.8%; Average loss: 3.5291
# Iteration: 490; Percent complete: 9.8%; Average loss: 3.4938
# Iteration: 491; Percent complete: 9.8%; Average loss: 3.4399
# Iteration: 492; Percent complete: 9.8%; Average loss: 3.4648
# Iteration: 493; Percent complete: 9.9%; Average loss: 3.5004
# Iteration: 494; Percent complete: 9.9%; Average loss: 3.5235
# Iteration: 495; Percent complete: 9.9%; Average loss: 3.5014
# Iteration: 496; Percent complete: 9.9%; Average loss: 3.4778
# Iteration: 497; Percent complete: 9.9%; Average loss: 3.5067
# Iteration: 498; Percent complete: 10.0%; Average loss: 3.4690
# Iteration: 499; Percent complete: 10.0%; Average loss: 3.4785
# Iteration: 500; Percent complete: 10.0%; Average loss: 3.5489
# Iteration: 501; Percent complete: 10.0%; Average loss: 3.4474
# Iteration: 502; Percent complete: 10.0%; Average loss: 3.4923
# Iteration: 503; Percent complete: 10.1%; Average loss: 3.4957
# Iteration: 504; Percent complete: 10.1%; Average loss: 3.4752
# Iteration: 505; Percent complete: 10.1%; Average loss: 3.4444
# Iteration: 506; Percent complete: 10.1%; Average loss: 3.4330
# Iteration: 507; Percent complete: 10.1%; Average loss: 3.4194
# Iteration: 508; Percent complete: 10.2%; Average loss: 3.4466
# Iteration: 509; Percent complete: 10.2%; Average loss: 3.4749
# Iteration: 510; Percent complete: 10.2%; Average loss: 3.5130
# Iteration: 511; Percent complete: 10.2%; Average loss: 3.4517
# Iteration: 512; Percent complete: 10.2%; Average loss: 3.4709
# Iteration: 513; Percent complete: 10.3%; Average loss: 3.4016
# Iteration: 514; Percent complete: 10.3%; Average loss: 3.4582
# Iteration: 515; Percent complete: 10.3%; Average loss: 3.4651
# Iteration: 516; Percent complete: 10.3%; Average loss: 3.3941
# Iteration: 517; Percent complete: 10.3%; Average loss: 3.4630
# Iteration: 518; Percent complete: 10.4%; Average loss: 3.4615
# Iteration: 519; Percent complete: 10.4%; Average loss: 3.4241
# Iteration: 520; Percent complete: 10.4%; Average loss: 3.4400
# Iteration: 521; Percent complete: 10.4%; Average loss: 3.4444
# Iteration: 522; Percent complete: 10.4%; Average loss: 3.4614
# Iteration: 523; Percent complete: 10.5%; Average loss: 3.4041
# Iteration: 524; Percent complete: 10.5%; Average loss: 3.4350
# Iteration: 525; Percent complete: 10.5%; Average loss: 3.4706
# Iteration: 526; Percent complete: 10.5%; Average loss: 3.4699
# Iteration: 527; Percent complete: 10.5%; Average loss: 3.4539
# Iteration: 528; Percent complete: 10.6%; Average loss: 3.4988
# Iteration: 529; Percent complete: 10.6%; Average loss: 3.3865
# Iteration: 530; Percent complete: 10.6%; Average loss: 3.3784
# Iteration: 531; Percent complete: 10.6%; Average loss: 3.5402
# Iteration: 532; Percent complete: 10.6%; Average loss: 3.4654
# Iteration: 533; Percent complete: 10.7%; Average loss: 3.4114
# Iteration: 534; Percent complete: 10.7%; Average loss: 3.4594
# Iteration: 535; Percent complete: 10.7%; Average loss: 3.4451
# Iteration: 536; Percent complete: 10.7%; Average loss: 3.3387
# Iteration: 537; Percent complete: 10.7%; Average loss: 3.4390
# Iteration: 538; Percent complete: 10.8%; Average loss: 3.3910
# Iteration: 539; Percent complete: 10.8%; Average loss: 3.4401
# Iteration: 540; Percent complete: 10.8%; Average loss: 3.4434
# Iteration: 541; Percent complete: 10.8%; Average loss: 3.4354
# Iteration: 542; Percent complete: 10.8%; Average loss: 3.3685
# Iteration: 543; Percent complete: 10.9%; Average loss: 3.4624
# Iteration: 544; Percent complete: 10.9%; Average loss: 3.3960
# Iteration: 545; Percent complete: 10.9%; Average loss: 3.3982
# Iteration: 546; Percent complete: 10.9%; Average loss: 3.4397
# Iteration: 547; Percent complete: 10.9%; Average loss: 3.4062
# Iteration: 548; Percent complete: 11.0%; Average loss: 3.3895
# Iteration: 549; Percent complete: 11.0%; Average loss: 3.4277
# Iteration: 550; Percent complete: 11.0%; Average loss: 3.3974
# Iteration: 551; Percent complete: 11.0%; Average loss: 3.4224
# Iteration: 552; Percent complete: 11.0%; Average loss: 3.3679
# Iteration: 553; Percent complete: 11.1%; Average loss: 3.4039
# Iteration: 554; Percent complete: 11.1%; Average loss: 3.3870
# Iteration: 555; Percent complete: 11.1%; Average loss: 3.4131
# Iteration: 556; Percent complete: 11.1%; Average loss: 3.3740
# Iteration: 557; Percent complete: 11.1%; Average loss: 3.3957
# Iteration: 558; Percent complete: 11.2%; Average loss: 3.4783
# Iteration: 559; Percent complete: 11.2%; Average loss: 3.3888
# Iteration: 560; Percent complete: 11.2%; Average loss: 3.4001
# Iteration: 561; Percent complete: 11.2%; Average loss: 3.4104
# Iteration: 562; Percent complete: 11.2%; Average loss: 3.3940
# Iteration: 563; Percent complete: 11.3%; Average loss: 3.3873
# Iteration: 564; Percent complete: 11.3%; Average loss: 3.3838
# Iteration: 565; Percent complete: 11.3%; Average loss: 3.4012
# Iteration: 566; Percent complete: 11.3%; Average loss: 3.3966
# Iteration: 567; Percent complete: 11.3%; Average loss: 3.3773
# Iteration: 568; Percent complete: 11.4%; Average loss: 3.4409
# Iteration: 569; Percent complete: 11.4%; Average loss: 3.3811
# Iteration: 570; Percent complete: 11.4%; Average loss: 3.3664
# Iteration: 571; Percent complete: 11.4%; Average loss: 3.3861
# Iteration: 572; Percent complete: 11.4%; Average loss: 3.3754
# Iteration: 573; Percent complete: 11.5%; Average loss: 3.4029
# Iteration: 574; Percent complete: 11.5%; Average loss: 3.3542
# Iteration: 575; Percent complete: 11.5%; Average loss: 3.4347
# Iteration: 576; Percent complete: 11.5%; Average loss: 3.3969
# Iteration: 577; Percent complete: 11.5%; Average loss: 3.3807
# Iteration: 578; Percent complete: 11.6%; Average loss: 3.3969
# Iteration: 579; Percent complete: 11.6%; Average loss: 3.3762
# Iteration: 580; Percent complete: 11.6%; Average loss: 3.3876
# Iteration: 581; Percent complete: 11.6%; Average loss: 3.3369
# Iteration: 582; Percent complete: 11.6%; Average loss: 3.3579
# Iteration: 583; Percent complete: 11.7%; Average loss: 3.4055
# Iteration: 584; Percent complete: 11.7%; Average loss: 3.4047
# Iteration: 585; Percent complete: 11.7%; Average loss: 3.3245
# Iteration: 586; Percent complete: 11.7%; Average loss: 3.3136
# Iteration: 587; Percent complete: 11.7%; Average loss: 3.3446
# Iteration: 588; Percent complete: 11.8%; Average loss: 3.3856
# Iteration: 589; Percent complete: 11.8%; Average loss: 3.3707
# Iteration: 590; Percent complete: 11.8%; Average loss: 3.3586
# Iteration: 591; Percent complete: 11.8%; Average loss: 3.3902
# Iteration: 592; Percent complete: 11.8%; Average loss: 3.3312
# Iteration: 593; Percent complete: 11.9%; Average loss: 3.3593
# Iteration: 594; Percent complete: 11.9%; Average loss: 3.3340
# Iteration: 595; Percent complete: 11.9%; Average loss: 3.3182
# Iteration: 596; Percent complete: 11.9%; Average loss: 3.4424
# Iteration: 597; Percent complete: 11.9%; Average loss: 3.3726
# Iteration: 598; Percent complete: 12.0%; Average loss: 3.3952
# Iteration: 599; Percent complete: 12.0%; Average loss: 3.3388
# Iteration: 600; Percent complete: 12.0%; Average loss: 3.3480
# Iteration: 601; Percent complete: 12.0%; Average loss: 3.2850
# Iteration: 602; Percent complete: 12.0%; Average loss: 3.3591
# Iteration: 603; Percent complete: 12.1%; Average loss: 3.3266
# Iteration: 604; Percent complete: 12.1%; Average loss: 3.3541
# Iteration: 605; Percent complete: 12.1%; Average loss: 3.4035
# Iteration: 606; Percent complete: 12.1%; Average loss: 3.3111
# Iteration: 607; Percent complete: 12.1%; Average loss: 3.3364
# Iteration: 608; Percent complete: 12.2%; Average loss: 3.3672
# Iteration: 609; Percent complete: 12.2%; Average loss: 3.3515
# Iteration: 610; Percent complete: 12.2%; Average loss: 3.3021
# Iteration: 611; Percent complete: 12.2%; Average loss: 3.3559
# Iteration: 612; Percent complete: 12.2%; Average loss: 3.2939
# Iteration: 613; Percent complete: 12.3%; Average loss: 3.2918
# Iteration: 614; Percent complete: 12.3%; Average loss: 3.3025
# Iteration: 615; Percent complete: 12.3%; Average loss: 3.3539
# Iteration: 616; Percent complete: 12.3%; Average loss: 3.3847
# Iteration: 617; Percent complete: 12.3%; Average loss: 3.2973
# Iteration: 618; Percent complete: 12.4%; Average loss: 3.3101
# Iteration: 619; Percent complete: 12.4%; Average loss: 3.3226
# Iteration: 620; Percent complete: 12.4%; Average loss: 3.3592
# Iteration: 621; Percent complete: 12.4%; Average loss: 3.3489
# Iteration: 622; Percent complete: 12.4%; Average loss: 3.3265
# Iteration: 623; Percent complete: 12.5%; Average loss: 3.3143
# Iteration: 624; Percent complete: 12.5%; Average loss: 3.3468
# Iteration: 625; Percent complete: 12.5%; Average loss: 3.2932
# Iteration: 626; Percent complete: 12.5%; Average loss: 3.2947
# Iteration: 627; Percent complete: 12.5%; Average loss: 3.3243
# Iteration: 628; Percent complete: 12.6%; Average loss: 3.3049
# Iteration: 629; Percent complete: 12.6%; Average loss: 3.3923
# Iteration: 630; Percent complete: 12.6%; Average loss: 3.3204
# Iteration: 631; Percent complete: 12.6%; Average loss: 3.3002
# Iteration: 632; Percent complete: 12.6%; Average loss: 3.3443
# Iteration: 633; Percent complete: 12.7%; Average loss: 3.3503
# Iteration: 634; Percent complete: 12.7%; Average loss: 3.2797
# Iteration: 635; Percent complete: 12.7%; Average loss: 3.3007
# Iteration: 636; Percent complete: 12.7%; Average loss: 3.3012
# Iteration: 637; Percent complete: 12.7%; Average loss: 3.2941
# Iteration: 638; Percent complete: 12.8%; Average loss: 3.3456
# Iteration: 639; Percent complete: 12.8%; Average loss: 3.3207
# Iteration: 640; Percent complete: 12.8%; Average loss: 3.3044
# Iteration: 641; Percent complete: 12.8%; Average loss: 3.2653
# Iteration: 642; Percent complete: 12.8%; Average loss: 3.3255
# Iteration: 643; Percent complete: 12.9%; Average loss: 3.2767
# Iteration: 644; Percent complete: 12.9%; Average loss: 3.2904
# Iteration: 645; Percent complete: 12.9%; Average loss: 3.2882
# Iteration: 646; Percent complete: 12.9%; Average loss: 3.3094
# Iteration: 647; Percent complete: 12.9%; Average loss: 3.2357
# Iteration: 648; Percent complete: 13.0%; Average loss: 3.3578
# Iteration: 649; Percent complete: 13.0%; Average loss: 3.2730
# Iteration: 650; Percent complete: 13.0%; Average loss: 3.3186
# Iteration: 651; Percent complete: 13.0%; Average loss: 3.2424
# Iteration: 652; Percent complete: 13.0%; Average loss: 3.2164
# Iteration: 653; Percent complete: 13.1%; Average loss: 3.2829
# Iteration: 654; Percent complete: 13.1%; Average loss: 3.2433
# Iteration: 655; Percent complete: 13.1%; Average loss: 3.3111
# Iteration: 656; Percent complete: 13.1%; Average loss: 3.2536
# Iteration: 657; Percent complete: 13.1%; Average loss: 3.2901
# Iteration: 658; Percent complete: 13.2%; Average loss: 3.3030
# Iteration: 659; Percent complete: 13.2%; Average loss: 3.3081
# Iteration: 660; Percent complete: 13.2%; Average loss: 3.2635
# Iteration: 661; Percent complete: 13.2%; Average loss: 3.3329
# Iteration: 662; Percent complete: 13.2%; Average loss: 3.2392
# Iteration: 663; Percent complete: 13.3%; Average loss: 3.1949
# Iteration: 664; Percent complete: 13.3%; Average loss: 3.3507
# Iteration: 665; Percent complete: 13.3%; Average loss: 3.3406
# Iteration: 666; Percent complete: 13.3%; Average loss: 3.2504
# Iteration: 667; Percent complete: 13.3%; Average loss: 3.2353
# Iteration: 668; Percent complete: 13.4%; Average loss: 3.2055
# Iteration: 669; Percent complete: 13.4%; Average loss: 3.1724
# Iteration: 670; Percent complete: 13.4%; Average loss: 3.2930
# Iteration: 671; Percent complete: 13.4%; Average loss: 3.2791
# Iteration: 672; Percent complete: 13.4%; Average loss: 3.2825
# Iteration: 673; Percent complete: 13.5%; Average loss: 3.2728
# Iteration: 674; Percent complete: 13.5%; Average loss: 3.2657
# Iteration: 675; Percent complete: 13.5%; Average loss: 3.3077
# Iteration: 676; Percent complete: 13.5%; Average loss: 3.2944
# Iteration: 677; Percent complete: 13.5%; Average loss: 3.3255
# Iteration: 678; Percent complete: 13.6%; Average loss: 3.2804
# Iteration: 679; Percent complete: 13.6%; Average loss: 3.2630
# Iteration: 680; Percent complete: 13.6%; Average loss: 3.2402
# Iteration: 681; Percent complete: 13.6%; Average loss: 3.3096
# Iteration: 682; Percent complete: 13.6%; Average loss: 3.2401
# Iteration: 683; Percent complete: 13.7%; Average loss: 3.2329
# Iteration: 684; Percent complete: 13.7%; Average loss: 3.2800
# Iteration: 685; Percent complete: 13.7%; Average loss: 3.2787
# Iteration: 686; Percent complete: 13.7%; Average loss: 3.2812
# Iteration: 687; Percent complete: 13.7%; Average loss: 3.2681
# Iteration: 688; Percent complete: 13.8%; Average loss: 3.2665
# Iteration: 689; Percent complete: 13.8%; Average loss: 3.2431
# Iteration: 690; Percent complete: 13.8%; Average loss: 3.2482
# Iteration: 691; Percent complete: 13.8%; Average loss: 3.2642
# Iteration: 692; Percent complete: 13.8%; Average loss: 3.2807
# Iteration: 693; Percent complete: 13.9%; Average loss: 3.2725
# Iteration: 694; Percent complete: 13.9%; Average loss: 3.2051
# Iteration: 695; Percent complete: 13.9%; Average loss: 3.2422
# Iteration: 696; Percent complete: 13.9%; Average loss: 3.2121
# Iteration: 697; Percent complete: 13.9%; Average loss: 3.2112
# Iteration: 698; Percent complete: 14.0%; Average loss: 3.2286
# Iteration: 699; Percent complete: 14.0%; Average loss: 3.2471
# Iteration: 700; Percent complete: 14.0%; Average loss: 3.2474
# Iteration: 701; Percent complete: 14.0%; Average loss: 3.2334
# Iteration: 702; Percent complete: 14.0%; Average loss: 3.2845
# Iteration: 703; Percent complete: 14.1%; Average loss: 3.2590
# Iteration: 704; Percent complete: 14.1%; Average loss: 3.2500
# Iteration: 705; Percent complete: 14.1%; Average loss: 3.1654
# Iteration: 706; Percent complete: 14.1%; Average loss: 3.1731
# Iteration: 707; Percent complete: 14.1%; Average loss: 3.2449
# Iteration: 708; Percent complete: 14.2%; Average loss: 3.2758
# Iteration: 709; Percent complete: 14.2%; Average loss: 3.3277
# Iteration: 710; Percent complete: 14.2%; Average loss: 3.1929
# Iteration: 711; Percent complete: 14.2%; Average loss: 3.2108
# Iteration: 712; Percent complete: 14.2%; Average loss: 3.2136
# Iteration: 713; Percent complete: 14.3%; Average loss: 3.2094
# Iteration: 714; Percent complete: 14.3%; Average loss: 3.2573
# Iteration: 715; Percent complete: 14.3%; Average loss: 3.2381
# Iteration: 716; Percent complete: 14.3%; Average loss: 3.2505
# Iteration: 717; Percent complete: 14.3%; Average loss: 3.2324
# Iteration: 718; Percent complete: 14.4%; Average loss: 3.2274
# Iteration: 719; Percent complete: 14.4%; Average loss: 3.1825
# Iteration: 720; Percent complete: 14.4%; Average loss: 3.1910
# Iteration: 721; Percent complete: 14.4%; Average loss: 3.3064
# Iteration: 722; Percent complete: 14.4%; Average loss: 3.1865
# Iteration: 723; Percent complete: 14.5%; Average loss: 3.2017
# Iteration: 724; Percent complete: 14.5%; Average loss: 3.1869
# Iteration: 725; Percent complete: 14.5%; Average loss: 3.2433
# Iteration: 726; Percent complete: 14.5%; Average loss: 3.2450
# Iteration: 727; Percent complete: 14.5%; Average loss: 3.2135
# Iteration: 728; Percent complete: 14.6%; Average loss: 3.2098
# Iteration: 729; Percent complete: 14.6%; Average loss: 3.2232
# Iteration: 730; Percent complete: 14.6%; Average loss: 3.1898
# Iteration: 731; Percent complete: 14.6%; Average loss: 3.1920
# Iteration: 732; Percent complete: 14.6%; Average loss: 3.1847
# Iteration: 733; Percent complete: 14.7%; Average loss: 3.2246
# Iteration: 734; Percent complete: 14.7%; Average loss: 3.1600
# Iteration: 735; Percent complete: 14.7%; Average loss: 3.1850
# Iteration: 736; Percent complete: 14.7%; Average loss: 3.2495
# Iteration: 737; Percent complete: 14.7%; Average loss: 3.2082
# Iteration: 738; Percent complete: 14.8%; Average loss: 3.2283
# Iteration: 739; Percent complete: 14.8%; Average loss: 3.2440
# Iteration: 740; Percent complete: 14.8%; Average loss: 3.1726
# Iteration: 741; Percent complete: 14.8%; Average loss: 3.1424
# Iteration: 742; Percent complete: 14.8%; Average loss: 3.1581
# Iteration: 743; Percent complete: 14.9%; Average loss: 3.2437
# Iteration: 744; Percent complete: 14.9%; Average loss: 3.2201
# Iteration: 745; Percent complete: 14.9%; Average loss: 3.2264
# Iteration: 746; Percent complete: 14.9%; Average loss: 3.2063
# Iteration: 747; Percent complete: 14.9%; Average loss: 3.1886
# Iteration: 748; Percent complete: 15.0%; Average loss: 3.2379
# Iteration: 749; Percent complete: 15.0%; Average loss: 3.2075
# Iteration: 750; Percent complete: 15.0%; Average loss: 3.1898
# Iteration: 751; Percent complete: 15.0%; Average loss: 3.2320
# Iteration: 752; Percent complete: 15.0%; Average loss: 3.2340
# Iteration: 753; Percent complete: 15.1%; Average loss: 3.1275
# Iteration: 754; Percent complete: 15.1%; Average loss: 3.1858
# Iteration: 755; Percent complete: 15.1%; Average loss: 3.2230
# Iteration: 756; Percent complete: 15.1%; Average loss: 3.2227
# Iteration: 757; Percent complete: 15.1%; Average loss: 3.1692
# Iteration: 758; Percent complete: 15.2%; Average loss: 3.1731
# Iteration: 759; Percent complete: 15.2%; Average loss: 3.1775
# Iteration: 760; Percent complete: 15.2%; Average loss: 3.1540
# Iteration: 761; Percent complete: 15.2%; Average loss: 3.1139
# Iteration: 762; Percent complete: 15.2%; Average loss: 3.2062
# Iteration: 763; Percent complete: 15.3%; Average loss: 3.1889
# Iteration: 764; Percent complete: 15.3%; Average loss: 3.1834
# Iteration: 765; Percent complete: 15.3%; Average loss: 3.1683
# Iteration: 766; Percent complete: 15.3%; Average loss: 3.2019
# Iteration: 767; Percent complete: 15.3%; Average loss: 3.2449
# Iteration: 768; Percent complete: 15.4%; Average loss: 3.1362
# Iteration: 769; Percent complete: 15.4%; Average loss: 3.1925
# Iteration: 770; Percent complete: 15.4%; Average loss: 3.1675
# Iteration: 771; Percent complete: 15.4%; Average loss: 3.1671
# Iteration: 772; Percent complete: 15.4%; Average loss: 3.1113
# Iteration: 773; Percent complete: 15.5%; Average loss: 3.1589
# Iteration: 774; Percent complete: 15.5%; Average loss: 3.1538
# Iteration: 775; Percent complete: 15.5%; Average loss: 3.1464
# Iteration: 776; Percent complete: 15.5%; Average loss: 3.1321
# Iteration: 777; Percent complete: 15.5%; Average loss: 3.2160
# Iteration: 778; Percent complete: 15.6%; Average loss: 3.1310
# Iteration: 779; Percent complete: 15.6%; Average loss: 3.1118
# Iteration: 780; Percent complete: 15.6%; Average loss: 3.0427
# Iteration: 781; Percent complete: 15.6%; Average loss: 3.1344
# Iteration: 782; Percent complete: 15.6%; Average loss: 3.1508
# ...
# Iteration: 4748; Percent complete: 95.0%; Average loss: 0.2659
# Iteration: 4749; Percent complete: 95.0%; Average loss: 0.2596
# Iteration: 4750; Percent complete: 95.0%; Average loss: 0.2695
# Iteration: 4751; Percent complete: 95.0%; Average loss: 0.2595
# Iteration: 4752; Percent complete: 95.0%; Average loss: 0.2377
# Iteration: 4753; Percent complete: 95.1%; Average loss: 0.2637
# Iteration: 4754; Percent complete: 95.1%; Average loss: 0.2683
# Iteration: 4755; Percent complete: 95.1%; Average loss: 0.2487
# Iteration: 4756; Percent complete: 95.1%; Average loss: 0.2846
# Iteration: 4757; Percent complete: 95.1%; Average loss: 0.2715
# Iteration: 4758; Percent complete: 95.2%; Average loss: 0.2834
# Iteration: 4759; Percent complete: 95.2%; Average loss: 0.2803
# Iteration: 4760; Percent complete: 95.2%; Average loss: 0.2850
# Iteration: 4761; Percent complete: 95.2%; Average loss: 0.2655
# Iteration: 4762; Percent complete: 95.2%; Average loss: 0.2626
# Iteration: 4763; Percent complete: 95.3%; Average loss: 0.2425
# Iteration: 4764; Percent complete: 95.3%; Average loss: 0.2657
# Iteration: 4765; Percent complete: 95.3%; Average loss: 0.2703
# Iteration: 4766; Percent complete: 95.3%; Average loss: 0.2768
# Iteration: 4767; Percent complete: 95.3%; Average loss: 0.2422
# Iteration: 4768; Percent complete: 95.4%; Average loss: 0.2598
# Iteration: 4769; Percent complete: 95.4%; Average loss: 0.2893
# Iteration: 4770; Percent complete: 95.4%; Average loss: 0.2642
# Iteration: 4771; Percent complete: 95.4%; Average loss: 0.2807
# Iteration: 4772; Percent complete: 95.4%; Average loss: 0.2721
# Iteration: 4773; Percent complete: 95.5%; Average loss: 0.2836
# Iteration: 4774; Percent complete: 95.5%; Average loss: 0.2585
# Iteration: 4775; Percent complete: 95.5%; Average loss: 0.2718
# Iteration: 4776; Percent complete: 95.5%; Average loss: 0.2618
# Iteration: 4777; Percent complete: 95.5%; Average loss: 0.2672
# Iteration: 4778; Percent complete: 95.6%; Average loss: 0.2612
# Iteration: 4779; Percent complete: 95.6%; Average loss: 0.2623
# Iteration: 4780; Percent complete: 95.6%; Average loss: 0.2561
# Iteration: 4781; Percent complete: 95.6%; Average loss: 0.2553
# Iteration: 4782; Percent complete: 95.6%; Average loss: 0.2585
# Iteration: 4783; Percent complete: 95.7%; Average loss: 0.2644
# Iteration: 4784; Percent complete: 95.7%; Average loss: 0.2774
# Iteration: 4785; Percent complete: 95.7%; Average loss: 0.2405
# Iteration: 4786; Percent complete: 95.7%; Average loss: 0.2700
# Iteration: 4787; Percent complete: 95.7%; Average loss: 0.2632
# Iteration: 4788; Percent complete: 95.8%; Average loss: 0.2503
# Iteration: 4789; Percent complete: 95.8%; Average loss: 0.2593
# Iteration: 4790; Percent complete: 95.8%; Average loss: 0.2717
# Iteration: 4791; Percent complete: 95.8%; Average loss: 0.2576
# Iteration: 4792; Percent complete: 95.8%; Average loss: 0.2650
# Iteration: 4793; Percent complete: 95.9%; Average loss: 0.2626
# Iteration: 4794; Percent complete: 95.9%; Average loss: 0.2462
# Iteration: 4795; Percent complete: 95.9%; Average loss: 0.2687
# Iteration: 4796; Percent complete: 95.9%; Average loss: 0.2648
# Iteration: 4797; Percent complete: 95.9%; Average loss: 0.2595
# Iteration: 4798; Percent complete: 96.0%; Average loss: 0.2372
# Iteration: 4799; Percent complete: 96.0%; Average loss: 0.2499
# Iteration: 4800; Percent complete: 96.0%; Average loss: 0.2517
# Iteration: 4801; Percent complete: 96.0%; Average loss: 0.2785
# Iteration: 4802; Percent complete: 96.0%; Average loss: 0.2649
# Iteration: 4803; Percent complete: 96.1%; Average loss: 0.2581
# Iteration: 4804; Percent complete: 96.1%; Average loss: 0.2429
# Iteration: 4805; Percent complete: 96.1%; Average loss: 0.2566
# Iteration: 4806; Percent complete: 96.1%; Average loss: 0.2526
# Iteration: 4807; Percent complete: 96.1%; Average loss: 0.2618
# Iteration: 4808; Percent complete: 96.2%; Average loss: 0.2350
# Iteration: 4809; Percent complete: 96.2%; Average loss: 0.2533
# Iteration: 4810; Percent complete: 96.2%; Average loss: 0.2658
# Iteration: 4811; Percent complete: 96.2%; Average loss: 0.2520
# Iteration: 4812; Percent complete: 96.2%; Average loss: 0.2841
# Iteration: 4813; Percent complete: 96.3%; Average loss: 0.2589
# Iteration: 4814; Percent complete: 96.3%; Average loss: 0.2479
# Iteration: 4815; Percent complete: 96.3%; Average loss: 0.2661
# Iteration: 4816; Percent complete: 96.3%; Average loss: 0.2748
# Iteration: 4817; Percent complete: 96.3%; Average loss: 0.2785
# Iteration: 4818; Percent complete: 96.4%; Average loss: 0.2586
# Iteration: 4819; Percent complete: 96.4%; Average loss: 0.2561
# Iteration: 4820; Percent complete: 96.4%; Average loss: 0.2444
# Iteration: 4821; Percent complete: 96.4%; Average loss: 0.2554
# Iteration: 4822; Percent complete: 96.4%; Average loss: 0.2591
# Iteration: 4823; Percent complete: 96.5%; Average loss: 0.2681
# Iteration: 4824; Percent complete: 96.5%; Average loss: 0.2605
# Iteration: 4825; Percent complete: 96.5%; Average loss: 0.2803
# Iteration: 4826; Percent complete: 96.5%; Average loss: 0.2773
# Iteration: 4827; Percent complete: 96.5%; Average loss: 0.2722
# Iteration: 4828; Percent complete: 96.6%; Average loss: 0.2698
# Iteration: 4829; Percent complete: 96.6%; Average loss: 0.2698
# Iteration: 4830; Percent complete: 96.6%; Average loss: 0.2657
# Iteration: 4831; Percent complete: 96.6%; Average loss: 0.2473
# Iteration: 4832; Percent complete: 96.6%; Average loss: 0.2373
# Iteration: 4833; Percent complete: 96.7%; Average loss: 0.2676
# Iteration: 4834; Percent complete: 96.7%; Average loss: 0.2689
# Iteration: 4835; Percent complete: 96.7%; Average loss: 0.2554
# Iteration: 4836; Percent complete: 96.7%; Average loss: 0.2612
# Iteration: 4837; Percent complete: 96.7%; Average loss: 0.2890
# Iteration: 4838; Percent complete: 96.8%; Average loss: 0.2598
# Iteration: 4839; Percent complete: 96.8%; Average loss: 0.2498
# Iteration: 4840; Percent complete: 96.8%; Average loss: 0.2498
# Iteration: 4841; Percent complete: 96.8%; Average loss: 0.2741
# Iteration: 4842; Percent complete: 96.8%; Average loss: 0.2715
# Iteration: 4843; Percent complete: 96.9%; Average loss: 0.2601
# Iteration: 4844; Percent complete: 96.9%; Average loss: 0.2286
# Iteration: 4845; Percent complete: 96.9%; Average loss: 0.2552
# Iteration: 4846; Percent complete: 96.9%; Average loss: 0.2691
# Iteration: 4847; Percent complete: 96.9%; Average loss: 0.2737
# Iteration: 4848; Percent complete: 97.0%; Average loss: 0.2422
# Iteration: 4849; Percent complete: 97.0%; Average loss: 0.2619
# Iteration: 4850; Percent complete: 97.0%; Average loss: 0.2658
# Iteration: 4851; Percent complete: 97.0%; Average loss: 0.2549
# Iteration: 4852; Percent complete: 97.0%; Average loss: 0.2683
# Iteration: 4853; Percent complete: 97.1%; Average loss: 0.2650
# Iteration: 4854; Percent complete: 97.1%; Average loss: 0.2637
# Iteration: 4855; Percent complete: 97.1%; Average loss: 0.2630
# Iteration: 4856; Percent complete: 97.1%; Average loss: 0.2571
# Iteration: 4857; Percent complete: 97.1%; Average loss: 0.2514
# Iteration: 4858; Percent complete: 97.2%; Average loss: 0.2794
# Iteration: 4859; Percent complete: 97.2%; Average loss: 0.2443
# Iteration: 4860; Percent complete: 97.2%; Average loss: 0.2778
# Iteration: 4861; Percent complete: 97.2%; Average loss: 0.2548
# Iteration: 4862; Percent complete: 97.2%; Average loss: 0.2744
# Iteration: 4863; Percent complete: 97.3%; Average loss: 0.2569
# Iteration: 4864; Percent complete: 97.3%; Average loss: 0.2360
# Iteration: 4865; Percent complete: 97.3%; Average loss: 0.2573
# Iteration: 4866; Percent complete: 97.3%; Average loss: 0.2880
# Iteration: 4867; Percent complete: 97.3%; Average loss: 0.2685
# Iteration: 4868; Percent complete: 97.4%; Average loss: 0.2612
# Iteration: 4869; Percent complete: 97.4%; Average loss: 0.2525
# Iteration: 4870; Percent complete: 97.4%; Average loss: 0.2708
# Iteration: 4871; Percent complete: 97.4%; Average loss: 0.2588
# Iteration: 4872; Percent complete: 97.4%; Average loss: 0.2521
# Iteration: 4873; Percent complete: 97.5%; Average loss: 0.2524
# Iteration: 4874; Percent complete: 97.5%; Average loss: 0.2452
# Iteration: 4875; Percent complete: 97.5%; Average loss: 0.2628
# Iteration: 4876; Percent complete: 97.5%; Average loss: 0.2745
# Iteration: 4877; Percent complete: 97.5%; Average loss: 0.2715
# Iteration: 4878; Percent complete: 97.6%; Average loss: 0.2829
# Iteration: 4879; Percent complete: 97.6%; Average loss: 0.2624
# Iteration: 4880; Percent complete: 97.6%; Average loss: 0.2684
# Iteration: 4881; Percent complete: 97.6%; Average loss: 0.2704
# Iteration: 4882; Percent complete: 97.6%; Average loss: 0.2800
# Iteration: 4883; Percent complete: 97.7%; Average loss: 0.2446
# Iteration: 4884; Percent complete: 97.7%; Average loss: 0.2715
# Iteration: 4885; Percent complete: 97.7%; Average loss: 0.2499
# Iteration: 4886; Percent complete: 97.7%; Average loss: 0.2715
# Iteration: 4887; Percent complete: 97.7%; Average loss: 0.2430
# Iteration: 4888; Percent complete: 97.8%; Average loss: 0.2824
# Iteration: 4889; Percent complete: 97.8%; Average loss: 0.2580
# Iteration: 4890; Percent complete: 97.8%; Average loss: 0.2569
# Iteration: 4891; Percent complete: 97.8%; Average loss: 0.2660
# Iteration: 4892; Percent complete: 97.8%; Average loss: 0.2557
# Iteration: 4893; Percent complete: 97.9%; Average loss: 0.2727
# Iteration: 4894; Percent complete: 97.9%; Average loss: 0.2360
# Iteration: 4895; Percent complete: 97.9%; Average loss: 0.2736
# Iteration: 4896; Percent complete: 97.9%; Average loss: 0.2676
# Iteration: 4897; Percent complete: 97.9%; Average loss: 0.2529
# Iteration: 4898; Percent complete: 98.0%; Average loss: 0.2623
# Iteration: 4899; Percent complete: 98.0%; Average loss: 0.2625
# Iteration: 4900; Percent complete: 98.0%; Average loss: 0.2599
# Iteration: 4901; Percent complete: 98.0%; Average loss: 0.2644
# Iteration: 4902; Percent complete: 98.0%; Average loss: 0.2657
# Iteration: 4903; Percent complete: 98.1%; Average loss: 0.2749
# Iteration: 4904; Percent complete: 98.1%; Average loss: 0.2656
# Iteration: 4905; Percent complete: 98.1%; Average loss: 0.2511
# Iteration: 4906; Percent complete: 98.1%; Average loss: 0.2614
# Iteration: 4907; Percent complete: 98.1%; Average loss: 0.2606
# Iteration: 4908; Percent complete: 98.2%; Average loss: 0.2580
# Iteration: 4909; Percent complete: 98.2%; Average loss: 0.2529
# Iteration: 4910; Percent complete: 98.2%; Average loss: 0.2462
# Iteration: 4911; Percent complete: 98.2%; Average loss: 0.2520
# Iteration: 4912; Percent complete: 98.2%; Average loss: 0.2586
# Iteration: 4913; Percent complete: 98.3%; Average loss: 0.2545
# Iteration: 4914; Percent complete: 98.3%; Average loss: 0.2615
# Iteration: 4915; Percent complete: 98.3%; Average loss: 0.2546
# Iteration: 4916; Percent complete: 98.3%; Average loss: 0.2305
# Iteration: 4917; Percent complete: 98.3%; Average loss: 0.2428
# Iteration: 4918; Percent complete: 98.4%; Average loss: 0.2621
# Iteration: 4919; Percent complete: 98.4%; Average loss: 0.2696
# Iteration: 4920; Percent complete: 98.4%; Average loss: 0.2687
# Iteration: 4921; Percent complete: 98.4%; Average loss: 0.2493
# Iteration: 4922; Percent complete: 98.4%; Average loss: 0.2323
# Iteration: 4923; Percent complete: 98.5%; Average loss: 0.2598
# Iteration: 4924; Percent complete: 98.5%; Average loss: 0.2518
# Iteration: 4925; Percent complete: 98.5%; Average loss: 0.2716
# Iteration: 4926; Percent complete: 98.5%; Average loss: 0.2470
# Iteration: 4927; Percent complete: 98.5%; Average loss: 0.2447
# Iteration: 4928; Percent complete: 98.6%; Average loss: 0.2356
# Iteration: 4929; Percent complete: 98.6%; Average loss: 0.2450
# Iteration: 4930; Percent complete: 98.6%; Average loss: 0.2292
# Iteration: 4931; Percent complete: 98.6%; Average loss: 0.2495
# Iteration: 4932; Percent complete: 98.6%; Average loss: 0.2423
# Iteration: 4933; Percent complete: 98.7%; Average loss: 0.2606
# Iteration: 4934; Percent complete: 98.7%; Average loss: 0.2558
# Iteration: 4935; Percent complete: 98.7%; Average loss: 0.2317
# Iteration: 4936; Percent complete: 98.7%; Average loss: 0.2442
# Iteration: 4937; Percent complete: 98.7%; Average loss: 0.2385
# Iteration: 4938; Percent complete: 98.8%; Average loss: 0.2657
# Iteration: 4939; Percent complete: 98.8%; Average loss: 0.2698
# Iteration: 4940; Percent complete: 98.8%; Average loss: 0.2555
# Iteration: 4941; Percent complete: 98.8%; Average loss: 0.2738
# Iteration: 4942; Percent complete: 98.8%; Average loss: 0.2584
# Iteration: 4943; Percent complete: 98.9%; Average loss: 0.2664
# Iteration: 4944; Percent complete: 98.9%; Average loss: 0.2469
# Iteration: 4945; Percent complete: 98.9%; Average loss: 0.2863
# Iteration: 4946; Percent complete: 98.9%; Average loss: 0.2356
# Iteration: 4947; Percent complete: 98.9%; Average loss: 0.2741
# Iteration: 4948; Percent complete: 99.0%; Average loss: 0.2568
# Iteration: 4949; Percent complete: 99.0%; Average loss: 0.2432
# Iteration: 4950; Percent complete: 99.0%; Average loss: 0.2420
# Iteration: 4951; Percent complete: 99.0%; Average loss: 0.2515
# Iteration: 4952; Percent complete: 99.0%; Average loss: 0.2676
# Iteration: 4953; Percent complete: 99.1%; Average loss: 0.2494
# Iteration: 4954; Percent complete: 99.1%; Average loss: 0.2663
# Iteration: 4955; Percent complete: 99.1%; Average loss: 0.2349
# Iteration: 4956; Percent complete: 99.1%; Average loss: 0.2597
# Iteration: 4957; Percent complete: 99.1%; Average loss: 0.2512
# Iteration: 4958; Percent complete: 99.2%; Average loss: 0.2639
# Iteration: 4959; Percent complete: 99.2%; Average loss: 0.2457
# Iteration: 4960; Percent complete: 99.2%; Average loss: 0.2607
# Iteration: 4961; Percent complete: 99.2%; Average loss: 0.2524
# Iteration: 4962; Percent complete: 99.2%; Average loss: 0.2388
# Iteration: 4963; Percent complete: 99.3%; Average loss: 0.2481
# Iteration: 4964; Percent complete: 99.3%; Average loss: 0.2593
# Iteration: 4965; Percent complete: 99.3%; Average loss: 0.2151
# Iteration: 4966; Percent complete: 99.3%; Average loss: 0.2464
# Iteration: 4967; Percent complete: 99.3%; Average loss: 0.2514
# Iteration: 4968; Percent complete: 99.4%; Average loss: 0.2566
# Iteration: 4969; Percent complete: 99.4%; Average loss: 0.2341
# Iteration: 4970; Percent complete: 99.4%; Average loss: 0.2188
# Iteration: 4971; Percent complete: 99.4%; Average loss: 0.2482
# Iteration: 4972; Percent complete: 99.4%; Average loss: 0.2422
# Iteration: 4973; Percent complete: 99.5%; Average loss: 0.2544
# Iteration: 4974; Percent complete: 99.5%; Average loss: 0.2588
# Iteration: 4975; Percent complete: 99.5%; Average loss: 0.2352
# Iteration: 4976; Percent complete: 99.5%; Average loss: 0.2473
# Iteration: 4977; Percent complete: 99.5%; Average loss: 0.2556
# Iteration: 4978; Percent complete: 99.6%; Average loss: 0.2406
# Iteration: 4979; Percent complete: 99.6%; Average loss: 0.2441
# Iteration: 4980; Percent complete: 99.6%; Average loss: 0.2504
# Iteration: 4981; Percent complete: 99.6%; Average loss: 0.2545
# Iteration: 4982; Percent complete: 99.6%; Average loss: 0.2491
# Iteration: 4983; Percent complete: 99.7%; Average loss: 0.2630
# Iteration: 4984; Percent complete: 99.7%; Average loss: 0.2661
# Iteration: 4985; Percent complete: 99.7%; Average loss: 0.2316
# Iteration: 4986; Percent complete: 99.7%; Average loss: 0.2321
# Iteration: 4987; Percent complete: 99.7%; Average loss: 0.2481
# Iteration: 4988; Percent complete: 99.8%; Average loss: 0.2422
# Iteration: 4989; Percent complete: 99.8%; Average loss: 0.2405
# Iteration: 4990; Percent complete: 99.8%; Average loss: 0.2455
# Iteration: 4991; Percent complete: 99.8%; Average loss: 0.2266
# Iteration: 4992; Percent complete: 99.8%; Average loss: 0.2533
# Iteration: 4993; Percent complete: 99.9%; Average loss: 0.2328
# Iteration: 4994; Percent complete: 99.9%; Average loss: 0.2293
# Iteration: 4995; Percent complete: 99.9%; Average loss: 0.2494
# Iteration: 4996; Percent complete: 99.9%; Average loss: 0.2628
# Iteration: 4997; Percent complete: 99.9%; Average loss: 0.2345
# Iteration: 4998; Percent complete: 100.0%; Average loss: 0.2417
# Iteration: 4999; Percent complete: 100.0%; Average loss: 0.2523
# Iteration: 5000; Percent complete: 100.0%; Average loss: 0.2421

# %% [markdown]
# Run the model :)

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > Hello
# Bot: hello . is telly late . 6
# > Maybe she is
# Bot: what is it ? . 5
# > I do not really know
# Bot: fine . . ? 4
# > How are you today
# Bot: fine . . . 4
# > That is good to hear
# Bot: it s good . let the radio . 8
# > What about the radio?
# Bot: sorry . has . . 5
# > Hmm
# Bot: i ll call them . . 6
# > Okay sure.
# Bot: if she wasn t such done eddie else ? 9
# > What
# Bot: what is it ? just ? 6
# > quit

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = StochasticTopKUniformDecoder(encoder, decoder, 2)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > Hello
# Bot: hello this is telly singer . go . ? 9
# > Hi telly, how are you?
# Bot: okay thank you guys . . ! 7
# > You are welcome
# Bot: i know i am ! damn right . now ! 10
# > What are you doing today?
# Bot: i m going back to your face . 8
# > That is funny.
# Bot: yeah i think so okay ? ? ! 8
# > Haha
# Error: Encountered unknown word.
# > Let us go out for dinner
# Bot: i m not asking you something to worry do 9
# > Okay bye
# Bot: i ll get you there tomorrow night . go 9
# > Cool
# Bot: does ? you need one guy ? go ! 9
# > No Goodnight
# Bot: night night tomorrow . now . go go 8
# > quit

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = StochasticTopKSampleDecoder(encoder, decoder, 5)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > What music do you listen to?
# Bot: oh no i need to help . .
# > Why do you need help?
# Bot: i ve got any cream . .
# > Cream?
# Bot: i m thinking . . . . ?
# > Ok
# Bot: i ll see you there . .
# > See me where?
# Bot: i m not sure . .
# > Loser
# Bot: what s this ? salvatore ?
# > I am not salvatore.
# Bot: what are you going to do ? ?
# > Beat you up!
# Bot: what ? . .
# > Exactly.
# Bot: exactly what ? you hate him ?
# > No, I hate you.
# Bot: i don t want to hurt the questions .
# > I will hurt you.
# Bot: i ll get you through the day tonight .
# > quit

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = StochasticSentenceInitializerSamplingDecoder(encoder, decoder, 5, 3)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > quit

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = StochasticSentenceInitializerUniformDecoder(encoder, decoder, 10, 3)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > Hello
# Bot: hello it . i see you . 7
# > What do you see?
# Bot: somethin i forget it . . . . 8
# > Hmm
# Bot: may they mother and wrote we like it ? 9
# > I do not know what you are saying
# Bot: here and i ! . ! 6
# > quit

# %% [markdown]
# ### Notes on the Model

# %% [markdown]
# Overall, the model is OK. It was not as intelligent as i thought it would be, but I suppose that is a good thing. One of the things that I noticed from playing with the bot was that everything is pretty predictable. In fact, it feels less like it is responding to you and more like it has memories what to day based on an input string from the user. I think the first thing we can do to improve the model is to add some randomness to the model, so asking "hello" wont keep generating the same output. To improve this one a bit more we can change some of the variable like the learning rate and the depth. Eventually, to improve the overall feeling of the chat bot we can implement an entirely new model. Try to give a more meaningful number to words rather than what index they first appear in (ask professor if he thinks this would even matter, or would this just be a change of domain).
