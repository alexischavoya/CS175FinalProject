# %% [markdown]
# # ChatBot References
#
# Professor Smyth's website discussing projects
#
# https://www.ics.uci.edu/~smyth/courses/cs175/project_reading.html
#
# Chatbot resources on website
#
# https://pytorch.org/tutorials/beginner/chatbot_tutorial.html
#
# https://web.stanford.edu/~jurafsky/slp3/26.pdf
#
# https://www.microsoft.com/en-us/research/wp-content/uploads/2016/12/CortanaLUDialog-FromSLTproceedings.pdf
#
# Dataset for tutorial
#
# https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html

# %% [markdown]
# # Start of Tutorial

# %% [markdown]
# ### Import necessary libraries

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# ### Preprocess Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Looking at some files in the data to see how they are structured ...

# %%
data = "/content/drive/MyDrive/CS175_Datasets"
# corpus = os.path.join("data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

# printLines(os.path.join(data, "qa_Video_Games.json"))

# %% [markdown]
# Scan through data files and reformat them to be (sentence, response) pairs separated by a tab eventually. First we create helper functions to help clean up the data a bit and make it more readable ...

# %%
import json
import gzip

def parse(file):
  g = gzip.open(path, 'r')
  for l in g:
    yield eval(l)

def loadConversations(fileName):
  conversations = []
  g = gzip.open(fileName, 'r')
  for conversation in g:
      conversation=eval(conversation)
      conversations.append([conversation["question"], conversation["answer"]])
  return conversations


def extractSentencePairs(conversations):
    return conversations

# %% [markdown]
# Next we will be using the functions above we now parse the data into a form that is useful to us and see what a few lines from the data look like ...

# %%
# Define path to new file
corpus=data
datafile_path = os.path.join(corpus, "amazonqa")
datasets = [f for f in os.listdir(datafile_path) if os.path.isfile(os.path.join(datafile_path,f))]
outfile_path = os.path.join(datafile_path, "csv_files")
datafile = os.path.join(outfile_path, "amazon_qa.csv")
corpus_name = "amazon_qa"
# load data if data file is already been processed as csv file
load_data = True

conversations = []
if not load_data: 
  # Load lines and process conversations
  print("\nProcessing corpus...")
  # lines = loadLines(os.path.join(corpus, "movie_lines.txt"), MOVIE_LINES_FIELDS)
  print("\nLoading conversations...")
  print(datasets)
  for gzip_file in datasets:
      print("processing data file", gzip_file)
      conversations = loadConversations(os.path.join(datafile_path,gzip_file))

  # Write new csv file
  print("\nWriting newly formatted file...")
  with open(datafile, 'w', encoding='utf-8') as outputfile:
      writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
      for pair in extractSentencePairs(conversations):
          writer.writerow(pair)
# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Sample lines from file:
# b'Are both sides white? Are both sides magnetic?\tYes, both sides are white and magnetic but markers do not wipe off easily...\n'
# b"How sturdy or flimsy is the board. I am also looking at the Expo dry erase magnetic easel. I would like for a child to be on each side of the board.\tThe board is very sturdy. It folds flat. It is great for a child's table top. It is not tall enough to stand and play. I have been very pleased with it.\n"
# b'Does it come with letters, numbers and/or pictures?\tNo,it is just the easel.\n'
# b"Can it hold up wooden magnetic letters?\tsorry, i do not have like-wooden magnet letters to test...but there is no reason to believe that it wouldn't hold wooden magnet unless the wood letters itself is too heavy that it falls off the slanted surface...it holds the plastic mag-letters just fine and the surface can be written/draw on with an erasable marker...and you can use the letters on the fridge surface...the board is a nice addition...kids like different things to do to keep their interests up...\n"
# b'Can this be lain on its side? I need a landscape board. Thank you.\tIt can, yes...but may be a bit awkward to work with, but I guess that depends on what you are using it for. It folds up flat...the bottom pieces have 2 little velcro circles that snap together to keep the bottom pieces together.\n'
# b'should I purchase plain magnet alphabets and numbers?\tMy grandsons love their letters and animals but any magnets work, and fridge works fine for them.\n'
# b'Is it Dry-erase?\tYes\n'
# b'Is it Dry-erase?\tYes\n'
# b'What is appropriate age group for this easel?\tMy four year old granddaughter loves it.\n'
# b'Can 2 children use it simultaneously from opposite sides, as in this 2-step easel http://www.amazon.com/gp/aw/d/B008VUP...\tYes...love this product!\n'

# %% [markdown]
# We want to create a vocabulary of words that we see. We represent these words numerically using the index of their first appearance in the history of all added words to the set of vocuabulary. See `addWord()` for specifics.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we finally getting to the part where we begin to make the (sentence, response) pairs. We begin preprocessing by converting the Unicode string texts to ASCII `unicodeToAscii()`. We also make everything lower case, and remove nonletters except for basic punctuation `normalizeString()`. The last thing that is done in preprocessing is ignore sentences beyond a certain length to aid in training `filterPair()` and `MAX_LENGTH`.

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join(data, "LSRM_save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 51486 sentence pairs
# Trimmed to 7983 sentence pairs
# Counting words...
# Counted words: 5374
#
# pairs:
# ['is it dry erase ?', 'yes']
# ['is it dry erase ?', 'yes']
# ['what is appropriate age group for this easel ?', 'my four year old granddaughter loves it .']
# ['how many pages in book ?', 'up to pages']
# ['what age child is this directed to ?', 'yrs old']
# ['for yr . olds ?', 'yes with adult help .']
# ['how many cards are in this game ?', 'cards with questions per card . questions']
# ['can you just purchase the birthday outfit alone ?', 'it s the outfit and book .']
# ['would they fit an ipad mini ?', 'yes it would fit any apple product .']
# ['can these fit on lg g phones ?', 'no']

# %% [markdown]
# Another way to speed up training is by removing words that are rarely used. We "trim" these words using `Voc.trim()` and as a result must also remove (sentence, response) pairs that include these words.

# %%
MIN_COUNT = 10    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 743 / 5371 = 0.1383
# Trimmed from 7983 pairs to 2897, 0.3629 of total

# %% [markdown]
# ### Using our Data on our Models

# %% [markdown]
# The data still needs to be processed more. The model that we use will take numerical values and not actual strings to do computation. We convert our sentences to tensors (vectors) that our model will take as inputs. To do this, we just take every sentence and change it to be a vector of index that corresponds to that word. This is how we will use our data to train the model.
#
# If we would like to train our model we usually do it with minbatches since it makes things faster. We make a matrix of dimensions (BatchLength, MaxLengthOfSentenceInBatch) represented numerically as mentioned in the previous paragraph. With this we make sure that each row (sentence) of our matrix terminates with `EOS_Token` and is followed by 0 entries until the end of the row.
#
# This implementation almost works, the problem with this is that each row is a sentence and every column is a step in time. However, it is better to think of every row as a step in time and the column to be possible words to choose for that step in time. For this reason, we construct the Matrix as mentioned in the previous paragraph except it is now transposed.
#
# We define some function that help us achieve this ...

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[  44,   39,   39,    3,   70],
#         [   4, 4545,   63,   14, 1043],
#         [ 265,   52, 1242,  965,  196],
#         [ 290, 1178, 1274,  210,  735],
#         [  48, 1141, 1204,  214, 2265],
#         [ 717,   93,    7,    2,    2],
#         [1271,  650,    2,    0,    0],
#         [ 890,    7,    0,    0,    0],
#         [   7,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([10,  9,  7,  6,  6])
# target_variable: tensor([[   8, 1141,   68,   68,   48],
#         [1100,    2,   22,    2, 2265],
#         [ 121,    0,    2,    0,   39],
#         [   2,    0,    0,    0,  313],
#         [   0,    0,    0,    0,  207],
#         [   0,    0,    0,    0, 1141],
#         [   0,    0,    0,    0,  790],
#         [   0,    0,    0,    0,  424],
#         [   0,    0,    0,    0,    2]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False,  True, False,  True],
#         [ True, False, False, False,  True],
#         [False, False, False, False,  True],
#         [False, False, False, False,  True],
#         [False, False, False, False,  True],
#         [False, False, False, False,  True],
#         [False, False, False, False,  True]])
# max_target_len: 9

# %% [markdown]
# Seeing the output from preping the data above, it appears that `input_variable` is the matrix described in the previous secsion. `lenghts` is just a tensor (vector) of how long the sentences in the input were. This will eventually be used for the **decoder** later in the program. `target_variable` seems to be the response that our model is supposed to learn. `mask` looks like it is a mask for responses where true is that there is a word and false is that there is no word there. Not sure why this variable is necessary but maybe it will become clearer at some point in the tutorial.

# %% [markdown]
# ### Defining our Model

# %% [markdown]
# Our base model is a Sequence-to-Sequence model using two RNN's. The first RNN is what is called the **encoder** and it takes a variable length input and converts it into a *fixed length* "context" vector that is intended to hold onto some semantic meaning of the input. The **decoder** takes the context vector provided by the decoder along with an input word to guess the next word in a sequence. I suppose our (sentence, response) pairs are learned as one long continuous sequence where the sentence is the start of hte sequence and the response is the remainder of the sequence, though this might be entirely incorrect.

# %% [markdown]
# Some discussion on the Encoder. The encoder uses a bidirectional GRU (Gated Recurrent Unit), meaning that there is basically two RNN's that make up the encoder, one that goes through the sequence of data in the forward direction while another RNN goes through the sequence in the backward direction. At each time step, both RNN's produce an output and a hidden state vector. At each time step, the output of both RNNs are summed and the output is recorded (somewhere) while the hidden state vectors are pushed along and used in the next step of the RNN. The outputs are summed makes it so that at each time step, the RNN is considering present and future context.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.LSTM(hidden_size,hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Some discussion on the Decoder. The decoder uses the context vector that is produced by the encoder. Usually, this is all that will be used by a decoder to produce output but this can result in a loss of information, expecially when the input sentences are very long. To counter this, the decoder also uses its current hidden state as a way of determining what it should be "paying attention" to. These are refered to as attention weights and are multiplied by the outputs from the encoder (the output that is apperantly recorded somewhere, this is where they are used) from the current time step to rescale the values, making less important parts of the encoder output smaller and more important parts of the encoder output larger. This can be further improved by using all of the encoder outputs instead of just the one of the current time step to have a more comprehensive set of attention weights. This is the method implemented below, followed by the implementation of the decoder using this attention method.

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.LSTM(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# ### Defining the Training Procedure

# %% [markdown]
# Recall earlier in the `mask` produced along side the `target_variable` was produced for an unknown purpose, it turns out its purpose is for determining the loss of the model. This implementation below is the negative-log-likelihood loss and the variable `mask` along with `target_variable`.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# For training the model, two tricks are used to help convergence. The first trick is refered to as "teacher forcing" which just overrides the prediction of the decoder and uses the actual target value instead, this happens with some small probability p. Doing it too much will make the decoder unable to make predictions on its own and not having this feature will make it so that convergence is just slower. The second trick they do is gradient clipping, meaning that at areas in the feature space where there is a steep gradient and therefore a chance to improve the model very fast, the magnitude of the gradient is limited some value. This is to not drastically overshoot local minima on "cliffs". The training function is implemented below. This trains only one iteration.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
        #Get the encoder final h_hidden_state
    encoder_h_hidden, encoder_c_hidden = encoder_hidden
    decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
    decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
    # Recombine the final hidden states as hidden tuple
    decoder_hidden = (decoder_h_hidden, decoder_c_hidden)

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# This version of the training function trains on multiple iterations. It is built on the previous training function. This function also saves the current variables in a tarball file. This is to continue training at a later period or just use the current accumulated training to make predictions.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, 
               encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, 
               clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(
                iteration, iteration / n_iteration * 100, print_loss_avg
            ))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(
                encoder_n_layers, decoder_n_layers, hidden_size
            ))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# ### Defining Evaluation

# %% [markdown]
# This is the training method used by our bot when we are not using the "teacher forcing" method. This just basically chooses the output of hte decoder to be the output with the highest softmax score, ie the best response given its prior training. I think this is defining a decoder method for whenever we are actually using our model instead of when it is training.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# The `evaluateInput` function is meant to take input from the user, prepare it so that it may be fed to our model, and pring out the response from our bot. `evaluate` handles most of hte actual calculation while `evaluateInput` handles most of the user interaction phase.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    #lengths = lengths.to(device) # removed bc of gpu cpu tensor difference ###################################
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words), len(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# ### Running the Model

# %% [markdown]
# This defines and builds our model based on the following parameters. Notice that parts of the code are commented out as these are other possibilities ofr initialization. attn_model can be given one of three different models. We can also choose to load a model that we previously trained.

# %%
# Configure models
model_name = 'cb_model_amazon_qa'
attn_model = 'dot'
# attn_model = 'general'
# attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Now we train our model using `trainIters`. We first set some training parameters and initialize optimizers and prepare our model for training. Training is likely to take a very long time, thankfully there is the option to load from a previous model and this piece of code here doesn't need to be run every time.

# %%
# Safty precaution so that we dont accidentally begin training a model we didnt want to train
TRAIN_THE_MODEL = True

# %%
if TRAIN_THE_MODEL:
    
    # Configure training/optimization
    clip = 50.0
    teacher_forcing_ratio = 1.0
    learning_rate = 0.0001
    decoder_learning_ratio = 5.0
    n_iteration = 5000
    print_every = 1
    save_every = 500

    # Ensure dropout layers are in train mode
    encoder.train()
    decoder.train()

    # Initialize optimizers
    print('Building optimizers ...')
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
    if loadFilename:
        encoder_optimizer.load_state_dict(encoder_optimizer_sd)
        decoder_optimizer.load_state_dict(decoder_optimizer_sd)

    # If you have cuda, configure cuda to call
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    # Run training iterations
    print("Starting Training!")
    trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
               embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
               print_every, save_every, clip, corpus_name, loadFilename)
    
    TRAIN_THE_MODEL = False

else:
    
    print(f"Make the variable 'TRAIN_THE_MODEL' in the code block above True and run the code block")
    print(f"Value of 'TRAIN_THE_MODEL' currently: {TRAIN_THE_MODEL}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.5787
# Iteration: 2; Percent complete: 0.0%; Average loss: 8.5361
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.4832
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.4280
# Iteration: 5; Percent complete: 0.1%; Average loss: 8.3035
# Iteration: 6; Percent complete: 0.1%; Average loss: 8.0813
# Iteration: 7; Percent complete: 0.1%; Average loss: 7.7339
# Iteration: 8; Percent complete: 0.2%; Average loss: 7.3674
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.9383
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.8086
# Iteration: 11; Percent complete: 0.2%; Average loss: 7.0429
# Iteration: 12; Percent complete: 0.2%; Average loss: 6.6416
# Iteration: 13; Percent complete: 0.3%; Average loss: 6.4940
# Iteration: 14; Percent complete: 0.3%; Average loss: 6.0465
# Iteration: 15; Percent complete: 0.3%; Average loss: 5.9311
# Iteration: 16; Percent complete: 0.3%; Average loss: 5.6636
# Iteration: 17; Percent complete: 0.3%; Average loss: 5.6337
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.2813
# Iteration: 19; Percent complete: 0.4%; Average loss: 5.2907
# Iteration: 20; Percent complete: 0.4%; Average loss: 5.4677
# Iteration: 21; Percent complete: 0.4%; Average loss: 4.9301
# Iteration: 22; Percent complete: 0.4%; Average loss: 5.1350
# Iteration: 23; Percent complete: 0.5%; Average loss: 5.2927
# Iteration: 24; Percent complete: 0.5%; Average loss: 5.0173
# Iteration: 25; Percent complete: 0.5%; Average loss: 5.2381
# Iteration: 26; Percent complete: 0.5%; Average loss: 5.1854
# Iteration: 27; Percent complete: 0.5%; Average loss: 5.3449
# Iteration: 28; Percent complete: 0.6%; Average loss: 5.3086
# Iteration: 29; Percent complete: 0.6%; Average loss: 4.9607
# Iteration: 30; Percent complete: 0.6%; Average loss: 5.0546
# Iteration: 31; Percent complete: 0.6%; Average loss: 4.7295
# Iteration: 32; Percent complete: 0.6%; Average loss: 4.9199
# Iteration: 33; Percent complete: 0.7%; Average loss: 4.8689
# Iteration: 34; Percent complete: 0.7%; Average loss: 5.0992
# Iteration: 35; Percent complete: 0.7%; Average loss: 5.2409
# Iteration: 36; Percent complete: 0.7%; Average loss: 4.9225
# Iteration: 37; Percent complete: 0.7%; Average loss: 4.9588
# Iteration: 38; Percent complete: 0.8%; Average loss: 4.9804
# Iteration: 39; Percent complete: 0.8%; Average loss: 5.0132
# Iteration: 40; Percent complete: 0.8%; Average loss: 4.7818
# Iteration: 41; Percent complete: 0.8%; Average loss: 4.8098
# Iteration: 42; Percent complete: 0.8%; Average loss: 5.4040
# Iteration: 43; Percent complete: 0.9%; Average loss: 4.9405
# Iteration: 44; Percent complete: 0.9%; Average loss: 4.9674
# Iteration: 45; Percent complete: 0.9%; Average loss: 5.0626
# Iteration: 46; Percent complete: 0.9%; Average loss: 5.1534
# Iteration: 47; Percent complete: 0.9%; Average loss: 5.1492
# Iteration: 48; Percent complete: 1.0%; Average loss: 5.1274
# Iteration: 49; Percent complete: 1.0%; Average loss: 4.9651
# Iteration: 50; Percent complete: 1.0%; Average loss: 4.9885
# Iteration: 51; Percent complete: 1.0%; Average loss: 4.7442
# Iteration: 52; Percent complete: 1.0%; Average loss: 4.8854
# Iteration: 53; Percent complete: 1.1%; Average loss: 4.8893
# Iteration: 54; Percent complete: 1.1%; Average loss: 4.9188
# Iteration: 55; Percent complete: 1.1%; Average loss: 5.1025
# Iteration: 56; Percent complete: 1.1%; Average loss: 4.7304
# Iteration: 57; Percent complete: 1.1%; Average loss: 4.7504
# Iteration: 58; Percent complete: 1.2%; Average loss: 4.7289
# Iteration: 59; Percent complete: 1.2%; Average loss: 4.9164
# Iteration: 60; Percent complete: 1.2%; Average loss: 4.8887
# Iteration: 61; Percent complete: 1.2%; Average loss: 5.1164
# Iteration: 62; Percent complete: 1.2%; Average loss: 4.6865
# Iteration: 63; Percent complete: 1.3%; Average loss: 4.7944
# Iteration: 64; Percent complete: 1.3%; Average loss: 4.9614
# Iteration: 65; Percent complete: 1.3%; Average loss: 4.6593
# Iteration: 66; Percent complete: 1.3%; Average loss: 4.7765
# Iteration: 67; Percent complete: 1.3%; Average loss: 4.7112
# Iteration: 68; Percent complete: 1.4%; Average loss: 4.4814
# Iteration: 69; Percent complete: 1.4%; Average loss: 4.6422
# Iteration: 70; Percent complete: 1.4%; Average loss: 4.3971
# Iteration: 71; Percent complete: 1.4%; Average loss: 4.6974
# Iteration: 72; Percent complete: 1.4%; Average loss: 4.7050
# Iteration: 73; Percent complete: 1.5%; Average loss: 4.6438
# Iteration: 74; Percent complete: 1.5%; Average loss: 4.6815
# Iteration: 75; Percent complete: 1.5%; Average loss: 4.6483
# Iteration: 76; Percent complete: 1.5%; Average loss: 4.5575
# Iteration: 77; Percent complete: 1.5%; Average loss: 4.5123
# Iteration: 78; Percent complete: 1.6%; Average loss: 4.6410
# Iteration: 79; Percent complete: 1.6%; Average loss: 4.5167
# Iteration: 80; Percent complete: 1.6%; Average loss: 4.6913
# Iteration: 81; Percent complete: 1.6%; Average loss: 4.5981
# Iteration: 82; Percent complete: 1.6%; Average loss: 4.7124
# Iteration: 83; Percent complete: 1.7%; Average loss: 4.5330
# Iteration: 84; Percent complete: 1.7%; Average loss: 4.6805
# Iteration: 85; Percent complete: 1.7%; Average loss: 4.4679
# Iteration: 86; Percent complete: 1.7%; Average loss: 4.6349
# Iteration: 87; Percent complete: 1.7%; Average loss: 4.5923
# Iteration: 88; Percent complete: 1.8%; Average loss: 4.5364
# Iteration: 89; Percent complete: 1.8%; Average loss: 4.5678
# Iteration: 90; Percent complete: 1.8%; Average loss: 4.5829
# Iteration: 91; Percent complete: 1.8%; Average loss: 4.5549
# Iteration: 92; Percent complete: 1.8%; Average loss: 4.3198
# Iteration: 93; Percent complete: 1.9%; Average loss: 4.4345
# Iteration: 94; Percent complete: 1.9%; Average loss: 4.6438
# Iteration: 95; Percent complete: 1.9%; Average loss: 4.2614
# Iteration: 96; Percent complete: 1.9%; Average loss: 4.3883
# Iteration: 97; Percent complete: 1.9%; Average loss: 4.4258
# Iteration: 98; Percent complete: 2.0%; Average loss: 4.5790
# Iteration: 99; Percent complete: 2.0%; Average loss: 4.7804
# Iteration: 100; Percent complete: 2.0%; Average loss: 4.3661
# Iteration: 101; Percent complete: 2.0%; Average loss: 4.4392
# Iteration: 102; Percent complete: 2.0%; Average loss: 4.6633
# Iteration: 103; Percent complete: 2.1%; Average loss: 4.4251
# Iteration: 104; Percent complete: 2.1%; Average loss: 4.3516
# Iteration: 105; Percent complete: 2.1%; Average loss: 4.3565
# Iteration: 106; Percent complete: 2.1%; Average loss: 4.2202
# Iteration: 107; Percent complete: 2.1%; Average loss: 4.8897
# Iteration: 108; Percent complete: 2.2%; Average loss: 4.6545
# Iteration: 109; Percent complete: 2.2%; Average loss: 4.5779
# Iteration: 110; Percent complete: 2.2%; Average loss: 4.5528
# Iteration: 111; Percent complete: 2.2%; Average loss: 4.4470
# Iteration: 112; Percent complete: 2.2%; Average loss: 4.3382
# Iteration: 113; Percent complete: 2.3%; Average loss: 4.1614
# Iteration: 114; Percent complete: 2.3%; Average loss: 4.6067
# Iteration: 115; Percent complete: 2.3%; Average loss: 4.4794
# Iteration: 116; Percent complete: 2.3%; Average loss: 4.2865
# Iteration: 117; Percent complete: 2.3%; Average loss: 4.7560
# Iteration: 118; Percent complete: 2.4%; Average loss: 4.3592
# Iteration: 119; Percent complete: 2.4%; Average loss: 4.3682
# Iteration: 120; Percent complete: 2.4%; Average loss: 4.4035
# Iteration: 121; Percent complete: 2.4%; Average loss: 4.2663
# Iteration: 122; Percent complete: 2.4%; Average loss: 4.2269
# Iteration: 123; Percent complete: 2.5%; Average loss: 4.1879
# Iteration: 124; Percent complete: 2.5%; Average loss: 4.2785
# Iteration: 125; Percent complete: 2.5%; Average loss: 4.5967
# Iteration: 126; Percent complete: 2.5%; Average loss: 4.6666
# Iteration: 127; Percent complete: 2.5%; Average loss: 4.6774
# Iteration: 128; Percent complete: 2.6%; Average loss: 4.5348
# Iteration: 129; Percent complete: 2.6%; Average loss: 4.7196
# Iteration: 130; Percent complete: 2.6%; Average loss: 4.5231
# Iteration: 131; Percent complete: 2.6%; Average loss: 4.3684
# Iteration: 132; Percent complete: 2.6%; Average loss: 4.3309
# Iteration: 133; Percent complete: 2.7%; Average loss: 4.4753
# Iteration: 134; Percent complete: 2.7%; Average loss: 4.4963
# Iteration: 135; Percent complete: 2.7%; Average loss: 4.4210
# Iteration: 136; Percent complete: 2.7%; Average loss: 4.6774
# Iteration: 137; Percent complete: 2.7%; Average loss: 4.3115
# Iteration: 138; Percent complete: 2.8%; Average loss: 4.4728
# Iteration: 139; Percent complete: 2.8%; Average loss: 4.3982
# Iteration: 140; Percent complete: 2.8%; Average loss: 4.2479
# Iteration: 141; Percent complete: 2.8%; Average loss: 4.1001
# Iteration: 142; Percent complete: 2.8%; Average loss: 4.4741
# Iteration: 143; Percent complete: 2.9%; Average loss: 4.1738
# Iteration: 144; Percent complete: 2.9%; Average loss: 4.3303
# Iteration: 145; Percent complete: 2.9%; Average loss: 4.3077
# Iteration: 146; Percent complete: 2.9%; Average loss: 4.3693
# Iteration: 147; Percent complete: 2.9%; Average loss: 4.5469
# Iteration: 148; Percent complete: 3.0%; Average loss: 4.2722
# Iteration: 149; Percent complete: 3.0%; Average loss: 4.5862
# Iteration: 150; Percent complete: 3.0%; Average loss: 3.9557
# Iteration: 151; Percent complete: 3.0%; Average loss: 4.4368
# Iteration: 152; Percent complete: 3.0%; Average loss: 4.3782
# Iteration: 153; Percent complete: 3.1%; Average loss: 4.3406
# Iteration: 154; Percent complete: 3.1%; Average loss: 4.2837
# Iteration: 155; Percent complete: 3.1%; Average loss: 4.2661
# Iteration: 156; Percent complete: 3.1%; Average loss: 4.4894
# Iteration: 157; Percent complete: 3.1%; Average loss: 4.6110
# Iteration: 158; Percent complete: 3.2%; Average loss: 4.6094
# Iteration: 159; Percent complete: 3.2%; Average loss: 4.2362
# Iteration: 160; Percent complete: 3.2%; Average loss: 4.5438
# Iteration: 161; Percent complete: 3.2%; Average loss: 4.2440
# Iteration: 162; Percent complete: 3.2%; Average loss: 4.2284
# Iteration: 163; Percent complete: 3.3%; Average loss: 4.0997
# Iteration: 164; Percent complete: 3.3%; Average loss: 4.4740
# Iteration: 165; Percent complete: 3.3%; Average loss: 4.2794
# Iteration: 166; Percent complete: 3.3%; Average loss: 4.3028
# Iteration: 167; Percent complete: 3.3%; Average loss: 4.0648
# Iteration: 168; Percent complete: 3.4%; Average loss: 4.2518
# Iteration: 169; Percent complete: 3.4%; Average loss: 4.0316
# Iteration: 170; Percent complete: 3.4%; Average loss: 4.5670
# Iteration: 171; Percent complete: 3.4%; Average loss: 4.6586
# Iteration: 172; Percent complete: 3.4%; Average loss: 3.9504
# Iteration: 173; Percent complete: 3.5%; Average loss: 4.0527
# Iteration: 174; Percent complete: 3.5%; Average loss: 4.1040
# Iteration: 175; Percent complete: 3.5%; Average loss: 3.9974
# Iteration: 176; Percent complete: 3.5%; Average loss: 4.2010
# Iteration: 177; Percent complete: 3.5%; Average loss: 4.0838
# Iteration: 178; Percent complete: 3.6%; Average loss: 3.9748
# Iteration: 179; Percent complete: 3.6%; Average loss: 4.2927
# Iteration: 180; Percent complete: 3.6%; Average loss: 4.2284
# Iteration: 181; Percent complete: 3.6%; Average loss: 4.3916
# Iteration: 182; Percent complete: 3.6%; Average loss: 3.9444
# Iteration: 183; Percent complete: 3.7%; Average loss: 3.8924
# Iteration: 184; Percent complete: 3.7%; Average loss: 3.8581
# Iteration: 185; Percent complete: 3.7%; Average loss: 4.3951
# Iteration: 186; Percent complete: 3.7%; Average loss: 4.5958
# Iteration: 187; Percent complete: 3.7%; Average loss: 4.4726
# Iteration: 188; Percent complete: 3.8%; Average loss: 4.0440
# Iteration: 189; Percent complete: 3.8%; Average loss: 4.2192
# Iteration: 190; Percent complete: 3.8%; Average loss: 4.1572
# Iteration: 191; Percent complete: 3.8%; Average loss: 4.3641
# Iteration: 192; Percent complete: 3.8%; Average loss: 4.1289
# Iteration: 193; Percent complete: 3.9%; Average loss: 4.3257
# Iteration: 194; Percent complete: 3.9%; Average loss: 3.9939
# Iteration: 195; Percent complete: 3.9%; Average loss: 4.4021
# Iteration: 196; Percent complete: 3.9%; Average loss: 4.1941
# Iteration: 197; Percent complete: 3.9%; Average loss: 4.1475
# Iteration: 198; Percent complete: 4.0%; Average loss: 3.8274
# Iteration: 199; Percent complete: 4.0%; Average loss: 4.4014
# Iteration: 200; Percent complete: 4.0%; Average loss: 4.3080
# Iteration: 201; Percent complete: 4.0%; Average loss: 4.2229
# Iteration: 202; Percent complete: 4.0%; Average loss: 3.8650
# Iteration: 203; Percent complete: 4.1%; Average loss: 4.3240
# Iteration: 204; Percent complete: 4.1%; Average loss: 4.5787
# Iteration: 205; Percent complete: 4.1%; Average loss: 3.7157
# Iteration: 206; Percent complete: 4.1%; Average loss: 4.6219
# Iteration: 207; Percent complete: 4.1%; Average loss: 4.2391
# Iteration: 208; Percent complete: 4.2%; Average loss: 4.0029
# Iteration: 209; Percent complete: 4.2%; Average loss: 3.9250
# Iteration: 210; Percent complete: 4.2%; Average loss: 4.5149
# Iteration: 211; Percent complete: 4.2%; Average loss: 4.1796
# Iteration: 212; Percent complete: 4.2%; Average loss: 4.2018
# Iteration: 213; Percent complete: 4.3%; Average loss: 4.3699
# Iteration: 214; Percent complete: 4.3%; Average loss: 4.3384
# Iteration: 215; Percent complete: 4.3%; Average loss: 4.4352
# Iteration: 216; Percent complete: 4.3%; Average loss: 4.2023
# Iteration: 217; Percent complete: 4.3%; Average loss: 3.9414
# Iteration: 218; Percent complete: 4.4%; Average loss: 4.0584
# Iteration: 219; Percent complete: 4.4%; Average loss: 4.1256
# Iteration: 220; Percent complete: 4.4%; Average loss: 4.0403
# Iteration: 221; Percent complete: 4.4%; Average loss: 3.9234
# Iteration: 222; Percent complete: 4.4%; Average loss: 4.1925
# Iteration: 223; Percent complete: 4.5%; Average loss: 4.0398
# Iteration: 224; Percent complete: 4.5%; Average loss: 4.4666
# Iteration: 225; Percent complete: 4.5%; Average loss: 4.6274
# Iteration: 226; Percent complete: 4.5%; Average loss: 3.8613
# Iteration: 227; Percent complete: 4.5%; Average loss: 3.7902
# Iteration: 228; Percent complete: 4.6%; Average loss: 3.8285
# Iteration: 229; Percent complete: 4.6%; Average loss: 4.3289
# Iteration: 230; Percent complete: 4.6%; Average loss: 4.1914
# Iteration: 231; Percent complete: 4.6%; Average loss: 4.1770
# Iteration: 232; Percent complete: 4.6%; Average loss: 4.3308
# Iteration: 233; Percent complete: 4.7%; Average loss: 3.9257
# Iteration: 234; Percent complete: 4.7%; Average loss: 4.0549
# Iteration: 235; Percent complete: 4.7%; Average loss: 4.0972
# Iteration: 236; Percent complete: 4.7%; Average loss: 4.1706
# Iteration: 237; Percent complete: 4.7%; Average loss: 4.2721
# Iteration: 238; Percent complete: 4.8%; Average loss: 4.2470
# Iteration: 239; Percent complete: 4.8%; Average loss: 3.9917
# Iteration: 240; Percent complete: 4.8%; Average loss: 4.1570
# Iteration: 241; Percent complete: 4.8%; Average loss: 3.7659
# Iteration: 242; Percent complete: 4.8%; Average loss: 4.1525
# Iteration: 243; Percent complete: 4.9%; Average loss: 3.8426
# Iteration: 244; Percent complete: 4.9%; Average loss: 4.2365
# Iteration: 245; Percent complete: 4.9%; Average loss: 4.0394
# Iteration: 246; Percent complete: 4.9%; Average loss: 3.8971
# Iteration: 247; Percent complete: 4.9%; Average loss: 4.0039
# Iteration: 248; Percent complete: 5.0%; Average loss: 3.9867
# Iteration: 249; Percent complete: 5.0%; Average loss: 4.3052
# Iteration: 250; Percent complete: 5.0%; Average loss: 4.4454
# Iteration: 251; Percent complete: 5.0%; Average loss: 3.9030
# Iteration: 252; Percent complete: 5.0%; Average loss: 3.9712
# Iteration: 253; Percent complete: 5.1%; Average loss: 4.0128
# Iteration: 254; Percent complete: 5.1%; Average loss: 3.9478
# Iteration: 255; Percent complete: 5.1%; Average loss: 4.2332
# Iteration: 256; Percent complete: 5.1%; Average loss: 4.3663
# Iteration: 257; Percent complete: 5.1%; Average loss: 4.1637
# Iteration: 258; Percent complete: 5.2%; Average loss: 4.2944
# Iteration: 259; Percent complete: 5.2%; Average loss: 4.3181
# Iteration: 260; Percent complete: 5.2%; Average loss: 3.9493
# Iteration: 261; Percent complete: 5.2%; Average loss: 4.0235
# Iteration: 262; Percent complete: 5.2%; Average loss: 4.2176
# Iteration: 263; Percent complete: 5.3%; Average loss: 3.9595
# Iteration: 264; Percent complete: 5.3%; Average loss: 3.7409
# Iteration: 265; Percent complete: 5.3%; Average loss: 4.1559
# Iteration: 266; Percent complete: 5.3%; Average loss: 4.3313
# Iteration: 267; Percent complete: 5.3%; Average loss: 4.0893
# Iteration: 268; Percent complete: 5.4%; Average loss: 3.6927
# Iteration: 269; Percent complete: 5.4%; Average loss: 4.0572
# Iteration: 270; Percent complete: 5.4%; Average loss: 4.0681
# Iteration: 271; Percent complete: 5.4%; Average loss: 3.7632
# Iteration: 272; Percent complete: 5.4%; Average loss: 4.3100
# Iteration: 273; Percent complete: 5.5%; Average loss: 3.7677
# Iteration: 274; Percent complete: 5.5%; Average loss: 3.6436
# Iteration: 275; Percent complete: 5.5%; Average loss: 4.0316
# Iteration: 276; Percent complete: 5.5%; Average loss: 3.8045
# Iteration: 277; Percent complete: 5.5%; Average loss: 4.2071
# Iteration: 278; Percent complete: 5.6%; Average loss: 3.9140
# Iteration: 279; Percent complete: 5.6%; Average loss: 4.1592
# Iteration: 280; Percent complete: 5.6%; Average loss: 3.9551
# Iteration: 281; Percent complete: 5.6%; Average loss: 4.3125
# Iteration: 282; Percent complete: 5.6%; Average loss: 4.2426
# Iteration: 283; Percent complete: 5.7%; Average loss: 3.5975
# Iteration: 284; Percent complete: 5.7%; Average loss: 4.1295
# Iteration: 285; Percent complete: 5.7%; Average loss: 3.9207
# Iteration: 286; Percent complete: 5.7%; Average loss: 4.0999
# Iteration: 287; Percent complete: 5.7%; Average loss: 3.9038
# Iteration: 288; Percent complete: 5.8%; Average loss: 4.3990
# Iteration: 289; Percent complete: 5.8%; Average loss: 3.8182
# Iteration: 290; Percent complete: 5.8%; Average loss: 4.2055
# Iteration: 291; Percent complete: 5.8%; Average loss: 4.0192
# Iteration: 292; Percent complete: 5.8%; Average loss: 4.2491
# Iteration: 293; Percent complete: 5.9%; Average loss: 3.9414
# Iteration: 294; Percent complete: 5.9%; Average loss: 3.7121
# Iteration: 295; Percent complete: 5.9%; Average loss: 3.6251
# Iteration: 296; Percent complete: 5.9%; Average loss: 4.1091
# Iteration: 297; Percent complete: 5.9%; Average loss: 3.9924
# Iteration: 298; Percent complete: 6.0%; Average loss: 3.7949
# Iteration: 299; Percent complete: 6.0%; Average loss: 4.0189
# Iteration: 300; Percent complete: 6.0%; Average loss: 3.7742
# Iteration: 301; Percent complete: 6.0%; Average loss: 3.6446
# Iteration: 302; Percent complete: 6.0%; Average loss: 3.8565
# Iteration: 303; Percent complete: 6.1%; Average loss: 3.5051
# Iteration: 304; Percent complete: 6.1%; Average loss: 4.0986
# Iteration: 305; Percent complete: 6.1%; Average loss: 4.1135
# Iteration: 306; Percent complete: 6.1%; Average loss: 4.2657
# Iteration: 307; Percent complete: 6.1%; Average loss: 3.5732
# Iteration: 308; Percent complete: 6.2%; Average loss: 3.9513
# Iteration: 309; Percent complete: 6.2%; Average loss: 3.7044
# Iteration: 310; Percent complete: 6.2%; Average loss: 3.8882
# Iteration: 311; Percent complete: 6.2%; Average loss: 4.1897
# Iteration: 312; Percent complete: 6.2%; Average loss: 3.9216
# Iteration: 313; Percent complete: 6.3%; Average loss: 3.8330
# Iteration: 314; Percent complete: 6.3%; Average loss: 3.6826
# Iteration: 315; Percent complete: 6.3%; Average loss: 3.7710
# Iteration: 316; Percent complete: 6.3%; Average loss: 3.8267
# Iteration: 317; Percent complete: 6.3%; Average loss: 4.0013
# Iteration: 318; Percent complete: 6.4%; Average loss: 4.1062
# Iteration: 319; Percent complete: 6.4%; Average loss: 3.7490
# Iteration: 320; Percent complete: 6.4%; Average loss: 4.1135
# Iteration: 321; Percent complete: 6.4%; Average loss: 3.9703
# Iteration: 322; Percent complete: 6.4%; Average loss: 3.9092
# Iteration: 323; Percent complete: 6.5%; Average loss: 3.6896
# Iteration: 324; Percent complete: 6.5%; Average loss: 3.5295
# Iteration: 325; Percent complete: 6.5%; Average loss: 3.8384
# Iteration: 326; Percent complete: 6.5%; Average loss: 3.9823
# Iteration: 327; Percent complete: 6.5%; Average loss: 3.9296
# Iteration: 328; Percent complete: 6.6%; Average loss: 3.7441
# Iteration: 329; Percent complete: 6.6%; Average loss: 3.6085
# Iteration: 330; Percent complete: 6.6%; Average loss: 3.8575
# Iteration: 331; Percent complete: 6.6%; Average loss: 4.1230
# Iteration: 332; Percent complete: 6.6%; Average loss: 3.9048
# Iteration: 333; Percent complete: 6.7%; Average loss: 4.1211
# Iteration: 334; Percent complete: 6.7%; Average loss: 3.8282
# Iteration: 335; Percent complete: 6.7%; Average loss: 3.9713
# Iteration: 336; Percent complete: 6.7%; Average loss: 3.9878
# Iteration: 337; Percent complete: 6.7%; Average loss: 3.8635
# Iteration: 338; Percent complete: 6.8%; Average loss: 3.9654
# Iteration: 339; Percent complete: 6.8%; Average loss: 3.7130
# Iteration: 340; Percent complete: 6.8%; Average loss: 3.7623
# Iteration: 341; Percent complete: 6.8%; Average loss: 3.8173
# Iteration: 342; Percent complete: 6.8%; Average loss: 3.8871
# Iteration: 343; Percent complete: 6.9%; Average loss: 3.6243
# Iteration: 344; Percent complete: 6.9%; Average loss: 3.6249
# Iteration: 345; Percent complete: 6.9%; Average loss: 3.5914
# Iteration: 346; Percent complete: 6.9%; Average loss: 4.1829
# Iteration: 347; Percent complete: 6.9%; Average loss: 3.8463
# Iteration: 348; Percent complete: 7.0%; Average loss: 3.9594
# Iteration: 349; Percent complete: 7.0%; Average loss: 3.9499
# Iteration: 350; Percent complete: 7.0%; Average loss: 3.8776
# Iteration: 351; Percent complete: 7.0%; Average loss: 3.9819
# Iteration: 352; Percent complete: 7.0%; Average loss: 3.7056
# Iteration: 353; Percent complete: 7.1%; Average loss: 3.7380
# Iteration: 354; Percent complete: 7.1%; Average loss: 3.4439
# Iteration: 355; Percent complete: 7.1%; Average loss: 4.0517
# Iteration: 356; Percent complete: 7.1%; Average loss: 3.7272
# Iteration: 357; Percent complete: 7.1%; Average loss: 3.6160
# Iteration: 358; Percent complete: 7.2%; Average loss: 3.8091
# Iteration: 359; Percent complete: 7.2%; Average loss: 3.9888
# Iteration: 360; Percent complete: 7.2%; Average loss: 3.7597
# Iteration: 361; Percent complete: 7.2%; Average loss: 3.9412
# Iteration: 362; Percent complete: 7.2%; Average loss: 4.0918
# Iteration: 363; Percent complete: 7.3%; Average loss: 3.5935
# Iteration: 364; Percent complete: 7.3%; Average loss: 3.6432
# Iteration: 365; Percent complete: 7.3%; Average loss: 3.8891
# Iteration: 366; Percent complete: 7.3%; Average loss: 3.8876
# Iteration: 367; Percent complete: 7.3%; Average loss: 3.9846
# Iteration: 368; Percent complete: 7.4%; Average loss: 3.4342
# Iteration: 369; Percent complete: 7.4%; Average loss: 4.1350
# Iteration: 370; Percent complete: 7.4%; Average loss: 3.5730
# Iteration: 371; Percent complete: 7.4%; Average loss: 3.6045
# Iteration: 372; Percent complete: 7.4%; Average loss: 3.7081
# Iteration: 373; Percent complete: 7.5%; Average loss: 3.6656
# Iteration: 374; Percent complete: 7.5%; Average loss: 3.6872
# Iteration: 375; Percent complete: 7.5%; Average loss: 3.6781
# Iteration: 376; Percent complete: 7.5%; Average loss: 3.1074
# Iteration: 377; Percent complete: 7.5%; Average loss: 3.7199
# Iteration: 378; Percent complete: 7.6%; Average loss: 3.7252
# Iteration: 379; Percent complete: 7.6%; Average loss: 3.7604
# Iteration: 380; Percent complete: 7.6%; Average loss: 3.9284
# Iteration: 381; Percent complete: 7.6%; Average loss: 3.6321
# Iteration: 382; Percent complete: 7.6%; Average loss: 3.9131
# Iteration: 383; Percent complete: 7.7%; Average loss: 3.5968
# Iteration: 384; Percent complete: 7.7%; Average loss: 3.9389
# Iteration: 385; Percent complete: 7.7%; Average loss: 3.4734
# Iteration: 386; Percent complete: 7.7%; Average loss: 3.6696
# Iteration: 387; Percent complete: 7.7%; Average loss: 3.4787
# Iteration: 388; Percent complete: 7.8%; Average loss: 3.7710
# Iteration: 389; Percent complete: 7.8%; Average loss: 3.5754
# Iteration: 390; Percent complete: 7.8%; Average loss: 4.0484
# Iteration: 391; Percent complete: 7.8%; Average loss: 3.7868
# Iteration: 392; Percent complete: 7.8%; Average loss: 3.9480
# Iteration: 393; Percent complete: 7.9%; Average loss: 3.9427
# Iteration: 394; Percent complete: 7.9%; Average loss: 4.2333
# Iteration: 395; Percent complete: 7.9%; Average loss: 3.4661
# Iteration: 396; Percent complete: 7.9%; Average loss: 3.6341
# Iteration: 397; Percent complete: 7.9%; Average loss: 3.7273
# Iteration: 398; Percent complete: 8.0%; Average loss: 3.8769
# Iteration: 399; Percent complete: 8.0%; Average loss: 3.7093
# Iteration: 400; Percent complete: 8.0%; Average loss: 3.5496
# Iteration: 401; Percent complete: 8.0%; Average loss: 3.5446
# Iteration: 402; Percent complete: 8.0%; Average loss: 3.6996
# Iteration: 403; Percent complete: 8.1%; Average loss: 3.4392
# Iteration: 404; Percent complete: 8.1%; Average loss: 3.2428
# Iteration: 405; Percent complete: 8.1%; Average loss: 3.7159
# Iteration: 406; Percent complete: 8.1%; Average loss: 3.3953
# Iteration: 407; Percent complete: 8.1%; Average loss: 3.6710
# Iteration: 408; Percent complete: 8.2%; Average loss: 4.1719
# Iteration: 409; Percent complete: 8.2%; Average loss: 3.6728
# Iteration: 410; Percent complete: 8.2%; Average loss: 3.5046
# Iteration: 411; Percent complete: 8.2%; Average loss: 3.7731
# Iteration: 412; Percent complete: 8.2%; Average loss: 3.8590
# Iteration: 413; Percent complete: 8.3%; Average loss: 3.5510
# Iteration: 414; Percent complete: 8.3%; Average loss: 3.5126
# Iteration: 415; Percent complete: 8.3%; Average loss: 3.5294
# Iteration: 416; Percent complete: 8.3%; Average loss: 3.7140
# Iteration: 417; Percent complete: 8.3%; Average loss: 3.7051
# Iteration: 418; Percent complete: 8.4%; Average loss: 3.8184
# Iteration: 419; Percent complete: 8.4%; Average loss: 3.7475
# Iteration: 420; Percent complete: 8.4%; Average loss: 3.5311
# Iteration: 421; Percent complete: 8.4%; Average loss: 3.8457
# Iteration: 422; Percent complete: 8.4%; Average loss: 3.3277
# Iteration: 423; Percent complete: 8.5%; Average loss: 3.4517
# Iteration: 424; Percent complete: 8.5%; Average loss: 3.4839
# Iteration: 425; Percent complete: 8.5%; Average loss: 3.7727
# Iteration: 426; Percent complete: 8.5%; Average loss: 3.3742
# Iteration: 427; Percent complete: 8.5%; Average loss: 3.7663
# Iteration: 428; Percent complete: 8.6%; Average loss: 3.1615
# Iteration: 429; Percent complete: 8.6%; Average loss: 3.5232
# Iteration: 430; Percent complete: 8.6%; Average loss: 3.7278
# Iteration: 431; Percent complete: 8.6%; Average loss: 3.4285
# Iteration: 432; Percent complete: 8.6%; Average loss: 3.4146
# Iteration: 433; Percent complete: 8.7%; Average loss: 3.5564
# Iteration: 434; Percent complete: 8.7%; Average loss: 3.4386
# Iteration: 435; Percent complete: 8.7%; Average loss: 4.0005
# Iteration: 436; Percent complete: 8.7%; Average loss: 3.5970
# Iteration: 437; Percent complete: 8.7%; Average loss: 3.6554
# Iteration: 438; Percent complete: 8.8%; Average loss: 3.6816
# Iteration: 439; Percent complete: 8.8%; Average loss: 3.5552
# Iteration: 440; Percent complete: 8.8%; Average loss: 3.7638
# Iteration: 441; Percent complete: 8.8%; Average loss: 3.6697
# Iteration: 442; Percent complete: 8.8%; Average loss: 3.4568
# Iteration: 443; Percent complete: 8.9%; Average loss: 3.7418
# Iteration: 444; Percent complete: 8.9%; Average loss: 3.4773
# Iteration: 445; Percent complete: 8.9%; Average loss: 3.6657
# Iteration: 446; Percent complete: 8.9%; Average loss: 3.4077
# Iteration: 447; Percent complete: 8.9%; Average loss: 3.0233
# Iteration: 448; Percent complete: 9.0%; Average loss: 3.4179
# Iteration: 449; Percent complete: 9.0%; Average loss: 3.5826
# Iteration: 450; Percent complete: 9.0%; Average loss: 3.3821
# Iteration: 451; Percent complete: 9.0%; Average loss: 3.7822
# Iteration: 452; Percent complete: 9.0%; Average loss: 3.5975
# Iteration: 453; Percent complete: 9.1%; Average loss: 3.4505
# Iteration: 454; Percent complete: 9.1%; Average loss: 3.4819
# Iteration: 455; Percent complete: 9.1%; Average loss: 3.5436
# Iteration: 456; Percent complete: 9.1%; Average loss: 3.1937
# Iteration: 457; Percent complete: 9.1%; Average loss: 3.6013
# Iteration: 458; Percent complete: 9.2%; Average loss: 3.4293
# Iteration: 459; Percent complete: 9.2%; Average loss: 3.3520
# Iteration: 460; Percent complete: 9.2%; Average loss: 3.2602
# Iteration: 461; Percent complete: 9.2%; Average loss: 3.4411
# Iteration: 462; Percent complete: 9.2%; Average loss: 3.4540
# Iteration: 463; Percent complete: 9.3%; Average loss: 3.2686
# Iteration: 464; Percent complete: 9.3%; Average loss: 3.7066
# Iteration: 465; Percent complete: 9.3%; Average loss: 3.5216
# Iteration: 466; Percent complete: 9.3%; Average loss: 3.5052
# Iteration: 467; Percent complete: 9.3%; Average loss: 3.2347
# Iteration: 468; Percent complete: 9.4%; Average loss: 3.2857
# Iteration: 469; Percent complete: 9.4%; Average loss: 3.4033
# Iteration: 470; Percent complete: 9.4%; Average loss: 3.6646
# Iteration: 471; Percent complete: 9.4%; Average loss: 3.2684
# Iteration: 472; Percent complete: 9.4%; Average loss: 3.2246
# Iteration: 473; Percent complete: 9.5%; Average loss: 3.4341
# Iteration: 474; Percent complete: 9.5%; Average loss: 3.3829
# Iteration: 475; Percent complete: 9.5%; Average loss: 3.3122
# Iteration: 476; Percent complete: 9.5%; Average loss: 3.2340
# Iteration: 477; Percent complete: 9.5%; Average loss: 3.7983
# Iteration: 478; Percent complete: 9.6%; Average loss: 3.5487
# Iteration: 479; Percent complete: 9.6%; Average loss: 3.5441
# Iteration: 480; Percent complete: 9.6%; Average loss: 3.1506
# Iteration: 481; Percent complete: 9.6%; Average loss: 3.2256
# Iteration: 482; Percent complete: 9.6%; Average loss: 3.5603
# Iteration: 483; Percent complete: 9.7%; Average loss: 3.3409
# Iteration: 484; Percent complete: 9.7%; Average loss: 2.9114
# Iteration: 485; Percent complete: 9.7%; Average loss: 3.4561
# Iteration: 486; Percent complete: 9.7%; Average loss: 3.5391
# Iteration: 487; Percent complete: 9.7%; Average loss: 3.1492
# Iteration: 488; Percent complete: 9.8%; Average loss: 3.5171
# Iteration: 489; Percent complete: 9.8%; Average loss: 3.3424
# Iteration: 490; Percent complete: 9.8%; Average loss: 3.8978
# Iteration: 491; Percent complete: 9.8%; Average loss: 3.4372
# Iteration: 492; Percent complete: 9.8%; Average loss: 3.2705
# Iteration: 493; Percent complete: 9.9%; Average loss: 3.6304
# Iteration: 494; Percent complete: 9.9%; Average loss: 3.5247
# Iteration: 495; Percent complete: 9.9%; Average loss: 3.4675
# Iteration: 496; Percent complete: 9.9%; Average loss: 3.5112
# Iteration: 497; Percent complete: 9.9%; Average loss: 3.2963
# Iteration: 498; Percent complete: 10.0%; Average loss: 3.4550
# Iteration: 499; Percent complete: 10.0%; Average loss: 3.6007
# Iteration: 500; Percent complete: 10.0%; Average loss: 3.4390
# Iteration: 501; Percent complete: 10.0%; Average loss: 3.2358
# Iteration: 502; Percent complete: 10.0%; Average loss: 3.6375
# Iteration: 503; Percent complete: 10.1%; Average loss: 3.6813
# Iteration: 504; Percent complete: 10.1%; Average loss: 3.4241
# Iteration: 505; Percent complete: 10.1%; Average loss: 3.2660
# Iteration: 506; Percent complete: 10.1%; Average loss: 3.3679
# Iteration: 507; Percent complete: 10.1%; Average loss: 3.3339
# Iteration: 508; Percent complete: 10.2%; Average loss: 3.5470
# Iteration: 509; Percent complete: 10.2%; Average loss: 3.3309
# Iteration: 510; Percent complete: 10.2%; Average loss: 3.6023
# Iteration: 511; Percent complete: 10.2%; Average loss: 3.5516
# Iteration: 512; Percent complete: 10.2%; Average loss: 3.2251
# Iteration: 513; Percent complete: 10.3%; Average loss: 3.1640
# Iteration: 514; Percent complete: 10.3%; Average loss: 3.3556
# Iteration: 515; Percent complete: 10.3%; Average loss: 3.4417
# Iteration: 516; Percent complete: 10.3%; Average loss: 3.0490
# Iteration: 517; Percent complete: 10.3%; Average loss: 3.5783
# Iteration: 518; Percent complete: 10.4%; Average loss: 3.2978
# Iteration: 519; Percent complete: 10.4%; Average loss: 3.4690
# Iteration: 520; Percent complete: 10.4%; Average loss: 3.2516
# Iteration: 521; Percent complete: 10.4%; Average loss: 3.6737
# Iteration: 522; Percent complete: 10.4%; Average loss: 3.5320
# Iteration: 523; Percent complete: 10.5%; Average loss: 3.5315
# Iteration: 524; Percent complete: 10.5%; Average loss: 3.2088
# Iteration: 525; Percent complete: 10.5%; Average loss: 3.2280
# Iteration: 526; Percent complete: 10.5%; Average loss: 3.3512
# Iteration: 527; Percent complete: 10.5%; Average loss: 3.1239
# Iteration: 528; Percent complete: 10.6%; Average loss: 3.2839
# Iteration: 529; Percent complete: 10.6%; Average loss: 3.3857
# Iteration: 530; Percent complete: 10.6%; Average loss: 3.2424
# Iteration: 531; Percent complete: 10.6%; Average loss: 3.3391
# Iteration: 532; Percent complete: 10.6%; Average loss: 3.2556
# Iteration: 533; Percent complete: 10.7%; Average loss: 3.5628
# Iteration: 534; Percent complete: 10.7%; Average loss: 3.3366
# Iteration: 535; Percent complete: 10.7%; Average loss: 2.8367
# Iteration: 536; Percent complete: 10.7%; Average loss: 2.9877
# Iteration: 537; Percent complete: 10.7%; Average loss: 3.4142
# Iteration: 538; Percent complete: 10.8%; Average loss: 3.5246
# Iteration: 539; Percent complete: 10.8%; Average loss: 3.1426
# Iteration: 540; Percent complete: 10.8%; Average loss: 3.4681
# Iteration: 541; Percent complete: 10.8%; Average loss: 3.2413
# Iteration: 542; Percent complete: 10.8%; Average loss: 3.0661
# Iteration: 543; Percent complete: 10.9%; Average loss: 3.5679
# Iteration: 544; Percent complete: 10.9%; Average loss: 3.3289
# Iteration: 545; Percent complete: 10.9%; Average loss: 3.3989
# Iteration: 546; Percent complete: 10.9%; Average loss: 2.9216
# Iteration: 547; Percent complete: 10.9%; Average loss: 3.0930
# Iteration: 548; Percent complete: 11.0%; Average loss: 3.3223
# Iteration: 549; Percent complete: 11.0%; Average loss: 3.3995
# Iteration: 550; Percent complete: 11.0%; Average loss: 3.2700
# Iteration: 551; Percent complete: 11.0%; Average loss: 3.1650
# Iteration: 552; Percent complete: 11.0%; Average loss: 3.3216
# Iteration: 553; Percent complete: 11.1%; Average loss: 3.1730
# Iteration: 554; Percent complete: 11.1%; Average loss: 3.4824
# Iteration: 555; Percent complete: 11.1%; Average loss: 3.2252
# Iteration: 556; Percent complete: 11.1%; Average loss: 3.2636
# Iteration: 557; Percent complete: 11.1%; Average loss: 3.5425
# Iteration: 558; Percent complete: 11.2%; Average loss: 3.1607
# Iteration: 559; Percent complete: 11.2%; Average loss: 3.4171
# Iteration: 560; Percent complete: 11.2%; Average loss: 3.3711
# Iteration: 561; Percent complete: 11.2%; Average loss: 3.0550
# Iteration: 562; Percent complete: 11.2%; Average loss: 3.5095
# Iteration: 563; Percent complete: 11.3%; Average loss: 3.4312
# Iteration: 564; Percent complete: 11.3%; Average loss: 3.5014
# Iteration: 565; Percent complete: 11.3%; Average loss: 3.0144
# Iteration: 566; Percent complete: 11.3%; Average loss: 3.2006
# Iteration: 567; Percent complete: 11.3%; Average loss: 3.5424
# Iteration: 568; Percent complete: 11.4%; Average loss: 3.1940
# Iteration: 569; Percent complete: 11.4%; Average loss: 2.8372
# Iteration: 570; Percent complete: 11.4%; Average loss: 3.0637
# Iteration: 571; Percent complete: 11.4%; Average loss: 3.3362
# Iteration: 572; Percent complete: 11.4%; Average loss: 3.4711
# Iteration: 573; Percent complete: 11.5%; Average loss: 3.3330
# Iteration: 574; Percent complete: 11.5%; Average loss: 3.3326
# Iteration: 575; Percent complete: 11.5%; Average loss: 3.1486
# Iteration: 576; Percent complete: 11.5%; Average loss: 3.0290
# Iteration: 577; Percent complete: 11.5%; Average loss: 3.4999
# Iteration: 578; Percent complete: 11.6%; Average loss: 3.4161
# Iteration: 579; Percent complete: 11.6%; Average loss: 3.0898
# Iteration: 580; Percent complete: 11.6%; Average loss: 3.4067
# Iteration: 581; Percent complete: 11.6%; Average loss: 3.2666
# Iteration: 582; Percent complete: 11.6%; Average loss: 3.2932
# Iteration: 583; Percent complete: 11.7%; Average loss: 3.1446
# Iteration: 584; Percent complete: 11.7%; Average loss: 3.0198
# Iteration: 585; Percent complete: 11.7%; Average loss: 3.0911
# Iteration: 586; Percent complete: 11.7%; Average loss: 3.3348
# Iteration: 587; Percent complete: 11.7%; Average loss: 3.1528
# Iteration: 588; Percent complete: 11.8%; Average loss: 3.6588
# Iteration: 589; Percent complete: 11.8%; Average loss: 3.0501
# Iteration: 590; Percent complete: 11.8%; Average loss: 3.3629
# Iteration: 591; Percent complete: 11.8%; Average loss: 2.9132
# Iteration: 592; Percent complete: 11.8%; Average loss: 3.3001
# Iteration: 593; Percent complete: 11.9%; Average loss: 3.4275
# Iteration: 594; Percent complete: 11.9%; Average loss: 3.4041
# Iteration: 595; Percent complete: 11.9%; Average loss: 2.8477
# Iteration: 596; Percent complete: 11.9%; Average loss: 3.1996
# Iteration: 597; Percent complete: 11.9%; Average loss: 3.3129
# Iteration: 598; Percent complete: 12.0%; Average loss: 3.3985
# Iteration: 599; Percent complete: 12.0%; Average loss: 3.0788
# Iteration: 600; Percent complete: 12.0%; Average loss: 2.9814
# Iteration: 601; Percent complete: 12.0%; Average loss: 3.0878
# Iteration: 602; Percent complete: 12.0%; Average loss: 3.1748
# Iteration: 603; Percent complete: 12.1%; Average loss: 3.1114
# Iteration: 604; Percent complete: 12.1%; Average loss: 3.2039
# Iteration: 605; Percent complete: 12.1%; Average loss: 3.3985
# Iteration: 606; Percent complete: 12.1%; Average loss: 2.8341
# Iteration: 607; Percent complete: 12.1%; Average loss: 3.0865
# Iteration: 608; Percent complete: 12.2%; Average loss: 3.2228
# Iteration: 609; Percent complete: 12.2%; Average loss: 3.5111
# Iteration: 610; Percent complete: 12.2%; Average loss: 3.2458
# Iteration: 611; Percent complete: 12.2%; Average loss: 3.1377
# Iteration: 612; Percent complete: 12.2%; Average loss: 3.2023
# Iteration: 613; Percent complete: 12.3%; Average loss: 2.8868
# Iteration: 614; Percent complete: 12.3%; Average loss: 2.8369
# Iteration: 615; Percent complete: 12.3%; Average loss: 3.2329
# Iteration: 616; Percent complete: 12.3%; Average loss: 3.0681
# Iteration: 617; Percent complete: 12.3%; Average loss: 2.9548
# Iteration: 618; Percent complete: 12.4%; Average loss: 2.7581
# Iteration: 619; Percent complete: 12.4%; Average loss: 2.8732
# Iteration: 620; Percent complete: 12.4%; Average loss: 3.1631
# Iteration: 621; Percent complete: 12.4%; Average loss: 3.4917
# Iteration: 622; Percent complete: 12.4%; Average loss: 3.0189
# Iteration: 623; Percent complete: 12.5%; Average loss: 3.3290
# Iteration: 624; Percent complete: 12.5%; Average loss: 3.1487
# Iteration: 625; Percent complete: 12.5%; Average loss: 3.1809
# Iteration: 626; Percent complete: 12.5%; Average loss: 3.0294
# Iteration: 627; Percent complete: 12.5%; Average loss: 2.6751
# Iteration: 628; Percent complete: 12.6%; Average loss: 3.1542
# Iteration: 629; Percent complete: 12.6%; Average loss: 3.1272
# Iteration: 630; Percent complete: 12.6%; Average loss: 3.1374
# Iteration: 631; Percent complete: 12.6%; Average loss: 3.0169
# Iteration: 632; Percent complete: 12.6%; Average loss: 3.3029
# Iteration: 633; Percent complete: 12.7%; Average loss: 2.9410
# Iteration: 634; Percent complete: 12.7%; Average loss: 3.1659
# Iteration: 635; Percent complete: 12.7%; Average loss: 3.2547
# Iteration: 636; Percent complete: 12.7%; Average loss: 3.0613
# Iteration: 637; Percent complete: 12.7%; Average loss: 3.0817
# Iteration: 638; Percent complete: 12.8%; Average loss: 3.3716
# Iteration: 639; Percent complete: 12.8%; Average loss: 3.0826
# Iteration: 640; Percent complete: 12.8%; Average loss: 3.1278
# Iteration: 641; Percent complete: 12.8%; Average loss: 3.3951
# Iteration: 642; Percent complete: 12.8%; Average loss: 3.2482
# Iteration: 643; Percent complete: 12.9%; Average loss: 3.1524
# Iteration: 644; Percent complete: 12.9%; Average loss: 3.4675
# Iteration: 645; Percent complete: 12.9%; Average loss: 3.0643
# Iteration: 646; Percent complete: 12.9%; Average loss: 2.9994
# Iteration: 647; Percent complete: 12.9%; Average loss: 2.9764
# Iteration: 648; Percent complete: 13.0%; Average loss: 3.2300
# Iteration: 649; Percent complete: 13.0%; Average loss: 2.9404
# Iteration: 650; Percent complete: 13.0%; Average loss: 3.0300
# Iteration: 651; Percent complete: 13.0%; Average loss: 2.8348
# Iteration: 652; Percent complete: 13.0%; Average loss: 2.8802
# Iteration: 653; Percent complete: 13.1%; Average loss: 3.0439
# Iteration: 654; Percent complete: 13.1%; Average loss: 2.9589
# Iteration: 655; Percent complete: 13.1%; Average loss: 3.2565
# Iteration: 656; Percent complete: 13.1%; Average loss: 3.2435
# Iteration: 657; Percent complete: 13.1%; Average loss: 3.3218
# Iteration: 658; Percent complete: 13.2%; Average loss: 3.0626
# Iteration: 659; Percent complete: 13.2%; Average loss: 3.1023
# Iteration: 660; Percent complete: 13.2%; Average loss: 3.0252
# Iteration: 661; Percent complete: 13.2%; Average loss: 2.9906
# Iteration: 662; Percent complete: 13.2%; Average loss: 2.9587
# Iteration: 663; Percent complete: 13.3%; Average loss: 3.0248
# Iteration: 664; Percent complete: 13.3%; Average loss: 2.7528
# Iteration: 665; Percent complete: 13.3%; Average loss: 3.2317
# Iteration: 666; Percent complete: 13.3%; Average loss: 2.7546
# Iteration: 667; Percent complete: 13.3%; Average loss: 2.9643
# Iteration: 668; Percent complete: 13.4%; Average loss: 2.6487
# Iteration: 669; Percent complete: 13.4%; Average loss: 2.8382
# Iteration: 670; Percent complete: 13.4%; Average loss: 2.8525
# Iteration: 671; Percent complete: 13.4%; Average loss: 2.7962
# Iteration: 672; Percent complete: 13.4%; Average loss: 2.9417
# Iteration: 673; Percent complete: 13.5%; Average loss: 2.8741
# Iteration: 674; Percent complete: 13.5%; Average loss: 2.7474
# Iteration: 675; Percent complete: 13.5%; Average loss: 2.8668
# Iteration: 676; Percent complete: 13.5%; Average loss: 2.8547
# Iteration: 677; Percent complete: 13.5%; Average loss: 2.9194
# Iteration: 678; Percent complete: 13.6%; Average loss: 2.9098
# Iteration: 679; Percent complete: 13.6%; Average loss: 2.9213
# Iteration: 680; Percent complete: 13.6%; Average loss: 2.8391
# Iteration: 681; Percent complete: 13.6%; Average loss: 3.0417
# Iteration: 682; Percent complete: 13.6%; Average loss: 2.9768
# Iteration: 683; Percent complete: 13.7%; Average loss: 3.0884
# Iteration: 684; Percent complete: 13.7%; Average loss: 3.0603
# Iteration: 685; Percent complete: 13.7%; Average loss: 2.8594
# Iteration: 686; Percent complete: 13.7%; Average loss: 2.7488
# Iteration: 687; Percent complete: 13.7%; Average loss: 2.7848
# Iteration: 688; Percent complete: 13.8%; Average loss: 3.1270
# Iteration: 689; Percent complete: 13.8%; Average loss: 3.1348
# Iteration: 690; Percent complete: 13.8%; Average loss: 3.2251
# Iteration: 691; Percent complete: 13.8%; Average loss: 2.8076
# Iteration: 692; Percent complete: 13.8%; Average loss: 3.2705
# Iteration: 693; Percent complete: 13.9%; Average loss: 2.9142
# Iteration: 694; Percent complete: 13.9%; Average loss: 2.7255
# Iteration: 695; Percent complete: 13.9%; Average loss: 3.0147
# Iteration: 696; Percent complete: 13.9%; Average loss: 2.8755
# Iteration: 697; Percent complete: 13.9%; Average loss: 3.2656
# Iteration: 698; Percent complete: 14.0%; Average loss: 3.0006
# Iteration: 699; Percent complete: 14.0%; Average loss: 2.8175
# Iteration: 700; Percent complete: 14.0%; Average loss: 3.2170
# Iteration: 701; Percent complete: 14.0%; Average loss: 3.1336
# Iteration: 702; Percent complete: 14.0%; Average loss: 2.8953
# Iteration: 703; Percent complete: 14.1%; Average loss: 2.8733
# Iteration: 704; Percent complete: 14.1%; Average loss: 2.5957
# Iteration: 705; Percent complete: 14.1%; Average loss: 3.2270
# Iteration: 706; Percent complete: 14.1%; Average loss: 3.1529
# Iteration: 707; Percent complete: 14.1%; Average loss: 2.6852
# Iteration: 708; Percent complete: 14.2%; Average loss: 3.0847
# Iteration: 709; Percent complete: 14.2%; Average loss: 2.7402
# Iteration: 710; Percent complete: 14.2%; Average loss: 3.0028
# Iteration: 711; Percent complete: 14.2%; Average loss: 3.1273
# Iteration: 712; Percent complete: 14.2%; Average loss: 3.1195
# Iteration: 713; Percent complete: 14.3%; Average loss: 3.0650
# Iteration: 714; Percent complete: 14.3%; Average loss: 3.0320
# Iteration: 715; Percent complete: 14.3%; Average loss: 2.5587
# Iteration: 716; Percent complete: 14.3%; Average loss: 2.9365
# Iteration: 717; Percent complete: 14.3%; Average loss: 3.0037
# Iteration: 718; Percent complete: 14.4%; Average loss: 2.4932
# Iteration: 719; Percent complete: 14.4%; Average loss: 3.0822
# Iteration: 720; Percent complete: 14.4%; Average loss: 3.0838
# Iteration: 721; Percent complete: 14.4%; Average loss: 2.8454
# Iteration: 722; Percent complete: 14.4%; Average loss: 2.7763
# Iteration: 723; Percent complete: 14.5%; Average loss: 2.7379
# Iteration: 724; Percent complete: 14.5%; Average loss: 3.2324
# Iteration: 725; Percent complete: 14.5%; Average loss: 2.9866
# Iteration: 726; Percent complete: 14.5%; Average loss: 2.6483
# Iteration: 727; Percent complete: 14.5%; Average loss: 2.8538
# Iteration: 728; Percent complete: 14.6%; Average loss: 2.7528
# Iteration: 729; Percent complete: 14.6%; Average loss: 2.8698
# Iteration: 730; Percent complete: 14.6%; Average loss: 2.9946
# Iteration: 731; Percent complete: 14.6%; Average loss: 2.8504
# Iteration: 732; Percent complete: 14.6%; Average loss: 3.1552
# Iteration: 733; Percent complete: 14.7%; Average loss: 2.6620
# Iteration: 734; Percent complete: 14.7%; Average loss: 3.1568
# Iteration: 735; Percent complete: 14.7%; Average loss: 2.9545
# Iteration: 736; Percent complete: 14.7%; Average loss: 3.0822
# Iteration: 737; Percent complete: 14.7%; Average loss: 2.8945
# Iteration: 738; Percent complete: 14.8%; Average loss: 2.8360
# Iteration: 739; Percent complete: 14.8%; Average loss: 2.7373
# Iteration: 740; Percent complete: 14.8%; Average loss: 2.9338
# Iteration: 741; Percent complete: 14.8%; Average loss: 3.2720
# Iteration: 742; Percent complete: 14.8%; Average loss: 2.4085
# Iteration: 743; Percent complete: 14.9%; Average loss: 2.6137
# Iteration: 744; Percent complete: 14.9%; Average loss: 2.9945
# Iteration: 745; Percent complete: 14.9%; Average loss: 2.8481
# Iteration: 746; Percent complete: 14.9%; Average loss: 3.0991
# Iteration: 747; Percent complete: 14.9%; Average loss: 3.0001
# Iteration: 748; Percent complete: 15.0%; Average loss: 2.7967
# Iteration: 749; Percent complete: 15.0%; Average loss: 2.8587
# Iteration: 750; Percent complete: 15.0%; Average loss: 2.9163
# Iteration: 751; Percent complete: 15.0%; Average loss: 2.8098
# Iteration: 752; Percent complete: 15.0%; Average loss: 2.8411
# Iteration: 753; Percent complete: 15.1%; Average loss: 2.8963
# Iteration: 754; Percent complete: 15.1%; Average loss: 2.8611
# Iteration: 755; Percent complete: 15.1%; Average loss: 3.0086
# Iteration: 756; Percent complete: 15.1%; Average loss: 2.9560
# Iteration: 757; Percent complete: 15.1%; Average loss: 2.6975
# Iteration: 758; Percent complete: 15.2%; Average loss: 2.6646
# Iteration: 759; Percent complete: 15.2%; Average loss: 2.6829
# Iteration: 760; Percent complete: 15.2%; Average loss: 2.7650
# Iteration: 761; Percent complete: 15.2%; Average loss: 2.4931
# Iteration: 762; Percent complete: 15.2%; Average loss: 2.9976
# Iteration: 763; Percent complete: 15.3%; Average loss: 2.7433
# Iteration: 764; Percent complete: 15.3%; Average loss: 2.9235
# Iteration: 765; Percent complete: 15.3%; Average loss: 2.7759
# Iteration: 766; Percent complete: 15.3%; Average loss: 2.9394
# Iteration: 767; Percent complete: 15.3%; Average loss: 2.6029
# Iteration: 768; Percent complete: 15.4%; Average loss: 2.6687
# Iteration: 769; Percent complete: 15.4%; Average loss: 2.9026
# Iteration: 770; Percent complete: 15.4%; Average loss: 3.0749
# Iteration: 771; Percent complete: 15.4%; Average loss: 2.7817
# Iteration: 772; Percent complete: 15.4%; Average loss: 2.9116
# Iteration: 773; Percent complete: 15.5%; Average loss: 2.6864
# Iteration: 774; Percent complete: 15.5%; Average loss: 2.7896
# Iteration: 775; Percent complete: 15.5%; Average loss: 2.8203
# Iteration: 776; Percent complete: 15.5%; Average loss: 2.8279
# Iteration: 777; Percent complete: 15.5%; Average loss: 2.7188
# Iteration: 778; Percent complete: 15.6%; Average loss: 2.8358
# Iteration: 779; Percent complete: 15.6%; Average loss: 2.8472
# Iteration: 780; Percent complete: 15.6%; Average loss: 2.4425
# Iteration: 781; Percent complete: 15.6%; Average loss: 2.5853
# Iteration: 782; Percent complete: 15.6%; Average loss: 2.7564
# Iteration: 783; Percent complete: 15.7%; Average loss: 2.7125
# ...
# Iteration: 4748; Percent complete: 95.0%; Average loss: 0.1143
# Iteration: 4749; Percent complete: 95.0%; Average loss: 0.0855
# Iteration: 4750; Percent complete: 95.0%; Average loss: 0.1002
# Iteration: 4751; Percent complete: 95.0%; Average loss: 0.0791
# Iteration: 4752; Percent complete: 95.0%; Average loss: 0.1369
# Iteration: 4753; Percent complete: 95.1%; Average loss: 0.2132
# Iteration: 4754; Percent complete: 95.1%; Average loss: 0.1106
# Iteration: 4755; Percent complete: 95.1%; Average loss: 0.0859
# Iteration: 4756; Percent complete: 95.1%; Average loss: 0.1255
# Iteration: 4757; Percent complete: 95.1%; Average loss: 0.0899
# Iteration: 4758; Percent complete: 95.2%; Average loss: 0.1284
# Iteration: 4759; Percent complete: 95.2%; Average loss: 0.1052
# Iteration: 4760; Percent complete: 95.2%; Average loss: 0.0987
# Iteration: 4761; Percent complete: 95.2%; Average loss: 0.1170
# Iteration: 4762; Percent complete: 95.2%; Average loss: 0.1497
# Iteration: 4763; Percent complete: 95.3%; Average loss: 0.1280
# Iteration: 4764; Percent complete: 95.3%; Average loss: 0.1484
# Iteration: 4765; Percent complete: 95.3%; Average loss: 0.1426
# Iteration: 4766; Percent complete: 95.3%; Average loss: 0.1787
# Iteration: 4767; Percent complete: 95.3%; Average loss: 0.1092
# Iteration: 4768; Percent complete: 95.4%; Average loss: 0.1611
# Iteration: 4769; Percent complete: 95.4%; Average loss: 0.1178
# Iteration: 4770; Percent complete: 95.4%; Average loss: 0.1247
# Iteration: 4771; Percent complete: 95.4%; Average loss: 0.1055
# Iteration: 4772; Percent complete: 95.4%; Average loss: 0.1052
# Iteration: 4773; Percent complete: 95.5%; Average loss: 0.0825
# Iteration: 4774; Percent complete: 95.5%; Average loss: 0.0711
# Iteration: 4775; Percent complete: 95.5%; Average loss: 0.0888
# Iteration: 4776; Percent complete: 95.5%; Average loss: 0.1051
# Iteration: 4777; Percent complete: 95.5%; Average loss: 0.1201
# Iteration: 4778; Percent complete: 95.6%; Average loss: 0.1157
# Iteration: 4779; Percent complete: 95.6%; Average loss: 0.1412
# Iteration: 4780; Percent complete: 95.6%; Average loss: 0.1300
# Iteration: 4781; Percent complete: 95.6%; Average loss: 0.0855
# Iteration: 4782; Percent complete: 95.6%; Average loss: 0.1606
# Iteration: 4783; Percent complete: 95.7%; Average loss: 0.1173
# Iteration: 4784; Percent complete: 95.7%; Average loss: 0.0573
# Iteration: 4785; Percent complete: 95.7%; Average loss: 0.0825
# Iteration: 4786; Percent complete: 95.7%; Average loss: 0.1264
# Iteration: 4787; Percent complete: 95.7%; Average loss: 0.1114
# Iteration: 4788; Percent complete: 95.8%; Average loss: 0.1167
# Iteration: 4789; Percent complete: 95.8%; Average loss: 0.1212
# Iteration: 4790; Percent complete: 95.8%; Average loss: 0.1289
# Iteration: 4791; Percent complete: 95.8%; Average loss: 0.1317
# Iteration: 4792; Percent complete: 95.8%; Average loss: 0.1358
# Iteration: 4793; Percent complete: 95.9%; Average loss: 0.1619
# Iteration: 4794; Percent complete: 95.9%; Average loss: 0.0956
# Iteration: 4795; Percent complete: 95.9%; Average loss: 0.1162
# Iteration: 4796; Percent complete: 95.9%; Average loss: 0.1126
# Iteration: 4797; Percent complete: 95.9%; Average loss: 0.0946
# Iteration: 4798; Percent complete: 96.0%; Average loss: 0.1323
# Iteration: 4799; Percent complete: 96.0%; Average loss: 0.1632
# Iteration: 4800; Percent complete: 96.0%; Average loss: 0.1173
# Iteration: 4801; Percent complete: 96.0%; Average loss: 0.1120
# Iteration: 4802; Percent complete: 96.0%; Average loss: 0.0740
# Iteration: 4803; Percent complete: 96.1%; Average loss: 0.1188
# Iteration: 4804; Percent complete: 96.1%; Average loss: 0.1063
# Iteration: 4805; Percent complete: 96.1%; Average loss: 0.1207
# Iteration: 4806; Percent complete: 96.1%; Average loss: 0.0700
# Iteration: 4807; Percent complete: 96.1%; Average loss: 0.1321
# Iteration: 4808; Percent complete: 96.2%; Average loss: 0.0972
# Iteration: 4809; Percent complete: 96.2%; Average loss: 0.1429
# Iteration: 4810; Percent complete: 96.2%; Average loss: 0.1576
# Iteration: 4811; Percent complete: 96.2%; Average loss: 0.1022
# Iteration: 4812; Percent complete: 96.2%; Average loss: 0.1013
# Iteration: 4813; Percent complete: 96.3%; Average loss: 0.1313
# Iteration: 4814; Percent complete: 96.3%; Average loss: 0.0978
# Iteration: 4815; Percent complete: 96.3%; Average loss: 0.1602
# Iteration: 4816; Percent complete: 96.3%; Average loss: 0.0744
# Iteration: 4817; Percent complete: 96.3%; Average loss: 0.1141
# Iteration: 4818; Percent complete: 96.4%; Average loss: 0.1075
# Iteration: 4819; Percent complete: 96.4%; Average loss: 0.1248
# Iteration: 4820; Percent complete: 96.4%; Average loss: 0.0810
# Iteration: 4821; Percent complete: 96.4%; Average loss: 0.1397
# Iteration: 4822; Percent complete: 96.4%; Average loss: 0.2052
# Iteration: 4823; Percent complete: 96.5%; Average loss: 0.1137
# Iteration: 4824; Percent complete: 96.5%; Average loss: 0.0731
# Iteration: 4825; Percent complete: 96.5%; Average loss: 0.1150
# Iteration: 4826; Percent complete: 96.5%; Average loss: 0.1185
# Iteration: 4827; Percent complete: 96.5%; Average loss: 0.1667
# Iteration: 4828; Percent complete: 96.6%; Average loss: 0.0737
# Iteration: 4829; Percent complete: 96.6%; Average loss: 0.1196
# Iteration: 4830; Percent complete: 96.6%; Average loss: 0.1172
# Iteration: 4831; Percent complete: 96.6%; Average loss: 0.0947
# Iteration: 4832; Percent complete: 96.6%; Average loss: 0.1299
# Iteration: 4833; Percent complete: 96.7%; Average loss: 0.0935
# Iteration: 4834; Percent complete: 96.7%; Average loss: 0.1378
# Iteration: 4835; Percent complete: 96.7%; Average loss: 0.1031
# Iteration: 4836; Percent complete: 96.7%; Average loss: 0.1088
# Iteration: 4837; Percent complete: 96.7%; Average loss: 0.0886
# Iteration: 4838; Percent complete: 96.8%; Average loss: 0.0708
# Iteration: 4839; Percent complete: 96.8%; Average loss: 0.1363
# Iteration: 4840; Percent complete: 96.8%; Average loss: 0.1098
# Iteration: 4841; Percent complete: 96.8%; Average loss: 0.1706
# Iteration: 4842; Percent complete: 96.8%; Average loss: 0.0569
# Iteration: 4843; Percent complete: 96.9%; Average loss: 0.0813
# Iteration: 4844; Percent complete: 96.9%; Average loss: 0.1027
# Iteration: 4845; Percent complete: 96.9%; Average loss: 0.1231
# Iteration: 4846; Percent complete: 96.9%; Average loss: 0.1090
# Iteration: 4847; Percent complete: 96.9%; Average loss: 0.1485
# Iteration: 4848; Percent complete: 97.0%; Average loss: 0.1221
# Iteration: 4849; Percent complete: 97.0%; Average loss: 0.1151
# Iteration: 4850; Percent complete: 97.0%; Average loss: 0.1131
# Iteration: 4851; Percent complete: 97.0%; Average loss: 0.1509
# Iteration: 4852; Percent complete: 97.0%; Average loss: 0.1176
# Iteration: 4853; Percent complete: 97.1%; Average loss: 0.0414
# Iteration: 4854; Percent complete: 97.1%; Average loss: 0.0665
# Iteration: 4855; Percent complete: 97.1%; Average loss: 0.1297
# Iteration: 4856; Percent complete: 97.1%; Average loss: 0.0869
# Iteration: 4857; Percent complete: 97.1%; Average loss: 0.0987
# Iteration: 4858; Percent complete: 97.2%; Average loss: 0.0711
# Iteration: 4859; Percent complete: 97.2%; Average loss: 0.0921
# Iteration: 4860; Percent complete: 97.2%; Average loss: 0.1685
# Iteration: 4861; Percent complete: 97.2%; Average loss: 0.1242
# Iteration: 4862; Percent complete: 97.2%; Average loss: 0.1461
# Iteration: 4863; Percent complete: 97.3%; Average loss: 0.1300
# Iteration: 4864; Percent complete: 97.3%; Average loss: 0.1013
# Iteration: 4865; Percent complete: 97.3%; Average loss: 0.0874
# Iteration: 4866; Percent complete: 97.3%; Average loss: 0.1608
# Iteration: 4867; Percent complete: 97.3%; Average loss: 0.1142
# Iteration: 4868; Percent complete: 97.4%; Average loss: 0.1481
# Iteration: 4869; Percent complete: 97.4%; Average loss: 0.0797
# Iteration: 4870; Percent complete: 97.4%; Average loss: 0.1237
# Iteration: 4871; Percent complete: 97.4%; Average loss: 0.1067
# Iteration: 4872; Percent complete: 97.4%; Average loss: 0.0700
# Iteration: 4873; Percent complete: 97.5%; Average loss: 0.1200
# Iteration: 4874; Percent complete: 97.5%; Average loss: 0.1003
# Iteration: 4875; Percent complete: 97.5%; Average loss: 0.0897
# Iteration: 4876; Percent complete: 97.5%; Average loss: 0.1680
# Iteration: 4877; Percent complete: 97.5%; Average loss: 0.1244
# Iteration: 4878; Percent complete: 97.6%; Average loss: 0.1156
# Iteration: 4879; Percent complete: 97.6%; Average loss: 0.0848
# Iteration: 4880; Percent complete: 97.6%; Average loss: 0.0829
# Iteration: 4881; Percent complete: 97.6%; Average loss: 0.1027
# Iteration: 4882; Percent complete: 97.6%; Average loss: 0.1460
# Iteration: 4883; Percent complete: 97.7%; Average loss: 0.1379
# Iteration: 4884; Percent complete: 97.7%; Average loss: 0.0704
# Iteration: 4885; Percent complete: 97.7%; Average loss: 0.0452
# Iteration: 4886; Percent complete: 97.7%; Average loss: 0.0734
# Iteration: 4887; Percent complete: 97.7%; Average loss: 0.1103
# Iteration: 4888; Percent complete: 97.8%; Average loss: 0.1265
# Iteration: 4889; Percent complete: 97.8%; Average loss: 0.1297
# Iteration: 4890; Percent complete: 97.8%; Average loss: 0.0915
# Iteration: 4891; Percent complete: 97.8%; Average loss: 0.0901
# Iteration: 4892; Percent complete: 97.8%; Average loss: 0.1012
# Iteration: 4893; Percent complete: 97.9%; Average loss: 0.1028
# Iteration: 4894; Percent complete: 97.9%; Average loss: 0.0942
# Iteration: 4895; Percent complete: 97.9%; Average loss: 0.1491
# Iteration: 4896; Percent complete: 97.9%; Average loss: 0.1244
# Iteration: 4897; Percent complete: 97.9%; Average loss: 0.1298
# Iteration: 4898; Percent complete: 98.0%; Average loss: 0.1058
# Iteration: 4899; Percent complete: 98.0%; Average loss: 0.1202
# Iteration: 4900; Percent complete: 98.0%; Average loss: 0.1544
# Iteration: 4901; Percent complete: 98.0%; Average loss: 0.1275
# Iteration: 4902; Percent complete: 98.0%; Average loss: 0.0988
# Iteration: 4903; Percent complete: 98.1%; Average loss: 0.0937
# Iteration: 4904; Percent complete: 98.1%; Average loss: 0.1543
# Iteration: 4905; Percent complete: 98.1%; Average loss: 0.1358
# Iteration: 4906; Percent complete: 98.1%; Average loss: 0.2009
# Iteration: 4907; Percent complete: 98.1%; Average loss: 0.0773
# Iteration: 4908; Percent complete: 98.2%; Average loss: 0.0897
# Iteration: 4909; Percent complete: 98.2%; Average loss: 0.0996
# Iteration: 4910; Percent complete: 98.2%; Average loss: 0.0818
# Iteration: 4911; Percent complete: 98.2%; Average loss: 0.0794
# Iteration: 4912; Percent complete: 98.2%; Average loss: 0.1831
# Iteration: 4913; Percent complete: 98.3%; Average loss: 0.1703
# Iteration: 4914; Percent complete: 98.3%; Average loss: 0.0783
# Iteration: 4915; Percent complete: 98.3%; Average loss: 0.2326
# Iteration: 4916; Percent complete: 98.3%; Average loss: 0.1259
# Iteration: 4917; Percent complete: 98.3%; Average loss: 0.1536
# Iteration: 4918; Percent complete: 98.4%; Average loss: 0.0678
# Iteration: 4919; Percent complete: 98.4%; Average loss: 0.1036
# Iteration: 4920; Percent complete: 98.4%; Average loss: 0.1756
# Iteration: 4921; Percent complete: 98.4%; Average loss: 0.0910
# Iteration: 4922; Percent complete: 98.4%; Average loss: 0.1426
# Iteration: 4923; Percent complete: 98.5%; Average loss: 0.1018
# Iteration: 4924; Percent complete: 98.5%; Average loss: 0.0778
# Iteration: 4925; Percent complete: 98.5%; Average loss: 0.0701
# Iteration: 4926; Percent complete: 98.5%; Average loss: 0.0683
# Iteration: 4927; Percent complete: 98.5%; Average loss: 0.1329
# Iteration: 4928; Percent complete: 98.6%; Average loss: 0.1009
# Iteration: 4929; Percent complete: 98.6%; Average loss: 0.0864
# Iteration: 4930; Percent complete: 98.6%; Average loss: 0.0854
# Iteration: 4931; Percent complete: 98.6%; Average loss: 0.1337
# Iteration: 4932; Percent complete: 98.6%; Average loss: 0.0865
# Iteration: 4933; Percent complete: 98.7%; Average loss: 0.1409
# Iteration: 4934; Percent complete: 98.7%; Average loss: 0.0907
# Iteration: 4935; Percent complete: 98.7%; Average loss: 0.1026
# Iteration: 4936; Percent complete: 98.7%; Average loss: 0.0720
# Iteration: 4937; Percent complete: 98.7%; Average loss: 0.1512
# Iteration: 4938; Percent complete: 98.8%; Average loss: 0.1089
# Iteration: 4939; Percent complete: 98.8%; Average loss: 0.0809
# Iteration: 4940; Percent complete: 98.8%; Average loss: 0.1108
# Iteration: 4941; Percent complete: 98.8%; Average loss: 0.1099
# Iteration: 4942; Percent complete: 98.8%; Average loss: 0.0591
# Iteration: 4943; Percent complete: 98.9%; Average loss: 0.1836
# Iteration: 4944; Percent complete: 98.9%; Average loss: 0.0668
# Iteration: 4945; Percent complete: 98.9%; Average loss: 0.1023
# Iteration: 4946; Percent complete: 98.9%; Average loss: 0.1131
# Iteration: 4947; Percent complete: 98.9%; Average loss: 0.0939
# Iteration: 4948; Percent complete: 99.0%; Average loss: 0.1697
# Iteration: 4949; Percent complete: 99.0%; Average loss: 0.1250
# Iteration: 4950; Percent complete: 99.0%; Average loss: 0.0849
# Iteration: 4951; Percent complete: 99.0%; Average loss: 0.1058
# Iteration: 4952; Percent complete: 99.0%; Average loss: 0.1141
# Iteration: 4953; Percent complete: 99.1%; Average loss: 0.1141
# Iteration: 4954; Percent complete: 99.1%; Average loss: 0.0996
# Iteration: 4955; Percent complete: 99.1%; Average loss: 0.1336
# Iteration: 4956; Percent complete: 99.1%; Average loss: 0.1046
# Iteration: 4957; Percent complete: 99.1%; Average loss: 0.1250
# Iteration: 4958; Percent complete: 99.2%; Average loss: 0.0945
# Iteration: 4959; Percent complete: 99.2%; Average loss: 0.1176
# Iteration: 4960; Percent complete: 99.2%; Average loss: 0.1178
# Iteration: 4961; Percent complete: 99.2%; Average loss: 0.0966
# Iteration: 4962; Percent complete: 99.2%; Average loss: 0.0536
# Iteration: 4963; Percent complete: 99.3%; Average loss: 0.1145
# Iteration: 4964; Percent complete: 99.3%; Average loss: 0.1015
# Iteration: 4965; Percent complete: 99.3%; Average loss: 0.1314
# Iteration: 4966; Percent complete: 99.3%; Average loss: 0.0816
# Iteration: 4967; Percent complete: 99.3%; Average loss: 0.1287
# Iteration: 4968; Percent complete: 99.4%; Average loss: 0.1284
# Iteration: 4969; Percent complete: 99.4%; Average loss: 0.1403
# Iteration: 4970; Percent complete: 99.4%; Average loss: 0.1150
# Iteration: 4971; Percent complete: 99.4%; Average loss: 0.0954
# Iteration: 4972; Percent complete: 99.4%; Average loss: 0.1381
# Iteration: 4973; Percent complete: 99.5%; Average loss: 0.0959
# Iteration: 4974; Percent complete: 99.5%; Average loss: 0.1105
# Iteration: 4975; Percent complete: 99.5%; Average loss: 0.1014
# Iteration: 4976; Percent complete: 99.5%; Average loss: 0.0831
# Iteration: 4977; Percent complete: 99.5%; Average loss: 0.1011
# Iteration: 4978; Percent complete: 99.6%; Average loss: 0.0737
# Iteration: 4979; Percent complete: 99.6%; Average loss: 0.1230
# Iteration: 4980; Percent complete: 99.6%; Average loss: 0.1082
# Iteration: 4981; Percent complete: 99.6%; Average loss: 0.1535
# Iteration: 4982; Percent complete: 99.6%; Average loss: 0.1041
# Iteration: 4983; Percent complete: 99.7%; Average loss: 0.1301
# Iteration: 4984; Percent complete: 99.7%; Average loss: 0.1463
# Iteration: 4985; Percent complete: 99.7%; Average loss: 0.0872
# Iteration: 4986; Percent complete: 99.7%; Average loss: 0.0805
# Iteration: 4987; Percent complete: 99.7%; Average loss: 0.0770
# Iteration: 4988; Percent complete: 99.8%; Average loss: 0.1206
# Iteration: 4989; Percent complete: 99.8%; Average loss: 0.0907
# Iteration: 4990; Percent complete: 99.8%; Average loss: 0.1009
# Iteration: 4991; Percent complete: 99.8%; Average loss: 0.1348
# Iteration: 4992; Percent complete: 99.8%; Average loss: 0.1210
# Iteration: 4993; Percent complete: 99.9%; Average loss: 0.1060
# Iteration: 4994; Percent complete: 99.9%; Average loss: 0.0838
# Iteration: 4995; Percent complete: 99.9%; Average loss: 0.0969
# Iteration: 4996; Percent complete: 99.9%; Average loss: 0.0765
# Iteration: 4997; Percent complete: 99.9%; Average loss: 0.1288
# Iteration: 4998; Percent complete: 100.0%; Average loss: 0.1053
# Iteration: 4999; Percent complete: 100.0%; Average loss: 0.1471
# Iteration: 5000; Percent complete: 100.0%; Average loss: 0.1169

# %% [markdown]
# Run the model :)

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > how are you
# Bot: . are about long . car car 7
# > any idea on what is going on here?
# Bot: no there s no brown them . grandson 8
# > seems like this datasets is not working
# Error: Encountered unknown word.
# > seems like it is not working
# Bot: yes . like the model ! 6
# > lol
# Bot: yes . are awesome ! quality 6
# > what should we eat
# Bot:  well good and metal 5
# > what is your favorite car
# Bot:  are fast ? ! 5
# > what is your favorite movie
# Bot:  only grandson ! 4
# > how is the weather today
# Bot:  can say grandson ! good 6
# > q

# %% [markdown]
# ### Notes on the Model

# %% [markdown]
# Overall, the model is OK. It was not as intelligent as i thought it would be, but I suppose that is a good thing. One of the things that I noticed from playing with the bot was that everything is pretty predictable. In fact, it feels less like it is responding to you and more like it has memories what to day based on an input string from the user. I think the first thing we can do to improve the model is to add some randomness to the model, so asking "hello" wont keep generating the same output. To improve this one a bit more we can change some of the variable like the learning rate and the depth. Eventually, to improve the overall feeling of the chat bot we can implement an entirely new model. Try to give a more meaningful number to words rather than what index they first appear in (ask professor if he thinks this would even matter, or would this just be a change of domain).
