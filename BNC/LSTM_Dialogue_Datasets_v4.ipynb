# %% [markdown]
# # ChatBot References
#
# Professor Smyth's website discussing projects
#
# https://www.ics.uci.edu/~smyth/courses/cs175/project_reading.html
#
# Chatbot resources on website
#
# https://pytorch.org/tutorials/beginner/chatbot_tutorial.html
#
# https://web.stanford.edu/~jurafsky/slp3/26.pdf
#
# https://www.microsoft.com/en-us/research/wp-content/uploads/2016/12/CortanaLUDialog-FromSLTproceedings.pdf
#
# Dataset for tutorial
#
# https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html

# %% [markdown]
# # Start of Tutorial

# %% [markdown]
# ### Import necessary libraries

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import numpy as np

USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# ### Preprocess Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Looking at some files in the data to see how they are structured ...

# %%
data = "/content/drive/MyDrive/CS175_Datasets"
# corpus = os.path.join("data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

# printLines(os.path.join(data, "qa_Video_Games.json"))

# %% [markdown]
# Scan through data files and reformat them to be (sentence, response) pairs separated by a tab eventually. First we create helper functions to help clean up the data a bit and make it more readable ...

# %%
import json
import gzip

def parse(file):
  lines = [line.rstrip() for line in file]
  return lines

def loadConversations(lines):
  return [[lines[i], lines[i+1]] for i in range(0,len(lines),2)]  


def extractSentencePairs(conversations):
    return conversations

# %% [markdown]
# Next we will be using the functions above we now parse the data into a form that is useful to us and see what a few lines from the data look like ...

# %%
# Define path to new file
corpus=data
datafile_path = os.path.join(corpus, "Dialogue_Datasets")
datasets = os.path.join(datafile_path,"BNCSplitWordsCorpus.txt")
outfile_path = os.path.join(datafile_path, "csv_files")
datafile = os.path.join(outfile_path, "BNC.csv")
corpus_name = "BNC"
delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))
# load data if data file is already been processed as csv file
load_data = True

conversations = []
if not load_data: 
  # Load lines and process conversations
  print("\nProcessing corpus...")
  # lines = loadLines(os.path.join(corpus, "movie_lines.txt"), MOVIE_LINES_FIELDS)
  print("\nLoading conversations...")
  print(datasets)
  lines = parse(open(datasets))
  conversations = loadConversations(lines)


  # Write new csv file
  print("\nWriting newly formatted file...")
  with open(datafile, 'w', encoding='utf-8') as outputfile:
      writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
      for pair in extractSentencePairs(conversations):
        writer.writerow(pair)
# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Sample lines from file:
# b'You enjoyed yourself in America\tEh\n'
# b'did you\tOh I covered a nice trip yes\n'
# b'Oh very good\tsaw Mary and Andrew and\n'
# b"Yes you did\tin fact the whole family was together for Mary's wedding\n"
# b"Oh very nice very nice yes\tIt's horrible\n"
# b"It is horrible isn't\tHave you been busy\n"
# b'Yes\tYes oh\n'
# b"Jim's been for a this afternoon at the H art and Straw Club\toh not very well we er m we stopped going after Christmas because we had bad chest s both of us\n"
# b"Oh\tboth cold and it's hard going that three hours in the morning you know\n"
# b"Yes\tbut we'll go back again\n"

# %% [markdown]
# We want to create a vocabulary of words that we see. We represent these words numerically using the index of their first appearance in the history of all added words to the set of vocuabulary. See `addWord()` for specifics.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we finally getting to the part where we begin to make the (sentence, response) pairs. We begin preprocessing by converting the Unicode string texts to ASCII `unicodeToAscii()`. We also make everything lower case, and remove nonletters except for basic punctuation `normalizeString()`. The last thing that is done in preprocessing is ignore sentences beyond a certain length to aid in training `filterPair()` and `MAX_LENGTH`.

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print(pairs[:10])
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join(data, "LSRM_save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# [['you enjoyed yourself in america', 'eh'], ['did you', 'oh i covered a nice trip yes'], ['oh very good', 'saw mary and andrew and'], ['yes you did', 'in fact the whole family was together for mary s wedding'], ['oh very nice very nice yes', 'it s horrible'], ['it is horrible isn t', 'have you been busy'], ['yes', 'yes oh'], ['jim s been for a this afternoon at the h art and straw club', 'oh not very well we er m we stopped going after christmas because we had bad chest s both of us'], ['oh', 'both cold and it s hard going that three hours in the morning you know'], ['yes', 'but we ll go back again']]
# Read 305507 sentence pairs
# Trimmed to 185299 sentence pairs
# Counting words...
# Counted words: 14962
#
# pairs:
# ['you enjoyed yourself in america', 'eh']
# ['did you', 'oh i covered a nice trip yes']
# ['oh very good', 'saw mary and andrew and']
# ['oh very nice very nice yes', 'it s horrible']
# ['it is horrible isn t', 'have you been busy']
# ['yes', 'yes oh']
# ['yes', 'but we ll go back again']
# ['well i ve had to stop my classes', 'yeah']
# ['because i m i m so busy', 'yes']
# ['mm', 'er anyway we re alright now so you know']

# %% [markdown]
# Another way to speed up training is by removing words that are rarely used. We "trim" these words using `Voc.trim()` and as a result must also remove (sentence, response) pairs that include these words.

# %%
MIN_COUNT = 10    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 4676 / 14959 = 0.3126
# Trimmed from 185299 pairs to 159552, 0.8611 of total

# %% [markdown]
# ### Using our Data on our Models

# %% [markdown]
# The data still needs to be processed more. The model that we use will take numerical values and not actual strings to do computation. We convert our sentences to tensors (vectors) that our model will take as inputs. To do this, we just take every sentence and change it to be a vector of index that corresponds to that word. This is how we will use our data to train the model.
#
# If we would like to train our model we usually do it with minbatches since it makes things faster. We make a matrix of dimensions (BatchLength, MaxLengthOfSentenceInBatch) represented numerically as mentioned in the previous paragraph. With this we make sure that each row (sentence) of our matrix terminates with `EOS_Token` and is followed by 0 entries until the end of the row.
#
# This implementation almost works, the problem with this is that each row is a sentence and every column is a step in time. However, it is better to think of every row as a step in time and the column to be possible words to choose for that step in time. For this reason, we construct the Matrix as mentioned in the previous paragraph except it is now transposed.
#
# We define some function that help us achieve this ...

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[  11,  161,   38,   50,   45],
#         [ 619,   11,  148,    2,    2],
#         [  28,   47,   24,    0,    0],
#         [ 729,  408, 2568,    0,    0],
#         [  41,  821, 3166,    0,    0],
#         [ 356,  307,    2,    0,    0],
#         [  13,    2,    0,    0,    0],
#         [ 730,    0,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([9, 7, 6, 2, 2])
# target_variable: tensor([[ 75,  11,  92, 274,  23],
#         [ 11,   2, 541,  13,  24],
#         [117,   0,   2, 263, 137],
#         [ 28,   0,   0,   2,  48],
#         [731,   0,   0,   0,  80],
#         [  3,   0,   0,   0,  59],
#         [  2,   0,   0,   0,  23],
#         [  0,   0,   0,   0,   2]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False,  True,  True,  True],
#         [ True, False, False,  True,  True],
#         [ True, False, False, False,  True],
#         [ True, False, False, False,  True],
#         [ True, False, False, False,  True],
#         [False, False, False, False,  True]])
# max_target_len: 8

# %% [markdown]
# Seeing the output from preping the data above, it appears that `input_variable` is the matrix described in the previous secsion. `lenghts` is just a tensor (vector) of how long the sentences in the input were. This will eventually be used for the **decoder** later in the program. `target_variable` seems to be the response that our model is supposed to learn. `mask` looks like it is a mask for responses where true is that there is a word and false is that there is no word there. Not sure why this variable is necessary but maybe it will become clearer at some point in the tutorial.

# %% [markdown]
# ### Defining our Model

# %% [markdown]
# Our base model is a Sequence-to-Sequence model using two RNN's. The first RNN is what is called the **encoder** and it takes a variable length input and converts it into a *fixed length* "context" vector that is intended to hold onto some semantic meaning of the input. The **decoder** takes the context vector provided by the decoder along with an input word to guess the next word in a sequence. I suppose our (sentence, response) pairs are learned as one long continuous sequence where the sentence is the start of hte sequence and the response is the remainder of the sequence, though this might be entirely incorrect.

# %% [markdown]
# Some discussion on the Encoder. The encoder uses a bidirectional GRU (Gated Recurrent Unit), meaning that there is basically two RNN's that make up the encoder, one that goes through the sequence of data in the forward direction while another RNN goes through the sequence in the backward direction. At each time step, both RNN's produce an output and a hidden state vector. At each time step, the output of both RNNs are summed and the output is recorded (somewhere) while the hidden state vectors are pushed along and used in the next step of the RNN. The outputs are summed makes it so that at each time step, the RNN is considering present and future context.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.LSTM(hidden_size,hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Some discussion on the Decoder. The decoder uses the context vector that is produced by the encoder. Usually, this is all that will be used by a decoder to produce output but this can result in a loss of information, expecially when the input sentences are very long. To counter this, the decoder also uses its current hidden state as a way of determining what it should be "paying attention" to. These are refered to as attention weights and are multiplied by the outputs from the encoder (the output that is apperantly recorded somewhere, this is where they are used) from the current time step to rescale the values, making less important parts of the encoder output smaller and more important parts of the encoder output larger. This can be further improved by using all of the encoder outputs instead of just the one of the current time step to have a more comprehensive set of attention weights. This is the method implemented below, followed by the implementation of the decoder using this attention method.

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.LSTM(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# ### Defining the Training Procedure

# %% [markdown]
# Recall earlier in the `mask` produced along side the `target_variable` was produced for an unknown purpose, it turns out its purpose is for determining the loss of the model. This implementation below is the negative-log-likelihood loss and the variable `mask` along with `target_variable`.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# For training the model, two tricks are used to help convergence. The first trick is refered to as "teacher forcing" which just overrides the prediction of the decoder and uses the actual target value instead, this happens with some small probability p. Doing it too much will make the decoder unable to make predictions on its own and not having this feature will make it so that convergence is just slower. The second trick they do is gradient clipping, meaning that at areas in the feature space where there is a steep gradient and therefore a chance to improve the model very fast, the magnitude of the gradient is limited some value. This is to not drastically overshoot local minima on "cliffs". The training function is implemented below. This trains only one iteration.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
        #Get the encoder final h_hidden_state
    encoder_h_hidden, encoder_c_hidden = encoder_hidden
    decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
    decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
    # Recombine the final hidden states as hidden tuple
    decoder_hidden = (decoder_h_hidden, decoder_c_hidden)

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# This version of the training function trains on multiple iterations. It is built on the previous training function. This function also saves the current variables in a tarball file. This is to continue training at a later period or just use the current accumulated training to make predictions.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, 
               encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, 
               clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(
                iteration, iteration / n_iteration * 100, print_loss_avg
            ))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(
                encoder_n_layers, decoder_n_layers, hidden_size
            ))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# ### Defining Evaluation

# %% [markdown]
# This is the training method used by our bot when we are not using the "teacher forcing" method. This just basically chooses the output of hte decoder to be the output with the highest softmax score, ie the best response given its prior training. I think this is defining a decoder method for whenever we are actually using our model instead of when it is training.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

#option to greedy search
class StochasticTopKUniformDecoder(nn.Module):
    def __init__(self, encoder, decoder, k):
        super(StochasticTopKUniformDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            # select from the top k words at each word in the sentence
            # uniformly at random.
            decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
            i = int(random.random()*self.k)
            decoder_input = torch.tensor([ind[0,i]]).to(device)
            decoder_scores = torch.tensor([decoder_output_topk[0,i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

class StochasticTopKSampleDecoder(nn.Module):
    def __init__(self, encoder, decoder, k):
        super(StochasticTopKSampleDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            # sample choice of word from the top k words at each word
            # in the sentence
            decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
            decoder_output_topk = decoder_output_topk.cpu().detach().numpy().flatten()
            ind = ind.cpu().detach().numpy().flatten()
            probabilities = decoder_output_topk/(np.sum(decoder_output_topk))
            value = np.random.choice(ind, 1, p=probabilities)
            i = np.where(ind == value[0])[0][0]
            decoder_input = torch.tensor([ind[i]]).to(device)
            decoder_scores = torch.tensor([decoder_output_topk[i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

class StochasticSentenceInitializerSamplingDecoder(nn.Module):
    def __init__(self, encoder, decoder, k, n):
        super(StochasticSentenceInitializerSamplingDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k
        self.n = n

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for i in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            if i >= self.n:
                # be greedy >:)
                decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            else:
                # sample choice of word from the top k words at each word
                # in the sentence
                decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
                decoder_output_topk = decoder_output_topk.cpu().detach().numpy().flatten()
                ind = ind.cpu().detach().numpy().flatten()
                probabilities = decoder_output_topk/(np.sum(decoder_output_topk))
                value = np.random.choice(ind, 1, p=probabilities)
                i = np.where(ind == value[0])[0][0]
                decoder_input = torch.tensor([ind[i]]).to(device)
                decoder_scores = torch.tensor([decoder_output_topk[i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

class StochasticSentenceInitializerUniformDecoder(nn.Module):
    def __init__(self, encoder, decoder, k, n):
        super(StochasticSentenceInitializerUniformDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.k = k
        self.n = n

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for i in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            
            if i >= self.n:
                # be greedy >:)
                decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            else:
                # sample choice of word from the top k words at each word
                # in the sentence (uniformly at random)
                decoder_output_topk, ind = torch.topk(decoder_output, k=self.k, dim=1)
                i = int(random.random()*self.k)
                decoder_input = torch.tensor([ind[0,i]]).to(device)
                decoder_scores = torch.tensor([decoder_output_topk[0,i]]).to(device)
            
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores
# The evaluateInput function is meant to take input from the user, prepare it so that it may be fed to our model, and pring out the response from our bot. evaluate handles most of hte actual calculation while evaluateInput handles most of the user interaction phase.

# %% [markdown]
# The `evaluateInput` function is meant to take input from the user, prepare it so that it may be fed to our model, and pring out the response from our bot. `evaluate` handles most of hte actual calculation while `evaluateInput` handles most of the user interaction phase.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    #lengths = lengths.to(device) # removed bc of gpu cpu tensor difference ###################################
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words), len(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# ### Running the Model

# %% [markdown]
# This defines and builds our model based on the following parameters. Notice that parts of the code are commented out as these are other possibilities ofr initialization. attn_model can be given one of three different models. We can also choose to load a model that we previously trained.

# %%
# Configure models
model_name = 'LSTM_dialogue_2048_batch_20000_iter'
attn_model = 'dot'
# attn_model = 'general'
# attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 2048

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 15000
# loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Now we train our model using `trainIters`. We first set some training parameters and initialize optimizers and prepare our model for training. Training is likely to take a very long time, thankfully there is the option to load from a previous model and this piece of code here doesn't need to be run every time.

# %%
# Safty precaution so that we dont accidentally begin training a model we didnt want to train
TRAIN_THE_MODEL = True

# %%
if TRAIN_THE_MODEL:
    
    # Configure training/optimization
    clip = 50.0
    teacher_forcing_ratio = 1.0
    learning_rate = 0.0001
    decoder_learning_ratio = 5.0
    n_iteration = 20000
    print_every = 1
    save_every = 1000

    # Ensure dropout layers are in train mode
    encoder.train()
    decoder.train()

    # Initialize optimizers
    print('Building optimizers ...')
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
    if loadFilename:
        encoder_optimizer.load_state_dict(encoder_optimizer_sd)
        decoder_optimizer.load_state_dict(decoder_optimizer_sd)

    # If you have cuda, configure cuda to call
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    # Run training iterations
    print("Starting Training!")
    trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
               embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
               print_every, save_every, clip, corpus_name, loadFilename)
    
    TRAIN_THE_MODEL = False

else:
    
    print(f"Make the variable 'TRAIN_THE_MODEL' in the code block above True and run the code block")
    print(f"Value of 'TRAIN_THE_MODEL' currently: {TRAIN_THE_MODEL}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration: 15001; Percent complete: 75.0%; Average loss: 0.6125
# Iteration: 15002; Percent complete: 75.0%; Average loss: 0.6291
# Iteration: 15003; Percent complete: 75.0%; Average loss: 0.6231
# Iteration: 15004; Percent complete: 75.0%; Average loss: 0.6349
# Iteration: 15005; Percent complete: 75.0%; Average loss: 0.6608
# Iteration: 15006; Percent complete: 75.0%; Average loss: 0.6333
# Iteration: 15007; Percent complete: 75.0%; Average loss: 0.6208
# Iteration: 15008; Percent complete: 75.0%; Average loss: 0.5843
# Iteration: 15009; Percent complete: 75.0%; Average loss: 0.6250
# Iteration: 15010; Percent complete: 75.0%; Average loss: 0.6258
# Iteration: 15011; Percent complete: 75.1%; Average loss: 0.6466
# Iteration: 15012; Percent complete: 75.1%; Average loss: 0.6269
# Iteration: 15013; Percent complete: 75.1%; Average loss: 0.6107
# Iteration: 15014; Percent complete: 75.1%; Average loss: 0.6185
# Iteration: 15015; Percent complete: 75.1%; Average loss: 0.6234
# Iteration: 15016; Percent complete: 75.1%; Average loss: 0.6442
# Iteration: 15017; Percent complete: 75.1%; Average loss: 0.6246
# Iteration: 15018; Percent complete: 75.1%; Average loss: 0.6437
# Iteration: 15019; Percent complete: 75.1%; Average loss: 0.6497
# Iteration: 15020; Percent complete: 75.1%; Average loss: 0.6094
# Iteration: 15021; Percent complete: 75.1%; Average loss: 0.6250
# Iteration: 15022; Percent complete: 75.1%; Average loss: 0.6346
# Iteration: 15023; Percent complete: 75.1%; Average loss: 0.6268
# Iteration: 15024; Percent complete: 75.1%; Average loss: 0.6312
# Iteration: 15025; Percent complete: 75.1%; Average loss: 0.6010
# Iteration: 15026; Percent complete: 75.1%; Average loss: 0.6418
# Iteration: 15027; Percent complete: 75.1%; Average loss: 0.6244
# Iteration: 15028; Percent complete: 75.1%; Average loss: 0.6286
# Iteration: 15029; Percent complete: 75.1%; Average loss: 0.6166
# Iteration: 15030; Percent complete: 75.1%; Average loss: 0.6304
# Iteration: 15031; Percent complete: 75.2%; Average loss: 0.6303
# Iteration: 15032; Percent complete: 75.2%; Average loss: 0.6389
# Iteration: 15033; Percent complete: 75.2%; Average loss: 0.6365
# Iteration: 15034; Percent complete: 75.2%; Average loss: 0.6153
# Iteration: 15035; Percent complete: 75.2%; Average loss: 0.6216
# Iteration: 15036; Percent complete: 75.2%; Average loss: 0.6209
# Iteration: 15037; Percent complete: 75.2%; Average loss: 0.6125
# Iteration: 15038; Percent complete: 75.2%; Average loss: 0.6462
# Iteration: 15039; Percent complete: 75.2%; Average loss: 0.6303
# Iteration: 15040; Percent complete: 75.2%; Average loss: 0.6188
# Iteration: 15041; Percent complete: 75.2%; Average loss: 0.6368
# Iteration: 15042; Percent complete: 75.2%; Average loss: 0.6188
# Iteration: 15043; Percent complete: 75.2%; Average loss: 0.6314
# Iteration: 15044; Percent complete: 75.2%; Average loss: 0.5973
# Iteration: 15045; Percent complete: 75.2%; Average loss: 0.6434
# Iteration: 15046; Percent complete: 75.2%; Average loss: 0.5999
# Iteration: 15047; Percent complete: 75.2%; Average loss: 0.6125
# Iteration: 15048; Percent complete: 75.2%; Average loss: 0.6377
# Iteration: 15049; Percent complete: 75.2%; Average loss: 0.6121
# Iteration: 15050; Percent complete: 75.2%; Average loss: 0.6042
# Iteration: 15051; Percent complete: 75.3%; Average loss: 0.5905
# Iteration: 15052; Percent complete: 75.3%; Average loss: 0.6086
# Iteration: 15053; Percent complete: 75.3%; Average loss: 0.6341
# Iteration: 15054; Percent complete: 75.3%; Average loss: 0.6359
# Iteration: 15055; Percent complete: 75.3%; Average loss: 0.6308
# Iteration: 15056; Percent complete: 75.3%; Average loss: 0.6223
# Iteration: 15057; Percent complete: 75.3%; Average loss: 0.6390
# Iteration: 15058; Percent complete: 75.3%; Average loss: 0.6362
# Iteration: 15059; Percent complete: 75.3%; Average loss: 0.6185
# Iteration: 15060; Percent complete: 75.3%; Average loss: 0.5975
# Iteration: 15061; Percent complete: 75.3%; Average loss: 0.6213
# Iteration: 15062; Percent complete: 75.3%; Average loss: 0.6139
# Iteration: 15063; Percent complete: 75.3%; Average loss: 0.6057
# Iteration: 15064; Percent complete: 75.3%; Average loss: 0.5885
# Iteration: 15065; Percent complete: 75.3%; Average loss: 0.6413
# Iteration: 15066; Percent complete: 75.3%; Average loss: 0.6006
# Iteration: 15067; Percent complete: 75.3%; Average loss: 0.6028
# Iteration: 15068; Percent complete: 75.3%; Average loss: 0.6095
# Iteration: 15069; Percent complete: 75.3%; Average loss: 0.6078
# Iteration: 15070; Percent complete: 75.3%; Average loss: 0.6494
# Iteration: 15071; Percent complete: 75.4%; Average loss: 0.6327
# Iteration: 15072; Percent complete: 75.4%; Average loss: 0.6235
# Iteration: 15073; Percent complete: 75.4%; Average loss: 0.5916
# Iteration: 15074; Percent complete: 75.4%; Average loss: 0.6395
# Iteration: 15075; Percent complete: 75.4%; Average loss: 0.6244
# Iteration: 15076; Percent complete: 75.4%; Average loss: 0.6030
# Iteration: 15077; Percent complete: 75.4%; Average loss: 0.6285
# Iteration: 15078; Percent complete: 75.4%; Average loss: 0.6508
# Iteration: 15079; Percent complete: 75.4%; Average loss: 0.5996
# Iteration: 15080; Percent complete: 75.4%; Average loss: 0.6425
# Iteration: 15081; Percent complete: 75.4%; Average loss: 0.6193
# Iteration: 15082; Percent complete: 75.4%; Average loss: 0.6533
# Iteration: 15083; Percent complete: 75.4%; Average loss: 0.6133
# Iteration: 15084; Percent complete: 75.4%; Average loss: 0.6126
# Iteration: 15085; Percent complete: 75.4%; Average loss: 0.6176
# Iteration: 15086; Percent complete: 75.4%; Average loss: 0.6012
# Iteration: 15087; Percent complete: 75.4%; Average loss: 0.6657
# Iteration: 15088; Percent complete: 75.4%; Average loss: 0.6164
# Iteration: 15089; Percent complete: 75.4%; Average loss: 0.6183
# Iteration: 15090; Percent complete: 75.4%; Average loss: 0.5885
# Iteration: 15091; Percent complete: 75.5%; Average loss: 0.6383
# Iteration: 15092; Percent complete: 75.5%; Average loss: 0.6396
# Iteration: 15093; Percent complete: 75.5%; Average loss: 0.6152
# Iteration: 15094; Percent complete: 75.5%; Average loss: 0.6274
# Iteration: 15095; Percent complete: 75.5%; Average loss: 0.6500
# Iteration: 15096; Percent complete: 75.5%; Average loss: 0.6031
# Iteration: 15097; Percent complete: 75.5%; Average loss: 0.6133
# Iteration: 15098; Percent complete: 75.5%; Average loss: 0.6217
# Iteration: 15099; Percent complete: 75.5%; Average loss: 0.6628
# Iteration: 15100; Percent complete: 75.5%; Average loss: 0.6028
# Iteration: 15101; Percent complete: 75.5%; Average loss: 0.6142
# Iteration: 15102; Percent complete: 75.5%; Average loss: 0.6314
# Iteration: 15103; Percent complete: 75.5%; Average loss: 0.6338
# Iteration: 15104; Percent complete: 75.5%; Average loss: 0.6215
# Iteration: 15105; Percent complete: 75.5%; Average loss: 0.6047
# Iteration: 15106; Percent complete: 75.5%; Average loss: 0.6493
# Iteration: 15107; Percent complete: 75.5%; Average loss: 0.6274
# Iteration: 15108; Percent complete: 75.5%; Average loss: 0.5994
# Iteration: 15109; Percent complete: 75.5%; Average loss: 0.6153
# Iteration: 15110; Percent complete: 75.5%; Average loss: 0.6101
# Iteration: 15111; Percent complete: 75.6%; Average loss: 0.6289
# Iteration: 15112; Percent complete: 75.6%; Average loss: 0.6498
# Iteration: 15113; Percent complete: 75.6%; Average loss: 0.6404
# Iteration: 15114; Percent complete: 75.6%; Average loss: 0.6005
# Iteration: 15115; Percent complete: 75.6%; Average loss: 0.6436
# Iteration: 15116; Percent complete: 75.6%; Average loss: 0.6238
# Iteration: 15117; Percent complete: 75.6%; Average loss: 0.6255
# Iteration: 15118; Percent complete: 75.6%; Average loss: 0.6234
# Iteration: 15119; Percent complete: 75.6%; Average loss: 0.6019
# Iteration: 15120; Percent complete: 75.6%; Average loss: 0.6419
# Iteration: 15121; Percent complete: 75.6%; Average loss: 0.6390
# Iteration: 15122; Percent complete: 75.6%; Average loss: 0.6224
# Iteration: 15123; Percent complete: 75.6%; Average loss: 0.6149
# Iteration: 15124; Percent complete: 75.6%; Average loss: 0.6269
# Iteration: 15125; Percent complete: 75.6%; Average loss: 0.6068
# Iteration: 15126; Percent complete: 75.6%; Average loss: 0.6504
# Iteration: 15127; Percent complete: 75.6%; Average loss: 0.6285
# Iteration: 15128; Percent complete: 75.6%; Average loss: 0.6183
# Iteration: 15129; Percent complete: 75.6%; Average loss: 0.5897
# Iteration: 15130; Percent complete: 75.6%; Average loss: 0.6080
# Iteration: 15131; Percent complete: 75.7%; Average loss: 0.6217
# Iteration: 15132; Percent complete: 75.7%; Average loss: 0.6223
# Iteration: 15133; Percent complete: 75.7%; Average loss: 0.6206
# Iteration: 15134; Percent complete: 75.7%; Average loss: 0.6421
# Iteration: 15135; Percent complete: 75.7%; Average loss: 0.6145
# Iteration: 15136; Percent complete: 75.7%; Average loss: 0.6137
# Iteration: 15137; Percent complete: 75.7%; Average loss: 0.6461
# Iteration: 15138; Percent complete: 75.7%; Average loss: 0.6471
# Iteration: 15139; Percent complete: 75.7%; Average loss: 0.5876
# Iteration: 15140; Percent complete: 75.7%; Average loss: 0.6262
# Iteration: 15141; Percent complete: 75.7%; Average loss: 0.6527
# Iteration: 15142; Percent complete: 75.7%; Average loss: 0.6210
# Iteration: 15143; Percent complete: 75.7%; Average loss: 0.6433
# Iteration: 15144; Percent complete: 75.7%; Average loss: 0.6142
# Iteration: 15145; Percent complete: 75.7%; Average loss: 0.6411
# Iteration: 15146; Percent complete: 75.7%; Average loss: 0.6309
# Iteration: 15147; Percent complete: 75.7%; Average loss: 0.6069
# Iteration: 15148; Percent complete: 75.7%; Average loss: 0.6162
# Iteration: 15149; Percent complete: 75.7%; Average loss: 0.6420
# Iteration: 15150; Percent complete: 75.8%; Average loss: 0.6461
# Iteration: 15151; Percent complete: 75.8%; Average loss: 0.6381
# Iteration: 15152; Percent complete: 75.8%; Average loss: 0.6070
# Iteration: 15153; Percent complete: 75.8%; Average loss: 0.6472
# Iteration: 15154; Percent complete: 75.8%; Average loss: 0.6147
# Iteration: 15155; Percent complete: 75.8%; Average loss: 0.6319
# Iteration: 15156; Percent complete: 75.8%; Average loss: 0.6282
# Iteration: 15157; Percent complete: 75.8%; Average loss: 0.6271
# Iteration: 15158; Percent complete: 75.8%; Average loss: 0.6237
# Iteration: 15159; Percent complete: 75.8%; Average loss: 0.6228
# Iteration: 15160; Percent complete: 75.8%; Average loss: 0.6196
# Iteration: 15161; Percent complete: 75.8%; Average loss: 0.6380
# Iteration: 15162; Percent complete: 75.8%; Average loss: 0.6132
# Iteration: 15163; Percent complete: 75.8%; Average loss: 0.5953
# Iteration: 15164; Percent complete: 75.8%; Average loss: 0.5781
# Iteration: 15165; Percent complete: 75.8%; Average loss: 0.6350
# Iteration: 15166; Percent complete: 75.8%; Average loss: 0.6175
# Iteration: 15167; Percent complete: 75.8%; Average loss: 0.6194
# Iteration: 15168; Percent complete: 75.8%; Average loss: 0.6270
# Iteration: 15169; Percent complete: 75.8%; Average loss: 0.6156
# Iteration: 15170; Percent complete: 75.8%; Average loss: 0.6055
# Iteration: 15171; Percent complete: 75.9%; Average loss: 0.6139
# Iteration: 15172; Percent complete: 75.9%; Average loss: 0.6351
# Iteration: 15173; Percent complete: 75.9%; Average loss: 0.6328
# Iteration: 15174; Percent complete: 75.9%; Average loss: 0.6470
# Iteration: 15175; Percent complete: 75.9%; Average loss: 0.6293
# Iteration: 15176; Percent complete: 75.9%; Average loss: 0.6151
# Iteration: 15177; Percent complete: 75.9%; Average loss: 0.6473
# Iteration: 15178; Percent complete: 75.9%; Average loss: 0.6030
# Iteration: 15179; Percent complete: 75.9%; Average loss: 0.6277
# Iteration: 15180; Percent complete: 75.9%; Average loss: 0.6507
# Iteration: 15181; Percent complete: 75.9%; Average loss: 0.6220
# Iteration: 15182; Percent complete: 75.9%; Average loss: 0.6237
# Iteration: 15183; Percent complete: 75.9%; Average loss: 0.6246
# Iteration: 15184; Percent complete: 75.9%; Average loss: 0.6266
# Iteration: 15185; Percent complete: 75.9%; Average loss: 0.6213
# Iteration: 15186; Percent complete: 75.9%; Average loss: 0.6275
# Iteration: 15187; Percent complete: 75.9%; Average loss: 0.6229
# Iteration: 15188; Percent complete: 75.9%; Average loss: 0.6258
# Iteration: 15189; Percent complete: 75.9%; Average loss: 0.6309
# Iteration: 15190; Percent complete: 75.9%; Average loss: 0.6285
# Iteration: 15191; Percent complete: 76.0%; Average loss: 0.6176
# Iteration: 15192; Percent complete: 76.0%; Average loss: 0.6273
# Iteration: 15193; Percent complete: 76.0%; Average loss: 0.6574
# Iteration: 15194; Percent complete: 76.0%; Average loss: 0.6202
# Iteration: 15195; Percent complete: 76.0%; Average loss: 0.6334
# Iteration: 15196; Percent complete: 76.0%; Average loss: 0.6016
# Iteration: 15197; Percent complete: 76.0%; Average loss: 0.6226
# Iteration: 15198; Percent complete: 76.0%; Average loss: 0.6396
# Iteration: 15199; Percent complete: 76.0%; Average loss: 0.6104
# Iteration: 15200; Percent complete: 76.0%; Average loss: 0.6076
# Iteration: 15201; Percent complete: 76.0%; Average loss: 0.6154
# Iteration: 15202; Percent complete: 76.0%; Average loss: 0.6165
# Iteration: 15203; Percent complete: 76.0%; Average loss: 0.6007
# Iteration: 15204; Percent complete: 76.0%; Average loss: 0.6324
# Iteration: 15205; Percent complete: 76.0%; Average loss: 0.6496
# Iteration: 15206; Percent complete: 76.0%; Average loss: 0.6119
# Iteration: 15207; Percent complete: 76.0%; Average loss: 0.6136
# Iteration: 15208; Percent complete: 76.0%; Average loss: 0.6244
# Iteration: 15209; Percent complete: 76.0%; Average loss: 0.6222
# Iteration: 15210; Percent complete: 76.0%; Average loss: 0.6226
# Iteration: 15211; Percent complete: 76.1%; Average loss: 0.6142
# Iteration: 15212; Percent complete: 76.1%; Average loss: 0.5999
# Iteration: 15213; Percent complete: 76.1%; Average loss: 0.6330
# Iteration: 15214; Percent complete: 76.1%; Average loss: 0.6274
# Iteration: 15215; Percent complete: 76.1%; Average loss: 0.6424
# Iteration: 15216; Percent complete: 76.1%; Average loss: 0.5874
# Iteration: 15217; Percent complete: 76.1%; Average loss: 0.6019
# Iteration: 15218; Percent complete: 76.1%; Average loss: 0.6052
# Iteration: 15219; Percent complete: 76.1%; Average loss: 0.6108
# Iteration: 15220; Percent complete: 76.1%; Average loss: 0.6125
# Iteration: 15221; Percent complete: 76.1%; Average loss: 0.6258
# Iteration: 15222; Percent complete: 76.1%; Average loss: 0.6318
# Iteration: 15223; Percent complete: 76.1%; Average loss: 0.6127
# Iteration: 15224; Percent complete: 76.1%; Average loss: 0.6040
# Iteration: 15225; Percent complete: 76.1%; Average loss: 0.6139
# Iteration: 15226; Percent complete: 76.1%; Average loss: 0.6083
# Iteration: 15227; Percent complete: 76.1%; Average loss: 0.6340
# Iteration: 15228; Percent complete: 76.1%; Average loss: 0.6071
# Iteration: 15229; Percent complete: 76.1%; Average loss: 0.5909
# Iteration: 15230; Percent complete: 76.1%; Average loss: 0.6183
# Iteration: 15231; Percent complete: 76.2%; Average loss: 0.6103
# Iteration: 15232; Percent complete: 76.2%; Average loss: 0.6414
# Iteration: 15233; Percent complete: 76.2%; Average loss: 0.6366
# Iteration: 15234; Percent complete: 76.2%; Average loss: 0.6280
# Iteration: 15235; Percent complete: 76.2%; Average loss: 0.6152
# Iteration: 15236; Percent complete: 76.2%; Average loss: 0.6287
# Iteration: 15237; Percent complete: 76.2%; Average loss: 0.6049
# Iteration: 15238; Percent complete: 76.2%; Average loss: 0.6072
# Iteration: 15239; Percent complete: 76.2%; Average loss: 0.6055
# Iteration: 15240; Percent complete: 76.2%; Average loss: 0.6294
# Iteration: 15241; Percent complete: 76.2%; Average loss: 0.6705
# Iteration: 15242; Percent complete: 76.2%; Average loss: 0.6236
# Iteration: 15243; Percent complete: 76.2%; Average loss: 0.5956
# Iteration: 15244; Percent complete: 76.2%; Average loss: 0.6172
# Iteration: 15245; Percent complete: 76.2%; Average loss: 0.6388
# Iteration: 15246; Percent complete: 76.2%; Average loss: 0.6259
# Iteration: 15247; Percent complete: 76.2%; Average loss: 0.6141
# Iteration: 15248; Percent complete: 76.2%; Average loss: 0.6052
# Iteration: 15249; Percent complete: 76.2%; Average loss: 0.6125
# Iteration: 15250; Percent complete: 76.2%; Average loss: 0.6203
# Iteration: 15251; Percent complete: 76.3%; Average loss: 0.6451
# Iteration: 15252; Percent complete: 76.3%; Average loss: 0.6230
# Iteration: 15253; Percent complete: 76.3%; Average loss: 0.5914
# Iteration: 15254; Percent complete: 76.3%; Average loss: 0.6008
# Iteration: 15255; Percent complete: 76.3%; Average loss: 0.6159
# Iteration: 15256; Percent complete: 76.3%; Average loss: 0.6113
# Iteration: 15257; Percent complete: 76.3%; Average loss: 0.6160
# Iteration: 15258; Percent complete: 76.3%; Average loss: 0.6297
# Iteration: 15259; Percent complete: 76.3%; Average loss: 0.6258
# Iteration: 15260; Percent complete: 76.3%; Average loss: 0.6323
# Iteration: 15261; Percent complete: 76.3%; Average loss: 0.6541
# Iteration: 15262; Percent complete: 76.3%; Average loss: 0.6256
# Iteration: 15263; Percent complete: 76.3%; Average loss: 0.6289
# Iteration: 15264; Percent complete: 76.3%; Average loss: 0.6112
# Iteration: 15265; Percent complete: 76.3%; Average loss: 0.6118
# Iteration: 15266; Percent complete: 76.3%; Average loss: 0.6280
# Iteration: 15267; Percent complete: 76.3%; Average loss: 0.6136
# Iteration: 15268; Percent complete: 76.3%; Average loss: 0.6434
# Iteration: 15269; Percent complete: 76.3%; Average loss: 0.6067
# Iteration: 15270; Percent complete: 76.3%; Average loss: 0.6187
# Iteration: 15271; Percent complete: 76.4%; Average loss: 0.6237
# Iteration: 15272; Percent complete: 76.4%; Average loss: 0.6237
# Iteration: 15273; Percent complete: 76.4%; Average loss: 0.6753
# Iteration: 15274; Percent complete: 76.4%; Average loss: 0.5903
# Iteration: 15275; Percent complete: 76.4%; Average loss: 0.6073
# Iteration: 15276; Percent complete: 76.4%; Average loss: 0.6460
# Iteration: 15277; Percent complete: 76.4%; Average loss: 0.6539
# Iteration: 15278; Percent complete: 76.4%; Average loss: 0.6110
# Iteration: 15279; Percent complete: 76.4%; Average loss: 0.6293
# Iteration: 15280; Percent complete: 76.4%; Average loss: 0.6232
# Iteration: 15281; Percent complete: 76.4%; Average loss: 0.6025
# Iteration: 15282; Percent complete: 76.4%; Average loss: 0.6101
# Iteration: 15283; Percent complete: 76.4%; Average loss: 0.6291
# Iteration: 15284; Percent complete: 76.4%; Average loss: 0.6082
# Iteration: 15285; Percent complete: 76.4%; Average loss: 0.6125
# Iteration: 15286; Percent complete: 76.4%; Average loss: 0.6285
# Iteration: 15287; Percent complete: 76.4%; Average loss: 0.6260
# Iteration: 15288; Percent complete: 76.4%; Average loss: 0.6085
# Iteration: 15289; Percent complete: 76.4%; Average loss: 0.6185
# Iteration: 15290; Percent complete: 76.4%; Average loss: 0.6136
# Iteration: 15291; Percent complete: 76.5%; Average loss: 0.6230
# Iteration: 15292; Percent complete: 76.5%; Average loss: 0.5984
# Iteration: 15293; Percent complete: 76.5%; Average loss: 0.6360
# Iteration: 15294; Percent complete: 76.5%; Average loss: 0.6303
# Iteration: 15295; Percent complete: 76.5%; Average loss: 0.6019
# Iteration: 15296; Percent complete: 76.5%; Average loss: 0.5992
# Iteration: 15297; Percent complete: 76.5%; Average loss: 0.6476
# Iteration: 15298; Percent complete: 76.5%; Average loss: 0.6219
# Iteration: 15299; Percent complete: 76.5%; Average loss: 0.6172
# Iteration: 15300; Percent complete: 76.5%; Average loss: 0.6217
# Iteration: 15301; Percent complete: 76.5%; Average loss: 0.6013
# Iteration: 15302; Percent complete: 76.5%; Average loss: 0.6110
# Iteration: 15303; Percent complete: 76.5%; Average loss: 0.6208
# Iteration: 15304; Percent complete: 76.5%; Average loss: 0.6149
# Iteration: 15305; Percent complete: 76.5%; Average loss: 0.6174
# Iteration: 15306; Percent complete: 76.5%; Average loss: 0.6208
# Iteration: 15307; Percent complete: 76.5%; Average loss: 0.6262
# Iteration: 15308; Percent complete: 76.5%; Average loss: 0.6037
# Iteration: 15309; Percent complete: 76.5%; Average loss: 0.6515
# Iteration: 15310; Percent complete: 76.5%; Average loss: 0.6225
# Iteration: 15311; Percent complete: 76.6%; Average loss: 0.5959
# Iteration: 15312; Percent complete: 76.6%; Average loss: 0.6334
# Iteration: 15313; Percent complete: 76.6%; Average loss: 0.6452
# Iteration: 15314; Percent complete: 76.6%; Average loss: 0.6227
# Iteration: 15315; Percent complete: 76.6%; Average loss: 0.6281
# Iteration: 15316; Percent complete: 76.6%; Average loss: 0.6097
# Iteration: 15317; Percent complete: 76.6%; Average loss: 0.6335
# Iteration: 15318; Percent complete: 76.6%; Average loss: 0.6302
# Iteration: 15319; Percent complete: 76.6%; Average loss: 0.6223
# Iteration: 15320; Percent complete: 76.6%; Average loss: 0.6131
# Iteration: 15321; Percent complete: 76.6%; Average loss: 0.6001
# Iteration: 15322; Percent complete: 76.6%; Average loss: 0.6477
# Iteration: 15323; Percent complete: 76.6%; Average loss: 0.6227
# Iteration: 15324; Percent complete: 76.6%; Average loss: 0.6002
# Iteration: 15325; Percent complete: 76.6%; Average loss: 0.6232
# Iteration: 15326; Percent complete: 76.6%; Average loss: 0.6170
# Iteration: 15327; Percent complete: 76.6%; Average loss: 0.6191
# Iteration: 15328; Percent complete: 76.6%; Average loss: 0.6234
# Iteration: 15329; Percent complete: 76.6%; Average loss: 0.6329
# Iteration: 15330; Percent complete: 76.6%; Average loss: 0.5999
# Iteration: 15331; Percent complete: 76.7%; Average loss: 0.6251
# Iteration: 15332; Percent complete: 76.7%; Average loss: 0.6280
# Iteration: 15333; Percent complete: 76.7%; Average loss: 0.6133
# Iteration: 15334; Percent complete: 76.7%; Average loss: 0.5974
# Iteration: 15335; Percent complete: 76.7%; Average loss: 0.6267
# Iteration: 15336; Percent complete: 76.7%; Average loss: 0.6207
# Iteration: 15337; Percent complete: 76.7%; Average loss: 0.6248
# Iteration: 15338; Percent complete: 76.7%; Average loss: 0.6339
# Iteration: 15339; Percent complete: 76.7%; Average loss: 0.6162
# Iteration: 15340; Percent complete: 76.7%; Average loss: 0.6204
# Iteration: 15341; Percent complete: 76.7%; Average loss: 0.6466
# Iteration: 15342; Percent complete: 76.7%; Average loss: 0.6347
# Iteration: 15343; Percent complete: 76.7%; Average loss: 0.6315
# Iteration: 15344; Percent complete: 76.7%; Average loss: 0.6489
# Iteration: 15345; Percent complete: 76.7%; Average loss: 0.6103
# Iteration: 15346; Percent complete: 76.7%; Average loss: 0.6019
# Iteration: 15347; Percent complete: 76.7%; Average loss: 0.6095
# Iteration: 15348; Percent complete: 76.7%; Average loss: 0.6161
# Iteration: 15349; Percent complete: 76.7%; Average loss: 0.6238
# Iteration: 15350; Percent complete: 76.8%; Average loss: 0.6180
# Iteration: 15351; Percent complete: 76.8%; Average loss: 0.6345
# Iteration: 15352; Percent complete: 76.8%; Average loss: 0.6238
# Iteration: 15353; Percent complete: 76.8%; Average loss: 0.6226
# Iteration: 15354; Percent complete: 76.8%; Average loss: 0.6524
# Iteration: 15355; Percent complete: 76.8%; Average loss: 0.6464
# Iteration: 15356; Percent complete: 76.8%; Average loss: 0.6458
# Iteration: 15357; Percent complete: 76.8%; Average loss: 0.6160
# Iteration: 15358; Percent complete: 76.8%; Average loss: 0.6274
# Iteration: 15359; Percent complete: 76.8%; Average loss: 0.6281
# Iteration: 15360; Percent complete: 76.8%; Average loss: 0.6288
# Iteration: 15361; Percent complete: 76.8%; Average loss: 0.6282
# Iteration: 15362; Percent complete: 76.8%; Average loss: 0.6029
# Iteration: 15363; Percent complete: 76.8%; Average loss: 0.6468
# Iteration: 15364; Percent complete: 76.8%; Average loss: 0.6415
# Iteration: 15365; Percent complete: 76.8%; Average loss: 0.5989
# Iteration: 15366; Percent complete: 76.8%; Average loss: 0.6254
# Iteration: 15367; Percent complete: 76.8%; Average loss: 0.6386
# Iteration: 15368; Percent complete: 76.8%; Average loss: 0.6250
# Iteration: 15369; Percent complete: 76.8%; Average loss: 0.6191
# Iteration: 15370; Percent complete: 76.8%; Average loss: 0.6162
# Iteration: 15371; Percent complete: 76.9%; Average loss: 0.5793
# Iteration: 15372; Percent complete: 76.9%; Average loss: 0.6294
# Iteration: 15373; Percent complete: 76.9%; Average loss: 0.6399
# Iteration: 15374; Percent complete: 76.9%; Average loss: 0.6409
# Iteration: 15375; Percent complete: 76.9%; Average loss: 0.6194
# Iteration: 15376; Percent complete: 76.9%; Average loss: 0.6123
# Iteration: 15377; Percent complete: 76.9%; Average loss: 0.6254
# Iteration: 15378; Percent complete: 76.9%; Average loss: 0.6014
# Iteration: 15379; Percent complete: 76.9%; Average loss: 0.6137
# Iteration: 15380; Percent complete: 76.9%; Average loss: 0.6117
# Iteration: 15381; Percent complete: 76.9%; Average loss: 0.6573
# Iteration: 15382; Percent complete: 76.9%; Average loss: 0.6087
# Iteration: 15383; Percent complete: 76.9%; Average loss: 0.6371
# Iteration: 15384; Percent complete: 76.9%; Average loss: 0.6139
# Iteration: 15385; Percent complete: 76.9%; Average loss: 0.6142
# Iteration: 15386; Percent complete: 76.9%; Average loss: 0.6086
# Iteration: 15387; Percent complete: 76.9%; Average loss: 0.6326
# Iteration: 15388; Percent complete: 76.9%; Average loss: 0.6155
# Iteration: 15389; Percent complete: 76.9%; Average loss: 0.6266
# Iteration: 15390; Percent complete: 77.0%; Average loss: 0.5909
# Iteration: 15391; Percent complete: 77.0%; Average loss: 0.6168
# Iteration: 15392; Percent complete: 77.0%; Average loss: 0.6121
# Iteration: 15393; Percent complete: 77.0%; Average loss: 0.6222
# Iteration: 15394; Percent complete: 77.0%; Average loss: 0.5993
# Iteration: 15395; Percent complete: 77.0%; Average loss: 0.5984
# Iteration: 15396; Percent complete: 77.0%; Average loss: 0.6132
# Iteration: 15397; Percent complete: 77.0%; Average loss: 0.6147
# Iteration: 15398; Percent complete: 77.0%; Average loss: 0.6484
# Iteration: 15399; Percent complete: 77.0%; Average loss: 0.6598
# Iteration: 15400; Percent complete: 77.0%; Average loss: 0.6256
# Iteration: 15401; Percent complete: 77.0%; Average loss: 0.5881
# Iteration: 15402; Percent complete: 77.0%; Average loss: 0.6556
# Iteration: 15403; Percent complete: 77.0%; Average loss: 0.5906
# Iteration: 15404; Percent complete: 77.0%; Average loss: 0.6260
# Iteration: 15405; Percent complete: 77.0%; Average loss: 0.6320
# Iteration: 15406; Percent complete: 77.0%; Average loss: 0.6607
# Iteration: 15407; Percent complete: 77.0%; Average loss: 0.6180
# Iteration: 15408; Percent complete: 77.0%; Average loss: 0.6397
# Iteration: 15409; Percent complete: 77.0%; Average loss: 0.6147
# Iteration: 15410; Percent complete: 77.0%; Average loss: 0.6091
# Iteration: 15411; Percent complete: 77.1%; Average loss: 0.6002
# Iteration: 15412; Percent complete: 77.1%; Average loss: 0.6170
# Iteration: 15413; Percent complete: 77.1%; Average loss: 0.5956
# Iteration: 15414; Percent complete: 77.1%; Average loss: 0.6292
# Iteration: 15415; Percent complete: 77.1%; Average loss: 0.5832
# Iteration: 15416; Percent complete: 77.1%; Average loss: 0.5962
# Iteration: 15417; Percent complete: 77.1%; Average loss: 0.6429
# Iteration: 15418; Percent complete: 77.1%; Average loss: 0.5823
# Iteration: 15419; Percent complete: 77.1%; Average loss: 0.6356
# Iteration: 15420; Percent complete: 77.1%; Average loss: 0.6285
# Iteration: 15421; Percent complete: 77.1%; Average loss: 0.6165
# Iteration: 15422; Percent complete: 77.1%; Average loss: 0.6319
# Iteration: 15423; Percent complete: 77.1%; Average loss: 0.6246
# Iteration: 15424; Percent complete: 77.1%; Average loss: 0.6163
# Iteration: 15425; Percent complete: 77.1%; Average loss: 0.6073
# Iteration: 15426; Percent complete: 77.1%; Average loss: 0.6270
# Iteration: 15427; Percent complete: 77.1%; Average loss: 0.6494
# Iteration: 15428; Percent complete: 77.1%; Average loss: 0.5916
# Iteration: 15429; Percent complete: 77.1%; Average loss: 0.6082
# Iteration: 15430; Percent complete: 77.1%; Average loss: 0.6182
# Iteration: 15431; Percent complete: 77.2%; Average loss: 0.6235
# Iteration: 15432; Percent complete: 77.2%; Average loss: 0.5995
# Iteration: 15433; Percent complete: 77.2%; Average loss: 0.6008
# Iteration: 15434; Percent complete: 77.2%; Average loss: 0.6086
# Iteration: 15435; Percent complete: 77.2%; Average loss: 0.6140
# Iteration: 15436; Percent complete: 77.2%; Average loss: 0.6094
# Iteration: 15437; Percent complete: 77.2%; Average loss: 0.6298
# Iteration: 15438; Percent complete: 77.2%; Average loss: 0.6328
# Iteration: 15439; Percent complete: 77.2%; Average loss: 0.6061
# Iteration: 15440; Percent complete: 77.2%; Average loss: 0.6176
# Iteration: 15441; Percent complete: 77.2%; Average loss: 0.6347
# Iteration: 15442; Percent complete: 77.2%; Average loss: 0.5937
# Iteration: 15443; Percent complete: 77.2%; Average loss: 0.5918
# Iteration: 15444; Percent complete: 77.2%; Average loss: 0.6231
# Iteration: 15445; Percent complete: 77.2%; Average loss: 0.6045
# Iteration: 15446; Percent complete: 77.2%; Average loss: 0.6216
# Iteration: 15447; Percent complete: 77.2%; Average loss: 0.6229
# Iteration: 15448; Percent complete: 77.2%; Average loss: 0.5975
# Iteration: 15449; Percent complete: 77.2%; Average loss: 0.6141
# Iteration: 15450; Percent complete: 77.2%; Average loss: 0.5941
# Iteration: 15451; Percent complete: 77.3%; Average loss: 0.5955
# Iteration: 15452; Percent complete: 77.3%; Average loss: 0.6217
# Iteration: 15453; Percent complete: 77.3%; Average loss: 0.6239
# Iteration: 15454; Percent complete: 77.3%; Average loss: 0.6222
# Iteration: 15455; Percent complete: 77.3%; Average loss: 0.6601
# Iteration: 15456; Percent complete: 77.3%; Average loss: 0.6001
# Iteration: 15457; Percent complete: 77.3%; Average loss: 0.5925
# Iteration: 15458; Percent complete: 77.3%; Average loss: 0.6360
# Iteration: 15459; Percent complete: 77.3%; Average loss: 0.6256
# Iteration: 15460; Percent complete: 77.3%; Average loss: 0.6193
# Iteration: 15461; Percent complete: 77.3%; Average loss: 0.6209
# Iteration: 15462; Percent complete: 77.3%; Average loss: 0.6098
# Iteration: 15463; Percent complete: 77.3%; Average loss: 0.6153
# Iteration: 15464; Percent complete: 77.3%; Average loss: 0.6142
# Iteration: 15465; Percent complete: 77.3%; Average loss: 0.5885
# Iteration: 15466; Percent complete: 77.3%; Average loss: 0.6119
# Iteration: 15467; Percent complete: 77.3%; Average loss: 0.6090
# Iteration: 15468; Percent complete: 77.3%; Average loss: 0.6066
# Iteration: 15469; Percent complete: 77.3%; Average loss: 0.6254
# Iteration: 15470; Percent complete: 77.3%; Average loss: 0.6298
# Iteration: 15471; Percent complete: 77.4%; Average loss: 0.6511
# Iteration: 15472; Percent complete: 77.4%; Average loss: 0.6176
# Iteration: 15473; Percent complete: 77.4%; Average loss: 0.6531
# Iteration: 15474; Percent complete: 77.4%; Average loss: 0.6131
# Iteration: 15475; Percent complete: 77.4%; Average loss: 0.6521
# Iteration: 15476; Percent complete: 77.4%; Average loss: 0.6218
# Iteration: 15477; Percent complete: 77.4%; Average loss: 0.6183
# Iteration: 15478; Percent complete: 77.4%; Average loss: 0.6452
# Iteration: 15479; Percent complete: 77.4%; Average loss: 0.6138
# Iteration: 15480; Percent complete: 77.4%; Average loss: 0.6254
# Iteration: 15481; Percent complete: 77.4%; Average loss: 0.6083
# Iteration: 15482; Percent complete: 77.4%; Average loss: 0.6337
# Iteration: 15483; Percent complete: 77.4%; Average loss: 0.6117
# Iteration: 15484; Percent complete: 77.4%; Average loss: 0.6367
# Iteration: 15485; Percent complete: 77.4%; Average loss: 0.6176
# Iteration: 15486; Percent complete: 77.4%; Average loss: 0.6388
# Iteration: 15487; Percent complete: 77.4%; Average loss: 0.6173
# Iteration: 15488; Percent complete: 77.4%; Average loss: 0.6184
# Iteration: 15489; Percent complete: 77.4%; Average loss: 0.6178
# Iteration: 15490; Percent complete: 77.5%; Average loss: 0.5745
# Iteration: 15491; Percent complete: 77.5%; Average loss: 0.6495
# Iteration: 15492; Percent complete: 77.5%; Average loss: 0.6152
# Iteration: 15493; Percent complete: 77.5%; Average loss: 0.6131
# Iteration: 15494; Percent complete: 77.5%; Average loss: 0.6382
# Iteration: 15495; Percent complete: 77.5%; Average loss: 0.6144
# Iteration: 15496; Percent complete: 77.5%; Average loss: 0.6174
# Iteration: 15497; Percent complete: 77.5%; Average loss: 0.5943
# Iteration: 15498; Percent complete: 77.5%; Average loss: 0.5890
# Iteration: 15499; Percent complete: 77.5%; Average loss: 0.6173
# Iteration: 15500; Percent complete: 77.5%; Average loss: 0.6232
# Iteration: 15501; Percent complete: 77.5%; Average loss: 0.6140
# Iteration: 15502; Percent complete: 77.5%; Average loss: 0.5976
# Iteration: 15503; Percent complete: 77.5%; Average loss: 0.6067
# Iteration: 15504; Percent complete: 77.5%; Average loss: 0.6398
# Iteration: 15505; Percent complete: 77.5%; Average loss: 0.5696
# Iteration: 15506; Percent complete: 77.5%; Average loss: 0.6706
# Iteration: 15507; Percent complete: 77.5%; Average loss: 0.6263
# Iteration: 15508; Percent complete: 77.5%; Average loss: 0.6018
# Iteration: 15509; Percent complete: 77.5%; Average loss: 0.6132
# Iteration: 15510; Percent complete: 77.5%; Average loss: 0.6204
# Iteration: 15511; Percent complete: 77.6%; Average loss: 0.5915
# Iteration: 15512; Percent complete: 77.6%; Average loss: 0.6300
# Iteration: 15513; Percent complete: 77.6%; Average loss: 0.6091
# Iteration: 15514; Percent complete: 77.6%; Average loss: 0.6127
# Iteration: 15515; Percent complete: 77.6%; Average loss: 0.5807
# Iteration: 15516; Percent complete: 77.6%; Average loss: 0.5992
# Iteration: 15517; Percent complete: 77.6%; Average loss: 0.6098
# Iteration: 15518; Percent complete: 77.6%; Average loss: 0.5831
# Iteration: 15519; Percent complete: 77.6%; Average loss: 0.5906
# Iteration: 15520; Percent complete: 77.6%; Average loss: 0.5885
# Iteration: 15521; Percent complete: 77.6%; Average loss: 0.6157
# Iteration: 15522; Percent complete: 77.6%; Average loss: 0.6206
# Iteration: 15523; Percent complete: 77.6%; Average loss: 0.6220
# Iteration: 15524; Percent complete: 77.6%; Average loss: 0.6280
# Iteration: 15525; Percent complete: 77.6%; Average loss: 0.6066
# Iteration: 15526; Percent complete: 77.6%; Average loss: 0.6291
# Iteration: 15527; Percent complete: 77.6%; Average loss: 0.6000
# Iteration: 15528; Percent complete: 77.6%; Average loss: 0.6271
# Iteration: 15529; Percent complete: 77.6%; Average loss: 0.6181
# Iteration: 15530; Percent complete: 77.6%; Average loss: 0.5685
# Iteration: 15531; Percent complete: 77.7%; Average loss: 0.6195
# Iteration: 15532; Percent complete: 77.7%; Average loss: 0.6107
# Iteration: 15533; Percent complete: 77.7%; Average loss: 0.6591
# Iteration: 15534; Percent complete: 77.7%; Average loss: 0.5979
# Iteration: 15535; Percent complete: 77.7%; Average loss: 0.5959
# Iteration: 15536; Percent complete: 77.7%; Average loss: 0.6314
# Iteration: 15537; Percent complete: 77.7%; Average loss: 0.6380
# Iteration: 15538; Percent complete: 77.7%; Average loss: 0.6085
# Iteration: 15539; Percent complete: 77.7%; Average loss: 0.6057
# Iteration: 15540; Percent complete: 77.7%; Average loss: 0.5834
# Iteration: 15541; Percent complete: 77.7%; Average loss: 0.6101
# Iteration: 15542; Percent complete: 77.7%; Average loss: 0.6138
# Iteration: 15543; Percent complete: 77.7%; Average loss: 0.5984
# Iteration: 15544; Percent complete: 77.7%; Average loss: 0.6170
# Iteration: 15545; Percent complete: 77.7%; Average loss: 0.5825
# Iteration: 15546; Percent complete: 77.7%; Average loss: 0.6424
# Iteration: 15547; Percent complete: 77.7%; Average loss: 0.6381
# Iteration: 15548; Percent complete: 77.7%; Average loss: 0.6386
# Iteration: 15549; Percent complete: 77.7%; Average loss: 0.6052
# Iteration: 15550; Percent complete: 77.8%; Average loss: 0.6042
# Iteration: 15551; Percent complete: 77.8%; Average loss: 0.6099
# Iteration: 15552; Percent complete: 77.8%; Average loss: 0.6441
# Iteration: 15553; Percent complete: 77.8%; Average loss: 0.6129
# Iteration: 15554; Percent complete: 77.8%; Average loss: 0.6169
# Iteration: 15555; Percent complete: 77.8%; Average loss: 0.6052
# Iteration: 15556; Percent complete: 77.8%; Average loss: 0.6151
# Iteration: 15557; Percent complete: 77.8%; Average loss: 0.6514
# Iteration: 15558; Percent complete: 77.8%; Average loss: 0.6270
# Iteration: 15559; Percent complete: 77.8%; Average loss: 0.6145
# Iteration: 15560; Percent complete: 77.8%; Average loss: 0.5883
# Iteration: 15561; Percent complete: 77.8%; Average loss: 0.6262
# Iteration: 15562; Percent complete: 77.8%; Average loss: 0.5829
# Iteration: 15563; Percent complete: 77.8%; Average loss: 0.6123
# Iteration: 15564; Percent complete: 77.8%; Average loss: 0.6593
# Iteration: 15565; Percent complete: 77.8%; Average loss: 0.5998
# Iteration: 15566; Percent complete: 77.8%; Average loss: 0.5914
# Iteration: 15567; Percent complete: 77.8%; Average loss: 0.5992
# Iteration: 15568; Percent complete: 77.8%; Average loss: 0.6217
# Iteration: 15569; Percent complete: 77.8%; Average loss: 0.6232
# Iteration: 15570; Percent complete: 77.8%; Average loss: 0.6154
# Iteration: 15571; Percent complete: 77.9%; Average loss: 0.6153
# Iteration: 15572; Percent complete: 77.9%; Average loss: 0.6136
# Iteration: 15573; Percent complete: 77.9%; Average loss: 0.6224
# Iteration: 15574; Percent complete: 77.9%; Average loss: 0.5993
# Iteration: 15575; Percent complete: 77.9%; Average loss: 0.6118
# Iteration: 15576; Percent complete: 77.9%; Average loss: 0.6354
# Iteration: 15577; Percent complete: 77.9%; Average loss: 0.5904
# Iteration: 15578; Percent complete: 77.9%; Average loss: 0.6365
# Iteration: 15579; Percent complete: 77.9%; Average loss: 0.6228
# Iteration: 15580; Percent complete: 77.9%; Average loss: 0.5803
# Iteration: 15581; Percent complete: 77.9%; Average loss: 0.5816
# Iteration: 15582; Percent complete: 77.9%; Average loss: 0.6504
# Iteration: 15583; Percent complete: 77.9%; Average loss: 0.5999
# Iteration: 15584; Percent complete: 77.9%; Average loss: 0.6001
# Iteration: 15585; Percent complete: 77.9%; Average loss: 0.6215
# Iteration: 15586; Percent complete: 77.9%; Average loss: 0.6094
# Iteration: 15587; Percent complete: 77.9%; Average loss: 0.6152
# Iteration: 15588; Percent complete: 77.9%; Average loss: 0.6221
# Iteration: 15589; Percent complete: 77.9%; Average loss: 0.6444
# Iteration: 15590; Percent complete: 78.0%; Average loss: 0.6021
# Iteration: 15591; Percent complete: 78.0%; Average loss: 0.6103
# Iteration: 15592; Percent complete: 78.0%; Average loss: 0.5780
# Iteration: 15593; Percent complete: 78.0%; Average loss: 0.5738
# Iteration: 15594; Percent complete: 78.0%; Average loss: 0.5816
# Iteration: 15595; Percent complete: 78.0%; Average loss: 0.6193
# Iteration: 15596; Percent complete: 78.0%; Average loss: 0.6030
# Iteration: 15597; Percent complete: 78.0%; Average loss: 0.6053
# Iteration: 15598; Percent complete: 78.0%; Average loss: 0.5995
# Iteration: 15599; Percent complete: 78.0%; Average loss: 0.6035
# Iteration: 15600; Percent complete: 78.0%; Average loss: 0.6198
# Iteration: 15601; Percent complete: 78.0%; Average loss: 0.6357
# Iteration: 15602; Percent complete: 78.0%; Average loss: 0.6416
# Iteration: 15603; Percent complete: 78.0%; Average loss: 0.6122
# Iteration: 15604; Percent complete: 78.0%; Average loss: 0.6015
# Iteration: 15605; Percent complete: 78.0%; Average loss: 0.5990
# Iteration: 15606; Percent complete: 78.0%; Average loss: 0.6001
# Iteration: 15607; Percent complete: 78.0%; Average loss: 0.5985
# Iteration: 15608; Percent complete: 78.0%; Average loss: 0.6228
# Iteration: 15609; Percent complete: 78.0%; Average loss: 0.6090
# Iteration: 15610; Percent complete: 78.0%; Average loss: 0.5987
# Iteration: 15611; Percent complete: 78.1%; Average loss: 0.6239
# Iteration: 15612; Percent complete: 78.1%; Average loss: 0.6253
# Iteration: 15613; Percent complete: 78.1%; Average loss: 0.6055
# Iteration: 15614; Percent complete: 78.1%; Average loss: 0.6529
# Iteration: 15615; Percent complete: 78.1%; Average loss: 0.6113
# Iteration: 15616; Percent complete: 78.1%; Average loss: 0.6153
# Iteration: 15617; Percent complete: 78.1%; Average loss: 0.6239
# Iteration: 15618; Percent complete: 78.1%; Average loss: 0.6280
# Iteration: 15619; Percent complete: 78.1%; Average loss: 0.6248
# Iteration: 15620; Percent complete: 78.1%; Average loss: 0.6031
# Iteration: 15621; Percent complete: 78.1%; Average loss: 0.6163
# Iteration: 15622; Percent complete: 78.1%; Average loss: 0.6250
# Iteration: 15623; Percent complete: 78.1%; Average loss: 0.6240
# Iteration: 15624; Percent complete: 78.1%; Average loss: 0.6018
# Iteration: 15625; Percent complete: 78.1%; Average loss: 0.5967
# Iteration: 15626; Percent complete: 78.1%; Average loss: 0.6223
# Iteration: 15627; Percent complete: 78.1%; Average loss: 0.6314
# Iteration: 15628; Percent complete: 78.1%; Average loss: 0.6058
# Iteration: 15629; Percent complete: 78.1%; Average loss: 0.6253
# Iteration: 15630; Percent complete: 78.1%; Average loss: 0.6147
# Iteration: 15631; Percent complete: 78.2%; Average loss: 0.6370
# Iteration: 15632; Percent complete: 78.2%; Average loss: 0.6407
# Iteration: 15633; Percent complete: 78.2%; Average loss: 0.5855
# Iteration: 15634; Percent complete: 78.2%; Average loss: 0.6006
# Iteration: 15635; Percent complete: 78.2%; Average loss: 0.6039
# Iteration: 15636; Percent complete: 78.2%; Average loss: 0.5879
# Iteration: 15637; Percent complete: 78.2%; Average loss: 0.5966
# Iteration: 15638; Percent complete: 78.2%; Average loss: 0.6619
# Iteration: 15639; Percent complete: 78.2%; Average loss: 0.6029
# Iteration: 15640; Percent complete: 78.2%; Average loss: 0.6254
# Iteration: 15641; Percent complete: 78.2%; Average loss: 0.6183
# Iteration: 15642; Percent complete: 78.2%; Average loss: 0.6239
# Iteration: 15643; Percent complete: 78.2%; Average loss: 0.6432
# Iteration: 15644; Percent complete: 78.2%; Average loss: 0.6223
# Iteration: 15645; Percent complete: 78.2%; Average loss: 0.6119
# Iteration: 15646; Percent complete: 78.2%; Average loss: 0.6050
# Iteration: 15647; Percent complete: 78.2%; Average loss: 0.6085
# Iteration: 15648; Percent complete: 78.2%; Average loss: 0.5992
# Iteration: 15649; Percent complete: 78.2%; Average loss: 0.6071
# Iteration: 15650; Percent complete: 78.2%; Average loss: 0.6130
# Iteration: 15651; Percent complete: 78.3%; Average loss: 0.5936
# Iteration: 15652; Percent complete: 78.3%; Average loss: 0.5962
# Iteration: 15653; Percent complete: 78.3%; Average loss: 0.5959
# Iteration: 15654; Percent complete: 78.3%; Average loss: 0.6098
# Iteration: 15655; Percent complete: 78.3%; Average loss: 0.6340
# Iteration: 15656; Percent complete: 78.3%; Average loss: 0.6240
# Iteration: 15657; Percent complete: 78.3%; Average loss: 0.5967
# Iteration: 15658; Percent complete: 78.3%; Average loss: 0.6413
# Iteration: 15659; Percent complete: 78.3%; Average loss: 0.6360
# Iteration: 15660; Percent complete: 78.3%; Average loss: 0.6018
# Iteration: 15661; Percent complete: 78.3%; Average loss: 0.6025
# Iteration: 15662; Percent complete: 78.3%; Average loss: 0.6248
# Iteration: 15663; Percent complete: 78.3%; Average loss: 0.6221
# Iteration: 15664; Percent complete: 78.3%; Average loss: 0.6081
# Iteration: 15665; Percent complete: 78.3%; Average loss: 0.5994
# Iteration: 15666; Percent complete: 78.3%; Average loss: 0.6236
# Iteration: 15667; Percent complete: 78.3%; Average loss: 0.5956
# Iteration: 15668; Percent complete: 78.3%; Average loss: 0.6289
# Iteration: 15669; Percent complete: 78.3%; Average loss: 0.6130
# Iteration: 15670; Percent complete: 78.3%; Average loss: 0.6080
# Iteration: 15671; Percent complete: 78.4%; Average loss: 0.5943
# Iteration: 15672; Percent complete: 78.4%; Average loss: 0.6376
# Iteration: 15673; Percent complete: 78.4%; Average loss: 0.6022
# Iteration: 15674; Percent complete: 78.4%; Average loss: 0.5896
# Iteration: 15675; Percent complete: 78.4%; Average loss: 0.6263
# Iteration: 15676; Percent complete: 78.4%; Average loss: 0.6325
# Iteration: 15677; Percent complete: 78.4%; Average loss: 0.6124
# Iteration: 15678; Percent complete: 78.4%; Average loss: 0.6132
# Iteration: 15679; Percent complete: 78.4%; Average loss: 0.5958
# Iteration: 15680; Percent complete: 78.4%; Average loss: 0.6438
# Iteration: 15681; Percent complete: 78.4%; Average loss: 0.6124
# Iteration: 15682; Percent complete: 78.4%; Average loss: 0.5884
# Iteration: 15683; Percent complete: 78.4%; Average loss: 0.6352
# Iteration: 15684; Percent complete: 78.4%; Average loss: 0.6051
# Iteration: 15685; Percent complete: 78.4%; Average loss: 0.6275
# Iteration: 15686; Percent complete: 78.4%; Average loss: 0.6290
# Iteration: 15687; Percent complete: 78.4%; Average loss: 0.6097
# Iteration: 15688; Percent complete: 78.4%; Average loss: 0.6194
# Iteration: 15689; Percent complete: 78.4%; Average loss: 0.6239
# Iteration: 15690; Percent complete: 78.5%; Average loss: 0.6149
# Iteration: 15691; Percent complete: 78.5%; Average loss: 0.5984
# Iteration: 15692; Percent complete: 78.5%; Average loss: 0.6158
# Iteration: 15693; Percent complete: 78.5%; Average loss: 0.6034
# Iteration: 15694; Percent complete: 78.5%; Average loss: 0.6431
# Iteration: 15695; Percent complete: 78.5%; Average loss: 0.6021
# Iteration: 15696; Percent complete: 78.5%; Average loss: 0.6167
# Iteration: 15697; Percent complete: 78.5%; Average loss: 0.6269
# Iteration: 15698; Percent complete: 78.5%; Average loss: 0.6313
# Iteration: 15699; Percent complete: 78.5%; Average loss: 0.5767
# Iteration: 15700; Percent complete: 78.5%; Average loss: 0.6193
# Iteration: 15701; Percent complete: 78.5%; Average loss: 0.6225
# Iteration: 15702; Percent complete: 78.5%; Average loss: 0.6524
# Iteration: 15703; Percent complete: 78.5%; Average loss: 0.6089
# Iteration: 15704; Percent complete: 78.5%; Average loss: 0.5931
# Iteration: 15705; Percent complete: 78.5%; Average loss: 0.6595
# Iteration: 15706; Percent complete: 78.5%; Average loss: 0.6090
# Iteration: 15707; Percent complete: 78.5%; Average loss: 0.6223
# Iteration: 15708; Percent complete: 78.5%; Average loss: 0.6142
# Iteration: 15709; Percent complete: 78.5%; Average loss: 0.6282
# Iteration: 15710; Percent complete: 78.5%; Average loss: 0.6284
# Iteration: 15711; Percent complete: 78.6%; Average loss: 0.6163
# Iteration: 15712; Percent complete: 78.6%; Average loss: 0.6318
# Iteration: 15713; Percent complete: 78.6%; Average loss: 0.6396
# Iteration: 15714; Percent complete: 78.6%; Average loss: 0.6165
# Iteration: 15715; Percent complete: 78.6%; Average loss: 0.6374
# Iteration: 15716; Percent complete: 78.6%; Average loss: 0.6229
# Iteration: 15717; Percent complete: 78.6%; Average loss: 0.6166
# Iteration: 15718; Percent complete: 78.6%; Average loss: 0.5870
# Iteration: 15719; Percent complete: 78.6%; Average loss: 0.6340
# Iteration: 15720; Percent complete: 78.6%; Average loss: 0.6019
# Iteration: 15721; Percent complete: 78.6%; Average loss: 0.6255
# Iteration: 15722; Percent complete: 78.6%; Average loss: 0.5873
# Iteration: 15723; Percent complete: 78.6%; Average loss: 0.6245
# Iteration: 15724; Percent complete: 78.6%; Average loss: 0.6207
# Iteration: 15725; Percent complete: 78.6%; Average loss: 0.6309
# Iteration: 15726; Percent complete: 78.6%; Average loss: 0.6147
# Iteration: 15727; Percent complete: 78.6%; Average loss: 0.5991
# Iteration: 15728; Percent complete: 78.6%; Average loss: 0.5758
# Iteration: 15729; Percent complete: 78.6%; Average loss: 0.6004
# Iteration: 15730; Percent complete: 78.6%; Average loss: 0.6074
# Iteration: 15731; Percent complete: 78.7%; Average loss: 0.6227
# Iteration: 15732; Percent complete: 78.7%; Average loss: 0.6007
# Iteration: 15733; Percent complete: 78.7%; Average loss: 0.6046
# Iteration: 15734; Percent complete: 78.7%; Average loss: 0.6029
# Iteration: 15735; Percent complete: 78.7%; Average loss: 0.6272
# Iteration: 15736; Percent complete: 78.7%; Average loss: 0.6352
# Iteration: 15737; Percent complete: 78.7%; Average loss: 0.6205
# Iteration: 15738; Percent complete: 78.7%; Average loss: 0.6395
# Iteration: 15739; Percent complete: 78.7%; Average loss: 0.5966
# Iteration: 15740; Percent complete: 78.7%; Average loss: 0.6237
# Iteration: 15741; Percent complete: 78.7%; Average loss: 0.6216
# Iteration: 15742; Percent complete: 78.7%; Average loss: 0.5972
# Iteration: 15743; Percent complete: 78.7%; Average loss: 0.6326
# Iteration: 15744; Percent complete: 78.7%; Average loss: 0.6064
# Iteration: 15745; Percent complete: 78.7%; Average loss: 0.5912
# Iteration: 15746; Percent complete: 78.7%; Average loss: 0.5760
# Iteration: 15747; Percent complete: 78.7%; Average loss: 0.5911
# Iteration: 15748; Percent complete: 78.7%; Average loss: 0.6044
# Iteration: 15749; Percent complete: 78.7%; Average loss: 0.6329
# ...
# Iteration: 19752; Percent complete: 98.8%; Average loss: 0.5661
# Iteration: 19753; Percent complete: 98.8%; Average loss: 0.5455
# Iteration: 19754; Percent complete: 98.8%; Average loss: 0.5602
# Iteration: 19755; Percent complete: 98.8%; Average loss: 0.5522
# Iteration: 19756; Percent complete: 98.8%; Average loss: 0.5731
# Iteration: 19757; Percent complete: 98.8%; Average loss: 0.5290
# Iteration: 19758; Percent complete: 98.8%; Average loss: 0.5914
# Iteration: 19759; Percent complete: 98.8%; Average loss: 0.5524
# Iteration: 19760; Percent complete: 98.8%; Average loss: 0.5459
# Iteration: 19761; Percent complete: 98.8%; Average loss: 0.5564
# Iteration: 19762; Percent complete: 98.8%; Average loss: 0.6000
# Iteration: 19763; Percent complete: 98.8%; Average loss: 0.5496
# Iteration: 19764; Percent complete: 98.8%; Average loss: 0.5917
# Iteration: 19765; Percent complete: 98.8%; Average loss: 0.5693
# Iteration: 19766; Percent complete: 98.8%; Average loss: 0.5319
# Iteration: 19767; Percent complete: 98.8%; Average loss: 0.5634
# Iteration: 19768; Percent complete: 98.8%; Average loss: 0.5772
# Iteration: 19769; Percent complete: 98.8%; Average loss: 0.5426
# Iteration: 19770; Percent complete: 98.9%; Average loss: 0.5126
# Iteration: 19771; Percent complete: 98.9%; Average loss: 0.5558
# Iteration: 19772; Percent complete: 98.9%; Average loss: 0.5674
# Iteration: 19773; Percent complete: 98.9%; Average loss: 0.5473
# Iteration: 19774; Percent complete: 98.9%; Average loss: 0.5537
# Iteration: 19775; Percent complete: 98.9%; Average loss: 0.5204
# Iteration: 19776; Percent complete: 98.9%; Average loss: 0.5903
# Iteration: 19777; Percent complete: 98.9%; Average loss: 0.5848
# Iteration: 19778; Percent complete: 98.9%; Average loss: 0.5747
# Iteration: 19779; Percent complete: 98.9%; Average loss: 0.5799
# Iteration: 19780; Percent complete: 98.9%; Average loss: 0.5510
# Iteration: 19781; Percent complete: 98.9%; Average loss: 0.5534
# Iteration: 19782; Percent complete: 98.9%; Average loss: 0.5989
# Iteration: 19783; Percent complete: 98.9%; Average loss: 0.5890
# Iteration: 19784; Percent complete: 98.9%; Average loss: 0.5590
# Iteration: 19785; Percent complete: 98.9%; Average loss: 0.5105
# Iteration: 19786; Percent complete: 98.9%; Average loss: 0.5848
# Iteration: 19787; Percent complete: 98.9%; Average loss: 0.5778
# Iteration: 19788; Percent complete: 98.9%; Average loss: 0.5787
# Iteration: 19789; Percent complete: 98.9%; Average loss: 0.5570
# Iteration: 19790; Percent complete: 99.0%; Average loss: 0.5375
# Iteration: 19791; Percent complete: 99.0%; Average loss: 0.5414
# Iteration: 19792; Percent complete: 99.0%; Average loss: 0.5468
# Iteration: 19793; Percent complete: 99.0%; Average loss: 0.5919
# Iteration: 19794; Percent complete: 99.0%; Average loss: 0.5428
# Iteration: 19795; Percent complete: 99.0%; Average loss: 0.5434
# Iteration: 19796; Percent complete: 99.0%; Average loss: 0.5851
# Iteration: 19797; Percent complete: 99.0%; Average loss: 0.5763
# Iteration: 19798; Percent complete: 99.0%; Average loss: 0.5793
# Iteration: 19799; Percent complete: 99.0%; Average loss: 0.5451
# Iteration: 19800; Percent complete: 99.0%; Average loss: 0.5728
# Iteration: 19801; Percent complete: 99.0%; Average loss: 0.5731
# Iteration: 19802; Percent complete: 99.0%; Average loss: 0.5624
# Iteration: 19803; Percent complete: 99.0%; Average loss: 0.5824
# Iteration: 19804; Percent complete: 99.0%; Average loss: 0.5553
# Iteration: 19805; Percent complete: 99.0%; Average loss: 0.5581
# Iteration: 19806; Percent complete: 99.0%; Average loss: 0.5532
# Iteration: 19807; Percent complete: 99.0%; Average loss: 0.5635
# Iteration: 19808; Percent complete: 99.0%; Average loss: 0.5431
# Iteration: 19809; Percent complete: 99.0%; Average loss: 0.5611
# Iteration: 19810; Percent complete: 99.1%; Average loss: 0.5837
# Iteration: 19811; Percent complete: 99.1%; Average loss: 0.5564
# Iteration: 19812; Percent complete: 99.1%; Average loss: 0.5824
# Iteration: 19813; Percent complete: 99.1%; Average loss: 0.5600
# Iteration: 19814; Percent complete: 99.1%; Average loss: 0.5613
# Iteration: 19815; Percent complete: 99.1%; Average loss: 0.5496
# Iteration: 19816; Percent complete: 99.1%; Average loss: 0.5608
# Iteration: 19817; Percent complete: 99.1%; Average loss: 0.5450
# Iteration: 19818; Percent complete: 99.1%; Average loss: 0.5453
# Iteration: 19819; Percent complete: 99.1%; Average loss: 0.5748
# Iteration: 19820; Percent complete: 99.1%; Average loss: 0.5723
# Iteration: 19821; Percent complete: 99.1%; Average loss: 0.5658
# Iteration: 19822; Percent complete: 99.1%; Average loss: 0.5536
# Iteration: 19823; Percent complete: 99.1%; Average loss: 0.5622
# Iteration: 19824; Percent complete: 99.1%; Average loss: 0.5437
# Iteration: 19825; Percent complete: 99.1%; Average loss: 0.5411
# Iteration: 19826; Percent complete: 99.1%; Average loss: 0.5764
# Iteration: 19827; Percent complete: 99.1%; Average loss: 0.5583
# Iteration: 19828; Percent complete: 99.1%; Average loss: 0.5631
# Iteration: 19829; Percent complete: 99.1%; Average loss: 0.5729
# Iteration: 19830; Percent complete: 99.2%; Average loss: 0.5720
# Iteration: 19831; Percent complete: 99.2%; Average loss: 0.5758
# Iteration: 19832; Percent complete: 99.2%; Average loss: 0.5642
# Iteration: 19833; Percent complete: 99.2%; Average loss: 0.5376
# Iteration: 19834; Percent complete: 99.2%; Average loss: 0.5536
# Iteration: 19835; Percent complete: 99.2%; Average loss: 0.5913
# Iteration: 19836; Percent complete: 99.2%; Average loss: 0.5924
# Iteration: 19837; Percent complete: 99.2%; Average loss: 0.5470
# Iteration: 19838; Percent complete: 99.2%; Average loss: 0.5619
# Iteration: 19839; Percent complete: 99.2%; Average loss: 0.5372
# Iteration: 19840; Percent complete: 99.2%; Average loss: 0.5848
# Iteration: 19841; Percent complete: 99.2%; Average loss: 0.5933
# Iteration: 19842; Percent complete: 99.2%; Average loss: 0.5885
# Iteration: 19843; Percent complete: 99.2%; Average loss: 0.5803
# Iteration: 19844; Percent complete: 99.2%; Average loss: 0.5782
# Iteration: 19845; Percent complete: 99.2%; Average loss: 0.5778
# Iteration: 19846; Percent complete: 99.2%; Average loss: 0.5674
# Iteration: 19847; Percent complete: 99.2%; Average loss: 0.5560
# Iteration: 19848; Percent complete: 99.2%; Average loss: 0.5565
# Iteration: 19849; Percent complete: 99.2%; Average loss: 0.5408
# Iteration: 19850; Percent complete: 99.2%; Average loss: 0.5593
# Iteration: 19851; Percent complete: 99.3%; Average loss: 0.5508
# Iteration: 19852; Percent complete: 99.3%; Average loss: 0.5867
# Iteration: 19853; Percent complete: 99.3%; Average loss: 0.5798
# Iteration: 19854; Percent complete: 99.3%; Average loss: 0.5683
# Iteration: 19855; Percent complete: 99.3%; Average loss: 0.5450
# Iteration: 19856; Percent complete: 99.3%; Average loss: 0.5693
# Iteration: 19857; Percent complete: 99.3%; Average loss: 0.5690
# Iteration: 19858; Percent complete: 99.3%; Average loss: 0.5633
# Iteration: 19859; Percent complete: 99.3%; Average loss: 0.5870
# Iteration: 19860; Percent complete: 99.3%; Average loss: 0.5838
# Iteration: 19861; Percent complete: 99.3%; Average loss: 0.5308
# Iteration: 19862; Percent complete: 99.3%; Average loss: 0.5460
# Iteration: 19863; Percent complete: 99.3%; Average loss: 0.5882
# Iteration: 19864; Percent complete: 99.3%; Average loss: 0.5759
# Iteration: 19865; Percent complete: 99.3%; Average loss: 0.5528
# Iteration: 19866; Percent complete: 99.3%; Average loss: 0.5812
# Iteration: 19867; Percent complete: 99.3%; Average loss: 0.5603
# Iteration: 19868; Percent complete: 99.3%; Average loss: 0.5484
# Iteration: 19869; Percent complete: 99.3%; Average loss: 0.5642
# Iteration: 19870; Percent complete: 99.4%; Average loss: 0.5572
# Iteration: 19871; Percent complete: 99.4%; Average loss: 0.5911
# Iteration: 19872; Percent complete: 99.4%; Average loss: 0.5505
# Iteration: 19873; Percent complete: 99.4%; Average loss: 0.5583
# Iteration: 19874; Percent complete: 99.4%; Average loss: 0.5677
# Iteration: 19875; Percent complete: 99.4%; Average loss: 0.5697
# Iteration: 19876; Percent complete: 99.4%; Average loss: 0.5683
# Iteration: 19877; Percent complete: 99.4%; Average loss: 0.5925
# Iteration: 19878; Percent complete: 99.4%; Average loss: 0.5532
# Iteration: 19879; Percent complete: 99.4%; Average loss: 0.5538
# Iteration: 19880; Percent complete: 99.4%; Average loss: 0.5345
# Iteration: 19881; Percent complete: 99.4%; Average loss: 0.5602
# Iteration: 19882; Percent complete: 99.4%; Average loss: 0.5884
# Iteration: 19883; Percent complete: 99.4%; Average loss: 0.5579
# Iteration: 19884; Percent complete: 99.4%; Average loss: 0.5289
# Iteration: 19885; Percent complete: 99.4%; Average loss: 0.5850
# Iteration: 19886; Percent complete: 99.4%; Average loss: 0.5390
# Iteration: 19887; Percent complete: 99.4%; Average loss: 0.5643
# Iteration: 19888; Percent complete: 99.4%; Average loss: 0.5785
# Iteration: 19889; Percent complete: 99.4%; Average loss: 0.5794
# Iteration: 19890; Percent complete: 99.5%; Average loss: 0.5549
# Iteration: 19891; Percent complete: 99.5%; Average loss: 0.5529
# Iteration: 19892; Percent complete: 99.5%; Average loss: 0.5553
# Iteration: 19893; Percent complete: 99.5%; Average loss: 0.5832
# Iteration: 19894; Percent complete: 99.5%; Average loss: 0.5966
# Iteration: 19895; Percent complete: 99.5%; Average loss: 0.5669
# Iteration: 19896; Percent complete: 99.5%; Average loss: 0.5788
# Iteration: 19897; Percent complete: 99.5%; Average loss: 0.5744
# Iteration: 19898; Percent complete: 99.5%; Average loss: 0.5695
# Iteration: 19899; Percent complete: 99.5%; Average loss: 0.5308
# Iteration: 19900; Percent complete: 99.5%; Average loss: 0.5656
# Iteration: 19901; Percent complete: 99.5%; Average loss: 0.5582
# Iteration: 19902; Percent complete: 99.5%; Average loss: 0.5446
# Iteration: 19903; Percent complete: 99.5%; Average loss: 0.5470
# Iteration: 19904; Percent complete: 99.5%; Average loss: 0.5676
# Iteration: 19905; Percent complete: 99.5%; Average loss: 0.5636
# Iteration: 19906; Percent complete: 99.5%; Average loss: 0.5416
# Iteration: 19907; Percent complete: 99.5%; Average loss: 0.5883
# Iteration: 19908; Percent complete: 99.5%; Average loss: 0.5944
# Iteration: 19909; Percent complete: 99.5%; Average loss: 0.5724
# Iteration: 19910; Percent complete: 99.6%; Average loss: 0.5728
# Iteration: 19911; Percent complete: 99.6%; Average loss: 0.5340
# Iteration: 19912; Percent complete: 99.6%; Average loss: 0.5540
# Iteration: 19913; Percent complete: 99.6%; Average loss: 0.5471
# Iteration: 19914; Percent complete: 99.6%; Average loss: 0.5605
# Iteration: 19915; Percent complete: 99.6%; Average loss: 0.5397
# Iteration: 19916; Percent complete: 99.6%; Average loss: 0.5830
# Iteration: 19917; Percent complete: 99.6%; Average loss: 0.5735
# Iteration: 19918; Percent complete: 99.6%; Average loss: 0.5669
# Iteration: 19919; Percent complete: 99.6%; Average loss: 0.5702
# Iteration: 19920; Percent complete: 99.6%; Average loss: 0.5801
# Iteration: 19921; Percent complete: 99.6%; Average loss: 0.5557
# Iteration: 19922; Percent complete: 99.6%; Average loss: 0.5745
# Iteration: 19923; Percent complete: 99.6%; Average loss: 0.5598
# Iteration: 19924; Percent complete: 99.6%; Average loss: 0.5387
# Iteration: 19925; Percent complete: 99.6%; Average loss: 0.5868
# Iteration: 19926; Percent complete: 99.6%; Average loss: 0.5602
# Iteration: 19927; Percent complete: 99.6%; Average loss: 0.5294
# Iteration: 19928; Percent complete: 99.6%; Average loss: 0.5540
# Iteration: 19929; Percent complete: 99.6%; Average loss: 0.5523
# Iteration: 19930; Percent complete: 99.7%; Average loss: 0.5634
# Iteration: 19931; Percent complete: 99.7%; Average loss: 0.5568
# Iteration: 19932; Percent complete: 99.7%; Average loss: 0.5621
# Iteration: 19933; Percent complete: 99.7%; Average loss: 0.5597
# Iteration: 19934; Percent complete: 99.7%; Average loss: 0.5733
# Iteration: 19935; Percent complete: 99.7%; Average loss: 0.5717
# Iteration: 19936; Percent complete: 99.7%; Average loss: 0.5468
# Iteration: 19937; Percent complete: 99.7%; Average loss: 0.5774
# Iteration: 19938; Percent complete: 99.7%; Average loss: 0.5632
# Iteration: 19939; Percent complete: 99.7%; Average loss: 0.5496
# Iteration: 19940; Percent complete: 99.7%; Average loss: 0.5889
# Iteration: 19941; Percent complete: 99.7%; Average loss: 0.5431
# Iteration: 19942; Percent complete: 99.7%; Average loss: 0.5622
# Iteration: 19943; Percent complete: 99.7%; Average loss: 0.5694
# Iteration: 19944; Percent complete: 99.7%; Average loss: 0.5633
# Iteration: 19945; Percent complete: 99.7%; Average loss: 0.5496
# Iteration: 19946; Percent complete: 99.7%; Average loss: 0.5771
# Iteration: 19947; Percent complete: 99.7%; Average loss: 0.5930
# Iteration: 19948; Percent complete: 99.7%; Average loss: 0.5506
# Iteration: 19949; Percent complete: 99.7%; Average loss: 0.5950
# Iteration: 19950; Percent complete: 99.8%; Average loss: 0.5694
# Iteration: 19951; Percent complete: 99.8%; Average loss: 0.5503
# Iteration: 19952; Percent complete: 99.8%; Average loss: 0.5448
# Iteration: 19953; Percent complete: 99.8%; Average loss: 0.5640
# Iteration: 19954; Percent complete: 99.8%; Average loss: 0.5739
# Iteration: 19955; Percent complete: 99.8%; Average loss: 0.5864
# Iteration: 19956; Percent complete: 99.8%; Average loss: 0.5796
# Iteration: 19957; Percent complete: 99.8%; Average loss: 0.5587
# Iteration: 19958; Percent complete: 99.8%; Average loss: 0.5714
# Iteration: 19959; Percent complete: 99.8%; Average loss: 0.5597
# Iteration: 19960; Percent complete: 99.8%; Average loss: 0.5327
# Iteration: 19961; Percent complete: 99.8%; Average loss: 0.5724
# Iteration: 19962; Percent complete: 99.8%; Average loss: 0.5394
# Iteration: 19963; Percent complete: 99.8%; Average loss: 0.5447
# Iteration: 19964; Percent complete: 99.8%; Average loss: 0.5316
# Iteration: 19965; Percent complete: 99.8%; Average loss: 0.5537
# Iteration: 19966; Percent complete: 99.8%; Average loss: 0.5751
# Iteration: 19967; Percent complete: 99.8%; Average loss: 0.5397
# Iteration: 19968; Percent complete: 99.8%; Average loss: 0.5717
# Iteration: 19969; Percent complete: 99.8%; Average loss: 0.5514
# Iteration: 19970; Percent complete: 99.9%; Average loss: 0.5544
# Iteration: 19971; Percent complete: 99.9%; Average loss: 0.5388
# Iteration: 19972; Percent complete: 99.9%; Average loss: 0.5686
# Iteration: 19973; Percent complete: 99.9%; Average loss: 0.5878
# Iteration: 19974; Percent complete: 99.9%; Average loss: 0.5683
# Iteration: 19975; Percent complete: 99.9%; Average loss: 0.5827
# Iteration: 19976; Percent complete: 99.9%; Average loss: 0.5826
# Iteration: 19977; Percent complete: 99.9%; Average loss: 0.5799
# Iteration: 19978; Percent complete: 99.9%; Average loss: 0.5468
# Iteration: 19979; Percent complete: 99.9%; Average loss: 0.5753
# Iteration: 19980; Percent complete: 99.9%; Average loss: 0.5791
# Iteration: 19981; Percent complete: 99.9%; Average loss: 0.5769
# Iteration: 19982; Percent complete: 99.9%; Average loss: 0.5536
# Iteration: 19983; Percent complete: 99.9%; Average loss: 0.5416
# Iteration: 19984; Percent complete: 99.9%; Average loss: 0.5282
# Iteration: 19985; Percent complete: 99.9%; Average loss: 0.5702
# Iteration: 19986; Percent complete: 99.9%; Average loss: 0.5701
# Iteration: 19987; Percent complete: 99.9%; Average loss: 0.5526
# Iteration: 19988; Percent complete: 99.9%; Average loss: 0.5451
# Iteration: 19989; Percent complete: 99.9%; Average loss: 0.5816
# Iteration: 19990; Percent complete: 100.0%; Average loss: 0.5665
# Iteration: 19991; Percent complete: 100.0%; Average loss: 0.5874
# Iteration: 19992; Percent complete: 100.0%; Average loss: 0.5499
# Iteration: 19993; Percent complete: 100.0%; Average loss: 0.5749
# Iteration: 19994; Percent complete: 100.0%; Average loss: 0.5741
# Iteration: 19995; Percent complete: 100.0%; Average loss: 0.5398
# Iteration: 19996; Percent complete: 100.0%; Average loss: 0.5667
# Iteration: 19997; Percent complete: 100.0%; Average loss: 0.5923
# Iteration: 19998; Percent complete: 100.0%; Average loss: 0.5664
# Iteration: 19999; Percent complete: 100.0%; Average loss: 0.5875
# Iteration: 20000; Percent complete: 100.0%; Average loss: 0.5555

# %% [markdown]
# Run the model :)

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > hello
# Bot: hello 1
# > how are you doing today
# Bot: i m not well 4
# > that s bad
# Bot: not to worry for a minute 6
# > good. what did you eat today
# Bot: aha 1
# > anyway, what about food
# Bot: so what s it like a bit 7
# > what do you like
# Bot: nice inn it 3
# > nice inn, interesting
# Bot: don t open the lot of those money 8
# > alright, see you later
# Bot: mum 1
# > bye
# Bot: bye 1
# > q

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = StochasticTopKSampleDecoder(encoder, decoder,5)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > Hello
# Bot: have you any er m stamps a year 8
# > how are you
# Bot: alright 1
# > good
# Bot: good morning us about it 5
# > so, what did you eat
# Bot: no 1
# > have not eaten anything yet
# Bot: not yet yet yet 4
# > i see. how is your day
# Bot: later mark 2
# > what?
# Error: Encountered unknown word.
# > what did you mean
# Bot: er m the hill order 5
# > are you a real human
# Bot: yes it s a serious fat lady 7
# > what type of music do you listen to
# Bot: yeah inches and sort of fog 6
# > i don t understand
# Bot: did you wash it last night 6
# > wash what
# Bot: looks just taping as a man 6
# > alright, see you later
# Bot: mum 1
# > bye
# Bot: oh come on down the stairs 6
# > q

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = StochasticTopKUniformDecoder(encoder, decoder,2)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > Hello
# Bot: hello it paul isn t it kay then 8
# > what is your name
# Bot:  called s grandma m mister light 7
# > what do you mean
# Bot: that there come on come on please on the 9
# > q

# %% [markdown]
# ### Notes on the Model

# %% [markdown]
# Overall, the model is OK. It was not as intelligent as i thought it would be, but I suppose that is a good thing. One of the things that I noticed from playing with the bot was that everything is pretty predictable. In fact, it feels less like it is responding to you and more like it has memories what to day based on an input string from the user. I think the first thing we can do to improve the model is to add some randomness to the model, so asking "hello" wont keep generating the same output. To improve this one a bit more we can change some of the variable like the learning rate and the depth. Eventually, to improve the overall feeling of the chat bot we can implement an entirely new model. Try to give a more meaningful number to words rather than what index they first appear in (ask professor if he thinks this would even matter, or would this just be a change of domain).
