# %% [markdown]
# # ChatBot References
#
# Professor Smyth's website discussing projects
#
# https://www.ics.uci.edu/~smyth/courses/cs175/project_reading.html
#
# Chatbot resources on website
#
# https://pytorch.org/tutorials/beginner/chatbot_tutorial.html
#
# https://web.stanford.edu/~jurafsky/slp3/26.pdf
#
# https://www.microsoft.com/en-us/research/wp-content/uploads/2016/12/CortanaLUDialog-FromSLTproceedings.pdf
#
# Dataset for tutorial
#
# https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html

# %% [markdown]
# # Start of Tutorial

# %% [markdown]
# ### Import necessary libraries

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# ### Preprocess Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Looking at some files in the data to see how they are structured ...

# %%
data = "/content/drive/MyDrive/CS175_Datasets"
# corpus = os.path.join("data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

# printLines(os.path.join(data, "qa_Video_Games.json"))

# %% [markdown]
# Scan through data files and reformat them to be (sentence, response) pairs separated by a tab eventually. First we create helper functions to help clean up the data a bit and make it more readable ...

# %%
import json
import gzip

def parse(file):
  lines = [line.rstrip() for line in file]
  return lines

def loadConversations(lines):
  return [[lines[i], lines[i+1]] for i in range(0,len(lines),2)]  


def extractSentencePairs(conversations):
    return conversations

# %% [markdown]
# Next we will be using the functions above we now parse the data into a form that is useful to us and see what a few lines from the data look like ...

# %%
# Define path to new file
corpus=data
datafile_path = os.path.join(corpus, "Dialogue_Datasets")
datasets = os.path.join(datafile_path,"BNCSplitWordsCorpus.txt")
outfile_path = os.path.join(datafile_path, "csv_files")
datafile = os.path.join(outfile_path, "BNC.csv")
corpus_name = "BNC"
delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))
# load data if data file is already been processed as csv file
load_data = True

conversations = []
if not load_data: 
  # Load lines and process conversations
  print("\nProcessing corpus...")
  # lines = loadLines(os.path.join(corpus, "movie_lines.txt"), MOVIE_LINES_FIELDS)
  print("\nLoading conversations...")
  print(datasets)
  lines = parse(open(datasets))
  conversations = loadConversations(lines)


  # Write new csv file
  print("\nWriting newly formatted file...")
  with open(datafile, 'w', encoding='utf-8') as outputfile:
      writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
      for pair in extractSentencePairs(conversations):
        writer.writerow(pair)
# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Sample lines from file:
# b'You enjoyed yourself in America\tEh\n'
# b'did you\tOh I covered a nice trip yes\n'
# b'Oh very good\tsaw Mary and Andrew and\n'
# b"Yes you did\tin fact the whole family was together for Mary's wedding\n"
# b"Oh very nice very nice yes\tIt's horrible\n"
# b"It is horrible isn't\tHave you been busy\n"
# b'Yes\tYes oh\n'
# b"Jim's been for a this afternoon at the H art and Straw Club\toh not very well we er m we stopped going after Christmas because we had bad chest s both of us\n"
# b"Oh\tboth cold and it's hard going that three hours in the morning you know\n"
# b"Yes\tbut we'll go back again\n"

# %% [markdown]
# We want to create a vocabulary of words that we see. We represent these words numerically using the index of their first appearance in the history of all added words to the set of vocuabulary. See `addWord()` for specifics.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we finally getting to the part where we begin to make the (sentence, response) pairs. We begin preprocessing by converting the Unicode string texts to ASCII `unicodeToAscii()`. We also make everything lower case, and remove nonletters except for basic punctuation `normalizeString()`. The last thing that is done in preprocessing is ignore sentences beyond a certain length to aid in training `filterPair()` and `MAX_LENGTH`.

# %%
MAX_LENGTH = 8  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print(pairs[:10])
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join(data, "LSRM_save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# [['you enjoyed yourself in america', 'eh'], ['did you', 'oh i covered a nice trip yes'], ['oh very good', 'saw mary and andrew and'], ['yes you did', 'in fact the whole family was together for mary s wedding'], ['oh very nice very nice yes', 'it s horrible'], ['it is horrible isn t', 'have you been busy'], ['yes', 'yes oh'], ['jim s been for a this afternoon at the h art and straw club', 'oh not very well we er m we stopped going after christmas because we had bad chest s both of us'], ['oh', 'both cold and it s hard going that three hours in the morning you know'], ['yes', 'but we ll go back again']]
# Read 305507 sentence pairs
# Trimmed to 145571 sentence pairs
# Counting words...
# Counted words: 13291
#
# pairs:
# ['you enjoyed yourself in america', 'eh']
# ['did you', 'oh i covered a nice trip yes']
# ['oh very good', 'saw mary and andrew and']
# ['oh very nice very nice yes', 'it s horrible']
# ['it is horrible isn t', 'have you been busy']
# ['yes', 'yes oh']
# ['yes', 'but we ll go back again']
# ['because i m i m so busy', 'yes']
# ['yes that is also a thing to', 'yeah']
# ['and you re busy at', 'aren t you']

# %% [markdown]
# Another way to speed up training is by removing words that are rarely used. We "trim" these words using `Voc.trim()` and as a result must also remove (sentence, response) pairs that include these words.

# %%
MIN_COUNT = 12    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 3305 / 13288 = 0.2487
# Trimmed from 145571 pairs to 119616, 0.8217 of total

# %% [markdown]
# ### Using our Data on our Models

# %% [markdown]
# The data still needs to be processed more. The model that we use will take numerical values and not actual strings to do computation. We convert our sentences to tensors (vectors) that our model will take as inputs. To do this, we just take every sentence and change it to be a vector of index that corresponds to that word. This is how we will use our data to train the model.
#
# If we would like to train our model we usually do it with minbatches since it makes things faster. We make a matrix of dimensions (BatchLength, MaxLengthOfSentenceInBatch) represented numerically as mentioned in the previous paragraph. With this we make sure that each row (sentence) of our matrix terminates with `EOS_Token` and is followed by 0 entries until the end of the row.
#
# This implementation almost works, the problem with this is that each row is a sentence and every column is a step in time. However, it is better to think of every row as a step in time and the column to be possible words to choose for that step in time. For this reason, we construct the Matrix as mentioned in the previous paragraph except it is now transposed.
#
# We define some function that help us achieve this ...

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[126, 146, 128, 751,  10],
#         [149, 753,   3, 751,   2],
#         [ 55,   2,   2,   2,   0],
#         [146,   0,   0,   0,   0],
#         [  2,   0,   0,   0,   0]])
# lengths: tensor([5, 3, 3, 3, 2])
# target_variable: tensor([[  55,   45,   41,   59,   11],
#         [ 146,    2,   24,    3,  399],
#         [   2,    0,   70,   35,   28],
#         [   0,    0,  250,   23, 2332],
#         [   0,    0,  192,   24,   41],
#         [   0,    0,  122,    2,    2],
#         [   0,    0,    2,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False,  True,  True,  True],
#         [False, False,  True,  True,  True],
#         [False, False,  True,  True,  True],
#         [False, False,  True,  True,  True],
#         [False, False,  True, False, False]])
# max_target_len: 7

# %% [markdown]
# Seeing the output from preping the data above, it appears that `input_variable` is the matrix described in the previous secsion. `lenghts` is just a tensor (vector) of how long the sentences in the input were. This will eventually be used for the **decoder** later in the program. `target_variable` seems to be the response that our model is supposed to learn. `mask` looks like it is a mask for responses where true is that there is a word and false is that there is no word there. Not sure why this variable is necessary but maybe it will become clearer at some point in the tutorial.

# %% [markdown]
# ### Defining our Model

# %% [markdown]
# Our base model is a Sequence-to-Sequence model using two RNN's. The first RNN is what is called the **encoder** and it takes a variable length input and converts it into a *fixed length* "context" vector that is intended to hold onto some semantic meaning of the input. The **decoder** takes the context vector provided by the decoder along with an input word to guess the next word in a sequence. I suppose our (sentence, response) pairs are learned as one long continuous sequence where the sentence is the start of hte sequence and the response is the remainder of the sequence, though this might be entirely incorrect.

# %% [markdown]
# Some discussion on the Encoder. The encoder uses a bidirectional GRU (Gated Recurrent Unit), meaning that there is basically two RNN's that make up the encoder, one that goes through the sequence of data in the forward direction while another RNN goes through the sequence in the backward direction. At each time step, both RNN's produce an output and a hidden state vector. At each time step, the output of both RNNs are summed and the output is recorded (somewhere) while the hidden state vectors are pushed along and used in the next step of the RNN. The outputs are summed makes it so that at each time step, the RNN is considering present and future context.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.LSTM(hidden_size,hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Some discussion on the Decoder. The decoder uses the context vector that is produced by the encoder. Usually, this is all that will be used by a decoder to produce output but this can result in a loss of information, expecially when the input sentences are very long. To counter this, the decoder also uses its current hidden state as a way of determining what it should be "paying attention" to. These are refered to as attention weights and are multiplied by the outputs from the encoder (the output that is apperantly recorded somewhere, this is where they are used) from the current time step to rescale the values, making less important parts of the encoder output smaller and more important parts of the encoder output larger. This can be further improved by using all of the encoder outputs instead of just the one of the current time step to have a more comprehensive set of attention weights. This is the method implemented below, followed by the implementation of the decoder using this attention method.

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.LSTM(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# ### Defining the Training Procedure

# %% [markdown]
# Recall earlier in the `mask` produced along side the `target_variable` was produced for an unknown purpose, it turns out its purpose is for determining the loss of the model. This implementation below is the negative-log-likelihood loss and the variable `mask` along with `target_variable`.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# For training the model, two tricks are used to help convergence. The first trick is refered to as "teacher forcing" which just overrides the prediction of the decoder and uses the actual target value instead, this happens with some small probability p. Doing it too much will make the decoder unable to make predictions on its own and not having this feature will make it so that convergence is just slower. The second trick they do is gradient clipping, meaning that at areas in the feature space where there is a steep gradient and therefore a chance to improve the model very fast, the magnitude of the gradient is limited some value. This is to not drastically overshoot local minima on "cliffs". The training function is implemented below. This trains only one iteration.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
        #Get the encoder final h_hidden_state
    encoder_h_hidden, encoder_c_hidden = encoder_hidden
    decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
    decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
    # Recombine the final hidden states as hidden tuple
    decoder_hidden = (decoder_h_hidden, decoder_c_hidden)

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# This version of the training function trains on multiple iterations. It is built on the previous training function. This function also saves the current variables in a tarball file. This is to continue training at a later period or just use the current accumulated training to make predictions.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, 
               encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, 
               clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(
                iteration, iteration / n_iteration * 100, print_loss_avg
            ))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(
                encoder_n_layers, decoder_n_layers, hidden_size
            ))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# ### Defining Evaluation

# %% [markdown]
# This is the training method used by our bot when we are not using the "teacher forcing" method. This just basically chooses the output of hte decoder to be the output with the highest softmax score, ie the best response given its prior training. I think this is defining a decoder method for whenever we are actually using our model instead of when it is training.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        #Get the encoder final h_hidden_state
        encoder_h_hidden, encoder_c_hidden= encoder_hidden
        decoder_h_hidden = encoder_h_hidden[:decoder.n_layers]
        decoder_c_hidden = encoder_c_hidden[:decoder.n_layers]
        # Recombine the final hidden states as hidden tuple
        decoder_hidden = (decoder_h_hidden, decoder_c_hidden)
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# The `evaluateInput` function is meant to take input from the user, prepare it so that it may be fed to our model, and pring out the response from our bot. `evaluate` handles most of hte actual calculation while `evaluateInput` handles most of the user interaction phase.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    #lengths = lengths.to(device) # removed bc of gpu cpu tensor difference ###################################
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words), len(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# ### Running the Model

# %% [markdown]
# This defines and builds our model based on the following parameters. Notice that parts of the code are commented out as these are other possibilities ofr initialization. attn_model can be given one of three different models. We can also choose to load a model that we previously trained.

# %%
# Configure models
model_name = 'LSTM_dialogue_1024_batch_15000_iter'
attn_model = 'dot'
# attn_model = 'general'
# attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 1024

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 20000
# loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Now we train our model using `trainIters`. We first set some training parameters and initialize optimizers and prepare our model for training. Training is likely to take a very long time, thankfully there is the option to load from a previous model and this piece of code here doesn't need to be run every time.

# %%
# Safty precaution so that we dont accidentally begin training a model we didnt want to train
TRAIN_THE_MODEL = True

# %%
if TRAIN_THE_MODEL:
    
    # Configure training/optimization
    clip = 50.0
    teacher_forcing_ratio = 1.0
    learning_rate = 0.0001
    decoder_learning_ratio = 5.0
    n_iteration = 15000
    print_every = 1
    save_every = 1000

    # Ensure dropout layers are in train mode
    encoder.train()
    decoder.train()

    # Initialize optimizers
    print('Building optimizers ...')
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
    if loadFilename:
        encoder_optimizer.load_state_dict(encoder_optimizer_sd)
        decoder_optimizer.load_state_dict(decoder_optimizer_sd)

    # If you have cuda, configure cuda to call
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()
    
    # Run training iterations
    print("Starting Training!")
    trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
               embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
               print_every, save_every, clip, corpus_name, loadFilename)
    
    TRAIN_THE_MODEL = False

else:
    
    print(f"Make the variable 'TRAIN_THE_MODEL' in the code block above True and run the code block")
    print(f"Value of 'TRAIN_THE_MODEL' currently: {TRAIN_THE_MODEL}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration: 10001; Percent complete: 66.7%; Average loss: 0.8260
# Iteration: 10002; Percent complete: 66.7%; Average loss: 0.7781
# Iteration: 10003; Percent complete: 66.7%; Average loss: 0.7873
# Iteration: 10004; Percent complete: 66.7%; Average loss: 0.8371
# Iteration: 10005; Percent complete: 66.7%; Average loss: 0.8196
# Iteration: 10006; Percent complete: 66.7%; Average loss: 0.7997
# Iteration: 10007; Percent complete: 66.7%; Average loss: 0.7766
# Iteration: 10008; Percent complete: 66.7%; Average loss: 0.8299
# Iteration: 10009; Percent complete: 66.7%; Average loss: 0.8071
# Iteration: 10010; Percent complete: 66.7%; Average loss: 0.8244
# Iteration: 10011; Percent complete: 66.7%; Average loss: 0.8393
# Iteration: 10012; Percent complete: 66.7%; Average loss: 0.8223
# Iteration: 10013; Percent complete: 66.8%; Average loss: 0.8737
# Iteration: 10014; Percent complete: 66.8%; Average loss: 0.8287
# Iteration: 10015; Percent complete: 66.8%; Average loss: 0.8274
# Iteration: 10016; Percent complete: 66.8%; Average loss: 0.8337
# Iteration: 10017; Percent complete: 66.8%; Average loss: 0.8548
# Iteration: 10018; Percent complete: 66.8%; Average loss: 0.8590
# Iteration: 10019; Percent complete: 66.8%; Average loss: 0.8187
# Iteration: 10020; Percent complete: 66.8%; Average loss: 0.8000
# Iteration: 10021; Percent complete: 66.8%; Average loss: 0.7931
# Iteration: 10022; Percent complete: 66.8%; Average loss: 0.8118
# Iteration: 10023; Percent complete: 66.8%; Average loss: 0.8310
# Iteration: 10024; Percent complete: 66.8%; Average loss: 0.8519
# Iteration: 10025; Percent complete: 66.8%; Average loss: 0.8142
# Iteration: 10026; Percent complete: 66.8%; Average loss: 0.8135
# Iteration: 10027; Percent complete: 66.8%; Average loss: 0.8542
# Iteration: 10028; Percent complete: 66.9%; Average loss: 0.8020
# Iteration: 10029; Percent complete: 66.9%; Average loss: 0.7969
# Iteration: 10030; Percent complete: 66.9%; Average loss: 0.8120
# Iteration: 10031; Percent complete: 66.9%; Average loss: 0.8228
# Iteration: 10032; Percent complete: 66.9%; Average loss: 0.8469
# Iteration: 10033; Percent complete: 66.9%; Average loss: 0.8544
# Iteration: 10034; Percent complete: 66.9%; Average loss: 0.8415
# Iteration: 10035; Percent complete: 66.9%; Average loss: 0.8088
# Iteration: 10036; Percent complete: 66.9%; Average loss: 0.8292
# Iteration: 10037; Percent complete: 66.9%; Average loss: 0.8287
# Iteration: 10038; Percent complete: 66.9%; Average loss: 0.8401
# Iteration: 10039; Percent complete: 66.9%; Average loss: 0.8292
# Iteration: 10040; Percent complete: 66.9%; Average loss: 0.8552
# Iteration: 10041; Percent complete: 66.9%; Average loss: 0.8354
# Iteration: 10042; Percent complete: 66.9%; Average loss: 0.8396
# Iteration: 10043; Percent complete: 67.0%; Average loss: 0.8486
# Iteration: 10044; Percent complete: 67.0%; Average loss: 0.8180
# Iteration: 10045; Percent complete: 67.0%; Average loss: 0.8795
# Iteration: 10046; Percent complete: 67.0%; Average loss: 0.7645
# Iteration: 10047; Percent complete: 67.0%; Average loss: 0.8339
# Iteration: 10048; Percent complete: 67.0%; Average loss: 0.8406
# Iteration: 10049; Percent complete: 67.0%; Average loss: 0.7996
# Iteration: 10050; Percent complete: 67.0%; Average loss: 0.8127
# Iteration: 10051; Percent complete: 67.0%; Average loss: 0.7896
# Iteration: 10052; Percent complete: 67.0%; Average loss: 0.8344
# Iteration: 10053; Percent complete: 67.0%; Average loss: 0.8515
# Iteration: 10054; Percent complete: 67.0%; Average loss: 0.7950
# Iteration: 10055; Percent complete: 67.0%; Average loss: 0.8125
# Iteration: 10056; Percent complete: 67.0%; Average loss: 0.8436
# Iteration: 10057; Percent complete: 67.0%; Average loss: 0.8313
# Iteration: 10058; Percent complete: 67.1%; Average loss: 0.8036
# Iteration: 10059; Percent complete: 67.1%; Average loss: 0.8505
# Iteration: 10060; Percent complete: 67.1%; Average loss: 0.7873
# Iteration: 10061; Percent complete: 67.1%; Average loss: 0.8265
# Iteration: 10062; Percent complete: 67.1%; Average loss: 0.8330
# Iteration: 10063; Percent complete: 67.1%; Average loss: 0.8665
# Iteration: 10064; Percent complete: 67.1%; Average loss: 0.8143
# Iteration: 10065; Percent complete: 67.1%; Average loss: 0.8475
# Iteration: 10066; Percent complete: 67.1%; Average loss: 0.7890
# Iteration: 10067; Percent complete: 67.1%; Average loss: 0.8001
# Iteration: 10068; Percent complete: 67.1%; Average loss: 0.8230
# Iteration: 10069; Percent complete: 67.1%; Average loss: 0.7619
# Iteration: 10070; Percent complete: 67.1%; Average loss: 0.8343
# Iteration: 10071; Percent complete: 67.1%; Average loss: 0.8037
# Iteration: 10072; Percent complete: 67.1%; Average loss: 0.8469
# Iteration: 10073; Percent complete: 67.2%; Average loss: 0.7499
# Iteration: 10074; Percent complete: 67.2%; Average loss: 0.7824
# Iteration: 10075; Percent complete: 67.2%; Average loss: 0.8209
# Iteration: 10076; Percent complete: 67.2%; Average loss: 0.8174
# Iteration: 10077; Percent complete: 67.2%; Average loss: 0.8784
# Iteration: 10078; Percent complete: 67.2%; Average loss: 0.8416
# Iteration: 10079; Percent complete: 67.2%; Average loss: 0.8487
# Iteration: 10080; Percent complete: 67.2%; Average loss: 0.8225
# Iteration: 10081; Percent complete: 67.2%; Average loss: 0.7939
# Iteration: 10082; Percent complete: 67.2%; Average loss: 0.7773
# Iteration: 10083; Percent complete: 67.2%; Average loss: 0.8158
# Iteration: 10084; Percent complete: 67.2%; Average loss: 0.8215
# Iteration: 10085; Percent complete: 67.2%; Average loss: 0.8467
# Iteration: 10086; Percent complete: 67.2%; Average loss: 0.8182
# Iteration: 10087; Percent complete: 67.2%; Average loss: 0.7942
# Iteration: 10088; Percent complete: 67.3%; Average loss: 0.8161
# Iteration: 10089; Percent complete: 67.3%; Average loss: 0.7963
# Iteration: 10090; Percent complete: 67.3%; Average loss: 0.8225
# Iteration: 10091; Percent complete: 67.3%; Average loss: 0.8372
# Iteration: 10092; Percent complete: 67.3%; Average loss: 0.8457
# Iteration: 10093; Percent complete: 67.3%; Average loss: 0.7899
# Iteration: 10094; Percent complete: 67.3%; Average loss: 0.7996
# Iteration: 10095; Percent complete: 67.3%; Average loss: 0.8375
# Iteration: 10096; Percent complete: 67.3%; Average loss: 0.8405
# Iteration: 10097; Percent complete: 67.3%; Average loss: 0.7896
# Iteration: 10098; Percent complete: 67.3%; Average loss: 0.8066
# Iteration: 10099; Percent complete: 67.3%; Average loss: 0.8241
# Iteration: 10100; Percent complete: 67.3%; Average loss: 0.7818
# Iteration: 10101; Percent complete: 67.3%; Average loss: 0.8285
# Iteration: 10102; Percent complete: 67.3%; Average loss: 0.8049
# Iteration: 10103; Percent complete: 67.4%; Average loss: 0.8098
# Iteration: 10104; Percent complete: 67.4%; Average loss: 0.8482
# Iteration: 10105; Percent complete: 67.4%; Average loss: 0.7993
# Iteration: 10106; Percent complete: 67.4%; Average loss: 0.7965
# Iteration: 10107; Percent complete: 67.4%; Average loss: 0.8272
# Iteration: 10108; Percent complete: 67.4%; Average loss: 0.8046
# Iteration: 10109; Percent complete: 67.4%; Average loss: 0.8212
# Iteration: 10110; Percent complete: 67.4%; Average loss: 0.8012
# Iteration: 10111; Percent complete: 67.4%; Average loss: 0.7907
# Iteration: 10112; Percent complete: 67.4%; Average loss: 0.8081
# Iteration: 10113; Percent complete: 67.4%; Average loss: 0.7838
# Iteration: 10114; Percent complete: 67.4%; Average loss: 0.8194
# Iteration: 10115; Percent complete: 67.4%; Average loss: 0.7659
# Iteration: 10116; Percent complete: 67.4%; Average loss: 0.7682
# Iteration: 10117; Percent complete: 67.4%; Average loss: 0.8510
# Iteration: 10118; Percent complete: 67.5%; Average loss: 0.8235
# Iteration: 10119; Percent complete: 67.5%; Average loss: 0.8415
# Iteration: 10120; Percent complete: 67.5%; Average loss: 0.8428
# Iteration: 10121; Percent complete: 67.5%; Average loss: 0.7958
# Iteration: 10122; Percent complete: 67.5%; Average loss: 0.8221
# Iteration: 10123; Percent complete: 67.5%; Average loss: 0.7658
# Iteration: 10124; Percent complete: 67.5%; Average loss: 0.8199
# Iteration: 10125; Percent complete: 67.5%; Average loss: 0.7822
# Iteration: 10126; Percent complete: 67.5%; Average loss: 0.8130
# Iteration: 10127; Percent complete: 67.5%; Average loss: 0.8388
# Iteration: 10128; Percent complete: 67.5%; Average loss: 0.7962
# Iteration: 10129; Percent complete: 67.5%; Average loss: 0.8158
# Iteration: 10130; Percent complete: 67.5%; Average loss: 0.8187
# Iteration: 10131; Percent complete: 67.5%; Average loss: 0.8062
# Iteration: 10132; Percent complete: 67.5%; Average loss: 0.8806
# Iteration: 10133; Percent complete: 67.6%; Average loss: 0.8186
# Iteration: 10134; Percent complete: 67.6%; Average loss: 0.7842
# Iteration: 10135; Percent complete: 67.6%; Average loss: 0.8301
# Iteration: 10136; Percent complete: 67.6%; Average loss: 0.8227
# Iteration: 10137; Percent complete: 67.6%; Average loss: 0.8029
# Iteration: 10138; Percent complete: 67.6%; Average loss: 0.8360
# Iteration: 10139; Percent complete: 67.6%; Average loss: 0.8486
# Iteration: 10140; Percent complete: 67.6%; Average loss: 0.8091
# Iteration: 10141; Percent complete: 67.6%; Average loss: 0.7809
# Iteration: 10142; Percent complete: 67.6%; Average loss: 0.8593
# Iteration: 10143; Percent complete: 67.6%; Average loss: 0.8299
# Iteration: 10144; Percent complete: 67.6%; Average loss: 0.7755
# Iteration: 10145; Percent complete: 67.6%; Average loss: 0.8150
# Iteration: 10146; Percent complete: 67.6%; Average loss: 0.7795
# Iteration: 10147; Percent complete: 67.6%; Average loss: 0.7935
# Iteration: 10148; Percent complete: 67.7%; Average loss: 0.8223
# Iteration: 10149; Percent complete: 67.7%; Average loss: 0.8236
# Iteration: 10150; Percent complete: 67.7%; Average loss: 0.8026
# Iteration: 10151; Percent complete: 67.7%; Average loss: 0.8205
# Iteration: 10152; Percent complete: 67.7%; Average loss: 0.8457
# Iteration: 10153; Percent complete: 67.7%; Average loss: 0.8060
# Iteration: 10154; Percent complete: 67.7%; Average loss: 0.8305
# Iteration: 10155; Percent complete: 67.7%; Average loss: 0.8565
# Iteration: 10156; Percent complete: 67.7%; Average loss: 0.7939
# Iteration: 10157; Percent complete: 67.7%; Average loss: 0.7827
# Iteration: 10158; Percent complete: 67.7%; Average loss: 0.8303
# Iteration: 10159; Percent complete: 67.7%; Average loss: 0.7899
# Iteration: 10160; Percent complete: 67.7%; Average loss: 0.8343
# Iteration: 10161; Percent complete: 67.7%; Average loss: 0.7459
# Iteration: 10162; Percent complete: 67.7%; Average loss: 0.7537
# Iteration: 10163; Percent complete: 67.8%; Average loss: 0.7944
# Iteration: 10164; Percent complete: 67.8%; Average loss: 0.8077
# Iteration: 10165; Percent complete: 67.8%; Average loss: 0.7654
# Iteration: 10166; Percent complete: 67.8%; Average loss: 0.7980
# Iteration: 10167; Percent complete: 67.8%; Average loss: 0.8426
# Iteration: 10168; Percent complete: 67.8%; Average loss: 0.8218
# Iteration: 10169; Percent complete: 67.8%; Average loss: 0.8404
# Iteration: 10170; Percent complete: 67.8%; Average loss: 0.7670
# Iteration: 10171; Percent complete: 67.8%; Average loss: 0.8185
# Iteration: 10172; Percent complete: 67.8%; Average loss: 0.8557
# Iteration: 10173; Percent complete: 67.8%; Average loss: 0.8047
# Iteration: 10174; Percent complete: 67.8%; Average loss: 0.8122
# Iteration: 10175; Percent complete: 67.8%; Average loss: 0.8231
# Iteration: 10176; Percent complete: 67.8%; Average loss: 0.8116
# Iteration: 10177; Percent complete: 67.8%; Average loss: 0.7910
# Iteration: 10178; Percent complete: 67.9%; Average loss: 0.8196
# Iteration: 10179; Percent complete: 67.9%; Average loss: 0.8466
# Iteration: 10180; Percent complete: 67.9%; Average loss: 0.8075
# Iteration: 10181; Percent complete: 67.9%; Average loss: 0.8480
# Iteration: 10182; Percent complete: 67.9%; Average loss: 0.8125
# Iteration: 10183; Percent complete: 67.9%; Average loss: 0.7570
# Iteration: 10184; Percent complete: 67.9%; Average loss: 0.8099
# Iteration: 10185; Percent complete: 67.9%; Average loss: 0.8406
# Iteration: 10186; Percent complete: 67.9%; Average loss: 0.8379
# Iteration: 10187; Percent complete: 67.9%; Average loss: 0.8428
# Iteration: 10188; Percent complete: 67.9%; Average loss: 0.8042
# Iteration: 10189; Percent complete: 67.9%; Average loss: 0.8083
# Iteration: 10190; Percent complete: 67.9%; Average loss: 0.8051
# Iteration: 10191; Percent complete: 67.9%; Average loss: 0.8559
# Iteration: 10192; Percent complete: 67.9%; Average loss: 0.7655
# Iteration: 10193; Percent complete: 68.0%; Average loss: 0.8424
# Iteration: 10194; Percent complete: 68.0%; Average loss: 0.7908
# Iteration: 10195; Percent complete: 68.0%; Average loss: 0.8333
# Iteration: 10196; Percent complete: 68.0%; Average loss: 0.8026
# Iteration: 10197; Percent complete: 68.0%; Average loss: 0.8142
# Iteration: 10198; Percent complete: 68.0%; Average loss: 0.8047
# Iteration: 10199; Percent complete: 68.0%; Average loss: 0.8190
# Iteration: 10200; Percent complete: 68.0%; Average loss: 0.8290
# Iteration: 10201; Percent complete: 68.0%; Average loss: 0.8415
# Iteration: 10202; Percent complete: 68.0%; Average loss: 0.7766
# Iteration: 10203; Percent complete: 68.0%; Average loss: 0.8110
# Iteration: 10204; Percent complete: 68.0%; Average loss: 0.8482
# Iteration: 10205; Percent complete: 68.0%; Average loss: 0.8118
# Iteration: 10206; Percent complete: 68.0%; Average loss: 0.8191
# Iteration: 10207; Percent complete: 68.0%; Average loss: 0.7315
# Iteration: 10208; Percent complete: 68.1%; Average loss: 0.8125
# Iteration: 10209; Percent complete: 68.1%; Average loss: 0.8387
# Iteration: 10210; Percent complete: 68.1%; Average loss: 0.8124
# Iteration: 10211; Percent complete: 68.1%; Average loss: 0.8681
# Iteration: 10212; Percent complete: 68.1%; Average loss: 0.8086
# Iteration: 10213; Percent complete: 68.1%; Average loss: 0.8237
# Iteration: 10214; Percent complete: 68.1%; Average loss: 0.8248
# Iteration: 10215; Percent complete: 68.1%; Average loss: 0.7869
# Iteration: 10216; Percent complete: 68.1%; Average loss: 0.7770
# Iteration: 10217; Percent complete: 68.1%; Average loss: 0.8277
# Iteration: 10218; Percent complete: 68.1%; Average loss: 0.8802
# Iteration: 10219; Percent complete: 68.1%; Average loss: 0.8230
# Iteration: 10220; Percent complete: 68.1%; Average loss: 0.8009
# Iteration: 10221; Percent complete: 68.1%; Average loss: 0.7661
# Iteration: 10222; Percent complete: 68.1%; Average loss: 0.7977
# Iteration: 10223; Percent complete: 68.2%; Average loss: 0.8249
# Iteration: 10224; Percent complete: 68.2%; Average loss: 0.8371
# Iteration: 10225; Percent complete: 68.2%; Average loss: 0.8125
# Iteration: 10226; Percent complete: 68.2%; Average loss: 0.7843
# Iteration: 10227; Percent complete: 68.2%; Average loss: 0.7924
# Iteration: 10228; Percent complete: 68.2%; Average loss: 0.8202
# Iteration: 10229; Percent complete: 68.2%; Average loss: 0.8000
# Iteration: 10230; Percent complete: 68.2%; Average loss: 0.8044
# Iteration: 10231; Percent complete: 68.2%; Average loss: 0.7798
# Iteration: 10232; Percent complete: 68.2%; Average loss: 0.7578
# Iteration: 10233; Percent complete: 68.2%; Average loss: 0.7959
# Iteration: 10234; Percent complete: 68.2%; Average loss: 0.7538
# Iteration: 10235; Percent complete: 68.2%; Average loss: 0.7975
# Iteration: 10236; Percent complete: 68.2%; Average loss: 0.8291
# Iteration: 10237; Percent complete: 68.2%; Average loss: 0.8322
# Iteration: 10238; Percent complete: 68.3%; Average loss: 0.8053
# Iteration: 10239; Percent complete: 68.3%; Average loss: 0.8275
# Iteration: 10240; Percent complete: 68.3%; Average loss: 0.8179
# Iteration: 10241; Percent complete: 68.3%; Average loss: 0.8106
# Iteration: 10242; Percent complete: 68.3%; Average loss: 0.7937
# Iteration: 10243; Percent complete: 68.3%; Average loss: 0.8335
# Iteration: 10244; Percent complete: 68.3%; Average loss: 0.7973
# Iteration: 10245; Percent complete: 68.3%; Average loss: 0.7365
# Iteration: 10246; Percent complete: 68.3%; Average loss: 0.8378
# Iteration: 10247; Percent complete: 68.3%; Average loss: 0.8333
# Iteration: 10248; Percent complete: 68.3%; Average loss: 0.7827
# Iteration: 10249; Percent complete: 68.3%; Average loss: 0.8572
# Iteration: 10250; Percent complete: 68.3%; Average loss: 0.7634
# Iteration: 10251; Percent complete: 68.3%; Average loss: 0.8213
# Iteration: 10252; Percent complete: 68.3%; Average loss: 0.8211
# Iteration: 10253; Percent complete: 68.4%; Average loss: 0.7845
# Iteration: 10254; Percent complete: 68.4%; Average loss: 0.8276
# Iteration: 10255; Percent complete: 68.4%; Average loss: 0.7956
# Iteration: 10256; Percent complete: 68.4%; Average loss: 0.8181
# Iteration: 10257; Percent complete: 68.4%; Average loss: 0.8265
# Iteration: 10258; Percent complete: 68.4%; Average loss: 0.8440
# Iteration: 10259; Percent complete: 68.4%; Average loss: 0.8319
# Iteration: 10260; Percent complete: 68.4%; Average loss: 0.8071
# Iteration: 10261; Percent complete: 68.4%; Average loss: 0.7893
# Iteration: 10262; Percent complete: 68.4%; Average loss: 0.8077
# Iteration: 10263; Percent complete: 68.4%; Average loss: 0.7716
# Iteration: 10264; Percent complete: 68.4%; Average loss: 0.8326
# Iteration: 10265; Percent complete: 68.4%; Average loss: 0.8386
# Iteration: 10266; Percent complete: 68.4%; Average loss: 0.8085
# Iteration: 10267; Percent complete: 68.4%; Average loss: 0.8119
# Iteration: 10268; Percent complete: 68.5%; Average loss: 0.8113
# Iteration: 10269; Percent complete: 68.5%; Average loss: 0.8432
# Iteration: 10270; Percent complete: 68.5%; Average loss: 0.7695
# Iteration: 10271; Percent complete: 68.5%; Average loss: 0.8167
# Iteration: 10272; Percent complete: 68.5%; Average loss: 0.8110
# Iteration: 10273; Percent complete: 68.5%; Average loss: 0.8282
# Iteration: 10274; Percent complete: 68.5%; Average loss: 0.7375
# Iteration: 10275; Percent complete: 68.5%; Average loss: 0.8513
# Iteration: 10276; Percent complete: 68.5%; Average loss: 0.7891
# Iteration: 10277; Percent complete: 68.5%; Average loss: 0.8858
# Iteration: 10278; Percent complete: 68.5%; Average loss: 0.7753
# Iteration: 10279; Percent complete: 68.5%; Average loss: 0.8518
# Iteration: 10280; Percent complete: 68.5%; Average loss: 0.7745
# Iteration: 10281; Percent complete: 68.5%; Average loss: 0.7826
# Iteration: 10282; Percent complete: 68.5%; Average loss: 0.8125
# Iteration: 10283; Percent complete: 68.6%; Average loss: 0.8205
# Iteration: 10284; Percent complete: 68.6%; Average loss: 0.7989
# Iteration: 10285; Percent complete: 68.6%; Average loss: 0.7962
# Iteration: 10286; Percent complete: 68.6%; Average loss: 0.7808
# Iteration: 10287; Percent complete: 68.6%; Average loss: 0.8184
# Iteration: 10288; Percent complete: 68.6%; Average loss: 0.8095
# Iteration: 10289; Percent complete: 68.6%; Average loss: 0.7715
# Iteration: 10290; Percent complete: 68.6%; Average loss: 0.7732
# Iteration: 10291; Percent complete: 68.6%; Average loss: 0.8051
# Iteration: 10292; Percent complete: 68.6%; Average loss: 0.7887
# Iteration: 10293; Percent complete: 68.6%; Average loss: 0.7980
# Iteration: 10294; Percent complete: 68.6%; Average loss: 0.7978
# Iteration: 10295; Percent complete: 68.6%; Average loss: 0.7996
# Iteration: 10296; Percent complete: 68.6%; Average loss: 0.8007
# Iteration: 10297; Percent complete: 68.6%; Average loss: 0.8012
# Iteration: 10298; Percent complete: 68.7%; Average loss: 0.8841
# Iteration: 10299; Percent complete: 68.7%; Average loss: 0.7981
# Iteration: 10300; Percent complete: 68.7%; Average loss: 0.7922
# Iteration: 10301; Percent complete: 68.7%; Average loss: 0.8034
# Iteration: 10302; Percent complete: 68.7%; Average loss: 0.8169
# Iteration: 10303; Percent complete: 68.7%; Average loss: 0.7770
# Iteration: 10304; Percent complete: 68.7%; Average loss: 0.7847
# Iteration: 10305; Percent complete: 68.7%; Average loss: 0.7952
# Iteration: 10306; Percent complete: 68.7%; Average loss: 0.7900
# Iteration: 10307; Percent complete: 68.7%; Average loss: 0.7929
# Iteration: 10308; Percent complete: 68.7%; Average loss: 0.7792
# Iteration: 10309; Percent complete: 68.7%; Average loss: 0.7734
# Iteration: 10310; Percent complete: 68.7%; Average loss: 0.7976
# Iteration: 10311; Percent complete: 68.7%; Average loss: 0.8221
# Iteration: 10312; Percent complete: 68.7%; Average loss: 0.7953
# Iteration: 10313; Percent complete: 68.8%; Average loss: 0.7774
# Iteration: 10314; Percent complete: 68.8%; Average loss: 0.7687
# Iteration: 10315; Percent complete: 68.8%; Average loss: 0.8173
# Iteration: 10316; Percent complete: 68.8%; Average loss: 0.8112
# Iteration: 10317; Percent complete: 68.8%; Average loss: 0.7933
# Iteration: 10318; Percent complete: 68.8%; Average loss: 0.8384
# Iteration: 10319; Percent complete: 68.8%; Average loss: 0.7764
# Iteration: 10320; Percent complete: 68.8%; Average loss: 0.8194
# Iteration: 10321; Percent complete: 68.8%; Average loss: 0.7782
# Iteration: 10322; Percent complete: 68.8%; Average loss: 0.7930
# Iteration: 10323; Percent complete: 68.8%; Average loss: 0.8251
# Iteration: 10324; Percent complete: 68.8%; Average loss: 0.7971
# Iteration: 10325; Percent complete: 68.8%; Average loss: 0.8059
# Iteration: 10326; Percent complete: 68.8%; Average loss: 0.8383
# Iteration: 10327; Percent complete: 68.8%; Average loss: 0.7636
# Iteration: 10328; Percent complete: 68.9%; Average loss: 0.8074
# Iteration: 10329; Percent complete: 68.9%; Average loss: 0.8211
# Iteration: 10330; Percent complete: 68.9%; Average loss: 0.7960
# Iteration: 10331; Percent complete: 68.9%; Average loss: 0.8197
# Iteration: 10332; Percent complete: 68.9%; Average loss: 0.7648
# Iteration: 10333; Percent complete: 68.9%; Average loss: 0.7933
# Iteration: 10334; Percent complete: 68.9%; Average loss: 0.7676
# Iteration: 10335; Percent complete: 68.9%; Average loss: 0.7702
# Iteration: 10336; Percent complete: 68.9%; Average loss: 0.8053
# Iteration: 10337; Percent complete: 68.9%; Average loss: 0.7955
# Iteration: 10338; Percent complete: 68.9%; Average loss: 0.7817
# Iteration: 10339; Percent complete: 68.9%; Average loss: 0.7761
# Iteration: 10340; Percent complete: 68.9%; Average loss: 0.7741
# Iteration: 10341; Percent complete: 68.9%; Average loss: 0.7971
# Iteration: 10342; Percent complete: 68.9%; Average loss: 0.7743
# Iteration: 10343; Percent complete: 69.0%; Average loss: 0.7784
# Iteration: 10344; Percent complete: 69.0%; Average loss: 0.8172
# Iteration: 10345; Percent complete: 69.0%; Average loss: 0.7695
# Iteration: 10346; Percent complete: 69.0%; Average loss: 0.8334
# Iteration: 10347; Percent complete: 69.0%; Average loss: 0.7636
# Iteration: 10348; Percent complete: 69.0%; Average loss: 0.7895
# Iteration: 10349; Percent complete: 69.0%; Average loss: 0.7688
# Iteration: 10350; Percent complete: 69.0%; Average loss: 0.7449
# Iteration: 10351; Percent complete: 69.0%; Average loss: 0.7689
# Iteration: 10352; Percent complete: 69.0%; Average loss: 0.8100
# Iteration: 10353; Percent complete: 69.0%; Average loss: 0.7988
# Iteration: 10354; Percent complete: 69.0%; Average loss: 0.8443
# Iteration: 10355; Percent complete: 69.0%; Average loss: 0.8505
# Iteration: 10356; Percent complete: 69.0%; Average loss: 0.7924
# Iteration: 10357; Percent complete: 69.0%; Average loss: 0.7837
# Iteration: 10358; Percent complete: 69.1%; Average loss: 0.8181
# Iteration: 10359; Percent complete: 69.1%; Average loss: 0.8141
# Iteration: 10360; Percent complete: 69.1%; Average loss: 0.7863
# Iteration: 10361; Percent complete: 69.1%; Average loss: 0.7810
# Iteration: 10362; Percent complete: 69.1%; Average loss: 0.8126
# Iteration: 10363; Percent complete: 69.1%; Average loss: 0.8265
# Iteration: 10364; Percent complete: 69.1%; Average loss: 0.8032
# Iteration: 10365; Percent complete: 69.1%; Average loss: 0.8218
# Iteration: 10366; Percent complete: 69.1%; Average loss: 0.8371
# Iteration: 10367; Percent complete: 69.1%; Average loss: 0.8492
# Iteration: 10368; Percent complete: 69.1%; Average loss: 0.8340
# Iteration: 10369; Percent complete: 69.1%; Average loss: 0.7948
# Iteration: 10370; Percent complete: 69.1%; Average loss: 0.8187
# Iteration: 10371; Percent complete: 69.1%; Average loss: 0.8418
# Iteration: 10372; Percent complete: 69.1%; Average loss: 0.7945
# Iteration: 10373; Percent complete: 69.2%; Average loss: 0.7654
# Iteration: 10374; Percent complete: 69.2%; Average loss: 0.8204
# Iteration: 10375; Percent complete: 69.2%; Average loss: 0.7672
# Iteration: 10376; Percent complete: 69.2%; Average loss: 0.7781
# Iteration: 10377; Percent complete: 69.2%; Average loss: 0.7920
# Iteration: 10378; Percent complete: 69.2%; Average loss: 0.7880
# Iteration: 10379; Percent complete: 69.2%; Average loss: 0.7803
# Iteration: 10380; Percent complete: 69.2%; Average loss: 0.8251
# Iteration: 10381; Percent complete: 69.2%; Average loss: 0.7805
# Iteration: 10382; Percent complete: 69.2%; Average loss: 0.7998
# Iteration: 10383; Percent complete: 69.2%; Average loss: 0.7852
# Iteration: 10384; Percent complete: 69.2%; Average loss: 0.7427
# Iteration: 10385; Percent complete: 69.2%; Average loss: 0.8363
# Iteration: 10386; Percent complete: 69.2%; Average loss: 0.7759
# Iteration: 10387; Percent complete: 69.2%; Average loss: 0.7685
# Iteration: 10388; Percent complete: 69.3%; Average loss: 0.8146
# Iteration: 10389; Percent complete: 69.3%; Average loss: 0.7939
# Iteration: 10390; Percent complete: 69.3%; Average loss: 0.7695
# Iteration: 10391; Percent complete: 69.3%; Average loss: 0.8106
# Iteration: 10392; Percent complete: 69.3%; Average loss: 0.8185
# Iteration: 10393; Percent complete: 69.3%; Average loss: 0.8494
# Iteration: 10394; Percent complete: 69.3%; Average loss: 0.8147
# Iteration: 10395; Percent complete: 69.3%; Average loss: 0.7736
# Iteration: 10396; Percent complete: 69.3%; Average loss: 0.7949
# Iteration: 10397; Percent complete: 69.3%; Average loss: 0.8241
# Iteration: 10398; Percent complete: 69.3%; Average loss: 0.7656
# Iteration: 10399; Percent complete: 69.3%; Average loss: 0.8184
# Iteration: 10400; Percent complete: 69.3%; Average loss: 0.7978
# Iteration: 10401; Percent complete: 69.3%; Average loss: 0.7580
# Iteration: 10402; Percent complete: 69.3%; Average loss: 0.7762
# Iteration: 10403; Percent complete: 69.4%; Average loss: 0.7571
# Iteration: 10404; Percent complete: 69.4%; Average loss: 0.7599
# Iteration: 10405; Percent complete: 69.4%; Average loss: 0.7747
# Iteration: 10406; Percent complete: 69.4%; Average loss: 0.7837
# Iteration: 10407; Percent complete: 69.4%; Average loss: 0.7675
# Iteration: 10408; Percent complete: 69.4%; Average loss: 0.7642
# Iteration: 10409; Percent complete: 69.4%; Average loss: 0.7542
# Iteration: 10410; Percent complete: 69.4%; Average loss: 0.8149
# Iteration: 10411; Percent complete: 69.4%; Average loss: 0.7912
# Iteration: 10412; Percent complete: 69.4%; Average loss: 0.7789
# Iteration: 10413; Percent complete: 69.4%; Average loss: 0.7593
# Iteration: 10414; Percent complete: 69.4%; Average loss: 0.7948
# Iteration: 10415; Percent complete: 69.4%; Average loss: 0.7506
# Iteration: 10416; Percent complete: 69.4%; Average loss: 0.7871
# Iteration: 10417; Percent complete: 69.4%; Average loss: 0.7921
# Iteration: 10418; Percent complete: 69.5%; Average loss: 0.7967
# Iteration: 10419; Percent complete: 69.5%; Average loss: 0.8310
# Iteration: 10420; Percent complete: 69.5%; Average loss: 0.7692
# Iteration: 10421; Percent complete: 69.5%; Average loss: 0.8223
# Iteration: 10422; Percent complete: 69.5%; Average loss: 0.8036
# Iteration: 10423; Percent complete: 69.5%; Average loss: 0.7677
# Iteration: 10424; Percent complete: 69.5%; Average loss: 0.8432
# Iteration: 10425; Percent complete: 69.5%; Average loss: 0.8172
# Iteration: 10426; Percent complete: 69.5%; Average loss: 0.7900
# Iteration: 10427; Percent complete: 69.5%; Average loss: 0.7934
# Iteration: 10428; Percent complete: 69.5%; Average loss: 0.8198
# Iteration: 10429; Percent complete: 69.5%; Average loss: 0.8353
# Iteration: 10430; Percent complete: 69.5%; Average loss: 0.8169
# Iteration: 10431; Percent complete: 69.5%; Average loss: 0.7825
# Iteration: 10432; Percent complete: 69.5%; Average loss: 0.8019
# Iteration: 10433; Percent complete: 69.6%; Average loss: 0.7593
# Iteration: 10434; Percent complete: 69.6%; Average loss: 0.8197
# Iteration: 10435; Percent complete: 69.6%; Average loss: 0.8128
# Iteration: 10436; Percent complete: 69.6%; Average loss: 0.8138
# Iteration: 10437; Percent complete: 69.6%; Average loss: 0.8020
# Iteration: 10438; Percent complete: 69.6%; Average loss: 0.8209
# Iteration: 10439; Percent complete: 69.6%; Average loss: 0.7901
# Iteration: 10440; Percent complete: 69.6%; Average loss: 0.8040
# Iteration: 10441; Percent complete: 69.6%; Average loss: 0.7516
# Iteration: 10442; Percent complete: 69.6%; Average loss: 0.8148
# Iteration: 10443; Percent complete: 69.6%; Average loss: 0.7918
# Iteration: 10444; Percent complete: 69.6%; Average loss: 0.7992
# Iteration: 10445; Percent complete: 69.6%; Average loss: 0.7664
# Iteration: 10446; Percent complete: 69.6%; Average loss: 0.7833
# Iteration: 10447; Percent complete: 69.6%; Average loss: 0.8375
# Iteration: 10448; Percent complete: 69.7%; Average loss: 0.7937
# Iteration: 10449; Percent complete: 69.7%; Average loss: 0.7603
# Iteration: 10450; Percent complete: 69.7%; Average loss: 0.8004
# Iteration: 10451; Percent complete: 69.7%; Average loss: 0.7700
# Iteration: 10452; Percent complete: 69.7%; Average loss: 0.7791
# Iteration: 10453; Percent complete: 69.7%; Average loss: 0.7977
# Iteration: 10454; Percent complete: 69.7%; Average loss: 0.7778
# Iteration: 10455; Percent complete: 69.7%; Average loss: 0.7883
# Iteration: 10456; Percent complete: 69.7%; Average loss: 0.7901
# Iteration: 10457; Percent complete: 69.7%; Average loss: 0.8161
# Iteration: 10458; Percent complete: 69.7%; Average loss: 0.7562
# Iteration: 10459; Percent complete: 69.7%; Average loss: 0.7467
# Iteration: 10460; Percent complete: 69.7%; Average loss: 0.8001
# Iteration: 10461; Percent complete: 69.7%; Average loss: 0.7719
# Iteration: 10462; Percent complete: 69.7%; Average loss: 0.7639
# Iteration: 10463; Percent complete: 69.8%; Average loss: 0.7771
# Iteration: 10464; Percent complete: 69.8%; Average loss: 0.8432
# Iteration: 10465; Percent complete: 69.8%; Average loss: 0.7501
# Iteration: 10466; Percent complete: 69.8%; Average loss: 0.7893
# Iteration: 10467; Percent complete: 69.8%; Average loss: 0.7577
# Iteration: 10468; Percent complete: 69.8%; Average loss: 0.7731
# Iteration: 10469; Percent complete: 69.8%; Average loss: 0.8055
# Iteration: 10470; Percent complete: 69.8%; Average loss: 0.7933
# Iteration: 10471; Percent complete: 69.8%; Average loss: 0.8101
# Iteration: 10472; Percent complete: 69.8%; Average loss: 0.7594
# Iteration: 10473; Percent complete: 69.8%; Average loss: 0.8174
# Iteration: 10474; Percent complete: 69.8%; Average loss: 0.7936
# Iteration: 10475; Percent complete: 69.8%; Average loss: 0.7636
# Iteration: 10476; Percent complete: 69.8%; Average loss: 0.8140
# Iteration: 10477; Percent complete: 69.8%; Average loss: 0.7821
# Iteration: 10478; Percent complete: 69.9%; Average loss: 0.7720
# Iteration: 10479; Percent complete: 69.9%; Average loss: 0.8068
# Iteration: 10480; Percent complete: 69.9%; Average loss: 0.8347
# Iteration: 10481; Percent complete: 69.9%; Average loss: 0.7996
# Iteration: 10482; Percent complete: 69.9%; Average loss: 0.8227
# Iteration: 10483; Percent complete: 69.9%; Average loss: 0.8218
# Iteration: 10484; Percent complete: 69.9%; Average loss: 0.7886
# Iteration: 10485; Percent complete: 69.9%; Average loss: 0.7941
# Iteration: 10486; Percent complete: 69.9%; Average loss: 0.8070
# Iteration: 10487; Percent complete: 69.9%; Average loss: 0.7915
# Iteration: 10488; Percent complete: 69.9%; Average loss: 0.8106
# Iteration: 10489; Percent complete: 69.9%; Average loss: 0.7361
# Iteration: 10490; Percent complete: 69.9%; Average loss: 0.7927
# Iteration: 10491; Percent complete: 69.9%; Average loss: 0.7755
# Iteration: 10492; Percent complete: 69.9%; Average loss: 0.7831
# Iteration: 10493; Percent complete: 70.0%; Average loss: 0.7857
# Iteration: 10494; Percent complete: 70.0%; Average loss: 0.7348
# Iteration: 10495; Percent complete: 70.0%; Average loss: 0.7901
# Iteration: 10496; Percent complete: 70.0%; Average loss: 0.7821
# Iteration: 10497; Percent complete: 70.0%; Average loss: 0.7819
# Iteration: 10498; Percent complete: 70.0%; Average loss: 0.8101
# Iteration: 10499; Percent complete: 70.0%; Average loss: 0.7624
# Iteration: 10500; Percent complete: 70.0%; Average loss: 0.7988
# Iteration: 10501; Percent complete: 70.0%; Average loss: 0.8222
# Iteration: 10502; Percent complete: 70.0%; Average loss: 0.7949
# Iteration: 10503; Percent complete: 70.0%; Average loss: 0.7722
# Iteration: 10504; Percent complete: 70.0%; Average loss: 0.8035
# Iteration: 10505; Percent complete: 70.0%; Average loss: 0.8173
# Iteration: 10506; Percent complete: 70.0%; Average loss: 0.8076
# Iteration: 10507; Percent complete: 70.0%; Average loss: 0.7983
# Iteration: 10508; Percent complete: 70.1%; Average loss: 0.7627
# Iteration: 10509; Percent complete: 70.1%; Average loss: 0.7774
# Iteration: 10510; Percent complete: 70.1%; Average loss: 0.8338
# Iteration: 10511; Percent complete: 70.1%; Average loss: 0.7765
# Iteration: 10512; Percent complete: 70.1%; Average loss: 0.7778
# Iteration: 10513; Percent complete: 70.1%; Average loss: 0.7687
# Iteration: 10514; Percent complete: 70.1%; Average loss: 0.8279
# Iteration: 10515; Percent complete: 70.1%; Average loss: 0.7283
# Iteration: 10516; Percent complete: 70.1%; Average loss: 0.7678
# Iteration: 10517; Percent complete: 70.1%; Average loss: 0.7982
# Iteration: 10518; Percent complete: 70.1%; Average loss: 0.7842
# Iteration: 10519; Percent complete: 70.1%; Average loss: 0.7274
# Iteration: 10520; Percent complete: 70.1%; Average loss: 0.8067
# Iteration: 10521; Percent complete: 70.1%; Average loss: 0.8158
# Iteration: 10522; Percent complete: 70.1%; Average loss: 0.7762
# Iteration: 10523; Percent complete: 70.2%; Average loss: 0.7789
# Iteration: 10524; Percent complete: 70.2%; Average loss: 0.7990
# Iteration: 10525; Percent complete: 70.2%; Average loss: 0.7808
# Iteration: 10526; Percent complete: 70.2%; Average loss: 0.7882
# Iteration: 10527; Percent complete: 70.2%; Average loss: 0.7696
# Iteration: 10528; Percent complete: 70.2%; Average loss: 0.8141
# Iteration: 10529; Percent complete: 70.2%; Average loss: 0.7814
# Iteration: 10530; Percent complete: 70.2%; Average loss: 0.8112
# Iteration: 10531; Percent complete: 70.2%; Average loss: 0.7787
# Iteration: 10532; Percent complete: 70.2%; Average loss: 0.7456
# Iteration: 10533; Percent complete: 70.2%; Average loss: 0.7951
# Iteration: 10534; Percent complete: 70.2%; Average loss: 0.7949
# Iteration: 10535; Percent complete: 70.2%; Average loss: 0.7700
# Iteration: 10536; Percent complete: 70.2%; Average loss: 0.7935
# Iteration: 10537; Percent complete: 70.2%; Average loss: 0.7547
# Iteration: 10538; Percent complete: 70.3%; Average loss: 0.7930
# Iteration: 10539; Percent complete: 70.3%; Average loss: 0.7893
# Iteration: 10540; Percent complete: 70.3%; Average loss: 0.8284
# Iteration: 10541; Percent complete: 70.3%; Average loss: 0.7916
# Iteration: 10542; Percent complete: 70.3%; Average loss: 0.7783
# Iteration: 10543; Percent complete: 70.3%; Average loss: 0.7502
# Iteration: 10544; Percent complete: 70.3%; Average loss: 0.7771
# Iteration: 10545; Percent complete: 70.3%; Average loss: 0.7940
# Iteration: 10546; Percent complete: 70.3%; Average loss: 0.7608
# Iteration: 10547; Percent complete: 70.3%; Average loss: 0.8063
# Iteration: 10548; Percent complete: 70.3%; Average loss: 0.7674
# Iteration: 10549; Percent complete: 70.3%; Average loss: 0.7852
# Iteration: 10550; Percent complete: 70.3%; Average loss: 0.7936
# Iteration: 10551; Percent complete: 70.3%; Average loss: 0.7707
# Iteration: 10552; Percent complete: 70.3%; Average loss: 0.8521
# Iteration: 10553; Percent complete: 70.4%; Average loss: 0.7867
# Iteration: 10554; Percent complete: 70.4%; Average loss: 0.7659
# Iteration: 10555; Percent complete: 70.4%; Average loss: 0.7842
# Iteration: 10556; Percent complete: 70.4%; Average loss: 0.7713
# Iteration: 10557; Percent complete: 70.4%; Average loss: 0.7929
# Iteration: 10558; Percent complete: 70.4%; Average loss: 0.7194
# Iteration: 10559; Percent complete: 70.4%; Average loss: 0.7954
# Iteration: 10560; Percent complete: 70.4%; Average loss: 0.8318
# Iteration: 10561; Percent complete: 70.4%; Average loss: 0.8131
# Iteration: 10562; Percent complete: 70.4%; Average loss: 0.7999
# Iteration: 10563; Percent complete: 70.4%; Average loss: 0.7939
# Iteration: 10564; Percent complete: 70.4%; Average loss: 0.7586
# Iteration: 10565; Percent complete: 70.4%; Average loss: 0.8137
# Iteration: 10566; Percent complete: 70.4%; Average loss: 0.8000
# Iteration: 10567; Percent complete: 70.4%; Average loss: 0.7648
# Iteration: 10568; Percent complete: 70.5%; Average loss: 0.8115
# Iteration: 10569; Percent complete: 70.5%; Average loss: 0.8440
# Iteration: 10570; Percent complete: 70.5%; Average loss: 0.7992
# Iteration: 10571; Percent complete: 70.5%; Average loss: 0.7748
# Iteration: 10572; Percent complete: 70.5%; Average loss: 0.7723
# Iteration: 10573; Percent complete: 70.5%; Average loss: 0.7821
# Iteration: 10574; Percent complete: 70.5%; Average loss: 0.8112
# Iteration: 10575; Percent complete: 70.5%; Average loss: 0.7615
# Iteration: 10576; Percent complete: 70.5%; Average loss: 0.8032
# Iteration: 10577; Percent complete: 70.5%; Average loss: 0.7466
# Iteration: 10578; Percent complete: 70.5%; Average loss: 0.8030
# Iteration: 10579; Percent complete: 70.5%; Average loss: 0.7768
# Iteration: 10580; Percent complete: 70.5%; Average loss: 0.7805
# Iteration: 10581; Percent complete: 70.5%; Average loss: 0.7846
# Iteration: 10582; Percent complete: 70.5%; Average loss: 0.8139
# Iteration: 10583; Percent complete: 70.6%; Average loss: 0.8327
# Iteration: 10584; Percent complete: 70.6%; Average loss: 0.7439
# Iteration: 10585; Percent complete: 70.6%; Average loss: 0.7628
# Iteration: 10586; Percent complete: 70.6%; Average loss: 0.7497
# Iteration: 10587; Percent complete: 70.6%; Average loss: 0.8224
# Iteration: 10588; Percent complete: 70.6%; Average loss: 0.8102
# Iteration: 10589; Percent complete: 70.6%; Average loss: 0.7863
# Iteration: 10590; Percent complete: 70.6%; Average loss: 0.7715
# Iteration: 10591; Percent complete: 70.6%; Average loss: 0.8415
# Iteration: 10592; Percent complete: 70.6%; Average loss: 0.7673
# Iteration: 10593; Percent complete: 70.6%; Average loss: 0.7786
# Iteration: 10594; Percent complete: 70.6%; Average loss: 0.7986
# Iteration: 10595; Percent complete: 70.6%; Average loss: 0.7627
# Iteration: 10596; Percent complete: 70.6%; Average loss: 0.7777
# Iteration: 10597; Percent complete: 70.6%; Average loss: 0.7407
# Iteration: 10598; Percent complete: 70.7%; Average loss: 0.7837
# Iteration: 10599; Percent complete: 70.7%; Average loss: 0.8143
# Iteration: 10600; Percent complete: 70.7%; Average loss: 0.7901
# Iteration: 10601; Percent complete: 70.7%; Average loss: 0.7883
# Iteration: 10602; Percent complete: 70.7%; Average loss: 0.8065
# Iteration: 10603; Percent complete: 70.7%; Average loss: 0.7947
# Iteration: 10604; Percent complete: 70.7%; Average loss: 0.7248
# Iteration: 10605; Percent complete: 70.7%; Average loss: 0.7727
# Iteration: 10606; Percent complete: 70.7%; Average loss: 0.7388
# Iteration: 10607; Percent complete: 70.7%; Average loss: 0.7900
# Iteration: 10608; Percent complete: 70.7%; Average loss: 0.8663
# Iteration: 10609; Percent complete: 70.7%; Average loss: 0.7922
# Iteration: 10610; Percent complete: 70.7%; Average loss: 0.7584
# Iteration: 10611; Percent complete: 70.7%; Average loss: 0.7543
# Iteration: 10612; Percent complete: 70.7%; Average loss: 0.7804
# Iteration: 10613; Percent complete: 70.8%; Average loss: 0.7795
# Iteration: 10614; Percent complete: 70.8%; Average loss: 0.8142
# Iteration: 10615; Percent complete: 70.8%; Average loss: 0.7407
# Iteration: 10616; Percent complete: 70.8%; Average loss: 0.8072
# Iteration: 10617; Percent complete: 70.8%; Average loss: 0.7727
# Iteration: 10618; Percent complete: 70.8%; Average loss: 0.8016
# Iteration: 10619; Percent complete: 70.8%; Average loss: 0.7947
# Iteration: 10620; Percent complete: 70.8%; Average loss: 0.8320
# Iteration: 10621; Percent complete: 70.8%; Average loss: 0.7513
# Iteration: 10622; Percent complete: 70.8%; Average loss: 0.7566
# Iteration: 10623; Percent complete: 70.8%; Average loss: 0.8519
# Iteration: 10624; Percent complete: 70.8%; Average loss: 0.7604
# Iteration: 10625; Percent complete: 70.8%; Average loss: 0.7781
# Iteration: 10626; Percent complete: 70.8%; Average loss: 0.7419
# Iteration: 10627; Percent complete: 70.8%; Average loss: 0.8019
# Iteration: 10628; Percent complete: 70.9%; Average loss: 0.8232
# Iteration: 10629; Percent complete: 70.9%; Average loss: 0.7817
# Iteration: 10630; Percent complete: 70.9%; Average loss: 0.7788
# Iteration: 10631; Percent complete: 70.9%; Average loss: 0.7949
# Iteration: 10632; Percent complete: 70.9%; Average loss: 0.7997
# Iteration: 10633; Percent complete: 70.9%; Average loss: 0.7584
# Iteration: 10634; Percent complete: 70.9%; Average loss: 0.7940
# Iteration: 10635; Percent complete: 70.9%; Average loss: 0.7904
# Iteration: 10636; Percent complete: 70.9%; Average loss: 0.8165
# Iteration: 10637; Percent complete: 70.9%; Average loss: 0.8226
# Iteration: 10638; Percent complete: 70.9%; Average loss: 0.7906
# Iteration: 10639; Percent complete: 70.9%; Average loss: 0.7626
# Iteration: 10640; Percent complete: 70.9%; Average loss: 0.7918
# Iteration: 10641; Percent complete: 70.9%; Average loss: 0.8111
# Iteration: 10642; Percent complete: 70.9%; Average loss: 0.7663
# Iteration: 10643; Percent complete: 71.0%; Average loss: 0.7595
# Iteration: 10644; Percent complete: 71.0%; Average loss: 0.8032
# Iteration: 10645; Percent complete: 71.0%; Average loss: 0.8130
# Iteration: 10646; Percent complete: 71.0%; Average loss: 0.7694
# Iteration: 10647; Percent complete: 71.0%; Average loss: 0.7592
# Iteration: 10648; Percent complete: 71.0%; Average loss: 0.7738
# Iteration: 10649; Percent complete: 71.0%; Average loss: 0.7611
# Iteration: 10650; Percent complete: 71.0%; Average loss: 0.7746
# Iteration: 10651; Percent complete: 71.0%; Average loss: 0.7698
# Iteration: 10652; Percent complete: 71.0%; Average loss: 0.8163
# Iteration: 10653; Percent complete: 71.0%; Average loss: 0.7899
# Iteration: 10654; Percent complete: 71.0%; Average loss: 0.7648
# Iteration: 10655; Percent complete: 71.0%; Average loss: 0.7477
# Iteration: 10656; Percent complete: 71.0%; Average loss: 0.7687
# Iteration: 10657; Percent complete: 71.0%; Average loss: 0.7813
# Iteration: 10658; Percent complete: 71.1%; Average loss: 0.7811
# Iteration: 10659; Percent complete: 71.1%; Average loss: 0.7925
# Iteration: 10660; Percent complete: 71.1%; Average loss: 0.7995
# Iteration: 10661; Percent complete: 71.1%; Average loss: 0.8315
# Iteration: 10662; Percent complete: 71.1%; Average loss: 0.7702
# Iteration: 10663; Percent complete: 71.1%; Average loss: 0.8010
# Iteration: 10664; Percent complete: 71.1%; Average loss: 0.7603
# Iteration: 10665; Percent complete: 71.1%; Average loss: 0.7907
# Iteration: 10666; Percent complete: 71.1%; Average loss: 0.7733
# Iteration: 10667; Percent complete: 71.1%; Average loss: 0.7769
# Iteration: 10668; Percent complete: 71.1%; Average loss: 0.7903
# Iteration: 10669; Percent complete: 71.1%; Average loss: 0.7590
# Iteration: 10670; Percent complete: 71.1%; Average loss: 0.7998
# Iteration: 10671; Percent complete: 71.1%; Average loss: 0.7974
# Iteration: 10672; Percent complete: 71.1%; Average loss: 0.7748
# Iteration: 10673; Percent complete: 71.2%; Average loss: 0.7852
# Iteration: 10674; Percent complete: 71.2%; Average loss: 0.7307
# Iteration: 10675; Percent complete: 71.2%; Average loss: 0.7605
# Iteration: 10676; Percent complete: 71.2%; Average loss: 0.7443
# Iteration: 10677; Percent complete: 71.2%; Average loss: 0.7875
# Iteration: 10678; Percent complete: 71.2%; Average loss: 0.7506
# Iteration: 10679; Percent complete: 71.2%; Average loss: 0.7959
# Iteration: 10680; Percent complete: 71.2%; Average loss: 0.7586
# Iteration: 10681; Percent complete: 71.2%; Average loss: 0.8282
# Iteration: 10682; Percent complete: 71.2%; Average loss: 0.7520
# Iteration: 10683; Percent complete: 71.2%; Average loss: 0.7719
# Iteration: 10684; Percent complete: 71.2%; Average loss: 0.8181
# Iteration: 10685; Percent complete: 71.2%; Average loss: 0.7908
# Iteration: 10686; Percent complete: 71.2%; Average loss: 0.7390
# Iteration: 10687; Percent complete: 71.2%; Average loss: 0.7774
# Iteration: 10688; Percent complete: 71.3%; Average loss: 0.7971
# Iteration: 10689; Percent complete: 71.3%; Average loss: 0.7712
# Iteration: 10690; Percent complete: 71.3%; Average loss: 0.8133
# Iteration: 10691; Percent complete: 71.3%; Average loss: 0.7814
# Iteration: 10692; Percent complete: 71.3%; Average loss: 0.7841
# Iteration: 10693; Percent complete: 71.3%; Average loss: 0.7882
# Iteration: 10694; Percent complete: 71.3%; Average loss: 0.8186
# Iteration: 10695; Percent complete: 71.3%; Average loss: 0.8180
# Iteration: 10696; Percent complete: 71.3%; Average loss: 0.7313
# Iteration: 10697; Percent complete: 71.3%; Average loss: 0.7999
# Iteration: 10698; Percent complete: 71.3%; Average loss: 0.7846
# Iteration: 10699; Percent complete: 71.3%; Average loss: 0.7709
# Iteration: 10700; Percent complete: 71.3%; Average loss: 0.7708
# Iteration: 10701; Percent complete: 71.3%; Average loss: 0.8187
# Iteration: 10702; Percent complete: 71.3%; Average loss: 0.7536
# Iteration: 10703; Percent complete: 71.4%; Average loss: 0.8108
# Iteration: 10704; Percent complete: 71.4%; Average loss: 0.7909
# Iteration: 10705; Percent complete: 71.4%; Average loss: 0.8312
# Iteration: 10706; Percent complete: 71.4%; Average loss: 0.7821
# Iteration: 10707; Percent complete: 71.4%; Average loss: 0.7863
# Iteration: 10708; Percent complete: 71.4%; Average loss: 0.7703
# Iteration: 10709; Percent complete: 71.4%; Average loss: 0.8020
# Iteration: 10710; Percent complete: 71.4%; Average loss: 0.7518
# Iteration: 10711; Percent complete: 71.4%; Average loss: 0.8161
# Iteration: 10712; Percent complete: 71.4%; Average loss: 0.7391
# Iteration: 10713; Percent complete: 71.4%; Average loss: 0.8183
# Iteration: 10714; Percent complete: 71.4%; Average loss: 0.7804
# Iteration: 10715; Percent complete: 71.4%; Average loss: 0.7458
# Iteration: 10716; Percent complete: 71.4%; Average loss: 0.7990
# Iteration: 10717; Percent complete: 71.4%; Average loss: 0.7791
# Iteration: 10718; Percent complete: 71.5%; Average loss: 0.7470
# Iteration: 10719; Percent complete: 71.5%; Average loss: 0.8155
# Iteration: 10720; Percent complete: 71.5%; Average loss: 0.7725
# Iteration: 10721; Percent complete: 71.5%; Average loss: 0.7565
# Iteration: 10722; Percent complete: 71.5%; Average loss: 0.7170
# Iteration: 10723; Percent complete: 71.5%; Average loss: 0.8181
# Iteration: 10724; Percent complete: 71.5%; Average loss: 0.7537
# Iteration: 10725; Percent complete: 71.5%; Average loss: 0.8217
# Iteration: 10726; Percent complete: 71.5%; Average loss: 0.7866
# Iteration: 10727; Percent complete: 71.5%; Average loss: 0.7763
# Iteration: 10728; Percent complete: 71.5%; Average loss: 0.7691
# Iteration: 10729; Percent complete: 71.5%; Average loss: 0.7799
# Iteration: 10730; Percent complete: 71.5%; Average loss: 0.8044
# Iteration: 10731; Percent complete: 71.5%; Average loss: 0.7809
# Iteration: 10732; Percent complete: 71.5%; Average loss: 0.8005
# Iteration: 10733; Percent complete: 71.6%; Average loss: 0.7919
# Iteration: 10734; Percent complete: 71.6%; Average loss: 0.7699
# Iteration: 10735; Percent complete: 71.6%; Average loss: 0.8160
# Iteration: 10736; Percent complete: 71.6%; Average loss: 0.7779
# Iteration: 10737; Percent complete: 71.6%; Average loss: 0.7770
# Iteration: 10738; Percent complete: 71.6%; Average loss: 0.7522
# Iteration: 10739; Percent complete: 71.6%; Average loss: 0.7944
# Iteration: 10740; Percent complete: 71.6%; Average loss: 0.7744
# Iteration: 10741; Percent complete: 71.6%; Average loss: 0.8496
# Iteration: 10742; Percent complete: 71.6%; Average loss: 0.7772
# Iteration: 10743; Percent complete: 71.6%; Average loss: 0.7735
# Iteration: 10744; Percent complete: 71.6%; Average loss: 0.7664
# Iteration: 10745; Percent complete: 71.6%; Average loss: 0.7805
# Iteration: 10746; Percent complete: 71.6%; Average loss: 0.7415
# Iteration: 10747; Percent complete: 71.6%; Average loss: 0.7641
# Iteration: 10748; Percent complete: 71.7%; Average loss: 0.7726
# Iteration: 10749; Percent complete: 71.7%; Average loss: 0.8113
# ...
# Iteration: 14752; Percent complete: 98.3%; Average loss: 0.6923
# Iteration: 14753; Percent complete: 98.4%; Average loss: 0.6704
# Iteration: 14754; Percent complete: 98.4%; Average loss: 0.6091
# Iteration: 14755; Percent complete: 98.4%; Average loss: 0.7282
# Iteration: 14756; Percent complete: 98.4%; Average loss: 0.6792
# Iteration: 14757; Percent complete: 98.4%; Average loss: 0.7005
# Iteration: 14758; Percent complete: 98.4%; Average loss: 0.6672
# Iteration: 14759; Percent complete: 98.4%; Average loss: 0.7161
# Iteration: 14760; Percent complete: 98.4%; Average loss: 0.7073
# Iteration: 14761; Percent complete: 98.4%; Average loss: 0.6574
# Iteration: 14762; Percent complete: 98.4%; Average loss: 0.7082
# Iteration: 14763; Percent complete: 98.4%; Average loss: 0.6732
# Iteration: 14764; Percent complete: 98.4%; Average loss: 0.6764
# Iteration: 14765; Percent complete: 98.4%; Average loss: 0.7000
# Iteration: 14766; Percent complete: 98.4%; Average loss: 0.7143
# Iteration: 14767; Percent complete: 98.4%; Average loss: 0.6651
# Iteration: 14768; Percent complete: 98.5%; Average loss: 0.6962
# Iteration: 14769; Percent complete: 98.5%; Average loss: 0.6356
# Iteration: 14770; Percent complete: 98.5%; Average loss: 0.6377
# Iteration: 14771; Percent complete: 98.5%; Average loss: 0.6747
# Iteration: 14772; Percent complete: 98.5%; Average loss: 0.6484
# Iteration: 14773; Percent complete: 98.5%; Average loss: 0.7337
# Iteration: 14774; Percent complete: 98.5%; Average loss: 0.6943
# Iteration: 14775; Percent complete: 98.5%; Average loss: 0.6578
# Iteration: 14776; Percent complete: 98.5%; Average loss: 0.7018
# Iteration: 14777; Percent complete: 98.5%; Average loss: 0.7109
# Iteration: 14778; Percent complete: 98.5%; Average loss: 0.6314
# Iteration: 14779; Percent complete: 98.5%; Average loss: 0.7341
# Iteration: 14780; Percent complete: 98.5%; Average loss: 0.7009
# Iteration: 14781; Percent complete: 98.5%; Average loss: 0.6622
# Iteration: 14782; Percent complete: 98.5%; Average loss: 0.6818
# Iteration: 14783; Percent complete: 98.6%; Average loss: 0.7012
# Iteration: 14784; Percent complete: 98.6%; Average loss: 0.6961
# Iteration: 14785; Percent complete: 98.6%; Average loss: 0.6706
# Iteration: 14786; Percent complete: 98.6%; Average loss: 0.6809
# Iteration: 14787; Percent complete: 98.6%; Average loss: 0.6768
# Iteration: 14788; Percent complete: 98.6%; Average loss: 0.7229
# Iteration: 14789; Percent complete: 98.6%; Average loss: 0.6899
# Iteration: 14790; Percent complete: 98.6%; Average loss: 0.6825
# Iteration: 14791; Percent complete: 98.6%; Average loss: 0.6976
# Iteration: 14792; Percent complete: 98.6%; Average loss: 0.6535
# Iteration: 14793; Percent complete: 98.6%; Average loss: 0.7013
# Iteration: 14794; Percent complete: 98.6%; Average loss: 0.6934
# Iteration: 14795; Percent complete: 98.6%; Average loss: 0.6718
# Iteration: 14796; Percent complete: 98.6%; Average loss: 0.6983
# Iteration: 14797; Percent complete: 98.6%; Average loss: 0.6628
# Iteration: 14798; Percent complete: 98.7%; Average loss: 0.6611
# Iteration: 14799; Percent complete: 98.7%; Average loss: 0.7077
# Iteration: 14800; Percent complete: 98.7%; Average loss: 0.6736
# Iteration: 14801; Percent complete: 98.7%; Average loss: 0.7079
# Iteration: 14802; Percent complete: 98.7%; Average loss: 0.6645
# Iteration: 14803; Percent complete: 98.7%; Average loss: 0.6986
# Iteration: 14804; Percent complete: 98.7%; Average loss: 0.6759
# Iteration: 14805; Percent complete: 98.7%; Average loss: 0.7212
# Iteration: 14806; Percent complete: 98.7%; Average loss: 0.6784
# Iteration: 14807; Percent complete: 98.7%; Average loss: 0.6568
# Iteration: 14808; Percent complete: 98.7%; Average loss: 0.6259
# Iteration: 14809; Percent complete: 98.7%; Average loss: 0.6406
# Iteration: 14810; Percent complete: 98.7%; Average loss: 0.6486
# Iteration: 14811; Percent complete: 98.7%; Average loss: 0.6783
# Iteration: 14812; Percent complete: 98.7%; Average loss: 0.6636
# Iteration: 14813; Percent complete: 98.8%; Average loss: 0.6831
# Iteration: 14814; Percent complete: 98.8%; Average loss: 0.6612
# Iteration: 14815; Percent complete: 98.8%; Average loss: 0.6478
# Iteration: 14816; Percent complete: 98.8%; Average loss: 0.6590
# Iteration: 14817; Percent complete: 98.8%; Average loss: 0.6951
# Iteration: 14818; Percent complete: 98.8%; Average loss: 0.6828
# Iteration: 14819; Percent complete: 98.8%; Average loss: 0.6909
# Iteration: 14820; Percent complete: 98.8%; Average loss: 0.6875
# Iteration: 14821; Percent complete: 98.8%; Average loss: 0.6626
# Iteration: 14822; Percent complete: 98.8%; Average loss: 0.7051
# Iteration: 14823; Percent complete: 98.8%; Average loss: 0.7059
# Iteration: 14824; Percent complete: 98.8%; Average loss: 0.6998
# Iteration: 14825; Percent complete: 98.8%; Average loss: 0.6854
# Iteration: 14826; Percent complete: 98.8%; Average loss: 0.7041
# Iteration: 14827; Percent complete: 98.8%; Average loss: 0.6695
# Iteration: 14828; Percent complete: 98.9%; Average loss: 0.6582
# Iteration: 14829; Percent complete: 98.9%; Average loss: 0.6959
# Iteration: 14830; Percent complete: 98.9%; Average loss: 0.6619
# Iteration: 14831; Percent complete: 98.9%; Average loss: 0.6848
# Iteration: 14832; Percent complete: 98.9%; Average loss: 0.7058
# Iteration: 14833; Percent complete: 98.9%; Average loss: 0.7185
# Iteration: 14834; Percent complete: 98.9%; Average loss: 0.6881
# Iteration: 14835; Percent complete: 98.9%; Average loss: 0.7072
# Iteration: 14836; Percent complete: 98.9%; Average loss: 0.7189
# Iteration: 14837; Percent complete: 98.9%; Average loss: 0.6862
# Iteration: 14838; Percent complete: 98.9%; Average loss: 0.7061
# Iteration: 14839; Percent complete: 98.9%; Average loss: 0.6850
# Iteration: 14840; Percent complete: 98.9%; Average loss: 0.7053
# Iteration: 14841; Percent complete: 98.9%; Average loss: 0.6569
# Iteration: 14842; Percent complete: 98.9%; Average loss: 0.6617
# Iteration: 14843; Percent complete: 99.0%; Average loss: 0.7035
# Iteration: 14844; Percent complete: 99.0%; Average loss: 0.6768
# Iteration: 14845; Percent complete: 99.0%; Average loss: 0.6785
# Iteration: 14846; Percent complete: 99.0%; Average loss: 0.7028
# Iteration: 14847; Percent complete: 99.0%; Average loss: 0.6264
# Iteration: 14848; Percent complete: 99.0%; Average loss: 0.6782
# Iteration: 14849; Percent complete: 99.0%; Average loss: 0.6830
# Iteration: 14850; Percent complete: 99.0%; Average loss: 0.6479
# Iteration: 14851; Percent complete: 99.0%; Average loss: 0.6638
# Iteration: 14852; Percent complete: 99.0%; Average loss: 0.6871
# Iteration: 14853; Percent complete: 99.0%; Average loss: 0.7142
# Iteration: 14854; Percent complete: 99.0%; Average loss: 0.6962
# Iteration: 14855; Percent complete: 99.0%; Average loss: 0.6979
# Iteration: 14856; Percent complete: 99.0%; Average loss: 0.6873
# Iteration: 14857; Percent complete: 99.0%; Average loss: 0.7171
# Iteration: 14858; Percent complete: 99.1%; Average loss: 0.7114
# Iteration: 14859; Percent complete: 99.1%; Average loss: 0.7456
# Iteration: 14860; Percent complete: 99.1%; Average loss: 0.6870
# Iteration: 14861; Percent complete: 99.1%; Average loss: 0.6835
# Iteration: 14862; Percent complete: 99.1%; Average loss: 0.6487
# Iteration: 14863; Percent complete: 99.1%; Average loss: 0.6877
# Iteration: 14864; Percent complete: 99.1%; Average loss: 0.7182
# Iteration: 14865; Percent complete: 99.1%; Average loss: 0.6866
# Iteration: 14866; Percent complete: 99.1%; Average loss: 0.7197
# Iteration: 14867; Percent complete: 99.1%; Average loss: 0.6734
# Iteration: 14868; Percent complete: 99.1%; Average loss: 0.7017
# Iteration: 14869; Percent complete: 99.1%; Average loss: 0.6624
# Iteration: 14870; Percent complete: 99.1%; Average loss: 0.6831
# Iteration: 14871; Percent complete: 99.1%; Average loss: 0.6997
# Iteration: 14872; Percent complete: 99.1%; Average loss: 0.6897
# Iteration: 14873; Percent complete: 99.2%; Average loss: 0.7192
# Iteration: 14874; Percent complete: 99.2%; Average loss: 0.6872
# Iteration: 14875; Percent complete: 99.2%; Average loss: 0.6575
# Iteration: 14876; Percent complete: 99.2%; Average loss: 0.6765
# Iteration: 14877; Percent complete: 99.2%; Average loss: 0.7000
# Iteration: 14878; Percent complete: 99.2%; Average loss: 0.6971
# Iteration: 14879; Percent complete: 99.2%; Average loss: 0.6802
# Iteration: 14880; Percent complete: 99.2%; Average loss: 0.6799
# Iteration: 14881; Percent complete: 99.2%; Average loss: 0.6886
# Iteration: 14882; Percent complete: 99.2%; Average loss: 0.6713
# Iteration: 14883; Percent complete: 99.2%; Average loss: 0.6511
# Iteration: 14884; Percent complete: 99.2%; Average loss: 0.6671
# Iteration: 14885; Percent complete: 99.2%; Average loss: 0.6535
# Iteration: 14886; Percent complete: 99.2%; Average loss: 0.6947
# Iteration: 14887; Percent complete: 99.2%; Average loss: 0.7013
# Iteration: 14888; Percent complete: 99.3%; Average loss: 0.6908
# Iteration: 14889; Percent complete: 99.3%; Average loss: 0.6818
# Iteration: 14890; Percent complete: 99.3%; Average loss: 0.6854
# Iteration: 14891; Percent complete: 99.3%; Average loss: 0.7280
# Iteration: 14892; Percent complete: 99.3%; Average loss: 0.7060
# Iteration: 14893; Percent complete: 99.3%; Average loss: 0.6677
# Iteration: 14894; Percent complete: 99.3%; Average loss: 0.6478
# Iteration: 14895; Percent complete: 99.3%; Average loss: 0.6865
# Iteration: 14896; Percent complete: 99.3%; Average loss: 0.6728
# Iteration: 14897; Percent complete: 99.3%; Average loss: 0.6642
# Iteration: 14898; Percent complete: 99.3%; Average loss: 0.6301
# Iteration: 14899; Percent complete: 99.3%; Average loss: 0.6800
# Iteration: 14900; Percent complete: 99.3%; Average loss: 0.6746
# Iteration: 14901; Percent complete: 99.3%; Average loss: 0.6920
# Iteration: 14902; Percent complete: 99.3%; Average loss: 0.6696
# Iteration: 14903; Percent complete: 99.4%; Average loss: 0.6800
# Iteration: 14904; Percent complete: 99.4%; Average loss: 0.6985
# Iteration: 14905; Percent complete: 99.4%; Average loss: 0.6699
# Iteration: 14906; Percent complete: 99.4%; Average loss: 0.6702
# Iteration: 14907; Percent complete: 99.4%; Average loss: 0.7041
# Iteration: 14908; Percent complete: 99.4%; Average loss: 0.6542
# Iteration: 14909; Percent complete: 99.4%; Average loss: 0.6832
# Iteration: 14910; Percent complete: 99.4%; Average loss: 0.6597
# Iteration: 14911; Percent complete: 99.4%; Average loss: 0.7206
# Iteration: 14912; Percent complete: 99.4%; Average loss: 0.6729
# Iteration: 14913; Percent complete: 99.4%; Average loss: 0.6648
# Iteration: 14914; Percent complete: 99.4%; Average loss: 0.6815
# Iteration: 14915; Percent complete: 99.4%; Average loss: 0.6418
# Iteration: 14916; Percent complete: 99.4%; Average loss: 0.6923
# Iteration: 14917; Percent complete: 99.4%; Average loss: 0.6799
# Iteration: 14918; Percent complete: 99.5%; Average loss: 0.7072
# Iteration: 14919; Percent complete: 99.5%; Average loss: 0.6751
# Iteration: 14920; Percent complete: 99.5%; Average loss: 0.6994
# Iteration: 14921; Percent complete: 99.5%; Average loss: 0.6738
# Iteration: 14922; Percent complete: 99.5%; Average loss: 0.6864
# Iteration: 14923; Percent complete: 99.5%; Average loss: 0.7159
# Iteration: 14924; Percent complete: 99.5%; Average loss: 0.6566
# Iteration: 14925; Percent complete: 99.5%; Average loss: 0.6738
# Iteration: 14926; Percent complete: 99.5%; Average loss: 0.6563
# Iteration: 14927; Percent complete: 99.5%; Average loss: 0.6960
# Iteration: 14928; Percent complete: 99.5%; Average loss: 0.6894
# Iteration: 14929; Percent complete: 99.5%; Average loss: 0.6537
# Iteration: 14930; Percent complete: 99.5%; Average loss: 0.7166
# Iteration: 14931; Percent complete: 99.5%; Average loss: 0.6602
# Iteration: 14932; Percent complete: 99.5%; Average loss: 0.7234
# Iteration: 14933; Percent complete: 99.6%; Average loss: 0.7143
# Iteration: 14934; Percent complete: 99.6%; Average loss: 0.6495
# Iteration: 14935; Percent complete: 99.6%; Average loss: 0.6513
# Iteration: 14936; Percent complete: 99.6%; Average loss: 0.7049
# Iteration: 14937; Percent complete: 99.6%; Average loss: 0.6989
# Iteration: 14938; Percent complete: 99.6%; Average loss: 0.7544
# Iteration: 14939; Percent complete: 99.6%; Average loss: 0.6772
# Iteration: 14940; Percent complete: 99.6%; Average loss: 0.7091
# Iteration: 14941; Percent complete: 99.6%; Average loss: 0.6818
# Iteration: 14942; Percent complete: 99.6%; Average loss: 0.6653
# Iteration: 14943; Percent complete: 99.6%; Average loss: 0.6513
# Iteration: 14944; Percent complete: 99.6%; Average loss: 0.7136
# Iteration: 14945; Percent complete: 99.6%; Average loss: 0.7082
# Iteration: 14946; Percent complete: 99.6%; Average loss: 0.6849
# Iteration: 14947; Percent complete: 99.6%; Average loss: 0.6969
# Iteration: 14948; Percent complete: 99.7%; Average loss: 0.7069
# Iteration: 14949; Percent complete: 99.7%; Average loss: 0.6874
# Iteration: 14950; Percent complete: 99.7%; Average loss: 0.6844
# Iteration: 14951; Percent complete: 99.7%; Average loss: 0.7218
# Iteration: 14952; Percent complete: 99.7%; Average loss: 0.7242
# Iteration: 14953; Percent complete: 99.7%; Average loss: 0.6873
# Iteration: 14954; Percent complete: 99.7%; Average loss: 0.7027
# Iteration: 14955; Percent complete: 99.7%; Average loss: 0.6322
# Iteration: 14956; Percent complete: 99.7%; Average loss: 0.7052
# Iteration: 14957; Percent complete: 99.7%; Average loss: 0.6652
# Iteration: 14958; Percent complete: 99.7%; Average loss: 0.6398
# Iteration: 14959; Percent complete: 99.7%; Average loss: 0.6830
# Iteration: 14960; Percent complete: 99.7%; Average loss: 0.7016
# Iteration: 14961; Percent complete: 99.7%; Average loss: 0.7120
# Iteration: 14962; Percent complete: 99.7%; Average loss: 0.6858
# Iteration: 14963; Percent complete: 99.8%; Average loss: 0.6567
# Iteration: 14964; Percent complete: 99.8%; Average loss: 0.6610
# Iteration: 14965; Percent complete: 99.8%; Average loss: 0.6861
# Iteration: 14966; Percent complete: 99.8%; Average loss: 0.6895
# Iteration: 14967; Percent complete: 99.8%; Average loss: 0.7129
# Iteration: 14968; Percent complete: 99.8%; Average loss: 0.6927
# Iteration: 14969; Percent complete: 99.8%; Average loss: 0.6968
# Iteration: 14970; Percent complete: 99.8%; Average loss: 0.6842
# Iteration: 14971; Percent complete: 99.8%; Average loss: 0.6760
# Iteration: 14972; Percent complete: 99.8%; Average loss: 0.7185
# Iteration: 14973; Percent complete: 99.8%; Average loss: 0.6959
# Iteration: 14974; Percent complete: 99.8%; Average loss: 0.6573
# Iteration: 14975; Percent complete: 99.8%; Average loss: 0.7005
# Iteration: 14976; Percent complete: 99.8%; Average loss: 0.6725
# Iteration: 14977; Percent complete: 99.8%; Average loss: 0.6614
# Iteration: 14978; Percent complete: 99.9%; Average loss: 0.7078
# Iteration: 14979; Percent complete: 99.9%; Average loss: 0.6463
# Iteration: 14980; Percent complete: 99.9%; Average loss: 0.6779
# Iteration: 14981; Percent complete: 99.9%; Average loss: 0.6833
# Iteration: 14982; Percent complete: 99.9%; Average loss: 0.7348
# Iteration: 14983; Percent complete: 99.9%; Average loss: 0.6778
# Iteration: 14984; Percent complete: 99.9%; Average loss: 0.6789
# Iteration: 14985; Percent complete: 99.9%; Average loss: 0.6596
# Iteration: 14986; Percent complete: 99.9%; Average loss: 0.6827
# Iteration: 14987; Percent complete: 99.9%; Average loss: 0.6779
# Iteration: 14988; Percent complete: 99.9%; Average loss: 0.6646
# Iteration: 14989; Percent complete: 99.9%; Average loss: 0.6755
# Iteration: 14990; Percent complete: 99.9%; Average loss: 0.7002
# Iteration: 14991; Percent complete: 99.9%; Average loss: 0.6611
# Iteration: 14992; Percent complete: 99.9%; Average loss: 0.7270
# Iteration: 14993; Percent complete: 100.0%; Average loss: 0.6576
# Iteration: 14994; Percent complete: 100.0%; Average loss: 0.7272
# Iteration: 14995; Percent complete: 100.0%; Average loss: 0.6653
# Iteration: 14996; Percent complete: 100.0%; Average loss: 0.6438
# Iteration: 14997; Percent complete: 100.0%; Average loss: 0.6610
# Iteration: 14998; Percent complete: 100.0%; Average loss: 0.6465
# Iteration: 14999; Percent complete: 100.0%; Average loss: 0.6655
# Iteration: 15000; Percent complete: 100.0%; Average loss: 0.6502

# %% [markdown]
# Run the model :)

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > hi
# Bot: hi late 2
# > who are you
# Bot: linda i 2
# > hello linda
# Bot: hello da s 3
# > hm
# Bot:  1
# > interesting
# Bot: right sort of conversation 4
# > what did you eat for lunch
# Bot: what what was the 4
# > how was your day
# Bot: fucking r s 3
# > that is rude
# Bot: it s 2
# > hm
# Bot:  1
# > interesting
# Bot: right sort of conversation 4
# > damn
# Bot: what fucking on the time 5
# > take it easy
# Bot: take it out in 4
# > q

# %% [markdown]
# ### Notes on the Model

# %% [markdown]
# Overall, the model is OK. It was not as intelligent as i thought it would be, but I suppose that is a good thing. One of the things that I noticed from playing with the bot was that everything is pretty predictable. In fact, it feels less like it is responding to you and more like it has memories what to day based on an input string from the user. I think the first thing we can do to improve the model is to add some randomness to the model, so asking "hello" wont keep generating the same output. To improve this one a bit more we can change some of the variable like the learning rate and the depth. Eventually, to improve the overall feeling of the chat bot we can implement an entirely new model. Try to give a more meaningful number to words rather than what index they first appear in (ask professor if he thinks this would even matter, or would this just be a change of domain).
